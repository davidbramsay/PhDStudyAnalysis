# %% [markdown]
# ## Matching Session 3
#
# Sess3 folder has E4 data and csvs of glasses/watch recording.  We want to grab data between the last TX_TIME_SEEN in the first CSV and the first TX_TIME_SEEN in the last CSV.
#
# - For P2, the watch disconnected, so we have no final TX_TIME_SEEN.
# -
# - For P22 and P24, they did *two* transitions for session 3 instead of one.  This can be inferred from the 'second_transition' folder existing in the sess3 folder.  The second transition data is again between the last TX_TIME_SEEN in the first CSV and the first TX_TIME_SEEN in the last CSV in the 'second_transition' folder.  The duration of this second session is required to compare against their time estimate in the final survey.
#
# To process, we need to
# - Grab the glasses and E4 data, putting them in the form we have for the rest of the sessions.
# - Grab the duration of the session and the time until noticed the light changed.

# %%
import os
import csv
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import time
import seaborn as sns
import humanize
import re
import glob
import datetime
import pickle
from IPython.display import display, clear_output, HTML
from csv import reader
import matplotlib.dates as mdates
from pympler import asizeof
from scipy import interpolate
from ahrs.filters import EKF
from ahrs import QuaternionArray
from dateutil import parser
#%matplotlib inline
# %matplotlib widget


TIMEZONE_OFFSET = 4

# %% [raw]
# E4 Processing and DF plotting functions below.  Simply loads data and creates DFs, transforms Accelerometer data to m/s^2.

# %%
def generate_timestamps(length, start_time, sample_rate):
    time_offset = np.arange(length) / sample_rate
    timestamps = pd.to_datetime(start_time, unit='s', origin='unix') + pd.to_timedelta(time_offset, unit='s') - datetime.timedelta(hours=TIMEZONE_OFFSET)
    return timestamps


def process_file(file_path, file_name):
    with open(file_path, 'r') as file:
        # only take the first timestamp
        start_time = float(file.readline().split(',')[0].strip())
        df = pd.DataFrame()
        if 'IBI' in file_name:
            data = pd.read_csv(file, header=None, names=['time', 'ibi']).values.tolist()
            df['timestamp'] = pd.to_datetime([item[0] + start_time for item in data], unit='s', origin='unix')
        else:
            sample_rate = float(file.readline().split(',')[0].strip())
            data = pd.read_csv(file, header=None).values.tolist()
            df['timestamp'] = generate_timestamps(len(data), start_time, sample_rate)
            
            if 'ACC' in file_name:
                #accelerometer data is in 1/64 Gs.  Our glasses data is in m/s^2. Transform it to m/s^2
                data = [[(i/64)*9.8 for i in l] for l in data]
        df['datatype'] = file_name.split('.')[0]
        df['data'] = data
        return df

    
def load_session_data(folder, participant_id, session_id):
    data_dir = f'{folder}/{participant_id}/{participant_id}_{session_id}'
    data_frames = []

    expected_files = ['ACC.csv', 'BVP.csv', 'EDA.csv', 'HR.csv', 'IBI.csv', 'TEMP.csv']

    #load all files, save the output of 'process_file' into data_frames
    for subdir, dirs, files in os.walk(data_dir):
        for file in files:
            if file in expected_files:
                file_path = subdir + os.sep + file
                df = process_file(file_path, file)
                data_frames.append(df)
    
    #turn data_frames into df
    final_df = pd.concat(data_frames)
    final_df.set_index('timestamp', inplace=True)
    final_df.sort_index(inplace=True)
    
    return final_df


def extract_datatype(df, datatype):
    # Filter the dataframe for the given datatype
    df_filtered = df[df['datatype'] == datatype].copy()
    
    # Determine the number of columns based on the length of the 'data' list in the first row
    num_cols = len(df_filtered['data'].iloc[0])
    
    # Create column names
    if datatype == 'ACC':
        col_names = ['x','y','z']
    else:
        col_names = ['d' + str(i + 1) for i in range(num_cols)]
    
    # Split the 'data' list into multiple columns
    df_split = pd.DataFrame(df_filtered['data'].to_list(), columns=col_names)
    
    # Add timestamp back to the dataframe
    df_split.index = df_filtered.index
    
    return df_split

def plot_df(df, title):
    fig, ax = plt.subplots(figsize=(15, 3))

    # Assuming df has timestamp as index
    for column in df.columns:
        if 'tick' not in column:
            sns.lineplot(data=df, x=df.index, y=column, ax=ax, lw=1.5)
        
    # Format the x axis
    ax.xaxis.set_major_locator(mdates.AutoDateLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

    # Set grid
    ax.grid(True, which="both", color='gray', linewidth=0.25)

    # Set title and labels
    ax.set_title(title, fontsize=14)
    ax.set_xlabel('Time', fontsize=11)
    ax.set_ylabel('Value', fontsize=11)

    # Set legend
    #ax.legend(loc='upper left', fontsize=14)

    # Set tick parameters
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    # Improve date tick display
    fig.autofmt_xdate()

    plt.show()

# %% [raw]
# Glasses processing function below.  Simply loads data and creates session_data object (which has a session per excel file from the app).
#
# Generates timestamp indexed dfs for gyro(x/y/z rad/sec), accel(x/y/z m/s^2), blink(raw analog ~reflectance), nose/temple temp(deg C), ambient temp(deg C) and humidity(%),

# %%
def get_size_mb(obj):
    size_bytes = asizeof.asizeof(obj)
    size_mb = size_bytes / (1024 * 1024)  # Convert bytes to megabytes
    return size_mb

def interpolate_df(df, start_timestamp, end_timestamp, new_freq):
    # Calculate the total time duration of the data in seconds
    total_time = (end_timestamp-start_timestamp).total_seconds()
    
    # Create new timestamp index at the desired frequency
    new_index = pd.date_range(start=start_timestamp, periods=int(total_time * new_freq), freq=f'{1/new_freq*1000}ms')

    # Initialize new DataFrame with the new index
    df_new = pd.DataFrame(index=new_index)

    # For each column in the original DataFrame, interpolate to the new frequency
    for col in df.columns:
        # Create spline interpolator for this column
        interpolator = interpolate.interp1d(df.index.values.astype(float), df[col].values, kind='cubic')

        # Interpolate this column at the new timestamps
        df_new[col] = interpolator(new_index.values.astype(float))

    return df_new

def gather_rows(path):
    csv_files = sorted([os.path.join(path, file) for file in os.listdir(path) if file.endswith('.csv')])

    # Initialize rows list
    rows = []

    # Iterate through the files
    for i, filepath in enumerate(csv_files):
        filesize = os.path.getsize(filepath)/(1024*1024)
        print(f'{filepath}, File size: {filesize:.1f} MB')

        with open(filepath, 'r') as file:
            csv_reader = csv.reader(file)
            file_rows = list(csv_reader)

            # If it's the first or the last file, handle 'TX_TIME_SEEN' times specially
            if i == 0 or i == len(csv_files) - 1:
                times_seen_indices = [index for index, row in enumerate(file_rows) if 'TX_TIME_SEEN' in row[3]]

                if i == 0 and times_seen_indices:
                    # On the first file, only append rows after the last TX_TIME_SEEN
                    last_time_seen_index = times_seen_indices[-1]
                    rows += file_rows[last_time_seen_index:]
                elif i == len(csv_files) - 1 and times_seen_indices:
                    # On the last file, only append rows before the first TX_TIME_SEEN
                    first_time_seen_index = -1
                    first_time_seen_index = times_seen_indices[0]
                    rows += file_rows[:first_time_seen_index+1]
                else:
                    # If no TX_TIME_SEEN in the last file, append all rows
                    rows += file_rows
            else:
                # For other files, append all rows
                rows += file_rows

    return rows


def load_session3_excel(folder, participant_id, session_id):
    
    # grab all filepaths in there, in order.
    data_dir = f'{folder}/{participant_id}/{participant_id}_{session_id}'
    rows = gather_rows(data_dir)

    logs, blinks, acc, gyro, thermal, ui, wtemp, wlux = [], [], [], [], [], [], [], []

    for row in rows:
        try:
            if   (row[0]=='l'):
                logs.append(row[1:])
            elif (row[0]=='g'):
                if   (row[2]=='b'):
                    blinks.append(row[1:])
                elif (row[2]=='t'):
                    thermal.append(row[1:])
                elif (row[2]=='a'):
                    acc.append(row[1:])
                elif (row[2]=='g'):
                    gyro.append(row[1:])
            elif (row[0]=='u'):
                ui.append(row[1:])
            elif (row[0]=='w'):
                if(row[3] == 'TX_TEMP_HUMD'):
                    wtemp.append(row[1:])
                elif(row[3] == 'TX_LUX_WHITELUX'):
                    wlux.append(row[1:])
                else:
                    ui.append(row[1:])
        except Exception as e:
            print(str(e) + ': ' + str(row))

    print('got raw data.')
        
    session = {
        'user': participant_id,
        'session': session_id,
        'filepath': data_dir,
        'session_type': 'Sess3FLOW',
        'timestamp': 'NA',
        'logs': logs,
        'ui': ui
    }
    
    print('\tthermal processing...')
    try:
        check_raw_packets(thermal, timeout_ms=4200)
        thermal_df = pd.DataFrame()
        for t in thermal:
            thermal_df = pd.concat([thermal_df, parseThermalRow(t)], axis=0)    
        thermal_df.reset_index(inplace=True)
        thermal_df = reindex_to_timestamp(thermal_df)
        thermal_df['nose_tp_rolling'] = thermal_df['nose_tp'].rolling(7).mean()
        thermal_df['temple_tp_rolling'] = thermal_df['temple_tp'].rolling(2).mean()
        thermal_df['nose_thermistor_rolling'] = thermal_df['nose_thermistor'].rolling(40).mean()
        thermal_df['temple_thermistor_rolling'] = thermal_df['temple_thermistor'].rolling(40).mean()
        thermal_df['nose_temp_C'] = thermal_df.apply(lambda x: convert_nose_temp(x['nose_tp_rolling'], x['nose_thermistor_rolling']), axis=1)
        thermal_df['temple_temp_C'] = thermal_df.apply(lambda x: convert_temple_temp(x['temple_tp_rolling'], x['temple_thermistor_rolling']), axis=1)
        thermal_df['differential_C'] = thermal_df['nose_temp_C'] - thermal_df['temple_temp_C']
        thermal_df['differential_C_rolling'] = thermal_df['differential_C'].rolling(15).mean() 
        session['thermal']= thermal_df
    except Exception as e:
        print('FAILED TO PROCESS DATA!!!! ' + str(e))
        
    print('\tgyro processing...')
    try:
        check_raw_packets(gyro, timeout_ms=900)
        gyro_df = parse_xyz_data(gyro)
        gyro_df.reset_index(inplace=True)
        gyro_df = reindex_to_timestamp(gyro_df)
        gyro_df = gyro_df[gyro_df['x'] < 10000]
        gyro_df = gyro_df[gyro_df['y'] < 10000]
        gyro_df = gyro_df[gyro_df['z'] < 10000]

        #convert int16s to floats with q=9.
        #this gives us rad/s (angular velocity), we expect values in the 0.3-3 range.
        #Gyro set to updates every 10ms, or 100Hz
        gyro_df['x'] = gyro_df['x'].astype(float) / 512
        gyro_df['y'] = gyro_df['y'].astype(float) / 512
        gyro_df['z'] = gyro_df['z'].astype(float) / 512
        session['gyro']= gyro_df
    except Exception as e:
        print('FAILED TO PROCESS DATA!!!! ' + str(e))
   
    print('\taccelerometer processing...')
    try:
        check_raw_packets(acc, timeout_ms=1350)
        acc_df = parse_xyz_data(acc)
        acc_df.reset_index(inplace=True) 
        acc_df = reindex_to_timestamp(acc_df)
        acc_df = acc_df[acc_df['x'] < 10000]
        acc_df = acc_df[acc_df['y'] < 10000]
        acc_df = acc_df[acc_df['z'] < 10000]

        #convert int16s to floats with q=8.
        #this gives us data in m/s^2, so we expect ~9.8 when at rest
        #accelerometer set for every 20ms, or 50Hz
        acc_df['x'] = acc_df['x'].astype(float) / 256
        acc_df['y'] = acc_df['y'].astype(float) / 256
        acc_df['z'] = acc_df['z'].astype(float) / 256
        session['acc']= acc_df
    except Exception as e:
        print('FAILED TO PROCESS DATA!!!! ' + str(e))
        
    print('\tquaternion extended kalman filter application...')
    try:
        start_timestamp = max(acc_df.index[0], gyro_df.index[0])
        end_timestamp = min(acc_df.index[-1], gyro_df.index[-1])

        acc_inter = interpolate_df(acc_df, start_timestamp, end_timestamp, 100)
        gyro_inter = interpolate_df(gyro_df, start_timestamp, end_timestamp, 100)

        ekf = EKF(gyr=gyro_inter[['x','y','z']].values, acc=acc_inter[['x','y','z']].values, frequency=100.0)
        qs = QuaternionArray(ekf.Q)
        qs.remove_jumps()
        qs_df = pd.DataFrame({'w': qs[:,0], 'i':qs[:,1], 'j':qs[:,2], 'k':qs[:,3]}, index=acc_inter.index)
        session['quaternions']= qs_df
    except Exception as e:
        print('FAILED TO PROCESS DATA!!!! ' + str(e))
        
    print('\tblink processing...')
    try:
        check_raw_packets(blinks, timeout_ms=500)
        blinks_df = parse_blink_rows(blinks)
        blinks_df.reset_index(inplace=True)
        blinks_df = reindex_to_timestamp(blinks_df)
        session['blinks']= blinks_df
    except Exception as e:
        print('FAILED TO PROCESS DATA!!!! ' + str(e))
        
    print('\twatch processing...')
    try:
        session['watch_temp']= processWatchTemp(wtemp)
        session['watch_lux'] = processWatchLux(wlux)     
    except Exception as e:
        print('FAILED TO PROCESS DATA!!!! ' + str(e))
    
    print(f"The size of the loaded data is {get_size_mb(session)} MB")
    return session


def processWatchTemp(watch_data):
    '''Apply simple calibration to temp data based on comparison with cheap temp/humd gauge from amazon.
    Also, process the timestamp and turn it into a df'''
    
    to_df = []    
    
    for item in watch_data:
        to_df.append({
            'timestamp': pd.to_datetime(item[0])-datetime.timedelta(hours=TIMEZONE_OFFSET),
            'temp': 21.2 + (6.7/5.4) * (float(item[3])-24),
            'humidity': float(item[4])
        })
    
    df = pd.DataFrame(to_df)

    try:
        df['timestamp'] = df['timestamp'].dt.tz_localize(None)
        df.set_index('timestamp', inplace=True)
    except:
        print('\t\tno entries')

    return df

def processWatchLux(watch_data):
    
    to_df = []    
    for item in watch_data:
        to_df.append({
            'timestamp': pd.to_datetime(item[0])-datetime.timedelta(hours=TIMEZONE_OFFSET),
            'lux': float(item[3]),
            'whitelux': float(item[4])
        })
    
    df = pd.DataFrame(to_df)
    try:
        df['timestamp'] = df['timestamp'].dt.tz_localize(None)
        df.set_index('timestamp', inplace=True)
    except:
        print('\t\tno entries')
    return df

def parse_blink_rows(blinks):
    blink_rows = []
    
    for b in blinks:
        packetLength = int(b[6])
        blink_df_row = pd.DataFrame(data=[b[0:12] for i in range(packetLength)], 
                                    columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 
                                             'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4']) 
        
        
        blink_df_row["data"] = pd.Series([int(v) for v in b[13:]], dtype=np.int32)
        blinkSampleRate = 2000 # 2kHz
        blinkSamplePeriod_ms = 1000 * (1/blinkSampleRate) # 0.5 ms
        blink_df_row["tick_ms"] = blink_df_row['msFromStart'].astype(int)
        blink_df_row["tick_ms"] /= 2
        blink_df_row["tick_ms"] -= (packetLength - np.array(range(1, packetLength+1))) * blinkSamplePeriod_ms
        blink_df_row["saturated"] = blink_df_row["res0"].astype(int)
        blink_rows.append(blink_df_row)   
     
    return pd.concat(blink_rows)
 
    
def parse_xyz_data(data):
    def parseXYZRow(p):
        packetLength = 25
        base_data = p[0:12]
        other_data = np.array(p[13:]).astype('int32').reshape(-1,5)
        return [(base_data + list(row)) for row in other_data]

    data_out = []
    for d in data:
        data_out.extend(parseXYZRow(d))

    df = pd.DataFrame(data_out, columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4', 'x','y','z','imu_tick_ms','tick_ms'])
    
    df["tick_ms"] = df["tick_ms"]/2
    
    return df


def parseThermalRow(t):
    tempSamplePeriod_ms = 100
    numInnerPackets = 4
    rowsInInnerPacket = 5
    # each row has 128 values; 4x 32 value 'packets'; 
    # each 32 has 5 repetitions of 6 values of data + 2 (tick,epoch)
    # these 6 values are interleaved; i.e. the first three are temple numbers, and the first
    # 15 sets of three are temple vals; the second 15 sets of 3 are the corresponding nose vals.
    # to get a timestamped packet, we need [0,1,2] matched with [15,16,17] and so on within each
    # 32 value 'packet'.  
    
    df_row = pd.DataFrame(data=[t[0:12] for i in range(numInnerPackets*rowsInInnerPacket)], columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4']) 
    
    payload = np.array(t[13:]).astype(np.int32).reshape(numInnerPackets, -1)
    
    def flatten(t): return [item for sublist in t for item in sublist]
    reindex = flatten([[*range(i*3,i*3+3)] + [*range(15+i*3, 18+i*3)] + [-2,-1] for i in range(rowsInInnerPacket)])
    proper_payload = payload[:,reindex].reshape(-1,8)
    
    df_row = pd.concat([df_row, pd.DataFrame(data=proper_payload, columns=["temple_tp","temple_thermistor","secondary_temple_tick_ms","nose_tp","nose_thermistor","secondary_nose_tick_ms","tick_ms","epoch"])], axis=1)
    df_row['tick_ms'] -= tempSamplePeriod_ms * np.array([4,3,2,1,0] * numInnerPackets)
    
    return df_row

def convert_thermistor_to_K(raw_value):
    # STEP 1. Calc R_thermistor value given ADC_val
    R_divider = 100000
    ADC_max = 4095
    
    R_t = (R_divider * raw_value/ADC_max) / (1 - raw_value/ADC_max)
    
    # STEP 2. Convert R_t to temp
    R_0 = 100000
    T_0 = 298.15
    Beta = 3960
    R_inf = R_0 * math.exp(-Beta/T_0)
    
    Temp_K = Beta / np.log(R_t / R_inf)
    return Temp_K
    
def convert_thermopile_to_C(raw_val, T_ref_K, A, a_0, a_1):
    #STEP 1. Calc V_thermopile based on preamp gain and bias
    V_tp = (((raw_val / 4095) * 3.3) - (1.15+0.6084))/1000.0
    
    #STEP 2. Solve for Temperature!
    f_V_tp = (V_tp - a_0) + a_1 * (V_tp - a_0)**2
    T_obj = (T_ref_K**4 + f_V_tp/A)**0.25
    return (T_obj - 273.15)
    
def convert_nose_temp(raw_val, raw_thermistor):
    A   =  7.8e-10
    a_0 = -2.31e-01
    a_1 =  3.61e-03
    try:
        return convert_thermopile_to_C(raw_val, 
                                  convert_thermistor_to_K(raw_thermistor), 
                                  A, a_0, a_1)
    except:
        return np.nan
    
def convert_temple_temp(raw_val, raw_thermistor):
    A   =  4.21e-10
    a_0 = -3.62e-01
    a_1 =  8.31e-02
    try:
        return convert_thermopile_to_C(raw_val, 
                                  convert_thermistor_to_K(raw_thermistor), 
                                  A, a_0, a_1)
    except:
        return np.nan
    

def check_raw_packets(data, timeout_ms=500):
    last_seen = pd.to_datetime(data[0][0]) #0 = serverTimestamp
    last_tick = int(data[0][4]) #4 = packet_tick
    last_packet = int(data[0][3]) #3 = packetNum
    packets = set() 
    packets.add(last_packet)

    for i, d in enumerate(data[1:]):

        current_seen = pd.to_datetime(d[0])
        current_packet = int(d[3])
        current_tick = int(d[4])

        # Check if serverTimestamp is proceeding in order, which it should. 
        if current_seen < last_seen:
            print(f"\t\t-- at index {i+1}: Timestamp out of order. Current: {current_seen}, Previous: {last_seen}")

        # Check for duplicate packetNumbers by checking for the number in set packets.
        #if current_packet in packets:
        #    print(f"Error at index {i+1}: Duplicate packetNum detected. packetNum: {current_packet}")

        # Make sure packetNum is one larger than previous.
        if current_packet != last_packet + 1 and current_packet != 0:
            print(f"\t\tat index {i+1}: packetNum not sequentially increasing. Current: {current_packet}, Previous: {last_packet}")

        # Make sure tick has increased from last_tick.
        if current_tick <= last_tick:
            print(f"\t\tat index {i+1}: packet_tick not increasing. Current: {current_tick}, Previous: {last_tick}")

        # Check if the current tick is no more than 500ms greater than last tick.
        if current_tick - last_tick > timeout_ms:
            print(f"\t\tat index {i+1}: tick increment greater than timeout. Difference: {current_tick - last_tick}ms")

        # Update last_seen, last_tick, last_packet, packets
        last_seen = current_seen
        last_tick = current_tick
        last_packet = current_packet

        
        
def check_time_deltas(data):
    ''' feed in raw data after reading it into a list, this will just check
    server timestamps vs packet vs ticks and look at the differences elapsed 
    from packet to packet.  For debugging. '''
    prev_server = pd.to_datetime(data[0][0])
    prev_packet = int(data[0][3])
    prev_tick   = int(data[0][4])

    for d in data[1:200]:
        cs = pd.to_datetime(d[0])
        cp = int(d[3])
        ct = int(d[4])
        
        print(f'Differences: PACKET:{cp-prev_packet}\tSERVER:{humanize.precisedelta(cs-prev_server)}\tTICK:{(ct-prev_tick)/1000}')
        
        prev_server = cs
        prev_packet = cp
        prev_tick   = ct
        

def reindex_to_timestamp(df, column='tick_ms'):
    '''assumes a serverTS and tick_ms.  grabs first serverTS, assumes it marks 
    the tick_ms of the last row in the first packet, and then uses the tick_ms
    as the gold standard for all other timestamps'''
    
    df = df.copy()

    #make sure column is a datetime type
    df[column] = pd.to_datetime(df[column], unit='ms')
    
    # Set the first serverTS as the base timestamp
    base_timestamp = pd.to_datetime(df.loc[0, 'serverTS'])

    # Find the tick_ms of the last entry in the first packet by looking at the change in packetNum
    first_packet_num = df.loc[0, 'packetNum']
    zero_time_index = np.where(df['packetNum'].shift(-1) != first_packet_num)[0]
    
    if len(zero_time_index) > 0:
        zero_time = df.loc[zero_time_index[0], column]
    else:
        zero_time = df.loc[0, column]

    # Adjust tick_ms to get the correct offset
    df.loc[:, column] -= zero_time
    df.loc[:, column] = pd.to_timedelta(df[column], unit='ms')

    
    # Create new timestamp and set as index
    df['timestamp'] = base_timestamp + df[column]
    
    # Drop duplicates
    l = len(df)
    df.drop_duplicates(subset='timestamp', keep='first', inplace=True)
    print(f'\t\tdropped {l-len(df)} rows of data due to duplication.')
    
    # Drop data that's not within 10 sec of first and last server timestamp
    l = len(df)
    cutoff = pd.to_datetime(df.iloc[0]['serverTS']) - datetime.timedelta(seconds=10)
    df = df[df['timestamp'] > cutoff]
    cutoff = pd.to_datetime(df.iloc[-1]['serverTS']) + datetime.timedelta(seconds=10)
    df = df[df['timestamp'] < cutoff]
    print(f'\t\tdropped {l-len(df)} rows of data due to weird timestamps.')
    
    df['timestamp'] -= datetime.timedelta(hours=TIMEZONE_OFFSET)
    
    df.set_index('timestamp', inplace=True)
    
    print('\t\t-----------------------------')
    #print('\t\t-- reindexed timestamps based on first packet server timestamp and last tick_ms of first packet')
    #print('\t\t-- there is the possibility of drift with this technique; check that these values of the')
    #print('\t\t-- final packet are roughly in sync.')
    #print('\t\t-- First server time: ' + pd.to_datetime(df['serverTS'].iloc[0]).time().isoformat())
    #print('\t\t-- Last server time: ' + pd.to_datetime(df['serverTS'].iloc[-1]).time().isoformat())
    #print('\t\t-- First timestamp: ' + df.index[0].time().isoformat())
    #print('\t\t-- Last timestamp: ' + df.index[-1].time().isoformat())
    #print('\t\t-- Duration serverTS:  ' + humanize.precisedelta(pd.to_datetime(df['serverTS'].iloc[-1])-pd.to_datetime(df['serverTS'].iloc[0])))
    #print('\t\t-- Duration timestamp: ' + humanize.precisedelta(df.index[-1]-df.index[0]))
    print('\t\tDuration: ' + humanize.precisedelta(df.index[-1]-df.index[0]))
    print('\t\tError (server timestamp vs tick): ' + humanize.precisedelta(pd.to_datetime(df['serverTS'].iloc[-1]) - df.index[-1] - datetime.timedelta(hours=TIMEZONE_OFFSET)))
    print('\t\t% drift: ' + str(100.0*(pd.to_datetime(df['serverTS'].iloc[-1]) - df.index[-1] - datetime.timedelta(hours=TIMEZONE_OFFSET))/(df.index[-1]- df.index[0])))
     
    df.drop([column, 'serverTS', 'msFromStart','index','packetTypeLetter','packetType','packetNum','epoch','packetSize','res0','res1','res2','res3','res4'], axis=1, inplace=True)

    return df

# %%
def update_sessions_with_E4_data(session_data, folder, user, session):
    
    #load E4 data
    df = load_session_data(folder, 'P' + str(user), 'sess' + str(session))
    
    df_names = ['ACC', 'IBI', 'TEMP', 'EDA', 'BVP', 'HR']
    
    #iterate over each data_type in the E4 session
    for df_type in df_names:
        
        #get just that data
        session_data['E4_' + df_type] = extract_datatype(df, df_type)
    
    return session_data

def process_ui_data(session_data):
    '''process the ui data from the session_data into a DF of important timestamps and a dictionary of survey data'''

    # Define lists for two dataframes
    timestamps = []
    
    for row in session_data['ui']:
        if row[2] in ['START_TRANSITION', 'FINISHED_TRANSITION']:
            timestamps.append([pd.to_datetime(row[0])-datetime.timedelta(hours=TIMEZONE_OFFSET), row[2]])
        elif row[2] == 'TX_TIME_SEEN':
            timestamps.append([pd.to_datetime(row[0])-datetime.timedelta(hours=TIMEZONE_OFFSET), 'WATCH_PRESS'])
        else:
            print(f'GOT unknown survey: {row}')
    
    # Create dataframes
    df_times = pd.DataFrame(timestamps, columns=['timestamp', 'event'])
    df_times['timestamp'] = pd.to_datetime(df_times['timestamp'], utc=True)
    df_times['timestamp'] = df_times['timestamp'].dt.tz_localize(None)
    df_times.set_index('timestamp', inplace=True)

    return df_times

# %%
users_to_process = []
#Done [5,21,20,9,16,17,18,15,19,24,22,23,12,2,3]; 13 below due to no E4 data

folder = '/Volumes/Secondary/PhDStudy_Results'

for user in users_to_process:
    try:
        #grab all sections of Session 1 for that user (glasses CSVs, each separated by task/env')
        session_data = load_session3_excel(folder, 'P' + str(user), 'sess3')
        print('Successfully processed P' + str(user) + ' sess3 csvs.')

        session_data = update_sessions_with_E4_data(session_data, folder, user, 3)
        print('Successfully processed P' + str(user) + ' sess3 E4 data.')

        session_data['timings'] = process_ui_data(session_data)
        del session_data['ui']
        print('Successfully processed P' + str(user) + ' sess3 timings.')

        #save to a pickle
        with open(folder + '/P' + str(user) + '_sess3_timeseries.pickle', 'wb') as handle:
            pickle.dump(session_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
        print('Successfully saved P' + str(user) + ' session #3 data.')
        
    except Exception as e:
        print(f'ERROR WITH USER {user}: {e}')
# Out:
# /Volumes/Secondary/PhDStudy_Results/P21/P21_sess3/recording_042223_163025.csv, File size: 12.1 MB
# /Volumes/Secondary/PhDStudy_Results/P21/P21_sess3/recording_042223_164800.csv, File size: 8.7 MB
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 13.90 seconds
# 		Error (server timestamp vs tick): 0.11 seconds
# 		% drift: -0.007464165400620913
# 	gyro processing...
# 		at index 63: packetNum not sequentially increasing. Current: 56, Previous: 54
# 		at index 63: tick increment greater than timeout. Difference: 1206ms
# 		at index 476: packetNum not sequentially increasing. Current: 214, Previous: 212
# 		at index 476: tick increment greater than timeout. Difference: 1164ms
# 		at index 1620: packetNum not sequentially increasing. Current: 79, Previous: 77
# 		at index 1620: tick increment greater than timeout. Difference: 1308ms
# 		at index 1751: packetNum not sequentially increasing. Current: 211, Previous: 209
# 		at index 1751: tick increment greater than timeout. Difference: 1123ms
# 		at index 2887: packetNum not sequentially increasing. Current: 68, Previous: 66
# 		at index 2887: tick increment greater than timeout. Difference: 1254ms
# 		at index 3527: packetNum not sequentially increasing. Current: 197, Previous: 195
# 		at index 3527: tick increment greater than timeout. Difference: 1068ms
# 		at index 4167: packetNum not sequentially increasing. Current: 70, Previous: 68
# 		at index 4167: tick increment greater than timeout. Difference: 1188ms
# 		at index 4655: packetNum not sequentially increasing. Current: 47, Previous: 45
# 		at index 4655: tick increment greater than timeout. Difference: 1198ms
# 		dropped 9 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 12.21 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.001719336785673428
# 	accelerometer processing...
# 		at index 2122: packetNum not sequentially increasing. Current: 37, Previous: 35
# 		at index 2122: tick increment greater than timeout. Difference: 1929ms
# 		at index 2135: packetNum not sequentially increasing. Current: 51, Previous: 49
# 		at index 2135: tick increment greater than timeout. Difference: 2011ms
# 		at index 2313: packetNum not sequentially increasing. Current: 228, Previous: 228
# 		at index 2313: packet_tick not increasing. Current: 2744549, Previous: 2744549
# 		dropped 72 rows of data due to duplication.
# 		dropped 13 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 12.26 seconds
# 		Error (server timestamp vs tick): 0.05 seconds
# 		% drift: 0.0031740626183040916
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 119: packetNum not sequentially increasing. Current: 55, Previous: 1516
# 		at index 119: packet_tick not increasing. Current: 512291, Previous: 512291
# 		at index 120: packetNum not sequentially increasing. Current: 1517, Previous: 55
# 		at index 877: packetNum not sequentially increasing. Current: 2273, Previous: 2273
# 		at index 877: packet_tick not increasing. Current: 764492, Previous: 764492
# 		at index 2966: packetNum not sequentially increasing. Current: 4361, Previous: 4361
# 		at index 2966: packet_tick not increasing. Current: 1460492, Previous: 1460492
# 		at index 3212: packetNum not sequentially increasing. Current: 4606, Previous: 4606
# 		at index 3212: packet_tick not increasing. Current: 1542291, Previous: 1542291
# 		at index 5285: packetNum not sequentially increasing. Current: 6678, Previous: 6678
# 		at index 5285: packet_tick not increasing. Current: 2232892, Previous: 2232892
# 		at index 6258: packetNum not sequentially increasing. Current: 7650, Previous: 7650
# 		at index 6258: packet_tick not increasing. Current: 2556892, Previous: 2556892
# 		at index 6302: packetNum not sequentially increasing. Current: 7693, Previous: 7693
# 		at index 6302: packet_tick not increasing. Current: 2571292, Previous: 2571292
# 		at index 6472: packetNum not sequentially increasing. Current: 7862, Previous: 7862
# 		at index 6472: packet_tick not increasing. Current: 2627491, Previous: 2627491
# 		at index 6823: packetNum not sequentially increasing. Current: 8214, Previous: 8212
# 		at index 6823: tick increment greater than timeout. Difference: 600ms
# 		at index 7656: packetNum not sequentially increasing. Current: 9046, Previous: 9046
# 		at index 7656: packet_tick not increasing. Current: 3022291, Previous: 3022291
# 		at index 8548: packetNum not sequentially increasing. Current: 9937, Previous: 9937
# 		at index 8548: packet_tick not increasing. Current: 3319291, Previous: 3319291
# 		dropped 4184 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 12.50 seconds
# 		Error (server timestamp vs tick): 0.24 seconds
# 		% drift: -0.015603310943243288
# 	watch processing...
# The size of the loaded data is 202.0109634399414 MB
# Successfully processed P21 sess3 csvs.
# Successfully processed P21 sess3 E4 data.
# Successfully processed P21 sess3 timings.
# Successfully saved P21 session #3 data.
# /Volumes/Secondary/PhDStudy_Results/P20/P20_sess3/recording_042223_172722.csv, File size: 10.2 MB
# /Volumes/Secondary/PhDStudy_Results/P20/P20_sess3/recording_042223_174457.csv, File size: 10.1 MB
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 11.90 seconds
# 		Error (server timestamp vs tick): 0.06 seconds
# 		% drift: -0.004166942258085852
# 	gyro processing...
# 		at index 401: packetNum not sequentially increasing. Current: 18, Previous: 16
# 		at index 401: tick increment greater than timeout. Difference: 1202ms
# 		at index 408: packetNum not sequentially increasing. Current: 26, Previous: 24
# 		at index 408: tick increment greater than timeout. Difference: 1166ms
# 		at index 3440: packetNum not sequentially increasing. Current: 243, Previous: 241
# 		at index 3440: tick increment greater than timeout. Difference: 1219ms
# 		at index 3870: packetNum not sequentially increasing. Current: 162, Previous: 160
# 		at index 3870: tick increment greater than timeout. Difference: 1211ms
# 		at index 3902: packetNum not sequentially increasing. Current: 195, Previous: 193
# 		at index 3902: tick increment greater than timeout. Difference: 1306ms
# 		at index 4107: packetNum not sequentially increasing. Current: 145, Previous: 143
# 		at index 4107: tick increment greater than timeout. Difference: 1191ms
# 		dropped 3 rows of data due to duplication.
# 		dropped 1 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 10.94 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 0.00023164456722341888
# 	accelerometer processing...
# 		at index 244: packetNum not sequentially increasing. Current: 189, Previous: 187
# 		at index 244: tick increment greater than timeout. Difference: 1949ms
# 		at index 1209: packetNum not sequentially increasing. Current: 131, Previous: 129
# 		at index 1209: tick increment greater than timeout. Difference: 1959ms
# 		at index 2345: packetNum not sequentially increasing. Current: 242, Previous: 242
# 		at index 2345: packet_tick not increasing. Current: 3074502, Previous: 3074502
# 		at index 2518: packetNum not sequentially increasing. Current: 158, Previous: 158
# 		at index 2518: packet_tick not increasing. Current: 3247494, Previous: 3247494
# 		at index 2798: packetNum not sequentially increasing. Current: 181, Previous: 181
# 		at index 2798: packet_tick not increasing. Current: 3528520, Previous: 3528520
# 		at index 2940: packetNum not sequentially increasing. Current: 66, Previous: 66
# 		at index 2940: packet_tick not increasing. Current: 3669538, Previous: 3669538
# 		dropped 186 rows of data due to duplication.
# 		dropped 6 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 11.03 seconds
# 		Error (server timestamp vs tick): 0.07 seconds
# 		% drift: -0.004467157458366093
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 734: packetNum not sequentially increasing. Current: 2868, Previous: 2866
# 		at index 734: tick increment greater than timeout. Difference: 600ms
# 		at index 3644: packetNum not sequentially increasing. Current: 5777, Previous: 5777
# 		at index 3644: packet_tick not increasing. Current: 1932488, Previous: 1932488
# 		at index 6229: packetNum not sequentially increasing. Current: 8361, Previous: 8361
# 		at index 6229: packet_tick not increasing. Current: 2793889, Previous: 2793889
# 		at index 7010: packetNum not sequentially increasing. Current: 9141, Previous: 9141
# 		at index 7010: packet_tick not increasing. Current: 3053889, Previous: 3053889
# 		at index 7447: packetNum not sequentially increasing. Current: 9577, Previous: 9577
# 		at index 7447: packet_tick not increasing. Current: 3199288, Previous: 3199288
# 		at index 7590: packetNum not sequentially increasing. Current: 9721, Previous: 9719
# 		at index 7590: tick increment greater than timeout. Difference: 801ms
# 		at index 8433: packetNum not sequentially increasing. Current: 10565, Previous: 10563
# 		at index 8433: tick increment greater than timeout. Difference: 600ms
# 		at index 8856: packetNum not sequentially increasing. Current: 10989, Previous: 10987
# 		at index 8856: tick increment greater than timeout. Difference: 600ms
# 		dropped 2275 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 10.70 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.001489376771944643
# 	watch processing...
# The size of the loaded data is 201.69913482666016 MB
# Successfully processed P20 sess3 csvs.
# Successfully processed P20 sess3 E4 data.
# Successfully processed P20 sess3 timings.
# Successfully saved P20 session #3 data.
# /Volumes/Secondary/PhDStudy_Results/P9/P9_sess3/recording_042523_172124.csv, File size: 10.2 MB
# /Volumes/Secondary/PhDStudy_Results/P9/P9_sess3/recording_042523_173950.csv, File size: 10.4 MB
# /Volumes/Secondary/PhDStudy_Results/P9/P9_sess3/recording_042523_175824.csv, File size: 1.8 MB
# got raw data.
# 	thermal processing...
# 		at index 122: packetNum not sequentially increasing. Current: 250, Previous: 248
# 		at index 122: tick increment greater than timeout. Difference: 8019ms
# 		at index 125: packetNum not sequentially increasing. Current: 254, Previous: 252
# 		at index 125: tick increment greater than timeout. Difference: 8019ms
# 		at index 133: packetNum not sequentially increasing. Current: 263, Previous: 261
# 		at index 133: tick increment greater than timeout. Difference: 8001ms
# 		at index 187: packetNum not sequentially increasing. Current: 318, Previous: 316
# 		at index 187: tick increment greater than timeout. Difference: 7981ms
# 		at index 214: packetNum not sequentially increasing. Current: 346, Previous: 344
# 		at index 214: tick increment greater than timeout. Difference: 8009ms
# 		at index 228: packetNum not sequentially increasing. Current: 361, Previous: 359
# 		at index 228: tick increment greater than timeout. Difference: 8002ms
# 		at index 233: packetNum not sequentially increasing. Current: 367, Previous: 365
# 		at index 233: tick increment greater than timeout. Difference: 8002ms
# 		at index 278: packetNum not sequentially increasing. Current: 413, Previous: 411
# 		at index 278: tick increment greater than timeout. Difference: 8002ms
# 		at index 300: packetNum not sequentially increasing. Current: 436, Previous: 434
# 		at index 300: tick increment greater than timeout. Difference: 8004ms
# 		at index 324: packetNum not sequentially increasing. Current: 461, Previous: 459
# 		at index 324: tick increment greater than timeout. Difference: 8000ms
# 		at index 335: packetNum not sequentially increasing. Current: 473, Previous: 471
# 		at index 335: tick increment greater than timeout. Difference: 8012ms
# 		at index 359: packetNum not sequentially increasing. Current: 498, Previous: 496
# 		at index 359: tick increment greater than timeout. Difference: 7999ms
# 		at index 365: packetNum not sequentially increasing. Current: 505, Previous: 503
# 		at index 365: tick increment greater than timeout. Difference: 7996ms
# 		at index 371: packetNum not sequentially increasing. Current: 512, Previous: 510
# 		at index 371: tick increment greater than timeout. Difference: 7998ms
# 		at index 372: packetNum not sequentially increasing. Current: 516, Previous: 512
# 		at index 372: tick increment greater than timeout. Difference: 16019ms
# 		at index 375: packetNum not sequentially increasing. Current: 520, Previous: 518
# 		at index 375: tick increment greater than timeout. Difference: 8000ms
# 		at index 387: packetNum not sequentially increasing. Current: 533, Previous: 531
# 		at index 387: tick increment greater than timeout. Difference: 7999ms
# 		at index 394: packetNum not sequentially increasing. Current: 541, Previous: 539
# 		at index 394: tick increment greater than timeout. Difference: 8000ms
# 		at index 403: packetNum not sequentially increasing. Current: 551, Previous: 549
# 		at index 403: tick increment greater than timeout. Difference: 8008ms
# 		at index 409: packetNum not sequentially increasing. Current: 558, Previous: 556
# 		at index 409: tick increment greater than timeout. Difference: 8007ms
# 		at index 411: packetNum not sequentially increasing. Current: 561, Previous: 559
# 		at index 411: tick increment greater than timeout. Difference: 7997ms
# 		at index 417: packetNum not sequentially increasing. Current: 568, Previous: 566
# 		at index 417: tick increment greater than timeout. Difference: 8008ms
# 		at index 426: packetNum not sequentially increasing. Current: 578, Previous: 576
# 		at index 426: tick increment greater than timeout. Difference: 7999ms
# 		at index 448: packetNum not sequentially increasing. Current: 602, Previous: 599
# 		at index 448: tick increment greater than timeout. Difference: 11999ms
# 		at index 450: packetNum not sequentially increasing. Current: 606, Previous: 603
# 		at index 450: tick increment greater than timeout. Difference: 11982ms
# 		at index 477: packetNum not sequentially increasing. Current: 634, Previous: 632
# 		at index 477: tick increment greater than timeout. Difference: 7997ms
# 		at index 479: packetNum not sequentially increasing. Current: 637, Previous: 635
# 		at index 479: tick increment greater than timeout. Difference: 8004ms
# 		at index 520: packetNum not sequentially increasing. Current: 679, Previous: 677
# 		at index 520: tick increment greater than timeout. Difference: 7987ms
# 		at index 541: packetNum not sequentially increasing. Current: 701, Previous: 699
# 		at index 541: tick increment greater than timeout. Difference: 8011ms
# 		at index 550: packetNum not sequentially increasing. Current: 711, Previous: 709
# 		at index 550: tick increment greater than timeout. Difference: 8006ms
# 		at index 557: packetNum not sequentially increasing. Current: 719, Previous: 717
# 		at index 557: tick increment greater than timeout. Difference: 8008ms
# 		at index 584: packetNum not sequentially increasing. Current: 749, Previous: 745
# 		at index 584: tick increment greater than timeout. Difference: 15978ms
# 		at index 587: packetNum not sequentially increasing. Current: 755, Previous: 751
# 		at index 587: tick increment greater than timeout. Difference: 16009ms
# 		at index 594: packetNum not sequentially increasing. Current: 763, Previous: 761
# 		at index 594: tick increment greater than timeout. Difference: 7999ms
# 		at index 645: packetNum not sequentially increasing. Current: 815, Previous: 813
# 		at index 645: tick increment greater than timeout. Difference: 7988ms
# 		at index 674: packetNum not sequentially increasing. Current: 845, Previous: 843
# 		at index 674: tick increment greater than timeout. Difference: 7997ms
# 		at index 747: packetNum not sequentially increasing. Current: 919, Previous: 917
# 		at index 747: tick increment greater than timeout. Difference: 7989ms
# 		at index 769: packetNum not sequentially increasing. Current: 942, Previous: 940
# 		at index 769: tick increment greater than timeout. Difference: 8018ms
# 		at index 777: packetNum not sequentially increasing. Current: 951, Previous: 949
# 		at index 777: tick increment greater than timeout. Difference: 8009ms
# 		at index 784: packetNum not sequentially increasing. Current: 959, Previous: 957
# 		at index 784: tick increment greater than timeout. Difference: 8018ms
# 		at index 802: packetNum not sequentially increasing. Current: 980, Previous: 976
# 		at index 802: tick increment greater than timeout. Difference: 15984ms
# 		at index 804: packetNum not sequentially increasing. Current: 983, Previous: 981
# 		at index 804: tick increment greater than timeout. Difference: 7999ms
# 		at index 813: packetNum not sequentially increasing. Current: 993, Previous: 991
# 		at index 813: tick increment greater than timeout. Difference: 8006ms
# 		at index 814: packetNum not sequentially increasing. Current: 996, Previous: 993
# 		at index 814: tick increment greater than timeout. Difference: 12008ms
# 		at index 816: packetNum not sequentially increasing. Current: 999, Previous: 997
# 		at index 816: tick increment greater than timeout. Difference: 8007ms
# 		at index 825: packetNum not sequentially increasing. Current: 1012, Previous: 1007
# 		at index 825: tick increment greater than timeout. Difference: 19993ms
# 		at index 828: packetNum not sequentially increasing. Current: 1016, Previous: 1014
# 		at index 828: tick increment greater than timeout. Difference: 7985ms
# 		at index 832: packetNum not sequentially increasing. Current: 1021, Previous: 1019
# 		at index 832: tick increment greater than timeout. Difference: 8013ms
# 		at index 846: packetNum not sequentially increasing. Current: 1037, Previous: 1034
# 		at index 846: tick increment greater than timeout. Difference: 12007ms
# 		at index 848: packetNum not sequentially increasing. Current: 1040, Previous: 1038
# 		at index 848: tick increment greater than timeout. Difference: 8002ms
# 		at index 850: packetNum not sequentially increasing. Current: 1043, Previous: 1041
# 		at index 850: tick increment greater than timeout. Difference: 7998ms
# 		at index 851: packetNum not sequentially increasing. Current: 1046, Previous: 1043
# 		at index 851: tick increment greater than timeout. Difference: 12002ms
# 		at index 859: packetNum not sequentially increasing. Current: 1055, Previous: 1053
# 		at index 859: tick increment greater than timeout. Difference: 8014ms
# 		at index 867: packetNum not sequentially increasing. Current: 1065, Previous: 1062
# 		at index 867: tick increment greater than timeout. Difference: 11997ms
# 		at index 911: packetNum not sequentially increasing. Current: 1110, Previous: 1108
# 		at index 911: tick increment greater than timeout. Difference: 8021ms
# 		at index 934: packetNum not sequentially increasing. Current: 1134, Previous: 1132
# 		at index 934: tick increment greater than timeout. Difference: 7995ms
# 		at index 965: packetNum not sequentially increasing. Current: 1166, Previous: 1164
# 		at index 965: tick increment greater than timeout. Difference: 7996ms
# 		at index 966: packetNum not sequentially increasing. Current: 1171, Previous: 1166
# 		at index 966: tick increment greater than timeout. Difference: 19996ms
# 		at index 969: packetNum not sequentially increasing. Current: 1175, Previous: 1173
# 		at index 969: tick increment greater than timeout. Difference: 8008ms
# 		at index 978: packetNum not sequentially increasing. Current: 1185, Previous: 1183
# 		at index 978: tick increment greater than timeout. Difference: 7991ms
# 		at index 979: packetNum not sequentially increasing. Current: 1188, Previous: 1185
# 		at index 979: tick increment greater than timeout. Difference: 11999ms
# 		at index 981: packetNum not sequentially increasing. Current: 1191, Previous: 1189
# 		at index 981: tick increment greater than timeout. Difference: 8002ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 35 minutes and 53.90 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: 0.0019963786619620226
# 	gyro processing...
# 		at index 463: packetNum not sequentially increasing. Current: 12, Previous: 10
# 		at index 463: tick increment greater than timeout. Difference: 1224ms
# 		at index 508: packetNum not sequentially increasing. Current: 58, Previous: 56
# 		at index 508: tick increment greater than timeout. Difference: 1359ms
# 		at index 573: packetNum not sequentially increasing. Current: 125, Previous: 122
# 		at index 573: tick increment greater than timeout. Difference: 1877ms
# 		at index 574: packetNum not sequentially increasing. Current: 127, Previous: 125
# 		at index 574: tick increment greater than timeout. Difference: 1114ms
# 		at index 699: packetNum not sequentially increasing. Current: 253, Previous: 251
# 		at index 699: tick increment greater than timeout. Difference: 1231ms
# 		at index 709: packetNum not sequentially increasing. Current: 8, Previous: 6
# 		at index 709: tick increment greater than timeout. Difference: 1240ms
# 		at index 739: packetNum not sequentially increasing. Current: 39, Previous: 37
# 		at index 739: tick increment greater than timeout. Difference: 1145ms
# 		at index 771: packetNum not sequentially increasing. Current: 72, Previous: 70
# 		at index 771: tick increment greater than timeout. Difference: 1200ms
# 		at index 773: packetNum not sequentially increasing. Current: 75, Previous: 73
# 		at index 773: tick increment greater than timeout. Difference: 1138ms
# 		at index 779: packetNum not sequentially increasing. Current: 82, Previous: 80
# 		at index 779: tick increment greater than timeout. Difference: 1205ms
# 		at index 781: packetNum not sequentially increasing. Current: 85, Previous: 83
# 		at index 781: tick increment greater than timeout. Difference: 1264ms
# 		at index 786: packetNum not sequentially increasing. Current: 91, Previous: 89
# 		at index 786: tick increment greater than timeout. Difference: 1138ms
# 		at index 805: packetNum not sequentially increasing. Current: 111, Previous: 109
# 		at index 805: tick increment greater than timeout. Difference: 1192ms
# 		at index 848: packetNum not sequentially increasing. Current: 155, Previous: 153
# 		at index 848: tick increment greater than timeout. Difference: 1264ms
# 		at index 852: packetNum not sequentially increasing. Current: 160, Previous: 158
# 		at index 852: tick increment greater than timeout. Difference: 1239ms
# 		at index 1060: packetNum not sequentially increasing. Current: 113, Previous: 111
# 		at index 1060: tick increment greater than timeout. Difference: 1283ms
# 		at index 1061: packetNum not sequentially increasing. Current: 115, Previous: 113
# 		at index 1061: tick increment greater than timeout. Difference: 1137ms
# 		at index 1094: packetNum not sequentially increasing. Current: 149, Previous: 147
# 		at index 1094: tick increment greater than timeout. Difference: 1264ms
# 		at index 1140: packetNum not sequentially increasing. Current: 196, Previous: 194
# 		at index 1140: tick increment greater than timeout. Difference: 1407ms
# 		at index 1196: packetNum not sequentially increasing. Current: 253, Previous: 251
# 		at index 1196: tick increment greater than timeout. Difference: 1282ms
# 		at index 1198: tick increment greater than timeout. Difference: 1257ms
# 		at index 1213: packetNum not sequentially increasing. Current: 16, Previous: 14
# 		at index 1213: tick increment greater than timeout. Difference: 1202ms
# 		at index 1378: packetNum not sequentially increasing. Current: 182, Previous: 180
# 		at index 1378: tick increment greater than timeout. Difference: 1245ms
# 		at index 1379: packetNum not sequentially increasing. Current: 185, Previous: 182
# 		at index 1379: tick increment greater than timeout. Difference: 2067ms
# 		at index 1389: packetNum not sequentially increasing. Current: 196, Previous: 194
# 		at index 1389: tick increment greater than timeout. Difference: 1239ms
# 		at index 1416: packetNum not sequentially increasing. Current: 224, Previous: 222
# 		at index 1416: tick increment greater than timeout. Difference: 1229ms
# 		at index 1426: packetNum not sequentially increasing. Current: 235, Previous: 233
# 		at index 1426: tick increment greater than timeout. Difference: 1230ms
# 		at index 1432: packetNum not sequentially increasing. Current: 242, Previous: 240
# 		at index 1432: tick increment greater than timeout. Difference: 1180ms
# 		at index 1438: packetNum not sequentially increasing. Current: 249, Previous: 247
# 		at index 1438: tick increment greater than timeout. Difference: 1213ms
# 		at index 1456: packetNum not sequentially increasing. Current: 12, Previous: 10
# 		at index 1456: tick increment greater than timeout. Difference: 1242ms
# 		at index 1457: packetNum not sequentially increasing. Current: 16, Previous: 12
# 		at index 1457: tick increment greater than timeout. Difference: 2441ms
# 		at index 1458: packetNum not sequentially increasing. Current: 18, Previous: 16
# 		at index 1458: tick increment greater than timeout. Difference: 1336ms
# 		at index 1459: packetNum not sequentially increasing. Current: 20, Previous: 18
# 		at index 1459: tick increment greater than timeout. Difference: 1214ms
# 		at index 1461: packetNum not sequentially increasing. Current: 23, Previous: 21
# 		at index 1461: tick increment greater than timeout. Difference: 1236ms
# 		at index 1499: packetNum not sequentially increasing. Current: 62, Previous: 60
# 		at index 1499: tick increment greater than timeout. Difference: 1231ms
# 		at index 1500: packetNum not sequentially increasing. Current: 64, Previous: 62
# 		at index 1500: tick increment greater than timeout. Difference: 1150ms
# 		at index 1501: packetNum not sequentially increasing. Current: 66, Previous: 64
# 		at index 1501: tick increment greater than timeout. Difference: 1178ms
# 		at index 1505: packetNum not sequentially increasing. Current: 71, Previous: 69
# 		at index 1505: tick increment greater than timeout. Difference: 1273ms
# 		at index 1509: packetNum not sequentially increasing. Current: 76, Previous: 74
# 		at index 1509: tick increment greater than timeout. Difference: 1118ms
# 		at index 1511: packetNum not sequentially increasing. Current: 79, Previous: 77
# 		at index 1511: tick increment greater than timeout. Difference: 1309ms
# 		at index 1513: packetNum not sequentially increasing. Current: 82, Previous: 80
# 		at index 1513: tick increment greater than timeout. Difference: 1163ms
# 		at index 1529: packetNum not sequentially increasing. Current: 97, Previous: 97
# 		at index 1529: packet_tick not increasing. Current: 1492545, Previous: 1492545
# 		at index 1573: packetNum not sequentially increasing. Current: 142, Previous: 140
# 		at index 1573: tick increment greater than timeout. Difference: 1196ms
# 		at index 1597: packetNum not sequentially increasing. Current: 167, Previous: 165
# 		at index 1597: tick increment greater than timeout. Difference: 1327ms
# 		at index 1710: packetNum not sequentially increasing. Current: 25, Previous: 23
# 		at index 1710: tick increment greater than timeout. Difference: 1135ms
# 		at index 1711: packetNum not sequentially increasing. Current: 27, Previous: 25
# 		at index 1711: tick increment greater than timeout. Difference: 1190ms
# 		at index 1715: packetNum not sequentially increasing. Current: 32, Previous: 30
# 		at index 1715: tick increment greater than timeout. Difference: 1085ms
# 		at index 1719: packetNum not sequentially increasing. Current: 37, Previous: 35
# 		at index 1719: tick increment greater than timeout. Difference: 1327ms
# 		at index 1763: packetNum not sequentially increasing. Current: 82, Previous: 80
# 		at index 1763: tick increment greater than timeout. Difference: 1273ms
# 		at index 1767: packetNum not sequentially increasing. Current: 87, Previous: 85
# 		at index 1767: tick increment greater than timeout. Difference: 1224ms
# 		at index 1768: packetNum not sequentially increasing. Current: 89, Previous: 87
# 		at index 1768: tick increment greater than timeout. Difference: 1271ms
# 		at index 1778: packetNum not sequentially increasing. Current: 100, Previous: 98
# 		at index 1778: tick increment greater than timeout. Difference: 1192ms
# 		at index 1877: packetNum not sequentially increasing. Current: 200, Previous: 198
# 		at index 1877: tick increment greater than timeout. Difference: 1260ms
# 		at index 1881: packetNum not sequentially increasing. Current: 205, Previous: 203
# 		at index 1881: tick increment greater than timeout. Difference: 1155ms
# 		at index 1882: packetNum not sequentially increasing. Current: 208, Previous: 205
# 		at index 1882: tick increment greater than timeout. Difference: 2061ms
# 		at index 1889: packetNum not sequentially increasing. Current: 216, Previous: 214
# 		at index 1889: tick increment greater than timeout. Difference: 1220ms
# 		at index 1899: packetNum not sequentially increasing. Current: 227, Previous: 225
# 		at index 1899: tick increment greater than timeout. Difference: 1206ms
# 		at index 1901: packetNum not sequentially increasing. Current: 230, Previous: 228
# 		at index 1901: tick increment greater than timeout. Difference: 1262ms
# 		at index 2010: packetNum not sequentially increasing. Current: 84, Previous: 82
# 		at index 2010: tick increment greater than timeout. Difference: 1137ms
# 		at index 2073: packetNum not sequentially increasing. Current: 148, Previous: 146
# 		at index 2073: tick increment greater than timeout. Difference: 1373ms
# 		at index 2089: packetNum not sequentially increasing. Current: 165, Previous: 163
# 		at index 2089: tick increment greater than timeout. Difference: 1200ms
# 		at index 2091: packetNum not sequentially increasing. Current: 168, Previous: 166
# 		at index 2091: tick increment greater than timeout. Difference: 1258ms
# 		at index 2095: packetNum not sequentially increasing. Current: 173, Previous: 171
# 		at index 2095: tick increment greater than timeout. Difference: 1196ms
# 		at index 2113: packetNum not sequentially increasing. Current: 192, Previous: 190
# 		at index 2113: tick increment greater than timeout. Difference: 1175ms
# 		at index 2140: packetNum not sequentially increasing. Current: 220, Previous: 218
# 		at index 2140: tick increment greater than timeout. Difference: 1270ms
# 		at index 2142: packetNum not sequentially increasing. Current: 223, Previous: 221
# 		at index 2142: tick increment greater than timeout. Difference: 1281ms
# 		at index 2146: packetNum not sequentially increasing. Current: 228, Previous: 226
# 		at index 2146: tick increment greater than timeout. Difference: 1279ms
# 		at index 2153: packetNum not sequentially increasing. Current: 236, Previous: 234
# 		at index 2153: tick increment greater than timeout. Difference: 1272ms
# 		at index 2190: packetNum not sequentially increasing. Current: 19, Previous: 16
# 		at index 2190: tick increment greater than timeout. Difference: 2055ms
# 		at index 2210: packetNum not sequentially increasing. Current: 40, Previous: 38
# 		at index 2210: tick increment greater than timeout. Difference: 1262ms
# 		at index 2236: packetNum not sequentially increasing. Current: 67, Previous: 65
# 		at index 2236: tick increment greater than timeout. Difference: 1115ms
# 		at index 2257: packetNum not sequentially increasing. Current: 89, Previous: 87
# 		at index 2257: tick increment greater than timeout. Difference: 1224ms
# 		at index 2268: packetNum not sequentially increasing. Current: 99, Previous: 99
# 		at index 2268: packet_tick not increasing. Current: 1977517, Previous: 1977517
# 		at index 2270: packetNum not sequentially increasing. Current: 102, Previous: 100
# 		at index 2270: tick increment greater than timeout. Difference: 1222ms
# 		at index 2293: packetNum not sequentially increasing. Current: 127, Previous: 124
# 		at index 2293: tick increment greater than timeout. Difference: 1826ms
# 		at index 2299: packetNum not sequentially increasing. Current: 134, Previous: 132
# 		at index 2299: tick increment greater than timeout. Difference: 1248ms
# 		at index 2306: packetNum not sequentially increasing. Current: 142, Previous: 140
# 		at index 2306: tick increment greater than timeout. Difference: 1186ms
# 		at index 2307: packetNum not sequentially increasing. Current: 144, Previous: 142
# 		at index 2307: tick increment greater than timeout. Difference: 1200ms
# 		at index 2317: packetNum not sequentially increasing. Current: 155, Previous: 153
# 		at index 2317: tick increment greater than timeout. Difference: 1278ms
# 		at index 2331: packetNum not sequentially increasing. Current: 170, Previous: 168
# 		at index 2331: tick increment greater than timeout. Difference: 1302ms
# 		at index 2332: packetNum not sequentially increasing. Current: 172, Previous: 170
# 		at index 2332: tick increment greater than timeout. Difference: 1214ms
# 		at index 2334: packetNum not sequentially increasing. Current: 178, Previous: 173
# 		at index 2334: tick increment greater than timeout. Difference: 3174ms
# 		at index 2351: packetNum not sequentially increasing. Current: 196, Previous: 194
# 		at index 2351: tick increment greater than timeout. Difference: 1143ms
# 		at index 2383: packetNum not sequentially increasing. Current: 229, Previous: 227
# 		at index 2383: tick increment greater than timeout. Difference: 1240ms
# 		at index 2387: packetNum not sequentially increasing. Current: 234, Previous: 232
# 		at index 2387: tick increment greater than timeout. Difference: 1341ms
# 		at index 2395: packetNum not sequentially increasing. Current: 243, Previous: 241
# 		at index 2395: tick increment greater than timeout. Difference: 1353ms
# 		at index 2411: packetNum not sequentially increasing. Current: 4, Previous: 2
# 		at index 2411: tick increment greater than timeout. Difference: 1172ms
# 		at index 2412: packetNum not sequentially increasing. Current: 6, Previous: 4
# 		at index 2412: tick increment greater than timeout. Difference: 1269ms
# 		at index 2414: packetNum not sequentially increasing. Current: 9, Previous: 7
# 		at index 2414: tick increment greater than timeout. Difference: 1242ms
# 		at index 2415: packetNum not sequentially increasing. Current: 11, Previous: 9
# 		at index 2415: tick increment greater than timeout. Difference: 1352ms
# 		at index 2455: packetNum not sequentially increasing. Current: 52, Previous: 50
# 		at index 2455: tick increment greater than timeout. Difference: 1208ms
# 		at index 2456: packetNum not sequentially increasing. Current: 54, Previous: 52
# 		at index 2456: tick increment greater than timeout. Difference: 1192ms
# 		at index 2463: packetNum not sequentially increasing. Current: 62, Previous: 60
# 		at index 2463: tick increment greater than timeout. Difference: 1206ms
# 		at index 2468: packetNum not sequentially increasing. Current: 68, Previous: 66
# 		at index 2468: tick increment greater than timeout. Difference: 1363ms
# 		at index 2479: packetNum not sequentially increasing. Current: 80, Previous: 78
# 		at index 2479: tick increment greater than timeout. Difference: 1302ms
# 		at index 2537: packetNum not sequentially increasing. Current: 139, Previous: 137
# 		at index 2537: tick increment greater than timeout. Difference: 1397ms
# 		at index 2542: packetNum not sequentially increasing. Current: 145, Previous: 143
# 		at index 2542: tick increment greater than timeout. Difference: 1297ms
# 		at index 2543: packetNum not sequentially increasing. Current: 147, Previous: 145
# 		at index 2543: tick increment greater than timeout. Difference: 1224ms
# 		at index 2583: packetNum not sequentially increasing. Current: 188, Previous: 186
# 		at index 2583: tick increment greater than timeout. Difference: 1339ms
# 		at index 2596: packetNum not sequentially increasing. Current: 202, Previous: 200
# 		at index 2596: tick increment greater than timeout. Difference: 1204ms
# 		at index 2603: packetNum not sequentially increasing. Current: 210, Previous: 208
# 		at index 2603: tick increment greater than timeout. Difference: 1330ms
# 		at index 2628: packetNum not sequentially increasing. Current: 236, Previous: 234
# 		at index 2628: tick increment greater than timeout. Difference: 1274ms
# 		at index 2636: packetNum not sequentially increasing. Current: 245, Previous: 243
# 		at index 2636: tick increment greater than timeout. Difference: 1224ms
# 		at index 2642: packetNum not sequentially increasing. Current: 253, Previous: 250
# 		at index 2642: tick increment greater than timeout. Difference: 1841ms
# 		at index 2643: packetNum not sequentially increasing. Current: 255, Previous: 253
# 		at index 2643: tick increment greater than timeout. Difference: 1174ms
# 		at index 2654: packetNum not sequentially increasing. Current: 11, Previous: 9
# 		at index 2654: tick increment greater than timeout. Difference: 1223ms
# 		at index 2655: packetNum not sequentially increasing. Current: 14, Previous: 11
# 		at index 2655: tick increment greater than timeout. Difference: 2128ms
# 		at index 2679: packetNum not sequentially increasing. Current: 39, Previous: 37
# 		at index 2679: tick increment greater than timeout. Difference: 1290ms
# 		at index 2695: packetNum not sequentially increasing. Current: 56, Previous: 54
# 		at index 2695: tick increment greater than timeout. Difference: 1249ms
# 		at index 2716: packetNum not sequentially increasing. Current: 78, Previous: 76
# 		at index 2716: tick increment greater than timeout. Difference: 1248ms
# 		at index 2738: packetNum not sequentially increasing. Current: 101, Previous: 99
# 		at index 2738: tick increment greater than timeout. Difference: 1194ms
# 		at index 2739: packetNum not sequentially increasing. Current: 103, Previous: 101
# 		at index 2739: tick increment greater than timeout. Difference: 1177ms
# 		at index 2753: packetNum not sequentially increasing. Current: 118, Previous: 116
# 		at index 2753: tick increment greater than timeout. Difference: 1278ms
# 		at index 2887: packetNum not sequentially increasing. Current: 253, Previous: 251
# 		at index 2887: tick increment greater than timeout. Difference: 1213ms
# 		at index 2894: packetNum not sequentially increasing. Current: 5, Previous: 3
# 		at index 2894: tick increment greater than timeout. Difference: 1393ms
# 		at index 2904: packetNum not sequentially increasing. Current: 16, Previous: 14
# 		at index 2904: tick increment greater than timeout. Difference: 1191ms
# 		at index 2909: packetNum not sequentially increasing. Current: 22, Previous: 20
# 		at index 2909: tick increment greater than timeout. Difference: 1419ms
# 		at index 2931: packetNum not sequentially increasing. Current: 45, Previous: 43
# 		at index 2931: tick increment greater than timeout. Difference: 1313ms
# 		at index 2997: packetNum not sequentially increasing. Current: 112, Previous: 110
# 		at index 2997: tick increment greater than timeout. Difference: 1346ms
# 		at index 2999: packetNum not sequentially increasing. Current: 115, Previous: 113
# 		at index 2999: tick increment greater than timeout. Difference: 1356ms
# 		at index 3009: packetNum not sequentially increasing. Current: 126, Previous: 124
# 		at index 3009: tick increment greater than timeout. Difference: 1351ms
# 		at index 3014: packetNum not sequentially increasing. Current: 132, Previous: 130
# 		at index 3014: tick increment greater than timeout. Difference: 1257ms
# 		at index 3015: packetNum not sequentially increasing. Current: 134, Previous: 132
# 		at index 3015: tick increment greater than timeout. Difference: 1268ms
# 		at index 3042: packetNum not sequentially increasing. Current: 162, Previous: 160
# 		at index 3042: tick increment greater than timeout. Difference: 1355ms
# 		at index 3048: packetNum not sequentially increasing. Current: 170, Previous: 167
# 		at index 3048: tick increment greater than timeout. Difference: 1898ms
# 		at index 3081: packetNum not sequentially increasing. Current: 204, Previous: 202
# 		at index 3081: tick increment greater than timeout. Difference: 1281ms
# 		at index 3132: tick increment greater than timeout. Difference: 1241ms
# 		at index 3198: packetNum not sequentially increasing. Current: 67, Previous: 65
# 		at index 3198: tick increment greater than timeout. Difference: 1334ms
# 		at index 3200: packetNum not sequentially increasing. Current: 70, Previous: 68
# 		at index 3200: tick increment greater than timeout. Difference: 1262ms
# 		at index 3201: packetNum not sequentially increasing. Current: 72, Previous: 70
# 		at index 3201: tick increment greater than timeout. Difference: 1323ms
# 		at index 3204: packetNum not sequentially increasing. Current: 76, Previous: 74
# 		at index 3204: tick increment greater than timeout. Difference: 1274ms
# 		at index 3282: packetNum not sequentially increasing. Current: 156, Previous: 153
# 		at index 3282: tick increment greater than timeout. Difference: 1864ms
# 		at index 3283: packetNum not sequentially increasing. Current: 158, Previous: 156
# 		at index 3283: tick increment greater than timeout. Difference: 1283ms
# 		at index 3350: packetNum not sequentially increasing. Current: 226, Previous: 224
# 		at index 3350: tick increment greater than timeout. Difference: 1267ms
# 		at index 3382: packetNum not sequentially increasing. Current: 3, Previous: 1
# 		at index 3382: tick increment greater than timeout. Difference: 1186ms
# 		at index 3474: packetNum not sequentially increasing. Current: 96, Previous: 94
# 		at index 3474: tick increment greater than timeout. Difference: 1261ms
# 		at index 3475: packetNum not sequentially increasing. Current: 98, Previous: 96
# 		at index 3475: tick increment greater than timeout. Difference: 1190ms
# 		at index 3478: packetNum not sequentially increasing. Current: 102, Previous: 100
# 		at index 3478: tick increment greater than timeout. Difference: 1181ms
# 		at index 3496: packetNum not sequentially increasing. Current: 121, Previous: 119
# 		at index 3496: tick increment greater than timeout. Difference: 1216ms
# 		at index 3500: packetNum not sequentially increasing. Current: 126, Previous: 124
# 		at index 3500: tick increment greater than timeout. Difference: 1213ms
# 		at index 3502: packetNum not sequentially increasing. Current: 129, Previous: 127
# 		at index 3502: tick increment greater than timeout. Difference: 1263ms
# 		at index 3510: packetNum not sequentially increasing. Current: 138, Previous: 136
# 		at index 3510: tick increment greater than timeout. Difference: 1360ms
# 		at index 3514: packetNum not sequentially increasing. Current: 143, Previous: 141
# 		at index 3514: tick increment greater than timeout. Difference: 1256ms
# 		at index 3515: packetNum not sequentially increasing. Current: 146, Previous: 143
# 		at index 3515: tick increment greater than timeout. Difference: 1832ms
# 		at index 3527: packetNum not sequentially increasing. Current: 159, Previous: 157
# 		at index 3527: tick increment greater than timeout. Difference: 1286ms
# 		at index 3542: packetNum not sequentially increasing. Current: 175, Previous: 173
# 		at index 3542: tick increment greater than timeout. Difference: 1198ms
# 		at index 3544: packetNum not sequentially increasing. Current: 178, Previous: 176
# 		at index 3544: tick increment greater than timeout. Difference: 1212ms
# 		at index 3551: packetNum not sequentially increasing. Current: 186, Previous: 184
# 		at index 3551: tick increment greater than timeout. Difference: 1284ms
# 		at index 3600: packetNum not sequentially increasing. Current: 236, Previous: 234
# 		at index 3600: tick increment greater than timeout. Difference: 1297ms
# 		at index 3602: packetNum not sequentially increasing. Current: 239, Previous: 237
# 		at index 3602: tick increment greater than timeout. Difference: 1275ms
# 		at index 3603: packetNum not sequentially increasing. Current: 242, Previous: 239
# 		at index 3603: tick increment greater than timeout. Difference: 1919ms
# 		at index 3624: packetNum not sequentially increasing. Current: 9, Previous: 6
# 		at index 3624: tick increment greater than timeout. Difference: 1969ms
# 		at index 3698: packetNum not sequentially increasing. Current: 84, Previous: 82
# 		at index 3698: tick increment greater than timeout. Difference: 1311ms
# 		at index 3721: packetNum not sequentially increasing. Current: 108, Previous: 106
# 		at index 3721: tick increment greater than timeout. Difference: 1321ms
# 		at index 3722: packetNum not sequentially increasing. Current: 110, Previous: 108
# 		at index 3722: tick increment greater than timeout. Difference: 1184ms
# 		at index 3727: packetNum not sequentially increasing. Current: 117, Previous: 114
# 		at index 3727: tick increment greater than timeout. Difference: 1919ms
# 		at index 3748: packetNum not sequentially increasing. Current: 140, Previous: 137
# 		at index 3748: tick increment greater than timeout. Difference: 1939ms
# 		at index 3752: packetNum not sequentially increasing. Current: 145, Previous: 143
# 		at index 3752: tick increment greater than timeout. Difference: 1116ms
# 		at index 3769: packetNum not sequentially increasing. Current: 163, Previous: 161
# 		at index 3769: tick increment greater than timeout. Difference: 1253ms
# 		at index 3771: packetNum not sequentially increasing. Current: 166, Previous: 164
# 		at index 3771: tick increment greater than timeout. Difference: 1176ms
# 		at index 3792: packetNum not sequentially increasing. Current: 188, Previous: 186
# 		at index 3792: tick increment greater than timeout. Difference: 1196ms
# 		at index 3804: packetNum not sequentially increasing. Current: 201, Previous: 199
# 		at index 3804: tick increment greater than timeout. Difference: 1222ms
# 		at index 3811: packetNum not sequentially increasing. Current: 209, Previous: 207
# 		at index 3811: tick increment greater than timeout. Difference: 1250ms
# 		at index 3829: packetNum not sequentially increasing. Current: 228, Previous: 226
# 		at index 3829: tick increment greater than timeout. Difference: 1151ms
# 		at index 3866: packetNum not sequentially increasing. Current: 10, Previous: 8
# 		at index 3866: tick increment greater than timeout. Difference: 1280ms
# 		at index 3872: packetNum not sequentially increasing. Current: 19, Previous: 15
# 		at index 3872: tick increment greater than timeout. Difference: 2572ms
# 		at index 3873: packetNum not sequentially increasing. Current: 22, Previous: 19
# 		at index 3873: tick increment greater than timeout. Difference: 1911ms
# 		at index 4180: packetNum not sequentially increasing. Current: 74, Previous: 72
# 		at index 4180: tick increment greater than timeout. Difference: 1276ms
# 		at index 4190: packetNum not sequentially increasing. Current: 85, Previous: 83
# 		at index 4190: tick increment greater than timeout. Difference: 1327ms
# 		at index 4255: packetNum not sequentially increasing. Current: 151, Previous: 149
# 		at index 4255: tick increment greater than timeout. Difference: 1217ms
# 		at index 4346: packetNum not sequentially increasing. Current: 243, Previous: 241
# 		at index 4346: tick increment greater than timeout. Difference: 1304ms
# 		at index 4363: packetNum not sequentially increasing. Current: 5, Previous: 3
# 		at index 4363: tick increment greater than timeout. Difference: 1328ms
# 		at index 4638: packetNum not sequentially increasing. Current: 25, Previous: 23
# 		at index 4638: tick increment greater than timeout. Difference: 1301ms
# 		at index 4693: packetNum not sequentially increasing. Current: 81, Previous: 79
# 		at index 4693: tick increment greater than timeout. Difference: 1323ms
# 		at index 4783: packetNum not sequentially increasing. Current: 172, Previous: 170
# 		at index 4783: tick increment greater than timeout. Difference: 1259ms
# 		at index 4967: packetNum not sequentially increasing. Current: 103, Previous: 99
# 		at index 4967: tick increment greater than timeout. Difference: 2478ms
# 		at index 4968: packetNum not sequentially increasing. Current: 106, Previous: 103
# 		at index 4968: tick increment greater than timeout. Difference: 1858ms
# 		at index 4984: packetNum not sequentially increasing. Current: 123, Previous: 121
# 		at index 4984: tick increment greater than timeout. Difference: 1413ms
# 		at index 5021: packetNum not sequentially increasing. Current: 161, Previous: 159
# ...
# 		at index 2062: tick increment greater than timeout. Difference: 601ms
# 		at index 2175: packetNum not sequentially increasing. Current: 2346, Previous: 2344
# 		at index 2175: tick increment greater than timeout. Difference: 599ms
# 		at index 2584: packetNum not sequentially increasing. Current: 2754, Previous: 2754
# 		at index 2584: packet_tick not increasing. Current: 924890, Previous: 924890
# 		at index 2873: packetNum not sequentially increasing. Current: 3045, Previous: 3042
# 		at index 2873: tick increment greater than timeout. Difference: 999ms
# 		at index 2882: packetNum not sequentially increasing. Current: 3057, Previous: 3053
# 		at index 2882: tick increment greater than timeout. Difference: 1400ms
# 		at index 2931: packetNum not sequentially increasing. Current: 3114, Previous: 3105
# 		at index 2931: tick increment greater than timeout. Difference: 3001ms
# 		at index 2937: packetNum not sequentially increasing. Current: 3121, Previous: 3119
# 		at index 2937: tick increment greater than timeout. Difference: 799ms
# 		at index 2941: packetNum not sequentially increasing. Current: 3126, Previous: 3124
# 		at index 2941: tick increment greater than timeout. Difference: 599ms
# 		at index 2943: packetNum not sequentially increasing. Current: 3129, Previous: 3127
# 		at index 2943: tick increment greater than timeout. Difference: 600ms
# 		at index 2955: packetNum not sequentially increasing. Current: 3144, Previous: 3140
# 		at index 2955: tick increment greater than timeout. Difference: 1399ms
# 		at index 2958: packetNum not sequentially increasing. Current: 3150, Previous: 3146
# 		at index 2958: tick increment greater than timeout. Difference: 1399ms
# 		at index 2961: packetNum not sequentially increasing. Current: 3156, Previous: 3152
# 		at index 2961: tick increment greater than timeout. Difference: 1401ms
# 		at index 2972: packetNum not sequentially increasing. Current: 3168, Previous: 3166
# 		at index 2972: tick increment greater than timeout. Difference: 601ms
# 		at index 3070: packetNum not sequentially increasing. Current: 3267, Previous: 3265
# 		at index 3070: tick increment greater than timeout. Difference: 600ms
# 		at index 3149: packetNum not sequentially increasing. Current: 3348, Previous: 3345
# 		at index 3149: tick increment greater than timeout. Difference: 1000ms
# 		at index 3687: packetNum not sequentially increasing. Current: 3887, Previous: 3885
# 		at index 3687: tick increment greater than timeout. Difference: 600ms
# 		at index 3723: packetNum not sequentially increasing. Current: 3924, Previous: 3922
# 		at index 3723: tick increment greater than timeout. Difference: 599ms
# 		at index 3983: packetNum not sequentially increasing. Current: 4185, Previous: 4183
# 		at index 3983: tick increment greater than timeout. Difference: 599ms
# 		at index 3985: packetNum not sequentially increasing. Current: 4188, Previous: 4186
# 		at index 3985: tick increment greater than timeout. Difference: 600ms
# 		at index 3989: packetNum not sequentially increasing. Current: 4194, Previous: 4191
# 		at index 3989: tick increment greater than timeout. Difference: 1001ms
# 		at index 4064: packetNum not sequentially increasing. Current: 4270, Previous: 4268
# 		at index 4064: tick increment greater than timeout. Difference: 800ms
# 		at index 4072: packetNum not sequentially increasing. Current: 4281, Previous: 4277
# 		at index 4072: tick increment greater than timeout. Difference: 1400ms
# 		at index 4117: packetNum not sequentially increasing. Current: 4329, Previous: 4325
# 		at index 4117: tick increment greater than timeout. Difference: 1399ms
# 		at index 4153: packetNum not sequentially increasing. Current: 4367, Previous: 4364
# 		at index 4153: tick increment greater than timeout. Difference: 1000ms
# 		at index 4154: packetNum not sequentially increasing. Current: 4367, Previous: 4367
# 		at index 4154: packet_tick not increasing. Current: 1462490, Previous: 1462490
# 		at index 4179: packetNum not sequentially increasing. Current: 4395, Previous: 4391
# 		at index 4179: tick increment greater than timeout. Difference: 1400ms
# 		at index 4180: packetNum not sequentially increasing. Current: 4398, Previous: 4395
# 		at index 4180: tick increment greater than timeout. Difference: 999ms
# 		at index 4350: packetNum not sequentially increasing. Current: 4569, Previous: 4567
# 		at index 4350: tick increment greater than timeout. Difference: 600ms
# 		at index 4362: packetNum not sequentially increasing. Current: 4582, Previous: 4580
# 		at index 4362: tick increment greater than timeout. Difference: 801ms
# 		at index 4409: packetNum not sequentially increasing. Current: 4635, Previous: 4628
# 		at index 4409: tick increment greater than timeout. Difference: 2400ms
# 		at index 4996: packetNum not sequentially increasing. Current: 5223, Previous: 5221
# 		at index 4996: tick increment greater than timeout. Difference: 599ms
# 		at index 5001: packetNum not sequentially increasing. Current: 5229, Previous: 5227
# 		at index 5001: tick increment greater than timeout. Difference: 600ms
# 		at index 5026: packetNum not sequentially increasing. Current: 5255, Previous: 5253
# 		at index 5026: tick increment greater than timeout. Difference: 600ms
# 		at index 5027: packetNum not sequentially increasing. Current: 5259, Previous: 5255
# 		at index 5027: tick increment greater than timeout. Difference: 1400ms
# 		at index 5028: packetNum not sequentially increasing. Current: 5261, Previous: 5259
# 		at index 5028: tick increment greater than timeout. Difference: 600ms
# 		at index 5037: packetNum not sequentially increasing. Current: 5271, Previous: 5269
# 		at index 5037: tick increment greater than timeout. Difference: 600ms
# 		at index 5045: packetNum not sequentially increasing. Current: 5280, Previous: 5278
# 		at index 5045: tick increment greater than timeout. Difference: 601ms
# 		at index 5100: packetNum not sequentially increasing. Current: 5337, Previous: 5334
# 		at index 5100: tick increment greater than timeout. Difference: 1001ms
# 		at index 5221: packetNum not sequentially increasing. Current: 5459, Previous: 5457
# 		at index 5221: tick increment greater than timeout. Difference: 600ms
# 		at index 5222: packetNum not sequentially increasing. Current: 5459, Previous: 5459
# 		at index 5222: packet_tick not increasing. Current: 1826489, Previous: 1826489
# 		at index 5223: packetNum not sequentially increasing. Current: 5459, Previous: 5459
# 		at index 5223: packet_tick not increasing. Current: 1826489, Previous: 1826489
# 		at index 5589: packetNum not sequentially increasing. Current: 5826, Previous: 5824
# 		at index 5589: tick increment greater than timeout. Difference: 600ms
# 		at index 6152: packetNum not sequentially increasing. Current: 6388, Previous: 6388
# 		at index 6152: packet_tick not increasing. Current: 2136290, Previous: 2136290
# 		at index 6321: packetNum not sequentially increasing. Current: 6558, Previous: 6556
# 		at index 6321: tick increment greater than timeout. Difference: 600ms
# 		at index 6323: packetNum not sequentially increasing. Current: 6561, Previous: 6559
# 		at index 6323: tick increment greater than timeout. Difference: 600ms
# 		at index 6691: packetNum not sequentially increasing. Current: 6930, Previous: 6928
# 		at index 6691: tick increment greater than timeout. Difference: 601ms
# 		at index 6694: packetNum not sequentially increasing. Current: 6932, Previous: 6932
# 		at index 6694: packet_tick not increasing. Current: 2317490, Previous: 2317490
# 		at index 6776: packetNum not sequentially increasing. Current: 7017, Previous: 7013
# 		at index 6776: tick increment greater than timeout. Difference: 1400ms
# 		at index 6783: packetNum not sequentially increasing. Current: 7029, Previous: 7023
# 		at index 6783: tick increment greater than timeout. Difference: 2000ms
# 		at index 6785: packetNum not sequentially increasing. Current: 7035, Previous: 7030
# 		at index 6785: tick increment greater than timeout. Difference: 1600ms
# 		at index 6787: packetNum not sequentially increasing. Current: 7041, Previous: 7036
# 		at index 6787: tick increment greater than timeout. Difference: 1600ms
# 		at index 7198: packetNum not sequentially increasing. Current: 7454, Previous: 7451
# 		at index 7198: tick increment greater than timeout. Difference: 1000ms
# 		at index 7253: packetNum not sequentially increasing. Current: 7511, Previous: 7508
# 		at index 7253: tick increment greater than timeout. Difference: 1001ms
# 		at index 7254: packetNum not sequentially increasing. Current: 7513, Previous: 7511
# 		at index 7254: tick increment greater than timeout. Difference: 800ms
# 		at index 7255: packetNum not sequentially increasing. Current: 7515, Previous: 7513
# 		at index 7255: tick increment greater than timeout. Difference: 600ms
# 		at index 7269: packetNum not sequentially increasing. Current: 7530, Previous: 7528
# 		at index 7269: tick increment greater than timeout. Difference: 600ms
# 		at index 7271: packetNum not sequentially increasing. Current: 7533, Previous: 7531
# 		at index 7271: tick increment greater than timeout. Difference: 600ms
# 		at index 7273: packetNum not sequentially increasing. Current: 7536, Previous: 7534
# 		at index 7273: tick increment greater than timeout. Difference: 602ms
# 		at index 7275: packetNum not sequentially increasing. Current: 7539, Previous: 7537
# 		at index 7275: tick increment greater than timeout. Difference: 599ms
# 		at index 7330: packetNum not sequentially increasing. Current: 7596, Previous: 7593
# 		at index 7330: tick increment greater than timeout. Difference: 999ms
# 		at index 7331: packetNum not sequentially increasing. Current: 7599, Previous: 7596
# 		at index 7331: tick increment greater than timeout. Difference: 1001ms
# 		at index 7341: packetNum not sequentially increasing. Current: 7611, Previous: 7608
# 		at index 7341: tick increment greater than timeout. Difference: 1001ms
# 		at index 7368: packetNum not sequentially increasing. Current: 7641, Previous: 7637
# 		at index 7368: tick increment greater than timeout. Difference: 1400ms
# 		at index 7371: packetNum not sequentially increasing. Current: 7646, Previous: 7643
# 		at index 7371: tick increment greater than timeout. Difference: 1000ms
# 		at index 7372: packetNum not sequentially increasing. Current: 7646, Previous: 7646
# 		at index 7372: packet_tick not increasing. Current: 2555490, Previous: 2555490
# 		at index 7486: packetNum not sequentially increasing. Current: 7761, Previous: 7759
# 		at index 7486: tick increment greater than timeout. Difference: 600ms
# 		at index 7491: packetNum not sequentially increasing. Current: 7767, Previous: 7765
# 		at index 7491: tick increment greater than timeout. Difference: 596ms
# 		at index 7594: packetNum not sequentially increasing. Current: 7869, Previous: 7869
# 		at index 7594: packet_tick not increasing. Current: 2629890, Previous: 2629890
# 		at index 7595: packetNum not sequentially increasing. Current: 7878, Previous: 7869
# 		at index 7595: tick increment greater than timeout. Difference: 2999ms
# 		at index 7605: packetNum not sequentially increasing. Current: 7890, Previous: 7887
# 		at index 7605: tick increment greater than timeout. Difference: 1001ms
# 		at index 7650: packetNum not sequentially increasing. Current: 7937, Previous: 7934
# 		at index 7650: tick increment greater than timeout. Difference: 999ms
# 		at index 7652: packetNum not sequentially increasing. Current: 7941, Previous: 7938
# 		at index 7652: tick increment greater than timeout. Difference: 1000ms
# 		at index 7654: packetNum not sequentially increasing. Current: 7944, Previous: 7942
# 		at index 7654: tick increment greater than timeout. Difference: 600ms
# 		at index 7655: packetNum not sequentially increasing. Current: 7950, Previous: 7944
# 		at index 7655: tick increment greater than timeout. Difference: 1999ms
# 		at index 7657: packetNum not sequentially increasing. Current: 7953, Previous: 7951
# 		at index 7657: tick increment greater than timeout. Difference: 601ms
# 		at index 7679: packetNum not sequentially increasing. Current: 7977, Previous: 7974
# 		at index 7679: tick increment greater than timeout. Difference: 1001ms
# 		at index 7761: packetNum not sequentially increasing. Current: 8061, Previous: 8058
# 		at index 7761: tick increment greater than timeout. Difference: 999ms
# 		at index 7773: packetNum not sequentially increasing. Current: 8075, Previous: 8072
# 		at index 7773: tick increment greater than timeout. Difference: 999ms
# 		at index 7774: packetNum not sequentially increasing. Current: 8075, Previous: 8075
# 		at index 7774: packet_tick not increasing. Current: 2698489, Previous: 2698489
# 		at index 7781: packetNum not sequentially increasing. Current: 8084, Previous: 8081
# 		at index 7781: tick increment greater than timeout. Difference: 1000ms
# 		at index 7782: packetNum not sequentially increasing. Current: 8084, Previous: 8084
# 		at index 7782: packet_tick not increasing. Current: 2701489, Previous: 2701489
# 		at index 7796: packetNum not sequentially increasing. Current: 8100, Previous: 8097
# 		at index 7796: tick increment greater than timeout. Difference: 1000ms
# 		at index 7799: packetNum not sequentially increasing. Current: 8106, Previous: 8102
# 		at index 7799: tick increment greater than timeout. Difference: 1399ms
# 		at index 7868: packetNum not sequentially increasing. Current: 8178, Previous: 8174
# 		at index 7868: tick increment greater than timeout. Difference: 1399ms
# 		at index 7871: packetNum not sequentially increasing. Current: 8183, Previous: 8180
# 		at index 7871: tick increment greater than timeout. Difference: 1005ms
# 		at index 7904: packetNum not sequentially increasing. Current: 8217, Previous: 8215
# 		at index 7904: tick increment greater than timeout. Difference: 600ms
# 		at index 7942: packetNum not sequentially increasing. Current: 8256, Previous: 8254
# 		at index 7942: tick increment greater than timeout. Difference: 600ms
# 		at index 8065: packetNum not sequentially increasing. Current: 8385, Previous: 8378
# 		at index 8065: tick increment greater than timeout. Difference: 2401ms
# 		at index 8253: packetNum not sequentially increasing. Current: 8576, Previous: 8572
# 		at index 8253: tick increment greater than timeout. Difference: 1200ms
# 		at index 8254: packetNum not sequentially increasing. Current: 8576, Previous: 8576
# 		at index 8254: packet_tick not increasing. Current: 2865490, Previous: 2865490
# 		at index 8255: packetNum not sequentially increasing. Current: 8576, Previous: 8576
# 		at index 8255: packet_tick not increasing. Current: 2865490, Previous: 2865490
# 		at index 8256: packetNum not sequentially increasing. Current: 8579, Previous: 8576
# 		at index 8256: tick increment greater than timeout. Difference: 1000ms
# 		at index 8257: packetNum not sequentially increasing. Current: 8579, Previous: 8579
# 		at index 8257: packet_tick not increasing. Current: 2866490, Previous: 2866490
# 		at index 8303: packetNum not sequentially increasing. Current: 8624, Previous: 8624
# 		at index 8303: packet_tick not increasing. Current: 2881489, Previous: 2881489
# 		at index 8304: packetNum not sequentially increasing. Current: 8628, Previous: 8624
# 		at index 8304: tick increment greater than timeout. Difference: 1401ms
# 		at index 8315: packetNum not sequentially increasing. Current: 8640, Previous: 8638
# 		at index 8315: tick increment greater than timeout. Difference: 599ms
# 		at index 8350: packetNum not sequentially increasing. Current: 8676, Previous: 8674
# 		at index 8350: tick increment greater than timeout. Difference: 599ms
# 		at index 8480: packetNum not sequentially increasing. Current: 8805, Previous: 8805
# 		at index 8480: packet_tick not increasing. Current: 2941890, Previous: 2941890
# 		dropped 6260 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 26 minutes and 10.00 seconds
# 		Error (server timestamp vs tick): 0.28 seconds
# 		% drift: -0.017515929145200365
# 	watch processing...
# The size of the loaded data is 203.22083282470703 MB
# Successfully processed P13 sess3 csvs.
# ERROR WITH USER 13: No objects to concatenate

# %%
#No E4 data version
users_to_process = [13]

folder = '/Volumes/Secondary/PhDStudy_Results'

for user in users_to_process:
    try:
        #grab all sections of Session 1 for that user (glasses CSVs, each separated by task/env')
        session_data = load_session3_excel(folder, 'P' + str(user), 'sess3')
        print('Successfully processed P' + str(user) + ' sess3 csvs.')

        session_data['timings'] = process_ui_data(session_data)
        del session_data['ui']
        print('Successfully processed P' + str(user) + ' sess3 timings.')

        #save to a pickle
        with open(folder + '/P' + str(user) + '_sess3_timeseries.pickle', 'wb') as handle:
            pickle.dump(session_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
        print('Successfully saved P' + str(user) + ' session #3 data.')
        
    except Exception as e:
        print(f'ERROR WITH USER {user}: {e}')
# Out:
# /Volumes/Secondary/PhDStudy_Results/P13/P13_sess3/recording_052023_233713.csv, File size: 10.1 MB
# /Volumes/Secondary/PhDStudy_Results/P13/P13_sess3/recording_052023_235526.csv, File size: 4.6 MB
# got raw data.
# 	thermal processing...
# 		at index 121: packetNum not sequentially increasing. Current: 125, Previous: 122
# 		at index 121: tick increment greater than timeout. Difference: 12013ms
# 		at index 123: packetNum not sequentially increasing. Current: 129, Previous: 126
# 		at index 123: tick increment greater than timeout. Difference: 11999ms
# 		at index 140: packetNum not sequentially increasing. Current: 147, Previous: 145
# 		at index 140: tick increment greater than timeout. Difference: 8005ms
# 		at index 142: packetNum not sequentially increasing. Current: 150, Previous: 148
# 		at index 142: tick increment greater than timeout. Difference: 7987ms
# 		at index 148: packetNum not sequentially increasing. Current: 157, Previous: 155
# 		at index 148: tick increment greater than timeout. Difference: 7987ms
# 		at index 169: packetNum not sequentially increasing. Current: 179, Previous: 177
# 		at index 169: tick increment greater than timeout. Difference: 8008ms
# 		at index 172: packetNum not sequentially increasing. Current: 184, Previous: 181
# 		at index 172: tick increment greater than timeout. Difference: 11993ms
# 		at index 243: packetNum not sequentially increasing. Current: 256, Previous: 254
# 		at index 243: tick increment greater than timeout. Difference: 7999ms
# 		at index 246: packetNum not sequentially increasing. Current: 260, Previous: 258
# 		at index 246: tick increment greater than timeout. Difference: 7997ms
# 		at index 248: packetNum not sequentially increasing. Current: 263, Previous: 261
# 		at index 248: tick increment greater than timeout. Difference: 7999ms
# 		at index 309: packetNum not sequentially increasing. Current: 325, Previous: 323
# 		at index 309: tick increment greater than timeout. Difference: 8000ms
# 		at index 340: packetNum not sequentially increasing. Current: 357, Previous: 355
# 		at index 340: tick increment greater than timeout. Difference: 7988ms
# 		at index 347: packetNum not sequentially increasing. Current: 365, Previous: 363
# 		at index 347: tick increment greater than timeout. Difference: 8004ms
# 		at index 364: packetNum not sequentially increasing. Current: 383, Previous: 381
# 		at index 364: tick increment greater than timeout. Difference: 7994ms
# 		at index 367: packetNum not sequentially increasing. Current: 387, Previous: 385
# 		at index 367: tick increment greater than timeout. Difference: 8008ms
# 		at index 416: packetNum not sequentially increasing. Current: 437, Previous: 435
# 		at index 416: tick increment greater than timeout. Difference: 8006ms
# 		at index 564: packetNum not sequentially increasing. Current: 588, Previous: 584
# 		at index 564: tick increment greater than timeout. Difference: 16001ms
# 		at index 604: packetNum not sequentially increasing. Current: 629, Previous: 627
# 		at index 604: tick increment greater than timeout. Difference: 7992ms
# 		at index 624: packetNum not sequentially increasing. Current: 650, Previous: 648
# 		at index 624: tick increment greater than timeout. Difference: 7995ms
# 		at index 636: packetNum not sequentially increasing. Current: 663, Previous: 661
# 		at index 636: tick increment greater than timeout. Difference: 8004ms
# 		at index 638: packetNum not sequentially increasing. Current: 666, Previous: 664
# 		at index 638: tick increment greater than timeout. Difference: 8000ms
# 		at index 644: packetNum not sequentially increasing. Current: 674, Previous: 671
# 		at index 644: tick increment greater than timeout. Difference: 12000ms
# 		at index 645: packetNum not sequentially increasing. Current: 676, Previous: 674
# 		at index 645: tick increment greater than timeout. Difference: 8000ms
# 		at index 649: packetNum not sequentially increasing. Current: 681, Previous: 679
# 		at index 649: tick increment greater than timeout. Difference: 8000ms
# 		at index 666: packetNum not sequentially increasing. Current: 700, Previous: 697
# 		at index 666: tick increment greater than timeout. Difference: 12002ms
# 		at index 679: packetNum not sequentially increasing. Current: 714, Previous: 712
# 		at index 679: tick increment greater than timeout. Difference: 8019ms
# 		at index 680: packetNum not sequentially increasing. Current: 716, Previous: 714
# 		at index 680: tick increment greater than timeout. Difference: 7980ms
# 		at index 683: packetNum not sequentially increasing. Current: 721, Previous: 718
# 		at index 683: tick increment greater than timeout. Difference: 11999ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 26 minutes and 9.90 seconds
# 		Error (server timestamp vs tick): 0.13 seconds
# 		% drift: -0.008408178864895853
# 	gyro processing...
# 		at index 98: packetNum not sequentially increasing. Current: 110, Previous: 108
# 		at index 98: tick increment greater than timeout. Difference: 1242ms
# 		at index 316: packetNum not sequentially increasing. Current: 73, Previous: 71
# 		at index 316: tick increment greater than timeout. Difference: 1292ms
# 		at index 689: packetNum not sequentially increasing. Current: 191, Previous: 189
# 		at index 689: tick increment greater than timeout. Difference: 1231ms
# 		at index 783: packetNum not sequentially increasing. Current: 31, Previous: 28
# 		at index 783: tick increment greater than timeout. Difference: 1839ms
# 		at index 784: packetNum not sequentially increasing. Current: 33, Previous: 31
# 		at index 784: tick increment greater than timeout. Difference: 1189ms
# 		at index 785: packetNum not sequentially increasing. Current: 35, Previous: 33
# 		at index 785: tick increment greater than timeout. Difference: 1162ms
# 		at index 788: packetNum not sequentially increasing. Current: 41, Previous: 37
# 		at index 788: tick increment greater than timeout. Difference: 2457ms
# 		at index 790: packetNum not sequentially increasing. Current: 46, Previous: 42
# 		at index 790: tick increment greater than timeout. Difference: 2453ms
# 		at index 791: packetNum not sequentially increasing. Current: 52, Previous: 46
# 		at index 791: tick increment greater than timeout. Difference: 3709ms
# 		at index 792: packetNum not sequentially increasing. Current: 54, Previous: 52
# 		at index 792: tick increment greater than timeout. Difference: 1230ms
# 		at index 793: packetNum not sequentially increasing. Current: 57, Previous: 54
# 		at index 793: tick increment greater than timeout. Difference: 1826ms
# 		at index 794: packetNum not sequentially increasing. Current: 59, Previous: 57
# 		at index 794: tick increment greater than timeout. Difference: 1179ms
# 		at index 795: packetNum not sequentially increasing. Current: 70, Previous: 59
# 		at index 795: tick increment greater than timeout. Difference: 6957ms
# 		at index 807: packetNum not sequentially increasing. Current: 84, Previous: 81
# 		at index 807: tick increment greater than timeout. Difference: 1874ms
# 		at index 871: packetNum not sequentially increasing. Current: 150, Previous: 147
# 		at index 871: tick increment greater than timeout. Difference: 1776ms
# 		at index 873: packetNum not sequentially increasing. Current: 153, Previous: 151
# 		at index 873: tick increment greater than timeout. Difference: 1100ms
# 		at index 875: packetNum not sequentially increasing. Current: 156, Previous: 154
# 		at index 875: tick increment greater than timeout. Difference: 1373ms
# 		at index 876: packetNum not sequentially increasing. Current: 160, Previous: 156
# 		at index 876: tick increment greater than timeout. Difference: 2475ms
# 		at index 898: packetNum not sequentially increasing. Current: 183, Previous: 181
# 		at index 898: tick increment greater than timeout. Difference: 1221ms
# 		at index 902: packetNum not sequentially increasing. Current: 188, Previous: 186
# 		at index 902: tick increment greater than timeout. Difference: 1214ms
# 		at index 903: packetNum not sequentially increasing. Current: 190, Previous: 188
# 		at index 903: tick increment greater than timeout. Difference: 1231ms
# 		at index 905: packetNum not sequentially increasing. Current: 193, Previous: 191
# 		at index 905: tick increment greater than timeout. Difference: 1171ms
# 		at index 907: packetNum not sequentially increasing. Current: 196, Previous: 194
# 		at index 907: tick increment greater than timeout. Difference: 1209ms
# 		at index 913: packetNum not sequentially increasing. Current: 204, Previous: 201
# 		at index 913: tick increment greater than timeout. Difference: 1882ms
# 		at index 916: packetNum not sequentially increasing. Current: 209, Previous: 206
# 		at index 916: tick increment greater than timeout. Difference: 1996ms
# 		at index 956: packetNum not sequentially increasing. Current: 250, Previous: 248
# 		at index 956: tick increment greater than timeout. Difference: 1116ms
# 		at index 959: packetNum not sequentially increasing. Current: 255, Previous: 252
# 		at index 959: tick increment greater than timeout. Difference: 1906ms
# 		at index 960: packetNum not sequentially increasing. Current: 1, Previous: 255
# 		at index 960: tick increment greater than timeout. Difference: 1340ms
# 		at index 988: packetNum not sequentially increasing. Current: 30, Previous: 28
# 		at index 988: tick increment greater than timeout. Difference: 1347ms
# 		at index 989: packetNum not sequentially increasing. Current: 32, Previous: 30
# 		at index 989: tick increment greater than timeout. Difference: 1136ms
# 		at index 990: packetNum not sequentially increasing. Current: 34, Previous: 32
# 		at index 990: tick increment greater than timeout. Difference: 1322ms
# 		at index 1070: packetNum not sequentially increasing. Current: 115, Previous: 113
# 		at index 1070: tick increment greater than timeout. Difference: 1172ms
# 		at index 1077: packetNum not sequentially increasing. Current: 123, Previous: 121
# 		at index 1077: tick increment greater than timeout. Difference: 1140ms
# 		at index 1081: packetNum not sequentially increasing. Current: 128, Previous: 126
# 		at index 1081: tick increment greater than timeout. Difference: 1130ms
# 		at index 1093: packetNum not sequentially increasing. Current: 143, Previous: 139
# 		at index 1093: tick increment greater than timeout. Difference: 2427ms
# 		at index 1099: packetNum not sequentially increasing. Current: 151, Previous: 148
# 		at index 1099: tick increment greater than timeout. Difference: 1986ms
# 		at index 1101: packetNum not sequentially increasing. Current: 154, Previous: 152
# 		at index 1101: tick increment greater than timeout. Difference: 1218ms
# 		at index 1102: packetNum not sequentially increasing. Current: 157, Previous: 154
# 		at index 1102: tick increment greater than timeout. Difference: 1842ms
# 		at index 1103: packetNum not sequentially increasing. Current: 159, Previous: 157
# 		at index 1103: tick increment greater than timeout. Difference: 1127ms
# 		at index 1104: packetNum not sequentially increasing. Current: 161, Previous: 159
# 		at index 1104: tick increment greater than timeout. Difference: 1307ms
# 		at index 1108: packetNum not sequentially increasing. Current: 166, Previous: 164
# 		at index 1108: tick increment greater than timeout. Difference: 1228ms
# 		at index 1110: packetNum not sequentially increasing. Current: 170, Previous: 167
# 		at index 1110: tick increment greater than timeout. Difference: 1774ms
# 		at index 1112: packetNum not sequentially increasing. Current: 176, Previous: 171
# 		at index 1112: tick increment greater than timeout. Difference: 3237ms
# 		at index 1126: packetNum not sequentially increasing. Current: 191, Previous: 189
# 		at index 1126: tick increment greater than timeout. Difference: 1233ms
# 		at index 1252: packetNum not sequentially increasing. Current: 62, Previous: 60
# 		at index 1252: tick increment greater than timeout. Difference: 1196ms
# 		at index 1417: packetNum not sequentially increasing. Current: 228, Previous: 226
# 		at index 1417: tick increment greater than timeout. Difference: 1304ms
# 		at index 1606: packetNum not sequentially increasing. Current: 164, Previous: 160
# 		at index 1606: tick increment greater than timeout. Difference: 2547ms
# 		at index 1607: packetNum not sequentially increasing. Current: 166, Previous: 164
# 		at index 1607: tick increment greater than timeout. Difference: 1270ms
# 		at index 1611: packetNum not sequentially increasing. Current: 171, Previous: 169
# 		at index 1611: tick increment greater than timeout. Difference: 1281ms
# 		at index 1613: packetNum not sequentially increasing. Current: 174, Previous: 172
# 		at index 1613: tick increment greater than timeout. Difference: 1323ms
# 		at index 1619: packetNum not sequentially increasing. Current: 182, Previous: 179
# 		at index 1619: tick increment greater than timeout. Difference: 1777ms
# 		at index 1620: packetNum not sequentially increasing. Current: 185, Previous: 182
# 		at index 1620: tick increment greater than timeout. Difference: 1810ms
# 		at index 1629: packetNum not sequentially increasing. Current: 195, Previous: 193
# 		at index 1629: tick increment greater than timeout. Difference: 1180ms
# 		at index 1683: packetNum not sequentially increasing. Current: 250, Previous: 248
# 		at index 1683: tick increment greater than timeout. Difference: 1169ms
# 		at index 1727: packetNum not sequentially increasing. Current: 39, Previous: 37
# 		at index 1727: tick increment greater than timeout. Difference: 1228ms
# 		at index 1735: packetNum not sequentially increasing. Current: 46, Previous: 46
# 		at index 1735: packet_tick not increasing. Current: 1127552, Previous: 1127552
# 		at index 2022: packetNum not sequentially increasing. Current: 78, Previous: 76
# 		at index 2022: tick increment greater than timeout. Difference: 1206ms
# 		at index 2184: packetNum not sequentially increasing. Current: 243, Previous: 239
# 		at index 2184: tick increment greater than timeout. Difference: 2359ms
# 		at index 2229: packetNum not sequentially increasing. Current: 34, Previous: 31
# 		at index 2229: tick increment greater than timeout. Difference: 1891ms
# 		at index 2231: packetNum not sequentially increasing. Current: 37, Previous: 35
# 		at index 2231: tick increment greater than timeout. Difference: 1165ms
# 		at index 2232: packetNum not sequentially increasing. Current: 39, Previous: 37
# 		at index 2232: tick increment greater than timeout. Difference: 1273ms
# 		at index 2265: packetNum not sequentially increasing. Current: 73, Previous: 71
# 		at index 2265: tick increment greater than timeout. Difference: 1166ms
# 		at index 2277: packetNum not sequentially increasing. Current: 86, Previous: 84
# 		at index 2277: tick increment greater than timeout. Difference: 1276ms
# 		at index 2291: packetNum not sequentially increasing. Current: 102, Previous: 99
# 		at index 2291: tick increment greater than timeout. Difference: 1882ms
# 		at index 2414: packetNum not sequentially increasing. Current: 229, Previous: 224
# 		at index 2414: tick increment greater than timeout. Difference: 3186ms
# 		at index 2728: packetNum not sequentially increasing. Current: 32, Previous: 30
# 		at index 2728: tick increment greater than timeout. Difference: 1330ms
# 		at index 2731: packetNum not sequentially increasing. Current: 36, Previous: 34
# 		at index 2731: tick increment greater than timeout. Difference: 1211ms
# 		at index 2746: packetNum not sequentially increasing. Current: 52, Previous: 50
# 		at index 2746: tick increment greater than timeout. Difference: 1225ms
# 		at index 2750: packetNum not sequentially increasing. Current: 58, Previous: 55
# 		at index 2750: tick increment greater than timeout. Difference: 1790ms
# 		at index 2761: packetNum not sequentially increasing. Current: 70, Previous: 68
# 		at index 2761: tick increment greater than timeout. Difference: 1283ms
# 		at index 2785: packetNum not sequentially increasing. Current: 95, Previous: 93
# 		at index 2785: tick increment greater than timeout. Difference: 1216ms
# 		at index 2850: packetNum not sequentially increasing. Current: 161, Previous: 159
# 		at index 2850: tick increment greater than timeout. Difference: 1225ms
# 		at index 3051: packetNum not sequentially increasing. Current: 105, Previous: 105
# 		at index 3051: packet_tick not increasing. Current: 1948546, Previous: 1948546
# 		at index 3346: packetNum not sequentially increasing. Current: 145, Previous: 143
# 		at index 3346: tick increment greater than timeout. Difference: 1287ms
# 		at index 3361: packetNum not sequentially increasing. Current: 161, Previous: 159
# 		at index 3361: tick increment greater than timeout. Difference: 1171ms
# 		at index 3453: packetNum not sequentially increasing. Current: 255, Previous: 252
# 		at index 3453: tick increment greater than timeout. Difference: 1993ms
# 		at index 3467: packetNum not sequentially increasing. Current: 14, Previous: 12
# 		at index 3467: tick increment greater than timeout. Difference: 1237ms
# 		at index 3655: packetNum not sequentially increasing. Current: 203, Previous: 201
# 		at index 3655: tick increment greater than timeout. Difference: 1286ms
# 		at index 3700: packetNum not sequentially increasing. Current: 249, Previous: 247
# 		at index 3700: tick increment greater than timeout. Difference: 1208ms
# 		at index 3703: packetNum not sequentially increasing. Current: 254, Previous: 251
# 		at index 3703: tick increment greater than timeout. Difference: 2029ms
# 		at index 3705: packetNum not sequentially increasing. Current: 2, Previous: 255
# 		at index 3705: tick increment greater than timeout. Difference: 2028ms
# 		at index 3706: packetNum not sequentially increasing. Current: 6, Previous: 2
# 		at index 3706: tick increment greater than timeout. Difference: 2515ms
# 		at index 3964: packetNum not sequentially increasing. Current: 9, Previous: 7
# 		at index 3964: tick increment greater than timeout. Difference: 1114ms
# 		at index 3973: packetNum not sequentially increasing. Current: 19, Previous: 17
# 		at index 3973: tick increment greater than timeout. Difference: 1164ms
# 		at index 4008: packetNum not sequentially increasing. Current: 55, Previous: 53
# 		at index 4008: tick increment greater than timeout. Difference: 1180ms
# 		at index 4014: packetNum not sequentially increasing. Current: 62, Previous: 60
# 		at index 4014: tick increment greater than timeout. Difference: 1126ms
# 		at index 4029: packetNum not sequentially increasing. Current: 78, Previous: 76
# 		at index 4029: tick increment greater than timeout. Difference: 1305ms
# 		at index 4031: packetNum not sequentially increasing. Current: 81, Previous: 79
# 		at index 4031: tick increment greater than timeout. Difference: 1248ms
# 		at index 4093: packetNum not sequentially increasing. Current: 144, Previous: 142
# 		at index 4093: tick increment greater than timeout. Difference: 1351ms
# 		at index 4106: packetNum not sequentially increasing. Current: 158, Previous: 156
# 		at index 4106: tick increment greater than timeout. Difference: 1199ms
# 		at index 4150: packetNum not sequentially increasing. Current: 203, Previous: 201
# 		at index 4150: tick increment greater than timeout. Difference: 1379ms
# 		at index 4151: packetNum not sequentially increasing. Current: 206, Previous: 203
# 		at index 4151: tick increment greater than timeout. Difference: 1830ms
# 		at index 4157: packetNum not sequentially increasing. Current: 213, Previous: 211
# 		at index 4157: tick increment greater than timeout. Difference: 1291ms
# 		at index 4182: packetNum not sequentially increasing. Current: 240, Previous: 237
# 		at index 4182: tick increment greater than timeout. Difference: 1941ms
# 		at index 4184: packetNum not sequentially increasing. Current: 243, Previous: 241
# 		at index 4184: tick increment greater than timeout. Difference: 1218ms
# 		at index 4185: packetNum not sequentially increasing. Current: 246, Previous: 243
# 		at index 4185: tick increment greater than timeout. Difference: 1790ms
# 		at index 4198: packetNum not sequentially increasing. Current: 4, Previous: 2
# 		at index 4198: tick increment greater than timeout. Difference: 1191ms
# 		at index 4243: packetNum not sequentially increasing. Current: 50, Previous: 48
# 		at index 4243: tick increment greater than timeout. Difference: 1275ms
# 		at index 4250: packetNum not sequentially increasing. Current: 58, Previous: 56
# 		at index 4250: tick increment greater than timeout. Difference: 1230ms
# 		at index 4262: packetNum not sequentially increasing. Current: 71, Previous: 69
# 		at index 4262: tick increment greater than timeout. Difference: 1235ms
# 		at index 4264: packetNum not sequentially increasing. Current: 74, Previous: 72
# 		at index 4264: tick increment greater than timeout. Difference: 1315ms
# 		at index 4290: packetNum not sequentially increasing. Current: 101, Previous: 99
# 		at index 4290: tick increment greater than timeout. Difference: 1160ms
# 		at index 4303: packetNum not sequentially increasing. Current: 115, Previous: 113
# 		at index 4303: tick increment greater than timeout. Difference: 1249ms
# 		at index 4337: packetNum not sequentially increasing. Current: 150, Previous: 148
# 		at index 4337: tick increment greater than timeout. Difference: 1258ms
# 		at index 4388: packetNum not sequentially increasing. Current: 202, Previous: 200
# 		at index 4388: tick increment greater than timeout. Difference: 1411ms
# 		at index 4395: packetNum not sequentially increasing. Current: 210, Previous: 208
# 		at index 4395: tick increment greater than timeout. Difference: 1379ms
# 		at index 4404: packetNum not sequentially increasing. Current: 221, Previous: 218
# 		at index 4404: tick increment greater than timeout. Difference: 1910ms
# 		at index 4405: packetNum not sequentially increasing. Current: 226, Previous: 221
# 		at index 4405: tick increment greater than timeout. Difference: 3158ms
# 		at index 4430: packetNum not sequentially increasing. Current: 252, Previous: 250
# 		at index 4430: tick increment greater than timeout. Difference: 1216ms
# 		at index 4507: packetNum not sequentially increasing. Current: 75, Previous: 72
# 		at index 4507: tick increment greater than timeout. Difference: 2160ms
# 		at index 4532: packetNum not sequentially increasing. Current: 101, Previous: 99
# 		at index 4532: tick increment greater than timeout. Difference: 1298ms
# 		at index 4533: packetNum not sequentially increasing. Current: 103, Previous: 101
# 		at index 4533: tick increment greater than timeout. Difference: 1294ms
# 		at index 4538: packetNum not sequentially increasing. Current: 109, Previous: 107
# 		at index 4538: tick increment greater than timeout. Difference: 1178ms
# 		at index 4557: packetNum not sequentially increasing. Current: 129, Previous: 127
# 		at index 4557: tick increment greater than timeout. Difference: 1234ms
# 		at index 4627: packetNum not sequentially increasing. Current: 200, Previous: 198
# 		at index 4627: tick increment greater than timeout. Difference: 1326ms
# 		at index 4871: packetNum not sequentially increasing. Current: 189, Previous: 187
# 		at index 4871: tick increment greater than timeout. Difference: 1260ms
# 		dropped 100 rows of data due to duplication.
# 		dropped 12 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 26 minutes and 10.34 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.001655695033710906
# 	accelerometer processing...
# 		at index 476: packetNum not sequentially increasing. Current: 225, Previous: 225
# 		at index 476: packet_tick not increasing. Current: 491542, Previous: 491542
# 		at index 479: packetNum not sequentially increasing. Current: 230, Previous: 227
# 		at index 479: tick increment greater than timeout. Difference: 3061ms
# 		at index 480: packetNum not sequentially increasing. Current: 239, Previous: 230
# 		at index 480: tick increment greater than timeout. Difference: 9225ms
# 		at index 481: packetNum not sequentially increasing. Current: 243, Previous: 239
# 		at index 481: tick increment greater than timeout. Difference: 3984ms
# 		at index 482: packetNum not sequentially increasing. Current: 253, Previous: 243
# 		at index 482: tick increment greater than timeout. Difference: 9953ms
# 		at index 529: packetNum not sequentially increasing. Current: 45, Previous: 43
# 		at index 529: tick increment greater than timeout. Difference: 1952ms
# 		at index 530: packetNum not sequentially increasing. Current: 47, Previous: 45
# 		at index 530: tick increment greater than timeout. Difference: 1925ms
# 		at index 532: packetNum not sequentially increasing. Current: 51, Previous: 48
# 		at index 532: tick increment greater than timeout. Difference: 3005ms
# 		at index 549: packetNum not sequentially increasing. Current: 69, Previous: 67
# 		at index 549: tick increment greater than timeout. Difference: 1798ms
# 		at index 550: packetNum not sequentially increasing. Current: 71, Previous: 69
# 		at index 550: tick increment greater than timeout. Difference: 1939ms
# 		at index 555: packetNum not sequentially increasing. Current: 77, Previous: 75
# 		at index 555: tick increment greater than timeout. Difference: 2040ms
# 		at index 557: packetNum not sequentially increasing. Current: 80, Previous: 78
# 		at index 557: tick increment greater than timeout. Difference: 1932ms
# 		at index 584: packetNum not sequentially increasing. Current: 108, Previous: 106
# 		at index 584: tick increment greater than timeout. Difference: 2100ms
# 		at index 603: packetNum not sequentially increasing. Current: 128, Previous: 126
# 		at index 603: tick increment greater than timeout. Difference: 2014ms
# 		at index 604: packetNum not sequentially increasing. Current: 130, Previous: 128
# 		at index 604: tick increment greater than timeout. Difference: 2261ms
# 		at index 658: packetNum not sequentially increasing. Current: 186, Previous: 183
# 		at index 658: tick increment greater than timeout. Difference: 2781ms
# 		at index 659: packetNum not sequentially increasing. Current: 186, Previous: 186
# 		at index 659: packet_tick not increasing. Current: 709548, Previous: 709548
# 		at index 661: packetNum not sequentially increasing. Current: 189, Previous: 187
# 		at index 661: tick increment greater than timeout. Difference: 2007ms
# 		at index 662: packetNum not sequentially increasing. Current: 191, Previous: 189
# 		at index 662: tick increment greater than timeout. Difference: 2109ms
# 		at index 664: packetNum not sequentially increasing. Current: 194, Previous: 192
# 		at index 664: tick increment greater than timeout. Difference: 1936ms
# 		at index 666: packetNum not sequentially increasing. Current: 200, Previous: 195
# 		at index 666: tick increment greater than timeout. Difference: 4994ms
# 		at index 668: packetNum not sequentially increasing. Current: 203, Previous: 201
# 		at index 668: tick increment greater than timeout. Difference: 2111ms
# 		at index 670: packetNum not sequentially increasing. Current: 207, Previous: 204
# 		at index 670: tick increment greater than timeout. Difference: 2973ms
# 		at index 671: packetNum not sequentially increasing. Current: 211, Previous: 207
# 		at index 671: tick increment greater than timeout. Difference: 3827ms
# 		at index 672: packetNum not sequentially increasing. Current: 213, Previous: 211
# 		at index 672: tick increment greater than timeout. Difference: 2048ms
# 		at index 673: packetNum not sequentially increasing. Current: 213, Previous: 213
# 		at index 673: packet_tick not increasing. Current: 736557, Previous: 736557
# 		at index 674: packetNum not sequentially increasing. Current: 215, Previous: 213
# 		at index 674: tick increment greater than timeout. Difference: 2066ms
# 		at index 675: packetNum not sequentially increasing. Current: 219, Previous: 215
# 		at index 675: tick increment greater than timeout. Difference: 4031ms
# 		at index 684: packetNum not sequentially increasing. Current: 227, Previous: 227
# 		at index 684: packet_tick not increasing. Current: 750540, Previous: 750540
# 		at index 956: packetNum not sequentially increasing. Current: 244, Previous: 242
# 		at index 956: tick increment greater than timeout. Difference: 1928ms
# 		at index 972: packetNum not sequentially increasing. Current: 7, Previous: 3
# 		at index 972: tick increment greater than timeout. Difference: 4052ms
# 		at index 974: packetNum not sequentially increasing. Current: 12, Previous: 8
# 		at index 974: tick increment greater than timeout. Difference: 3952ms
# 		at index 978: packetNum not sequentially increasing. Current: 17, Previous: 15
# 		at index 978: tick increment greater than timeout. Difference: 1952ms
# 		at index 979: packetNum not sequentially increasing. Current: 19, Previous: 17
# 		at index 979: tick increment greater than timeout. Difference: 1839ms
# 		at index 1017: packetNum not sequentially increasing. Current: 58, Previous: 56
# 		at index 1017: tick increment greater than timeout. Difference: 2045ms
# 		at index 1042: packetNum not sequentially increasing. Current: 84, Previous: 82
# 		at index 1042: tick increment greater than timeout. Difference: 1912ms
# 		at index 1046: packetNum not sequentially increasing. Current: 89, Previous: 87
# 		at index 1046: tick increment greater than timeout. Difference: 2093ms
# 		at index 1232: packetNum not sequentially increasing. Current: 20, Previous: 18
# 		at index 1232: tick increment greater than timeout. Difference: 1891ms
# 		at index 1317: packetNum not sequentially increasing. Current: 107, Previous: 104
# 		at index 1317: tick increment greater than timeout. Difference: 3018ms
# 		at index 1318: packetNum not sequentially increasing. Current: 109, Previous: 107
# 		at index 1318: tick increment greater than timeout. Difference: 2080ms
# 		at index 1343: packetNum not sequentially increasing. Current: 135, Previous: 133
# 		at index 1343: tick increment greater than timeout. Difference: 1813ms
# 		at index 1383: packetNum not sequentially increasing. Current: 177, Previous: 174
# 		at index 1383: tick increment greater than timeout. Difference: 2956ms
# 		at index 1445: packetNum not sequentially increasing. Current: 238, Previous: 238
# 		at index 1445: packet_tick not increasing. Current: 1534492, Previous: 1534492
# 		at index 1462: tick increment greater than timeout. Difference: 1994ms
# 		at index 1735: packetNum not sequentially increasing. Current: 18, Previous: 16
# 		at index 1735: tick increment greater than timeout. Difference: 1958ms
# 		at index 2099: packetNum not sequentially increasing. Current: 127, Previous: 125
# 		at index 2099: tick increment greater than timeout. Difference: 1930ms
# 		at index 2250: packetNum not sequentially increasing. Current: 23, Previous: 21
# 		at index 2250: tick increment greater than timeout. Difference: 2016ms
# 		at index 2253: packetNum not sequentially increasing. Current: 28, Previous: 25
# 		at index 2253: tick increment greater than timeout. Difference: 2943ms
# 		at index 2254: packetNum not sequentially increasing. Current: 31, Previous: 28
# 		at index 2254: tick increment greater than timeout. Difference: 3042ms
# 		at index 2410: packetNum not sequentially increasing. Current: 188, Previous: 186
# 		at index 2410: tick increment greater than timeout. Difference: 2052ms
# 		at index 2437: packetNum not sequentially increasing. Current: 216, Previous: 214
# 		at index 2437: tick increment greater than timeout. Difference: 2015ms
# 		at index 2438: packetNum not sequentially increasing. Current: 219, Previous: 216
# 		at index 2438: tick increment greater than timeout. Difference: 2994ms
# 		at index 2526: packetNum not sequentially increasing. Current: 52, Previous: 50
# 		at index 2526: tick increment greater than timeout. Difference: 2020ms
# 		at index 2550: packetNum not sequentially increasing. Current: 77, Previous: 75
# 		at index 2550: tick increment greater than timeout. Difference: 1902ms
# 		at index 2557: packetNum not sequentially increasing. Current: 85, Previous: 83
# 		at index 2557: tick increment greater than timeout. Difference: 2261ms
# 		at index 2597: packetNum not sequentially increasing. Current: 126, Previous: 124
# 		at index 2597: tick increment greater than timeout. Difference: 1763ms
# 		at index 2598: packetNum not sequentially increasing. Current: 128, Previous: 126
# 		at index 2598: tick increment greater than timeout. Difference: 1878ms
# 		at index 2621: packetNum not sequentially increasing. Current: 152, Previous: 150
# 		at index 2621: tick increment greater than timeout. Difference: 1902ms
# 		at index 2622: packetNum not sequentially increasing. Current: 154, Previous: 152
# 		at index 2622: tick increment greater than timeout. Difference: 2027ms
# 		at index 2673: packetNum not sequentially increasing. Current: 206, Previous: 204
# 		at index 2673: tick increment greater than timeout. Difference: 1862ms
# 		at index 2677: packetNum not sequentially increasing. Current: 211, Previous: 209
# 		at index 2677: tick increment greater than timeout. Difference: 1831ms
# 		at index 2685: packetNum not sequentially increasing. Current: 221, Previous: 218
# 		at index 2685: tick increment greater than timeout. Difference: 2968ms
# 		at index 2747: packetNum not sequentially increasing. Current: 29, Previous: 26
# 		at index 2747: tick increment greater than timeout. Difference: 2975ms
# 		at index 2760: packetNum not sequentially increasing. Current: 45, Previous: 41
# 		at index 2760: tick increment greater than timeout. Difference: 4100ms
# 		at index 2763: packetNum not sequentially increasing. Current: 49, Previous: 47
# 		at index 2763: tick increment greater than timeout. Difference: 2071ms
# 		at index 2870: packetNum not sequentially increasing. Current: 158, Previous: 155
# 		at index 2870: tick increment greater than timeout. Difference: 3036ms
# 		dropped 202 rows of data due to duplication.
# 		dropped 18 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 26 minutes and 10.59 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.0020056131700658094
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 181: packetNum not sequentially increasing. Current: 198, Previous: 198
# 		at index 181: packet_tick not increasing. Current: 72890, Previous: 72890
# 		at index 311: packetNum not sequentially increasing. Current: 330, Previous: 327
# 		at index 311: tick increment greater than timeout. Difference: 996ms
# 		at index 315: packetNum not sequentially increasing. Current: 335, Previous: 333
# 		at index 315: tick increment greater than timeout. Difference: 600ms
# 		at index 591: packetNum not sequentially increasing. Current: 610, Previous: 610
# 		at index 591: packet_tick not increasing. Current: 210290, Previous: 210290
# 		at index 1435: packetNum not sequentially increasing. Current: 1455, Previous: 1453
# 		at index 1435: tick increment greater than timeout. Difference: 600ms
# 		at index 1443: packetNum not sequentially increasing. Current: 1464, Previous: 1462
# 		at index 1443: tick increment greater than timeout. Difference: 599ms
# 		at index 1445: packetNum not sequentially increasing. Current: 1467, Previous: 1465
# 		at index 1445: tick increment greater than timeout. Difference: 601ms
# 		at index 1449: packetNum not sequentially increasing. Current: 1473, Previous: 1470
# 		at index 1449: tick increment greater than timeout. Difference: 1001ms
# 		at index 1450: packetNum not sequentially increasing. Current: 1476, Previous: 1473
# 		at index 1450: tick increment greater than timeout. Difference: 999ms
# 		at index 1452: packetNum not sequentially increasing. Current: 1482, Previous: 1477
# 		at index 1452: tick increment greater than timeout. Difference: 1600ms
# 		at index 1454: packetNum not sequentially increasing. Current: 1485, Previous: 1483
# 		at index 1454: tick increment greater than timeout. Difference: 601ms
# 		at index 1455: packetNum not sequentially increasing. Current: 1491, Previous: 1485
# 		at index 1455: tick increment greater than timeout. Difference: 1999ms
# 		at index 1457: packetNum not sequentially increasing. Current: 1503, Previous: 1492
# 		at index 1457: tick increment greater than timeout. Difference: 3600ms
# 		at index 1458: packetNum not sequentially increasing. Current: 1506, Previous: 1503
# 		at index 1458: tick increment greater than timeout. Difference: 1001ms
# 		at index 1463: packetNum not sequentially increasing. Current: 1512, Previous: 1510
# 		at index 1463: tick increment greater than timeout. Difference: 600ms
# 		at index 1464: packetNum not sequentially increasing. Current: 1515, Previous: 1512
# 		at index 1464: tick increment greater than timeout. Difference: 1000ms
# 		at index 1465: packetNum not sequentially increasing. Current: 1536, Previous: 1515
# 		at index 1465: tick increment greater than timeout. Difference: 7000ms
# 		at index 1490: packetNum not sequentially increasing. Current: 1563, Previous: 1560
# 		at index 1490: tick increment greater than timeout. Difference: 1000ms
# 		at index 1606: packetNum not sequentially increasing. Current: 1680, Previous: 1678
# 		at index 1606: tick increment greater than timeout. Difference: 599ms
# 		at index 1609: packetNum not sequentially increasing. Current: 1686, Previous: 1682
# 		at index 1609: tick increment greater than timeout. Difference: 1400ms
# 		at index 1612: packetNum not sequentially increasing. Current: 1692, Previous: 1688
# 		at index 1612: tick increment greater than timeout. Difference: 1400ms
# 		at index 1614: packetNum not sequentially increasing. Current: 1698, Previous: 1693
# 		at index 1614: tick increment greater than timeout. Difference: 1600ms
# 		at index 1616: packetNum not sequentially increasing. Current: 1701, Previous: 1699
# 		at index 1616: tick increment greater than timeout. Difference: 601ms
# 		at index 1661: packetNum not sequentially increasing. Current: 1749, Previous: 1745
# 		at index 1661: tick increment greater than timeout. Difference: 1400ms
# 		at index 1669: packetNum not sequentially increasing. Current: 1760, Previous: 1756
# 		at index 1669: tick increment greater than timeout. Difference: 1200ms
# 		at index 1670: packetNum not sequentially increasing. Current: 1760, Previous: 1760
# 		at index 1670: packet_tick not increasing. Current: 593489, Previous: 593489
# 		at index 1671: packetNum not sequentially increasing. Current: 1764, Previous: 1760
# 		at index 1671: tick increment greater than timeout. Difference: 1400ms
# 		at index 1680: packetNum not sequentially increasing. Current: 1782, Previous: 1772
# 		at index 1680: tick increment greater than timeout. Difference: 3400ms
# 		at index 1682: packetNum not sequentially increasing. Current: 1788, Previous: 1783
# 		at index 1682: tick increment greater than timeout. Difference: 1601ms
# 		at index 1756: packetNum not sequentially increasing. Current: 1861, Previous: 1861
# 		at index 1756: packet_tick not increasing. Current: 627289, Previous: 627289
# 		at index 1761: packetNum not sequentially increasing. Current: 1875, Previous: 1865
# 		at index 1761: tick increment greater than timeout. Difference: 3399ms
# 		at index 1762: packetNum not sequentially increasing. Current: 1878, Previous: 1875
# 		at index 1762: tick increment greater than timeout. Difference: 1000ms
# 		at index 1810: packetNum not sequentially increasing. Current: 1929, Previous: 1925
# 		at index 1810: tick increment greater than timeout. Difference: 1400ms
# 		at index 1811: packetNum not sequentially increasing. Current: 1932, Previous: 1929
# 		at index 1811: tick increment greater than timeout. Difference: 1000ms
# 		at index 1812: packetNum not sequentially increasing. Current: 1936, Previous: 1932
# 		at index 1812: tick increment greater than timeout. Difference: 1399ms
# 		at index 1918: packetNum not sequentially increasing. Current: 2043, Previous: 2041
# 		at index 1918: tick increment greater than timeout. Difference: 601ms
# 		at index 1942: packetNum not sequentially increasing. Current: 2069, Previous: 2066
# 		at index 1942: tick increment greater than timeout. Difference: 1000ms
# 		at index 1954: packetNum not sequentially increasing. Current: 2082, Previous: 2080
# 		at index 1954: tick increment greater than timeout. Difference: 600ms
# 		at index 1968: packetNum not sequentially increasing. Current: 2097, Previous: 2095
# 		at index 1968: tick increment greater than timeout. Difference: 600ms
# 		at index 1969: packetNum not sequentially increasing. Current: 2100, Previous: 2097
# 		at index 1969: tick increment greater than timeout. Difference: 1000ms
# 		at index 1970: packetNum not sequentially increasing. Current: 2103, Previous: 2100
# 		at index 1970: tick increment greater than timeout. Difference: 1000ms
# 		at index 1971: packetNum not sequentially increasing. Current: 2106, Previous: 2103
# 		at index 1971: tick increment greater than timeout. Difference: 1000ms
# 		at index 1972: packetNum not sequentially increasing. Current: 2109, Previous: 2106
# 		at index 1972: tick increment greater than timeout. Difference: 999ms
# 		at index 1983: packetNum not sequentially increasing. Current: 2121, Previous: 2119
# 		at index 1983: tick increment greater than timeout. Difference: 600ms
# 		at index 1989: packetNum not sequentially increasing. Current: 2130, Previous: 2126
# 		at index 1989: tick increment greater than timeout. Difference: 1399ms
# 		at index 1990: packetNum not sequentially increasing. Current: 2133, Previous: 2130
# 		at index 1990: tick increment greater than timeout. Difference: 1001ms
# 		at index 1992: packetNum not sequentially increasing. Current: 2136, Previous: 2134
# 		at index 1992: tick increment greater than timeout. Difference: 600ms
# 		at index 1994: packetNum not sequentially increasing. Current: 2139, Previous: 2137
# 		at index 1994: tick increment greater than timeout. Difference: 599ms
# 		at index 1997: packetNum not sequentially increasing. Current: 2146, Previous: 2141
# 		at index 1997: tick increment greater than timeout. Difference: 1801ms
# 		at index 1998: packetNum not sequentially increasing. Current: 2148, Previous: 2146
# 		at index 1998: tick increment greater than timeout. Difference: 599ms
# 		at index 2000: packetNum not sequentially increasing. Current: 2151, Previous: 2149
# 		at index 2000: tick increment greater than timeout. Difference: 600ms
# 		at index 2006: packetNum not sequentially increasing. Current: 2160, Previous: 2156
# 		at index 2006: tick increment greater than timeout. Difference: 1400ms
# 		at index 2008: packetNum not sequentially increasing. Current: 2163, Previous: 2161
# 		at index 2008: tick increment greater than timeout. Difference: 601ms
# 		at index 2011: packetNum not sequentially increasing. Current: 2167, Previous: 2165
# 		at index 2011: tick increment greater than timeout. Difference: 803ms
# 		at index 2012: packetNum not sequentially increasing. Current: 2169, Previous: 2167
# 		at index 2012: tick increment greater than timeout. Difference: 597ms
# 		at index 2017: packetNum not sequentially increasing. Current: 2175, Previous: 2173
# 		at index 2017: tick increment greater than timeout. Difference: 600ms
# 		at index 2018: packetNum not sequentially increasing. Current: 2178, Previous: 2175
# 		at index 2018: tick increment greater than timeout. Difference: 1001ms
# 		at index 2022: packetNum not sequentially increasing. Current: 2184, Previous: 2181
# 		at index 2022: tick increment greater than timeout. Difference: 1000ms
# 		at index 2024: packetNum not sequentially increasing. Current: 2193, Previous: 2185
# 		at index 2024: tick increment greater than timeout. Difference: 2599ms
# 		at index 2034: packetNum not sequentially increasing. Current: 2204, Previous: 2202
# 		at index 2034: tick increment greater than timeout. Difference: 600ms
# 		at index 2053: packetNum not sequentially increasing. Current: 2222, Previous: 2222
# 		at index 2053: packet_tick not increasing. Current: 747489, Previous: 747489
# 		at index 2062: packetNum not sequentially increasing. Current: 2232, Previous: 2230
# 		at index 2062: tick increment greater than timeout. Difference: 601ms
# 		at index 2175: packetNum not sequentially increasing. Current: 2346, Previous: 2344
# 		at index 2175: tick increment greater than timeout. Difference: 599ms
# 		at index 2584: packetNum not sequentially increasing. Current: 2754, Previous: 2754
# 		at index 2584: packet_tick not increasing. Current: 924890, Previous: 924890
# 		at index 2873: packetNum not sequentially increasing. Current: 3045, Previous: 3042
# 		at index 2873: tick increment greater than timeout. Difference: 999ms
# 		at index 2882: packetNum not sequentially increasing. Current: 3057, Previous: 3053
# 		at index 2882: tick increment greater than timeout. Difference: 1400ms
# 		at index 2931: packetNum not sequentially increasing. Current: 3114, Previous: 3105
# 		at index 2931: tick increment greater than timeout. Difference: 3001ms
# 		at index 2937: packetNum not sequentially increasing. Current: 3121, Previous: 3119
# 		at index 2937: tick increment greater than timeout. Difference: 799ms
# 		at index 2941: packetNum not sequentially increasing. Current: 3126, Previous: 3124
# 		at index 2941: tick increment greater than timeout. Difference: 599ms
# 		at index 2943: packetNum not sequentially increasing. Current: 3129, Previous: 3127
# 		at index 2943: tick increment greater than timeout. Difference: 600ms
# 		at index 2955: packetNum not sequentially increasing. Current: 3144, Previous: 3140
# 		at index 2955: tick increment greater than timeout. Difference: 1399ms
# 		at index 2958: packetNum not sequentially increasing. Current: 3150, Previous: 3146
# 		at index 2958: tick increment greater than timeout. Difference: 1399ms
# 		at index 2961: packetNum not sequentially increasing. Current: 3156, Previous: 3152
# 		at index 2961: tick increment greater than timeout. Difference: 1401ms
# 		at index 2972: packetNum not sequentially increasing. Current: 3168, Previous: 3166
# 		at index 2972: tick increment greater than timeout. Difference: 601ms
# 		at index 3070: packetNum not sequentially increasing. Current: 3267, Previous: 3265
# 		at index 3070: tick increment greater than timeout. Difference: 600ms
# 		at index 3149: packetNum not sequentially increasing. Current: 3348, Previous: 3345
# 		at index 3149: tick increment greater than timeout. Difference: 1000ms
# 		at index 3687: packetNum not sequentially increasing. Current: 3887, Previous: 3885
# 		at index 3687: tick increment greater than timeout. Difference: 600ms
# 		at index 3723: packetNum not sequentially increasing. Current: 3924, Previous: 3922
# 		at index 3723: tick increment greater than timeout. Difference: 599ms
# 		at index 3983: packetNum not sequentially increasing. Current: 4185, Previous: 4183
# 		at index 3983: tick increment greater than timeout. Difference: 599ms
# 		at index 3985: packetNum not sequentially increasing. Current: 4188, Previous: 4186
# 		at index 3985: tick increment greater than timeout. Difference: 600ms
# 		at index 3989: packetNum not sequentially increasing. Current: 4194, Previous: 4191
# 		at index 3989: tick increment greater than timeout. Difference: 1001ms
# 		at index 4064: packetNum not sequentially increasing. Current: 4270, Previous: 4268
# 		at index 4064: tick increment greater than timeout. Difference: 800ms
# 		at index 4072: packetNum not sequentially increasing. Current: 4281, Previous: 4277
# 		at index 4072: tick increment greater than timeout. Difference: 1400ms
# 		at index 4117: packetNum not sequentially increasing. Current: 4329, Previous: 4325
# 		at index 4117: tick increment greater than timeout. Difference: 1399ms
# 		at index 4153: packetNum not sequentially increasing. Current: 4367, Previous: 4364
# 		at index 4153: tick increment greater than timeout. Difference: 1000ms
# 		at index 4154: packetNum not sequentially increasing. Current: 4367, Previous: 4367
# 		at index 4154: packet_tick not increasing. Current: 1462490, Previous: 1462490
# 		at index 4179: packetNum not sequentially increasing. Current: 4395, Previous: 4391
# 		at index 4179: tick increment greater than timeout. Difference: 1400ms
# 		at index 4180: packetNum not sequentially increasing. Current: 4398, Previous: 4395
# 		at index 4180: tick increment greater than timeout. Difference: 999ms
# 		at index 4350: packetNum not sequentially increasing. Current: 4569, Previous: 4567
# 		at index 4350: tick increment greater than timeout. Difference: 600ms
# 		at index 4362: packetNum not sequentially increasing. Current: 4582, Previous: 4580
# 		at index 4362: tick increment greater than timeout. Difference: 801ms
# 		at index 4409: packetNum not sequentially increasing. Current: 4635, Previous: 4628
# 		at index 4409: tick increment greater than timeout. Difference: 2400ms
# 		at index 4996: packetNum not sequentially increasing. Current: 5223, Previous: 5221
# 		at index 4996: tick increment greater than timeout. Difference: 599ms
# 		at index 5001: packetNum not sequentially increasing. Current: 5229, Previous: 5227
# 		at index 5001: tick increment greater than timeout. Difference: 600ms
# 		at index 5026: packetNum not sequentially increasing. Current: 5255, Previous: 5253
# 		at index 5026: tick increment greater than timeout. Difference: 600ms
# 		at index 5027: packetNum not sequentially increasing. Current: 5259, Previous: 5255
# 		at index 5027: tick increment greater than timeout. Difference: 1400ms
# 		at index 5028: packetNum not sequentially increasing. Current: 5261, Previous: 5259
# 		at index 5028: tick increment greater than timeout. Difference: 600ms
# 		at index 5037: packetNum not sequentially increasing. Current: 5271, Previous: 5269
# 		at index 5037: tick increment greater than timeout. Difference: 600ms
# 		at index 5045: packetNum not sequentially increasing. Current: 5280, Previous: 5278
# 		at index 5045: tick increment greater than timeout. Difference: 601ms
# 		at index 5100: packetNum not sequentially increasing. Current: 5337, Previous: 5334
# 		at index 5100: tick increment greater than timeout. Difference: 1001ms
# 		at index 5221: packetNum not sequentially increasing. Current: 5459, Previous: 5457
# 		at index 5221: tick increment greater than timeout. Difference: 600ms
# 		at index 5222: packetNum not sequentially increasing. Current: 5459, Previous: 5459
# 		at index 5222: packet_tick not increasing. Current: 1826489, Previous: 1826489
# 		at index 5223: packetNum not sequentially increasing. Current: 5459, Previous: 5459
# 		at index 5223: packet_tick not increasing. Current: 1826489, Previous: 1826489
# 		at index 5589: packetNum not sequentially increasing. Current: 5826, Previous: 5824
# 		at index 5589: tick increment greater than timeout. Difference: 600ms
# 		at index 6152: packetNum not sequentially increasing. Current: 6388, Previous: 6388
# 		at index 6152: packet_tick not increasing. Current: 2136290, Previous: 2136290
# 		at index 6321: packetNum not sequentially increasing. Current: 6558, Previous: 6556
# 		at index 6321: tick increment greater than timeout. Difference: 600ms
# 		at index 6323: packetNum not sequentially increasing. Current: 6561, Previous: 6559
# 		at index 6323: tick increment greater than timeout. Difference: 600ms
# 		at index 6691: packetNum not sequentially increasing. Current: 6930, Previous: 6928
# 		at index 6691: tick increment greater than timeout. Difference: 601ms
# 		at index 6694: packetNum not sequentially increasing. Current: 6932, Previous: 6932
# 		at index 6694: packet_tick not increasing. Current: 2317490, Previous: 2317490
# 		at index 6776: packetNum not sequentially increasing. Current: 7017, Previous: 7013
# 		at index 6776: tick increment greater than timeout. Difference: 1400ms
# 		at index 6783: packetNum not sequentially increasing. Current: 7029, Previous: 7023
# 		at index 6783: tick increment greater than timeout. Difference: 2000ms
# 		at index 6785: packetNum not sequentially increasing. Current: 7035, Previous: 7030
# 		at index 6785: tick increment greater than timeout. Difference: 1600ms
# 		at index 6787: packetNum not sequentially increasing. Current: 7041, Previous: 7036
# 		at index 6787: tick increment greater than timeout. Difference: 1600ms
# 		at index 7198: packetNum not sequentially increasing. Current: 7454, Previous: 7451
# 		at index 7198: tick increment greater than timeout. Difference: 1000ms
# 		at index 7253: packetNum not sequentially increasing. Current: 7511, Previous: 7508
# 		at index 7253: tick increment greater than timeout. Difference: 1001ms
# 		at index 7254: packetNum not sequentially increasing. Current: 7513, Previous: 7511
# 		at index 7254: tick increment greater than timeout. Difference: 800ms
# 		at index 7255: packetNum not sequentially increasing. Current: 7515, Previous: 7513
# 		at index 7255: tick increment greater than timeout. Difference: 600ms
# 		at index 7269: packetNum not sequentially increasing. Current: 7530, Previous: 7528
# 		at index 7269: tick increment greater than timeout. Difference: 600ms
# 		at index 7271: packetNum not sequentially increasing. Current: 7533, Previous: 7531
# 		at index 7271: tick increment greater than timeout. Difference: 600ms
# 		at index 7273: packetNum not sequentially increasing. Current: 7536, Previous: 7534
# 		at index 7273: tick increment greater than timeout. Difference: 602ms
# 		at index 7275: packetNum not sequentially increasing. Current: 7539, Previous: 7537
# 		at index 7275: tick increment greater than timeout. Difference: 599ms
# 		at index 7330: packetNum not sequentially increasing. Current: 7596, Previous: 7593
# 		at index 7330: tick increment greater than timeout. Difference: 999ms
# 		at index 7331: packetNum not sequentially increasing. Current: 7599, Previous: 7596
# 		at index 7331: tick increment greater than timeout. Difference: 1001ms
# 		at index 7341: packetNum not sequentially increasing. Current: 7611, Previous: 7608
# 		at index 7341: tick increment greater than timeout. Difference: 1001ms
# 		at index 7368: packetNum not sequentially increasing. Current: 7641, Previous: 7637
# 		at index 7368: tick increment greater than timeout. Difference: 1400ms
# 		at index 7371: packetNum not sequentially increasing. Current: 7646, Previous: 7643
# 		at index 7371: tick increment greater than timeout. Difference: 1000ms
# 		at index 7372: packetNum not sequentially increasing. Current: 7646, Previous: 7646
# 		at index 7372: packet_tick not increasing. Current: 2555490, Previous: 2555490
# 		at index 7486: packetNum not sequentially increasing. Current: 7761, Previous: 7759
# 		at index 7486: tick increment greater than timeout. Difference: 600ms
# 		at index 7491: packetNum not sequentially increasing. Current: 7767, Previous: 7765
# 		at index 7491: tick increment greater than timeout. Difference: 596ms
# 		at index 7594: packetNum not sequentially increasing. Current: 7869, Previous: 7869
# 		at index 7594: packet_tick not increasing. Current: 2629890, Previous: 2629890
# 		at index 7595: packetNum not sequentially increasing. Current: 7878, Previous: 7869
# 		at index 7595: tick increment greater than timeout. Difference: 2999ms
# 		at index 7605: packetNum not sequentially increasing. Current: 7890, Previous: 7887
# 		at index 7605: tick increment greater than timeout. Difference: 1001ms
# 		at index 7650: packetNum not sequentially increasing. Current: 7937, Previous: 7934
# 		at index 7650: tick increment greater than timeout. Difference: 999ms
# 		at index 7652: packetNum not sequentially increasing. Current: 7941, Previous: 7938
# 		at index 7652: tick increment greater than timeout. Difference: 1000ms
# 		at index 7654: packetNum not sequentially increasing. Current: 7944, Previous: 7942
# 		at index 7654: tick increment greater than timeout. Difference: 600ms
# 		at index 7655: packetNum not sequentially increasing. Current: 7950, Previous: 7944
# 		at index 7655: tick increment greater than timeout. Difference: 1999ms
# 		at index 7657: packetNum not sequentially increasing. Current: 7953, Previous: 7951
# 		at index 7657: tick increment greater than timeout. Difference: 601ms
# 		at index 7679: packetNum not sequentially increasing. Current: 7977, Previous: 7974
# 		at index 7679: tick increment greater than timeout. Difference: 1001ms
# 		at index 7761: packetNum not sequentially increasing. Current: 8061, Previous: 8058
# 		at index 7761: tick increment greater than timeout. Difference: 999ms
# 		at index 7773: packetNum not sequentially increasing. Current: 8075, Previous: 8072
# 		at index 7773: tick increment greater than timeout. Difference: 999ms
# 		at index 7774: packetNum not sequentially increasing. Current: 8075, Previous: 8075
# 		at index 7774: packet_tick not increasing. Current: 2698489, Previous: 2698489
# 		at index 7781: packetNum not sequentially increasing. Current: 8084, Previous: 8081
# 		at index 7781: tick increment greater than timeout. Difference: 1000ms
# 		at index 7782: packetNum not sequentially increasing. Current: 8084, Previous: 8084
# 		at index 7782: packet_tick not increasing. Current: 2701489, Previous: 2701489
# 		at index 7796: packetNum not sequentially increasing. Current: 8100, Previous: 8097
# 		at index 7796: tick increment greater than timeout. Difference: 1000ms
# 		at index 7799: packetNum not sequentially increasing. Current: 8106, Previous: 8102
# 		at index 7799: tick increment greater than timeout. Difference: 1399ms
# 		at index 7868: packetNum not sequentially increasing. Current: 8178, Previous: 8174
# 		at index 7868: tick increment greater than timeout. Difference: 1399ms
# 		at index 7871: packetNum not sequentially increasing. Current: 8183, Previous: 8180
# 		at index 7871: tick increment greater than timeout. Difference: 1005ms
# 		at index 7904: packetNum not sequentially increasing. Current: 8217, Previous: 8215
# 		at index 7904: tick increment greater than timeout. Difference: 600ms
# 		at index 7942: packetNum not sequentially increasing. Current: 8256, Previous: 8254
# 		at index 7942: tick increment greater than timeout. Difference: 600ms
# 		at index 8065: packetNum not sequentially increasing. Current: 8385, Previous: 8378
# 		at index 8065: tick increment greater than timeout. Difference: 2401ms
# 		at index 8253: packetNum not sequentially increasing. Current: 8576, Previous: 8572
# 		at index 8253: tick increment greater than timeout. Difference: 1200ms
# 		at index 8254: packetNum not sequentially increasing. Current: 8576, Previous: 8576
# 		at index 8254: packet_tick not increasing. Current: 2865490, Previous: 2865490
# 		at index 8255: packetNum not sequentially increasing. Current: 8576, Previous: 8576
# 		at index 8255: packet_tick not increasing. Current: 2865490, Previous: 2865490
# 		at index 8256: packetNum not sequentially increasing. Current: 8579, Previous: 8576
# 		at index 8256: tick increment greater than timeout. Difference: 1000ms
# 		at index 8257: packetNum not sequentially increasing. Current: 8579, Previous: 8579
# 		at index 8257: packet_tick not increasing. Current: 2866490, Previous: 2866490
# 		at index 8303: packetNum not sequentially increasing. Current: 8624, Previous: 8624
# 		at index 8303: packet_tick not increasing. Current: 2881489, Previous: 2881489
# 		at index 8304: packetNum not sequentially increasing. Current: 8628, Previous: 8624
# 		at index 8304: tick increment greater than timeout. Difference: 1401ms
# 		at index 8315: packetNum not sequentially increasing. Current: 8640, Previous: 8638
# 		at index 8315: tick increment greater than timeout. Difference: 599ms
# 		at index 8350: packetNum not sequentially increasing. Current: 8676, Previous: 8674
# 		at index 8350: tick increment greater than timeout. Difference: 599ms
# 		at index 8480: packetNum not sequentially increasing. Current: 8805, Previous: 8805
# 		at index 8480: packet_tick not increasing. Current: 2941890, Previous: 2941890
# 		dropped 6260 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 26 minutes and 10.00 seconds
# 		Error (server timestamp vs tick): 0.28 seconds
# 		% drift: -0.017515929145200365
# 	watch processing...
# The size of the loaded data is 203.22083282470703 MB
# Successfully processed P13 sess3 csvs.
# Successfully processed P13 sess3 timings.
# Successfully saved P13 session #3 data.

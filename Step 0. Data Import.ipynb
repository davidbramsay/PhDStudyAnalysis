# %% [markdown]
# # Data Import Script
# This script pulls in all relevant data for a session in my PhD experiment in raw form; it will process the data and save it to pickles for use.

# %%
import os
import cv2
import time
import pandas as pd
import numpy as np
import seaborn as sns
import humanize
import re
import glob
import math
import datetime
import pickle
from IPython.display import display, clear_output, HTML
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
import seaborn as sns
from csv import reader
from scipy.stats import beta
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R
from pympler import asizeof
from scipy import interpolate
from ahrs.filters import EKF
from ahrs import QuaternionArray
#%matplotlib inline
# %matplotlib widget


TIMEZONE_OFFSET = 4

# %% [markdown]
# ## E4 Data
#
# by using `df = load_session_data('Data', 'P1', 'sess1')` this script will return a df with three columns: timestamp (ns), datatype (ACC, BVP, EDA, HR, IBI,or TEMP), and data (a list of values; typically a list with one value, but for acc we have three.)
#
# This is one large df with all of the E4 data for that session.  Nicely for us, it is effectively 'done'.
#
# To get dfs for each type of data separately, we can run `df_acc = extract_datatype(df, 'ACC')`.

# %% [markdown]
# What to do with the data here?
#
# #### ACC (32 Hz, m/s^2)
#
# Accelerometer data comes in at 1/64 Gs (ints) and needs to be transformed by 1/64 g (that's equivalent to '1'; 128 should give us 2G, -128 should give us -2G).  We then multiply by 9.8m/s^2 to get a similar value to our accelerometer on the glasses.
#
# For accelerometer data at the wrist, we might want to do a few things: (1) look over a time window and make a judgement about wrist movement-- is it a lot, or a little?  We may want to use that movement as a signal for how much we should trust the other sensors, which are contact based and can be pretty corrupted by motion artifacts.
#
# We can transform these three axes of motion into a vector, and see how different it is from an estimated gravity vector (resting, some stillness assumptions, etc).  Wrist stillness *may* tell us something about focus state, but probably not too much directly unless someone was engaged passively in something.  Perhaps the most interesting thing we could draw from it are patterns in the data, which summary statistics would destroy.  We can do a self-similarity matrix-style approach to build out some statistics on patterns in the accelerometer data
#
# #### BVP (64 Hz, unitless reflectance ratio)
#
# Raw PPG signal.  We may not need to look at this really-- our preference would be to derive HR and HRV/IBI from it anyway.  Maybe there is some interesting stuff in the raw signal, but that's out of scope.  Whats probably useful (if anything) is looking to see if the raw data looks trustworthy, and to check if we trust empatica's derivation of HR and IBI.  By running our own algorithm on the raw data, we might have a sense of confidence in our results.  We can also take into consideration the Accelerometer data once it's been transformed to a simple 'magnitude of motion' measure.
#
# #### HR (1 Hz, BPM)
#
# A derived signal from the BVP, this is grabbing the anticipated HR.  We may want to assess the quality of BVP and their HR algorithm on our own to see how well they're doing; we may also want to throw away data when motion is an issue.  This derived signal lends itself easily to summary stats/time slices.
#
# #### IBI (No Hz-- get them after each detected heartbeat-- so likely between 5 and 25 Hz, milliseconds)
#
# This is a processed signal, we can probably just do some summary stats on it over various windows.  Once again it relies on the BVP raw signal.
#
# #### EDA (4 Hz, uSiemens)
#
# This is one of the signals that needs the most processing work; we typically do quite a bit of cleanup, and split out SCR (transients) from SCL (low-frequency content).  10% of users are estimated to be non-responders.  This one will require a lot of cleaning.
#
# #### TEMP (4 Hz, degrees C)
#
# No cleaning necessary for skin temperature.  We'll use it in concert with the other temperature values we've been collecting.

# %% [raw]
# E4 Processing and DF plotting functions below.  Simply loads data and creates DFs, transforms Accelerometer data to m/s^2.

# %%
def generate_timestamps(length, start_time, sample_rate):
    time_offset = np.arange(length) / sample_rate
    timestamps = pd.to_datetime(start_time, unit='s', origin='unix') + pd.to_timedelta(time_offset, unit='s') - datetime.timedelta(hours=TIMEZONE_OFFSET)
    return timestamps


def process_file(file_path, file_name):
    with open(file_path, 'r') as file:
        # only take the first timestamp
        start_time = float(file.readline().split(',')[0].strip())
        df = pd.DataFrame()
        if 'IBI' in file_name:
            data = pd.read_csv(file, header=None, names=['time', 'ibi']).values.tolist()
            df['timestamp'] = pd.to_datetime([item[0] + start_time for item in data], unit='s', origin='unix')
        else:
            sample_rate = float(file.readline().split(',')[0].strip())
            data = pd.read_csv(file, header=None).values.tolist()
            df['timestamp'] = generate_timestamps(len(data), start_time, sample_rate)
            
            if 'ACC' in file_name:
                #accelerometer data is in 1/64 Gs.  Our glasses data is in m/s^2. Transform it to m/s^2
                data = [[(i/64)*9.8 for i in l] for l in data]
        df['datatype'] = file_name.split('.')[0]
        df['data'] = data
        return df

    
def load_session_data(folder, participant_id, session_id):
    data_dir = f'{folder}/{participant_id}/{participant_id}_{session_id}'
    data_frames = []

    expected_files = ['ACC.csv', 'BVP.csv', 'EDA.csv', 'HR.csv', 'IBI.csv', 'TEMP.csv']

    #load all files, save the output of 'process_file' into data_frames
    for subdir, dirs, files in os.walk(data_dir):
        for file in files:
            if file in expected_files:
                file_path = subdir + os.sep + file
                df = process_file(file_path, file)
                data_frames.append(df)
    
    #turn data_frames into df
    final_df = pd.concat(data_frames)
    final_df.set_index('timestamp', inplace=True)
    final_df.sort_index(inplace=True)
    
    return final_df


def extract_datatype(df, datatype):
    # Filter the dataframe for the given datatype
    df_filtered = df[df['datatype'] == datatype].copy()
    
    # Determine the number of columns based on the length of the 'data' list in the first row
    num_cols = len(df_filtered['data'].iloc[0])
    
    # Create column names
    if datatype == 'ACC':
        col_names = ['x','y','z']
    else:
        col_names = ['d' + str(i + 1) for i in range(num_cols)]
    
    # Split the 'data' list into multiple columns
    df_split = pd.DataFrame(df_filtered['data'].to_list(), columns=col_names)
    
    # Add timestamp back to the dataframe
    df_split.index = df_filtered.index
    
    return df_split

def plot_df(df, title):
    fig, ax = plt.subplots(figsize=(15, 3))

    # Assuming df has timestamp as index
    for column in df.columns:
        if 'tick' not in column:
            sns.lineplot(data=df, x=df.index, y=column, ax=ax, lw=1.5)
        
    # Format the x axis
    ax.xaxis.set_major_locator(mdates.AutoDateLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

    # Set grid
    ax.grid(True, which="both", color='gray', linewidth=0.25)

    # Set title and labels
    ax.set_title(title, fontsize=14)
    ax.set_xlabel('Time', fontsize=11)
    ax.set_ylabel('Value', fontsize=11)

    # Set legend
    #ax.legend(loc='upper left', fontsize=14)

    # Set tick parameters
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    # Improve date tick display
    fig.autofmt_xdate()

    plt.show()

# %% [markdown]
# ## Glasses and Watch Data
#
# We have more work to do on the glasses data, because it doesnt come with the preprocessing completed for us.  We have:
#
# (1) Accelerometer Data.  We can use similar accelerometer code as above.
#
# (2) Gyro Data.  We can combine with Accelerometer in a Kalman filter to get a sense of head orientation.  Potentially very interesting.
#
# (3) Nose and Temple Temp and Ambient Temp/Humidity data.  These come in at different rates and have different calibrations, but once applied this is straightforward to work with (we just have to do the processing).
#
# (4) Blink data.  Potentially a lot of sophisticated stuff to pull out here, but we can just start with a simple script that has some basic hueristics about blink duration and frequency content built into it.
#
# (5) Ambient Light data.  No real hard stuff here, just gotta calibrate correctly.

# %% [raw]
# Glasses processing function below.  Simply loads data and creates session_data object (which has a session per excel file from the app).
#
# Generates timestamp indexed dfs for gyro(x/y/z rad/sec), accel(x/y/z m/s^2), blink(raw analog ~reflectance), nose/temple temp(deg C), ambient temp(deg C) and humidity(%),

# %%
def get_size_mb(obj):
    size_bytes = asizeof.asizeof(obj)
    size_mb = size_bytes / (1024 * 1024)  # Convert bytes to megabytes
    return size_mb

def interpolate_df(df, start_timestamp, end_timestamp, new_freq):
    # Calculate the total time duration of the data in seconds
    total_time = (end_timestamp-start_timestamp).total_seconds()
    
    # Create new timestamp index at the desired frequency
    new_index = pd.date_range(start=start_timestamp, periods=int(total_time * new_freq), freq=f'{1/new_freq*1000}ms')

    # Initialize new DataFrame with the new index
    df_new = pd.DataFrame(index=new_index)

    # For each column in the original DataFrame, interpolate to the new frequency
    for col in df.columns:
        # Create spline interpolator for this column
        interpolator = interpolate.interp1d(df.index.values.astype(float), df[col].values, kind='cubic')

        # Interpolate this column at the new timestamps
        df_new[col] = interpolator(new_index.values.astype(float))

    return df_new

def load_session_excel(folder, participant_id, session_id):
    
    # grab all filepaths in there, in order.
    data_dir = f'{folder}/{participant_id}/{participant_id}_{session_id}'
    filepaths = sorted(glob.glob( data_dir + '/*.csv'))
    
    session_data = []
    
    # process all of them
    for file in filepaths:
        
        print('\n\nProcessing ' + file)
        # pull out timestamp and session type
        pattern = r".*/(\d{6})_(\d{6})_p\d+_(.*).csv"
        match = re.search(pattern, file)
        
        date_str = match.group(1)
        time_str = match.group(2)
        session_type = match.group(3)
        
        # Convert the date and time to a pandas.Timestamp object
        timestamp = pd.to_datetime(date_str + time_str, format='%m%d%y%H%M%S')
        
        logs, blinks, acc, gyro, thermal, ui, wtemp, wlux = [], [], [], [], [], [], [], []

        with open(file, 'r') as read_obj:
            csv_reader = reader(read_obj)
            for row in csv_reader:
                try:
                    if   (row[0]=='l'):
                        logs.append(row[1:])
                    elif (row[0]=='g'):
                        if   (row[2]=='b'):
                            blinks.append(row[1:])
                        elif (row[2]=='t'):
                            thermal.append(row[1:])
                        elif (row[2]=='a'):
                            acc.append(row[1:])
                        elif (row[2]=='g'):
                            gyro.append(row[1:])
                    elif (row[0]=='u'):
                        ui.append(row[1:])
                    elif (row[0]=='w'):
                        if(row[3] == 'TX_TEMP_HUMD'):
                            wtemp.append(row[1:])
                        elif(row[3] == 'TX_LUX_WHITELUX'):
                            wlux.append(row[1:])
                except Exception as e:
                    print(str(e) + ': ' + str(row))

        print('got raw data.')
        
        session = {
            'user': participant_id,
            'session': session_id,
            'filepath': file,
            'session_type': session_type,
            'timestamp': timestamp,
            'logs': logs,
            'ui': ui
        }
        
        print('\tthermal processing...')
        try:
            check_raw_packets(thermal, timeout_ms=4200)
            thermal_df = pd.DataFrame()
            for t in thermal:
                thermal_df = pd.concat([thermal_df, parseThermalRow(t)], axis=0)    
            thermal_df.reset_index(inplace=True)
            thermal_df = reindex_to_timestamp(thermal_df)
            thermal_df['nose_tp_rolling'] = thermal_df['nose_tp'].rolling(7).mean()
            thermal_df['temple_tp_rolling'] = thermal_df['temple_tp'].rolling(2).mean()
            thermal_df['nose_thermistor_rolling'] = thermal_df['nose_thermistor'].rolling(40).mean()
            thermal_df['temple_thermistor_rolling'] = thermal_df['temple_thermistor'].rolling(40).mean()
            thermal_df['nose_temp_C'] = thermal_df.apply(lambda x: convert_nose_temp(x['nose_tp_rolling'], x['nose_thermistor_rolling']), axis=1)
            thermal_df['temple_temp_C'] = thermal_df.apply(lambda x: convert_temple_temp(x['temple_tp_rolling'], x['temple_thermistor_rolling']), axis=1)
            thermal_df['differential_C'] = thermal_df['nose_temp_C'] - thermal_df['temple_temp_C']
            thermal_df['differential_C_rolling'] = thermal_df['differential_C'].rolling(15).mean() 
            session['thermal']= thermal_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\tgyro processing...')
        try:
            check_raw_packets(gyro, timeout_ms=900)
            gyro_df = parse_xyz_data(gyro)
            gyro_df.reset_index(inplace=True)
            gyro_df = reindex_to_timestamp(gyro_df)
            gyro_df = gyro_df[gyro_df['x'] < 10000]
            gyro_df = gyro_df[gyro_df['y'] < 10000]
            gyro_df = gyro_df[gyro_df['z'] < 10000]

            #convert int16s to floats with q=9.
            #this gives us rad/s (angular velocity), we expect values in the 0.3-3 range.
            #Gyro set to updates every 10ms, or 100Hz
            gyro_df['x'] = gyro_df['x'].astype(float) / 512
            gyro_df['y'] = gyro_df['y'].astype(float) / 512
            gyro_df['z'] = gyro_df['z'].astype(float) / 512
            session['gyro']= gyro_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
       
        print('\taccelerometer processing...')
        try:
            check_raw_packets(acc, timeout_ms=1350)
            acc_df = parse_xyz_data(acc)
            acc_df.reset_index(inplace=True) 
            acc_df = reindex_to_timestamp(acc_df)
            acc_df = acc_df[acc_df['x'] < 10000]
            acc_df = acc_df[acc_df['y'] < 10000]
            acc_df = acc_df[acc_df['z'] < 10000]

            #convert int16s to floats with q=8.
            #this gives us data in m/s^2, so we expect ~9.8 when at rest
            #accelerometer set for every 20ms, or 50Hz
            acc_df['x'] = acc_df['x'].astype(float) / 256
            acc_df['y'] = acc_df['y'].astype(float) / 256
            acc_df['z'] = acc_df['z'].astype(float) / 256
            session['acc']= acc_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\tquaternion extended kalman filter application...')
        try:
            start_timestamp = max(acc_df.index[0], gyro_df.index[0])
            end_timestamp = min(acc_df.index[-1], gyro_df.index[-1])

            acc_inter = interpolate_df(acc_df, start_timestamp, end_timestamp, 100)
            gyro_inter = interpolate_df(gyro_df, start_timestamp, end_timestamp, 100)

            ekf = EKF(gyr=gyro_inter[['x','y','z']].values, acc=acc_inter[['x','y','z']].values, frequency=100.0)
            qs = QuaternionArray(ekf.Q)
            qs.remove_jumps()
            qs_df = pd.DataFrame({'w': qs[:,0], 'i':qs[:,1], 'j':qs[:,2], 'k':qs[:,3]}, index=acc_inter.index)
            session['quaternions']= qs_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\tblink processing...')
        try:
            check_raw_packets(blinks, timeout_ms=500)
            blinks_df = parse_blink_rows(blinks)
            blinks_df.reset_index(inplace=True)
            blinks_df = reindex_to_timestamp(blinks_df)
            session['blinks']= blinks_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\twatch processing...')
        try:
            session['watch_temp']= processWatchTemp(wtemp)
            session['watch_lux'] = processWatchLux(wlux)     
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
        
        session_data.append(session)
    
    print(f"The size of the loaded data is {get_size_mb(session_data)} MB")
    return session_data


def processWatchTemp(watch_data):
    '''Apply simple calibration to temp data based on comparison with cheap temp/humd gauge from amazon.
    Also, process the timestamp and turn it into a df'''
    
    to_df = []    
    
    for item in watch_data:
        to_df.append({
            'timestamp':pd.to_datetime(item[1]),
            'temp': 21.2 + (6.7/5.4) * (float(item[3])-24),
            'humidity': float(item[4])
        })
    
    df = pd.DataFrame(to_df)

    try:
        df['timestamp'] = df['timestamp'].dt.tz_localize(None)
        df.set_index('timestamp', inplace=True)
    except:
        print('\t\tno entries')

    return df

def processWatchLux(watch_data):
    
    to_df = []    
    for item in watch_data:
        to_df.append({
            'timestamp':pd.to_datetime(item[1]),
            'lux': float(item[3]),
            'whitelux': float(item[4])
        })
    
    df = pd.DataFrame(to_df)
    try:
        df['timestamp'] = df['timestamp'].dt.tz_localize(None)
        df.set_index('timestamp', inplace=True)
    except:
        print('\t\tno entries')
    return df

def parse_blink_rows(blinks):
    blink_rows = []
    
    for b in blinks:
        packetLength = int(b[6])
        blink_df_row = pd.DataFrame(data=[b[0:12] for i in range(packetLength)], 
                                    columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 
                                             'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4']) 
        
        
        blink_df_row["data"] = pd.Series([int(v) for v in b[13:]], dtype=np.int32)
        blinkSampleRate = 2000 # 2kHz
        blinkSamplePeriod_ms = 1000 * (1/blinkSampleRate) # 0.5 ms
        blink_df_row["tick_ms"] = blink_df_row['msFromStart'].astype(int)
        blink_df_row["tick_ms"] /= 2
        blink_df_row["tick_ms"] -= (packetLength - np.array(range(1, packetLength+1))) * blinkSamplePeriod_ms
        blink_df_row["saturated"] = blink_df_row["res0"].astype(int)
        blink_rows.append(blink_df_row)   
     
    return pd.concat(blink_rows)
 
    
def parse_xyz_data(data):
    def parseXYZRow(p):
        packetLength = 25
        base_data = p[0:12]
        other_data = np.array(p[13:]).astype('int32').reshape(-1,5)
        return [(base_data + list(row)) for row in other_data]

    data_out = []
    for d in data:
        data_out.extend(parseXYZRow(d))

    df = pd.DataFrame(data_out, columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4', 'x','y','z','imu_tick_ms','tick_ms'])
    
    df["tick_ms"] = df["tick_ms"]/2
    
    return df


def parseThermalRow(t):
    tempSamplePeriod_ms = 100
    numInnerPackets = 4
    rowsInInnerPacket = 5
    # each row has 128 values; 4x 32 value 'packets'; 
    # each 32 has 5 repetitions of 6 values of data + 2 (tick,epoch)
    # these 6 values are interleaved; i.e. the first three are temple numbers, and the first
    # 15 sets of three are temple vals; the second 15 sets of 3 are the corresponding nose vals.
    # to get a timestamped packet, we need [0,1,2] matched with [15,16,17] and so on within each
    # 32 value 'packet'.  
    
    df_row = pd.DataFrame(data=[t[0:12] for i in range(numInnerPackets*rowsInInnerPacket)], columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4']) 
    
    payload = np.array(t[13:]).astype(np.int32).reshape(numInnerPackets, -1)
    
    def flatten(t): return [item for sublist in t for item in sublist]
    reindex = flatten([[*range(i*3,i*3+3)] + [*range(15+i*3, 18+i*3)] + [-2,-1] for i in range(rowsInInnerPacket)])
    proper_payload = payload[:,reindex].reshape(-1,8)
    
    df_row = pd.concat([df_row, pd.DataFrame(data=proper_payload, columns=["temple_tp","temple_thermistor","secondary_temple_tick_ms","nose_tp","nose_thermistor","secondary_nose_tick_ms","tick_ms","epoch"])], axis=1)
    df_row['tick_ms'] -= tempSamplePeriod_ms * np.array([4,3,2,1,0] * numInnerPackets)
    
    return df_row

def convert_thermistor_to_K(raw_value):
    # STEP 1. Calc R_thermistor value given ADC_val
    R_divider = 100000
    ADC_max = 4095
    
    R_t = (R_divider * raw_value/ADC_max) / (1 - raw_value/ADC_max)
    
    # STEP 2. Convert R_t to temp
    R_0 = 100000
    T_0 = 298.15
    Beta = 3960
    R_inf = R_0 * math.exp(-Beta/T_0)
    
    Temp_K = Beta / np.log(R_t / R_inf)
    return Temp_K
    
def convert_thermopile_to_C(raw_val, T_ref_K, A, a_0, a_1):
    #STEP 1. Calc V_thermopile based on preamp gain and bias
    V_tp = (((raw_val / 4095) * 3.3) - (1.15+0.6084))/1000.0
    
    #STEP 2. Solve for Temperature!
    f_V_tp = (V_tp - a_0) + a_1 * (V_tp - a_0)**2
    T_obj = (T_ref_K**4 + f_V_tp/A)**0.25
    return (T_obj - 273.15)
    
def convert_nose_temp(raw_val, raw_thermistor):
    A   =  7.8e-10
    a_0 = -2.31e-01
    a_1 =  3.61e-03
    try:
        return convert_thermopile_to_C(raw_val, 
                                  convert_thermistor_to_K(raw_thermistor), 
                                  A, a_0, a_1)
    except:
        return np.nan
    
def convert_temple_temp(raw_val, raw_thermistor):
    A   =  4.21e-10
    a_0 = -3.62e-01
    a_1 =  8.31e-02
    try:
        return convert_thermopile_to_C(raw_val, 
                                  convert_thermistor_to_K(raw_thermistor), 
                                  A, a_0, a_1)
    except:
        return np.nan
    

def check_raw_packets(data, timeout_ms=500):
    last_seen = pd.to_datetime(data[0][0]) #0 = serverTimestamp
    last_tick = int(data[0][4]) #4 = packet_tick
    last_packet = int(data[0][3]) #3 = packetNum
    packets = set() 
    packets.add(last_packet)

    for i, d in enumerate(data[1:]):

        current_seen = pd.to_datetime(d[0])
        current_packet = int(d[3])
        current_tick = int(d[4])

        # Check if serverTimestamp is proceeding in order, which it should. 
        if current_seen < last_seen:
            print(f"\t\t-- at index {i+1}: Timestamp out of order. Current: {current_seen}, Previous: {last_seen}")

        # Check for duplicate packetNumbers by checking for the number in set packets.
        #if current_packet in packets:
        #    print(f"Error at index {i+1}: Duplicate packetNum detected. packetNum: {current_packet}")

        # Make sure packetNum is one larger than previous.
        if current_packet != last_packet + 1 and current_packet != 0:
            print(f"\t\tat index {i+1}: packetNum not sequentially increasing. Current: {current_packet}, Previous: {last_packet}")

        # Make sure tick has increased from last_tick.
        if current_tick <= last_tick:
            print(f"\t\tat index {i+1}: packet_tick not increasing. Current: {current_tick}, Previous: {last_tick}")

        # Check if the current tick is no more than 500ms greater than last tick.
        if current_tick - last_tick > timeout_ms:
            print(f"\t\tat index {i+1}: tick increment greater than timeout. Difference: {current_tick - last_tick}ms")

        # Update last_seen, last_tick, last_packet, packets
        last_seen = current_seen
        last_tick = current_tick
        last_packet = current_packet

        
        
def check_time_deltas(data):
    ''' feed in raw data after reading it into a list, this will just check
    server timestamps vs packet vs ticks and look at the differences elapsed 
    from packet to packet.  For debugging. '''
    prev_server = pd.to_datetime(data[0][0])
    prev_packet = int(data[0][3])
    prev_tick   = int(data[0][4])

    for d in data[1:200]:
        cs = pd.to_datetime(d[0])
        cp = int(d[3])
        ct = int(d[4])
        
        print(f'Differences: PACKET:{cp-prev_packet}\tSERVER:{humanize.precisedelta(cs-prev_server)}\tTICK:{(ct-prev_tick)/1000}')
        
        prev_server = cs
        prev_packet = cp
        prev_tick   = ct
        

def reindex_to_timestamp(df, column='tick_ms'):
    '''assumes a serverTS and tick_ms.  grabs first serverTS, assumes it marks 
    the tick_ms of the last row in the first packet, and then uses the tick_ms
    as the gold standard for all other timestamps'''
    
    df = df.copy()

    #make sure column is a datetime type
    df[column] = pd.to_datetime(df[column], unit='ms')
    
    # Set the first serverTS as the base timestamp
    base_timestamp = pd.to_datetime(df.loc[0, 'serverTS'])

    # Find the tick_ms of the last entry in the first packet by looking at the change in packetNum
    first_packet_num = df.loc[0, 'packetNum']
    zero_time_index = np.where(df['packetNum'].shift(-1) != first_packet_num)[0]
    
    if len(zero_time_index) > 0:
        zero_time = df.loc[zero_time_index[0], column]
    else:
        zero_time = df.loc[0, column]

    # Adjust tick_ms to get the correct offset
    df.loc[:, column] -= zero_time
    df.loc[:, column] = pd.to_timedelta(df[column], unit='ms')

    
    # Create new timestamp and set as index
    df['timestamp'] = base_timestamp + df[column]
    
    # Drop duplicates
    l = len(df)
    df.drop_duplicates(subset='timestamp', keep='first', inplace=True)
    print(f'\t\tdropped {l-len(df)} rows of data due to duplication.')
    
    # Drop data that's not within 10 sec of first and last server timestamp
    l = len(df)
    cutoff = pd.to_datetime(df.iloc[0]['serverTS']) - datetime.timedelta(seconds=10)
    df = df[df['timestamp'] > cutoff]
    cutoff = pd.to_datetime(df.iloc[-1]['serverTS']) + datetime.timedelta(seconds=10)
    df = df[df['timestamp'] < cutoff]
    print(f'\t\tdropped {l-len(df)} rows of data due to weird timestamps.')
    
    df['timestamp'] -= datetime.timedelta(hours=TIMEZONE_OFFSET)
    
    df.set_index('timestamp', inplace=True)
    
    print('\t\t-----------------------------')
    #print('\t\t-- reindexed timestamps based on first packet server timestamp and last tick_ms of first packet')
    #print('\t\t-- there is the possibility of drift with this technique; check that these values of the')
    #print('\t\t-- final packet are roughly in sync.')
    #print('\t\t-- First server time: ' + pd.to_datetime(df['serverTS'].iloc[0]).time().isoformat())
    #print('\t\t-- Last server time: ' + pd.to_datetime(df['serverTS'].iloc[-1]).time().isoformat())
    #print('\t\t-- First timestamp: ' + df.index[0].time().isoformat())
    #print('\t\t-- Last timestamp: ' + df.index[-1].time().isoformat())
    #print('\t\t-- Duration serverTS:  ' + humanize.precisedelta(pd.to_datetime(df['serverTS'].iloc[-1])-pd.to_datetime(df['serverTS'].iloc[0])))
    #print('\t\t-- Duration timestamp: ' + humanize.precisedelta(df.index[-1]-df.index[0]))
    print('\t\tDuration: ' + humanize.precisedelta(df.index[-1]-df.index[0]))
    print('\t\tError (server timestamp vs tick): ' + humanize.precisedelta(pd.to_datetime(df['serverTS'].iloc[-1]) - df.index[-1] - datetime.timedelta(hours=TIMEZONE_OFFSET)))
    print('\t\t% drift: ' + str(100.0*(pd.to_datetime(df['serverTS'].iloc[-1]) - df.index[-1] - datetime.timedelta(hours=TIMEZONE_OFFSET))/(df.index[-1]- df.index[0])))
     
    df.drop([column, 'serverTS', 'msFromStart','index','packetTypeLetter','packetType','packetNum','epoch','packetSize','res0','res1','res2','res3','res4'], axis=1, inplace=True)

    return df

# %% [raw]
# Functions to chop up and append E4 to session data extracted from glasses is below.

# %%
def chop_df(df, taskbounds):
    """
    This function filters a dataframe based on the provided start and end times.
    The dataframe should have timestamps as the index.
    
    Args:
        df (pd.DataFrame): Input dataframe with timestamps as the index.
        taskbounds: Tuple of (start_time, end_time), where each is an (np.datetime64)
        
    Returns:
        pd.DataFrame: A new dataframe with only the data between the provided start and end times.
    """
    start_time, end_time = taskbounds
    
    start_time = pd.to_datetime(start_time).replace(tzinfo=None)
    end_time = pd.to_datetime(end_time).replace(tzinfo=None)

    # Filter the dataframe
    df_filtered = df[(df.index >= start_time) & (df.index <= end_time)]

    return df_filtered


#process E4 data into sessions
def update_sessions_with_E4_data(session_data, folder, user, session):
    
    #load E4 data
    df = load_session_data(folder, 'P' + str(user), 'sess' + str(session))
    
    df_names = ['ACC', 'IBI', 'TEMP', 'EDA', 'BVP', 'HR']
    
    #iterate over each data_type in the E4 session
    for df_type in df_names:
        
        #get just that data
        df_temp = extract_datatype(df, df_type)
        
        #now iterate over sessions in session_data
        for i, session in enumerate(session_data):
            
            try:
                #grab start/end timestamps; let's base it on blink data, which is sampled the fastest
                start_time = session['blinks'].index[0]
                end_time = session['blinks'].index[-1]

                #grab just the relevant section for this session of this datatype and append it into the session_data
                session_data[i]['E4_' + df_type] = chop_df(df_temp, (start_time, end_time))
            except Exception as e:
                print(f'Failed to add E4 {df_type} for session {session["session_type"]}')
                print(e)

# %% [markdown]
# ## Behavioral and Survey Data
#
# We need to process some data that will be useful for us to make estimates about what's going on here.  Below we'll start to group the data from the surveys by section:
#
# These have specific ways to process.
#
# - standard flow test data for each section (FSS, etc)
# - standard wellbeing questionaire
# - standard TAS (absorption trait)
#
# These do not:
# - standard affect (affect model of flow) -- alertness and valence, reaction times, stress (interesting work to look at alertness vs. reaction time).
# - free text answers about caffeine, life, stress, factors that matter that we're not measuring.
# - enjoyment of tetris, enjoyment of games, self-perceived skill
#
# Things that are going to get interesting to model and definitely don't have prior art for processing them:
#
# - time perception data (durations, clock time, confidence)
# - duration voluntarily continuing the task
# - duration until noticing of light
# - additional flow datapoints, including the drawn data.
#
# In this section, we'll just organize the data.

# %% [raw]
# Survey Data Processing functions below.

# %%
#All combined

def get_user_entrance_responses(folder, user):
    '''grab the entrance survey results from google form csv'''
    
    df = pd.read_csv(folder + '/Flow_Entrance_Survey.csv')

    # Filter DataFrame to get row of specified user  
    user_row = df[df['Participant number (from the email you received):'] == user]
    
    # Ignore the timestamp and participant ID column
    user_responses = user_row.iloc[:, 2:].values.tolist()
    
    # user_responses is a list of lists, we flatten it to a single list
    user_responses = [item for sublist in user_responses for item in sublist]
    
    
    survey_data = {}
    
    #TAS : scale 1-5
    TAS_responses = user_responses[21:55]
    #BIT : scale 1-7
    BIT_responses = [v* 5 / 7 for v in user_responses[55:65]]
    del user_responses[21:65]
    #Flow Desc : Y/N
    FlowDesc_responses = user_responses[11:17]
    del user_responses[11:17]
    
    #CODE TAS
    #TAS just sum for likert 5 point version
    # based on prior work, avg ~80, std-dev ~18 (Glisky et al., 1991, Studies 2 and 3)
    survey_data['TAS'] = sum(TAS_responses)
    survey_data['TAS_stdevs'] = (sum(TAS_responses) - 80) / 18.0
    #CODE BIT
    BIT_codes = [
     'Support', 
     'Belonging',
     'Flow',
     'Accomplishment',
     'Self-efficacy',
     'Self-worth',
     'Meaning and Purpose',
     'Optimism',
     'Life Satisfaction',
     'Positive Affect'
    ]    
    strengths, weaknesses = [],[]

    for i, v in enumerate(BIT_responses):
        if v > 4.2:
            strengths.append(BIT_codes[i])
        elif v < 3.3:
            weaknesses.append(BIT_codes[i])

    BIT_mean = np.mean(BIT_responses)
    BIT_std = np.std(BIT_responses)
    print(f'BIT CODING:\t{BIT_mean:.2f} with std {BIT_std:.2f}', end='')

    if BIT_mean > 4.2:
            print(' -- DESIGNATED "STRONG"')
    elif BIT_std < 3.3:
            print(' -- DESIGNATED "AT RISK"')

    print(f'\t\t{len(strengths)} BIT STRENGTHS:\n\t\t {strengths}')
    print(f'\t\t{len(weaknesses)} BIT WEAKNESSES:\n\t\t {weaknesses}')

    survey_data['BIT_score'] = BIT_mean
    survey_data['BIT_std'] = BIT_std
    survey_data['BIT_strengths'] = strengths
    survey_data['BIT_weaknesses'] = weaknesses
    
    
    #CODE FQ
    s_score, d_score = 0, 0
    
    for r in FlowDesc_responses[:3]:
        if r == 'Yes':
            s_score +=1
    for r in FlowDesc_responses[3:]:
        if r == 'Yes':
            d_score +=1
    
    print(f'FLOW DESC:\tshallow: {s_score}\tdeep: {d_score}')
    survey_data['shallowFQ'] = s_score
    survey_data['deepFQ'] = d_score
    
    #remaining responses
    resp_keys = ['sex', 'job', 'typical_day', 'focus_best', 
     'vidgame_experience', 'vidgame_enjoy_1to7', 'vidgame_experience', 'vidgame_favtypes',
     'tetris_experience',  'tetris_enjoy_1to7',  'tetris_experience', 'flow_experiences',
     'flow_freq', 'flow_reliability', 'flow_recognition', 'flow_activity']
    
    for i, k in enumerate(resp_keys):
        survey_data[k] = user_responses[i]
        
    return survey_data


def get_user_exit_responses(folder, user):
    '''get user results for the final session, hand coded from their booklet into Final_PhD_Survey_Results.csv'''
    
    df = pd.read_csv(folder + '/Final_PhD_Survey_Results.csv')

    questions = list(df['Question'].values)
    user_responses = list(df['P' + str(user)].values)
    
    survey_data = {}
    
    #BIT : scale 1-7
    BIT_responses = [(int(v)+1)* 5 / 7 for v in user_responses[39:49]]
    del questions[39:49]
    del user_responses[39:49]
    #Flow Desc : Y/N
    FlowDesc_responses = user_responses[26:32]
    del questions[26:32]
    del user_responses[26:32]
    
    #CODE BIT
    BIT_codes = [
     'Support', 
     'Belonging',
     'Flow',
     'Accomplishment',
     'Self-efficacy',
     'Self-worth',
     'Meaning and Purpose',
     'Optimism',
     'Life Satisfaction',
     'Positive Affect'
    ]    
    strengths, weaknesses = [],[]

    for i, v in enumerate(BIT_responses):
        if v > 4.2:
            strengths.append(BIT_codes[i])
        elif v < 3.3:
            weaknesses.append(BIT_codes[i])

    BIT_mean = np.mean(BIT_responses)
    BIT_std = np.std(BIT_responses)
    print(f'BIT CODING:\t{BIT_mean:.2f} with std {BIT_std:.2f}', end='')

    if BIT_mean > 4.2:
            print(' -- DESIGNATED "STRONG"')
    elif BIT_std < 3.3:
            print(' -- DESIGNATED "AT RISK"')

    print(f'\t\t{len(strengths)} BIT STRENGTHS:\n\t\t {strengths}')
    print(f'\t\t{len(weaknesses)} BIT WEAKNESSES:\n\t\t {weaknesses}')

    survey_data['BIT_score'] = BIT_mean
    survey_data['BIT_std'] = BIT_std
    survey_data['BIT_strengths'] = strengths
    survey_data['BIT_weaknesses'] = weaknesses
    
    #CODE FQ
    s_score, d_score = 0, 0
    
    for r in FlowDesc_responses[:3]:
        if r == 'y':
            s_score +=1
    for r in FlowDesc_responses[3:]:
        if r == 'y':
            d_score +=1
    
    print(f'FLOW DESC:\tshallow: {s_score}\tdeep: {d_score}')
    survey_data['shallowFQ'] = s_score
    survey_data['deepFQ'] = d_score
    
    #remaining responses
    
    resp_keys = ['durGuess','durTimeConfidence','guessTime','guessTimeConfidence','timeExp',
    'focus','effort','deepest','flow','durFlow','durToFlow','percentFlow',
    'flowDesc','flowQ1','flowQ2','flowQ3','flowQ4','FSS1','FSS2','FSS3','FSS4',
    'FSS5','FSS6','FSS7','FSS8','FSS9','nowAlertness','nowStress','nowEmotion',
    'nowEmoIntensity','written_description','written_food_caff_exercise_sleep',
    'written_other_relevant','written_comments','written_homevlab','written_timechoice',
    'written_iphonepaper','written_observed','written_naturalwearables']
    #missing (obviously) timeAtGuess and timeAtDurGuess.  We'll use the last timestamp of the wearables for the time at guess.
    #we don't really care about the timeAtDurGuess (just use duration of flow activity-- we do care about timeAtGuess.

    
    for i, k in enumerate(resp_keys):
        survey_data[k] = user_responses[i]
        
    return survey_data


def process_ui_data(data, user):
    '''process the ui data from the session_data into a DF of important timestamps and a dictionary of survey data'''
    
    SURVEY_NAMES = ['LabStartSurvey', 
                    'LabMid1Survey', 
                    'LabMidActivitySurvey', 
                    'LabMid2Survey', 
                    'LabFinalSurvey',
                    'HomeStartSurvey', 
                    'HomeMidSurvey', 
                    'HomeMidActivitySurvey',  
                    'HomeFinalSurvey']          
                    
    # Define lists for two dataframes
    timestamps = []
    surveys = {}
    current_survey = 'UNKNOWN'
    # Traverse through data
    for row in data:
        if row[2] in ['START_TEST', 'STOP_TEST', 'START_TRANSITION', 'FINISHED_TRANSITION', 'NOTICED']:
            timestamps.append([pd.to_datetime(row[0])-datetime.timedelta(hours=TIMEZONE_OFFSET), row[2]])
        elif row[2] == 'SURVEY':
            if 'empaticaStartTime' == row[3]:
                timestamps.append([pd.to_datetime(row[4]+row[5]), 'EMPATICA_START_TIME'])
            elif 'empaticaEndTime' == row[3]:
                timestamps.append([pd.to_datetime(row[4]+row[5]), 'EMPATICA_END_TIME'])
            elif 'recordingStartTime' == row[3]:
                timestamps.append([pd.to_datetime(row[4]+row[5]), 'RECORDING_START_TIME'])
            elif row[4] in SURVEY_NAMES:
                timestamps.append([pd.to_datetime(int(row[3]), unit='ms')-datetime.timedelta(hours=TIMEZONE_OFFSET), 'START_SURVEY'])
                current_survey = row[4]
                surveys[current_survey]={}
            else:
                try:
                    surveys[current_survey][row[3]] = (row[4] if len(row)==5 else row[4:])
                except:
                    print(f'GOT unknown survey: {row}')
    
    # Create dataframes
    df_times = pd.DataFrame(timestamps, columns=['timestamp', 'event'])
    df_times['timestamp'] = pd.to_datetime(df_times['timestamp'], utc=True)
    df_times['timestamp'] = df_times['timestamp'].dt.tz_localize(None)
    df_times.set_index('timestamp', inplace=True)

    for s in surveys:
        print('\t>> processing ' + s)
        surveys[s] = codeBIT(surveys[s])
        surveys[s] = codeFlowDesc(surveys[s])
        print(surveys[s])
        surveys[s] = transformFlowPathPlot(surveys[s], folder, 'P' + str(user) + s)
        
    return df_times, surveys


def codeBIT(survey_data):
    BIT_codes = {
     'BIT0':'Support', 
     'BIT1':'Belonging',
     'BIT2':'Flow',
     'BIT3':'Accomplishment',
     'BIT4':'Self-efficacy',
     'BIT5':'Self-worth',
     'BIT6':'Meaning and Purpose',
     'BIT7':'Optimism',
     'BIT8':'Life Satisfaction',
     'BIT9':'Positive Affect'
    }
    
    all_items=[]
    strengths = []
    weaknesses = []
    
    try:
        for k in BIT_codes.keys():
            score = (int(survey_data[k]) + 1) * 5 / 7
            all_items.append(score)
            if score > 4.2:
                strengths.append(BIT_codes[k])
            elif score < 3.3:
                weaknesses.append(BIT_codes[k])

        BIT_mean = np.mean(all_items)
        BIT_std = np.std(all_items)

        print(f'BIT CODING:\t{BIT_mean:.2f} with std {BIT_std:.2f}', end='')

        if BIT_mean > 4.2:
                print(' -- DESIGNATED "STRONG"')
        elif BIT_std < 3.3:
                print(' -- DESIGNATED "AT RISK"')
                
        print(f'\t\t{len(strengths)} BIT STRENGTHS:\n\t\t {strengths}')
        print(f'\t\t{len(weaknesses)} BIT WEAKNESSES:\n\t\t {weaknesses}')
        
        survey_data['BIT_score'] = BIT_mean
        survey_data['BIT_std'] = BIT_std
        survey_data['BIT_strengths'] = strengths
        survey_data['BIT_weaknesses'] = weaknesses
        
    except:
        print('No BIT Detected')
    
    return survey_data


def codeFlowDesc(survey_data):
    ''' we need all data across all sessions in order to properly z-score flow data.
    instead of doing anything, we'll just process the one bit of data we need to
    preprocess, which is the flowDesc.
    '''
    shallow_flow = ['flowDescA','flowDescB','flowDescC']
    deep_flow = ['flowDescD','flowDescE','flowDescF']
    
    s_score = 0
    d_score = 0
    
    try:
        for k in shallow_flow:
            if survey_data[k] == 'true':
                s_score += 1
        for k in deep_flow:
            if survey_data[k] == 'true':
                d_score += 1
        
        print(f'FLOW DESC:\tshallow: {s_score}\tdeep: {d_score}')
        survey_data['shallowFQ'] = s_score
        survey_data['deepFQ'] = d_score
            
    except:
        print('No Flow Desc Detected')

    return survey_data


def transformFlowPathPlot(survey_data, folder, filename):
    
    try:
        xy = survey_data['flowPath']
        canvassize = survey_data['flowCanvasSize']
    except:
        print('No flow path data')
        return survey_data
    
    if xy=='':
        print('No flow path data')
        return survey_data
    
    xy_float = [float(i) for i in xy]

    # Create list of dictionaries representing coordinates
    coordinates = [{'x': xy_float[i], 'y': xy_float[i + 1]} for i in range(0, len(xy_float), 2)]

    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(coordinates)

    # Define the size of the plot to match your canvas size (converted to inches)
    fig, ax = plt.subplots(figsize=(float(canvassize[0]) / 40, float(canvassize[1]) / 40))

    # Create the scatterplot
    sns.lineplot(data=df, x='x', y='y', lw=5, ax=ax)
    
    # Set title and labels
    plt.title('Flow Drawing', fontsize=12)
    #plt.set_xlabel('Time', fontsize=22)
    #plt.set_ylabel('Value', fontsize=22)
    
    ax.set_xticks([0, 5, float(canvassize[0])-5, float(canvassize[0])])
    ax.set_xticklabels(['','Start of Activity', 'End of Activity',''], fontsize=8)
    ax.set_yticks([0, 2, float(canvassize[1])/2, float(canvassize[1])-2, float(canvassize[1])])
    ax.set_yticklabels(['','Distracted', 'Light Focus', 'Deep Focus',''], fontsize=10)

    # Add x and y labels
    ax.set_xlabel('Time', fontsize=8)
    
    plt.xlim([0, 327.5])
    plt.ylim([0, 100])
    
    # Invert the y axis to match the typical screen/canvas coordinate system
    ax.invert_yaxis()

    # Remove tick marks
    plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, left=False, right=False, labelleft=False)

    survey_data['flowDrawing'] = folder + '/Flow_Drawings/' + filename + '.png'
    plt.savefig(survey_data['flowDrawing'], dpi=300)
    plt.close()
    
    print('SAVED ' + survey_data['flowDrawing'])
    
    return survey_data 


def clean_survey_types(session_data):

    #iterate over sessions
    for i, session in enumerate(session_data):
        #iterate over surveys in this session
        if 'surveys' in session:
            for survey in session['surveys']:
                print(f'Cleaning survey {survey}')
                clean_survey(session['surveys'][survey])

    
def clean_survey(survey): 
    #all out of seven EXCEPT nowEmotion and nowEmoIntensity, which are 5 for SAM
    #all start as zero indexed, move to one indexed
    likert_ints = ['FSS', 'flowQ', 'now', 'timeExp', 'focus', 'effort', 'deepest']        

    #these are one indexed and have a map in the data (except percentFlow/duration/durGuess, which are just mapped directly to an int
    map_ints = ['durFlow', 'durTimeConfidence', 'guessTimeConfidence', 'percentFlow', 'duration', 'durGuess']

    times = ['LastSeenTimeStartSurvey','actualTimeAtDuration','startSurveyTime','timeAtDurGuess','timeAtGuess']

    try:
        d = survey['timeAtGuess'][0]
    except:
        pass
    
    #iterate over each key in this survey
    for k in survey.keys():
        try:
            if k == 'reactionTimesMs':
                survey['reactionTimesMs'] = [int(t) for t in survey['reactionTimesMs']]
            elif k in map_ints:
                survey[k] = int(survey[k])
            elif k in times:
                survey[k] = datetime.datetime.strptime(''.join(survey[k]), '%m/%d/%Y %I:%M:%S %p')
            elif k == 'guessTime':
                try:
                    survey['guessTime'] = datetime.datetime.strptime(d + ' ' + survey['guessTime'], '%m/%d/%Y %I:%M %p')
                except:
                    print('Failed on guessTime; no timeAtGuess date to transform')
            else:
                #iterate over likert_ints, because some are partial names
                for st in likert_ints:
                    #with partial match to k
                    if st in k:
                        #match plus 1
                        survey[k] = int(survey[k])+1
        except:
            print(f'\tfailed on {k} with value {survey[k]}')

def process_surveys(folder, user, session_data):
 
    entrance_survey, exit_survey = {}, {}
    
    print('='*10 + ' Entrance Survey Processing')
    try:
        entrance_survey = get_user_entrance_responses(folder, user)
        print('GOT ENTRANCE SURVEY: ' + str(entrance_survey))
        clean_survey(entrance_survey)
    except Exception as e:
        print(e)
        print('NO ENTRANCE SURVEY FOR THIS PARTICIPANT!!!')
 
    print('='*10 + ' Exit Survey Processing')
    try:
        exit_survey = get_user_exit_responses(folder, user)
        print('GOT EXIT SURVEY: ' + str(exit_survey))
        clean_survey(exit_survey)
    except Exception as e:
        print(e)
        print('NO EXIT SURVEY FOR THIS PARTICIPANT!!!')

        
    for session in session_data:
        try:
            print('='*10, end=' ')
            print(f"Processing session {session['timestamp']} {session['user']} {session['session']} {session['session_type']}")
            df_times, survey_results = process_ui_data(session['ui'], user)
            print(df_times)
            print('GOT UI survey results: ' + str(survey_results))
            del session['ui']
            session['surveys'] = survey_results
            session['timings'] = df_times
        except Exception as e:
            print(e)
            print('FAILED SESSION PROCESSING')
            
    clean_survey_types(session_data)
    
    return session_data, entrance_survey, exit_survey
    return session_data, entrance_survey, exit_survey

# %% [markdown]
# # Runs the above scripts to generate our data!!

# %%
users_to_process = [9, 15]
folder = 'Data'

for user in users_to_process:
    #grab all sections of Session 1 for that user (glasses CSVs, each separated by task/env')
    session_data = load_session_excel(folder, 'P' + str(user), 'sess1')
    update_sessions_with_E4_data(session_data, folder, user, 1)
    
    #grab all sections of Session 2
    sess2_data = load_session_excel(folder, 'P' + str(user), 'sess2')
    update_sessions_with_E4_data(sess2_data, folder, user, 2)
        
    #combine into one
    session_data.extend(sess2_data)
    
    #process the survey data for each session
    session_data, entrance, exit = process_surveys(folder, user, session_data)
    
    #save to a pickle
    with open(folder + '/P' + str(user) + '_Processed.pickle', 'wb') as handle:
        pickle.dump((session_data, entrance, exit), handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Processing Data/P9/P9_sess1/042123_103001_p9_LAB_DEMO.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 7 minutes and 25.90 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.0033639829558196905
# 	gyro processing...
# 		dropped 55 rows of data due to duplication.
# 		dropped 20 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 7 minutes and 25.91 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 0.00033639150589021526
# 	accelerometer processing...
# 		dropped 21 rows of data due to duplication.
# 		dropped 4 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 7 minutes and 25.41 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 0.0006735359853438569
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		dropped 245 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 7 minutes and 26.00 seconds
# 		Error (server timestamp vs tick): 0.31 seconds
# 		% drift: -0.06894634292902002
# 	watch processing...
#
#
# Processing Data/P9/P9_sess1/042123_103726_p9_LAB_TETRIS.csv
# list index out of range: []
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 10 minutes and 47.90 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.004167309770026238
# 	gyro processing...
# 		dropped 69 rows of data due to duplication.
# 		dropped 30 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 10 minutes and 48.40 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: 0.0034700561146629922
# 	accelerometer processing...
# 		at index 1233: packetNum not sequentially increasing. Current: 75, Previous: 73
# 		at index 1233: tick increment greater than timeout. Difference: 1995ms
# 		dropped 10 rows of data due to duplication.
# 		dropped 15 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 10 minutes and 48.71 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.002851800410967562
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 3714: packetNum not sequentially increasing. Current: 8663, Previous: 8663
# 		at index 3714: packet_tick not increasing. Current: 2894484, Previous: 2894484
# 		dropped 575 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 10 minutes and 48.00 seconds
# 		Error (server timestamp vs tick): 0.25 seconds
# 		% drift: -0.03888891889577075
# 	watch processing...
#
#
# Processing Data/P9/P9_sess1/042123_104815_p9_TETRIS_CONTD.csv
# got raw data.
# 	thermal processing...
# 		at index 313: packetNum not sequentially increasing. Current: 1051, Previous: 1049
# 		at index 313: tick increment greater than timeout. Difference: 7992ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 31 minutes and 15.90 seconds
# 		Error (server timestamp vs tick): 0.16 seconds
# 		% drift: -0.008689162535316382
# 	gyro processing...
# 		at index 714: packetNum not sequentially increasing. Current: 123, Previous: 123
# 		at index 714: packet_tick not increasing. Current: 3388512, Previous: 3388512
# 		at index 905: packetNum not sequentially increasing. Current: 57, Previous: 57
# 		at index 905: packet_tick not increasing. Current: 3504547, Previous: 3504547
# 		at index 2051: packetNum not sequentially increasing. Current: 180, Previous: 178
# 		at index 2051: tick increment greater than timeout. Difference: 1229ms
# 		at index 2052: packetNum not sequentially increasing. Current: 184, Previous: 180
# 		at index 2052: tick increment greater than timeout. Difference: 2655ms
# 		at index 2053: packetNum not sequentially increasing. Current: 187, Previous: 184
# 		at index 2053: tick increment greater than timeout. Difference: 1880ms
# 		at index 2054: packetNum not sequentially increasing. Current: 190, Previous: 187
# 		at index 2054: tick increment greater than timeout. Difference: 1766ms
# 		at index 2055: packetNum not sequentially increasing. Current: 193, Previous: 190
# 		at index 2055: tick increment greater than timeout. Difference: 2044ms
# 		at index 4004: packetNum not sequentially increasing. Current: 95, Previous: 93
# 		at index 4004: tick increment greater than timeout. Difference: 1254ms
# 		at index 4075: packetNum not sequentially increasing. Current: 167, Previous: 165
# 		at index 4075: tick increment greater than timeout. Difference: 1359ms
# 		dropped 189 rows of data due to duplication.
# 		dropped 34 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 31 minutes and 14.55 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.0010935952129336572
# 	accelerometer processing...
# 		at index 549: packetNum not sequentially increasing. Current: 172, Previous: 170
# 		at index 549: tick increment greater than timeout. Difference: 1955ms
# 		at index 1247: packetNum not sequentially increasing. Current: 104, Previous: 101
# 		at index 1247: tick increment greater than timeout. Difference: 2935ms
# 		at index 1248: packetNum not sequentially increasing. Current: 106, Previous: 104
# 		at index 1248: tick increment greater than timeout. Difference: 1872ms
# 		at index 1249: packetNum not sequentially increasing. Current: 108, Previous: 106
# 		at index 1249: tick increment greater than timeout. Difference: 1911ms
# 		at index 1250: packetNum not sequentially increasing. Current: 112, Previous: 108
# 		at index 1250: tick increment greater than timeout. Difference: 3990ms
# 		at index 2019: packetNum not sequentially increasing. Current: 114, Previous: 112
# 		at index 2019: tick increment greater than timeout. Difference: 2013ms
# 		at index 2844: packetNum not sequentially increasing. Current: 172, Previous: 170
# 		at index 2844: tick increment greater than timeout. Difference: 2001ms
# 		at index 3583: packetNum not sequentially increasing. Current: 144, Previous: 142
# 		at index 3583: tick increment greater than timeout. Difference: 1945ms
# 		dropped 61 rows of data due to duplication.
# 		dropped 20 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 31 minutes and 14.28 seconds
# 		Error (server timestamp vs tick): 0.11 seconds
# 		% drift: -0.006002316093703357
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 1306: packetNum not sequentially increasing. Current: 10145, Previous: 10143
# 		at index 1306: tick increment greater than timeout. Difference: 600ms
# 		at index 3747: packetNum not sequentially increasing. Current: 12588, Previous: 12585
# 		at index 3747: tick increment greater than timeout. Difference: 1000ms
# 		at index 3748: packetNum not sequentially increasing. Current: 12591, Previous: 12588
# 		at index 3748: tick increment greater than timeout. Difference: 1001ms
# 		at index 3749: packetNum not sequentially increasing. Current: 12614, Previous: 12591
# 		at index 3749: tick increment greater than timeout. Difference: 7600ms
# 		at index 7318: packetNum not sequentially increasing. Current: 16182, Previous: 16182
# 		at index 7318: packet_tick not increasing. Current: 5400884, Previous: 5400884
# 		at index 7457: packetNum not sequentially increasing. Current: 166, Previous: 16320
# 		at index 7457: tick increment greater than timeout. Difference: 605ms
# 		at index 7458: packetNum not sequentially increasing. Current: 16321, Previous: 166
# 		at index 7458: packet_tick not increasing. Current: 5447284, Previous: 5447489
# 		at index 8554: packetNum not sequentially increasing. Current: 17416, Previous: 17416
# 		at index 8554: packet_tick not increasing. Current: 5812283, Previous: 5812283
# 		dropped 2250 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 31 minutes and 15.00 seconds
# 		Error (server timestamp vs tick): 0.40 seconds
# 		% drift: -0.02117335027201355
# 	watch processing...
#
#
# Processing Data/P9/P9_sess1/042123_111929_p9_LAB_FLOW.csv
# got raw data.
# 	thermal processing...
# 		dropped 15 rows of data due to duplication.
# 		dropped 45 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 23.90 seconds
# 		Error (server timestamp vs tick): 0.15 seconds
# 		% drift: -0.02178681093727153
# 	gyro processing...
# 		at index 445: packetNum not sequentially increasing. Current: 81, Previous: 81
# 		at index 445: packet_tick not increasing. Current: 6981536, Previous: 6981536
# 		at index 1424: packetNum not sequentially increasing. Current: 35, Previous: 35
# 		at index 1424: packet_tick not increasing. Current: 7601492, Previous: 7601492
# 		at index 1923: packetNum not sequentially increasing. Current: 21, Previous: 21
# 		at index 1923: packet_tick not increasing. Current: 7915512, Previous: 7915512
# 		at index 1946: packetNum not sequentially increasing. Current: 45, Previous: 43
# 		at index 1946: tick increment greater than timeout. Difference: 1151ms
# 		dropped 121 rows of data due to duplication.
# 		dropped 25 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 24.55 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.0018990508397821934
# 	accelerometer processing...
# 		at index 151: packetNum not sequentially increasing. Current: 186, Previous: 186
# 		at index 151: packet_tick not increasing. Current: 6853547, Previous: 6853547
# 		at index 255: packetNum not sequentially increasing. Current: 33, Previous: 33
# 		at index 255: packet_tick not increasing. Current: 6957545, Previous: 6957545
# 		at index 276: packetNum not sequentially increasing. Current: 53, Previous: 53
# 		at index 276: packet_tick not increasing. Current: 6977537, Previous: 6977537
# 		at index 558: packetNum not sequentially increasing. Current: 78, Previous: 78
# 		at index 558: packet_tick not increasing. Current: 7261518, Previous: 7261518
# 		at index 575: packetNum not sequentially increasing. Current: 96, Previous: 94
# 		at index 575: tick increment greater than timeout. Difference: 1899ms
# 		at index 582: packetNum not sequentially increasing. Current: 104, Previous: 102
# 		at index 582: tick increment greater than timeout. Difference: 2030ms
# 		at index 1219: packetNum not sequentially increasing. Current: 230, Previous: 228
# 		at index 1219: tick increment greater than timeout. Difference: 2171ms
# 		dropped 115 rows of data due to duplication.
# 		dropped 10 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 24.65 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: 0.0029942371888640666
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 452: packetNum not sequentially increasing. Current: 20541, Previous: 20539
# 		at index 452: tick increment greater than timeout. Difference: 600ms
# 		at index 763: packetNum not sequentially increasing. Current: 20853, Previous: 20851
# 		at index 763: tick increment greater than timeout. Difference: 600ms
# 		at index 822: packetNum not sequentially increasing. Current: 20913, Previous: 20911
# 		at index 822: tick increment greater than timeout. Difference: 600ms
# 		at index 833: packetNum not sequentially increasing. Current: 20925, Previous: 20923
# 		at index 833: tick increment greater than timeout. Difference: 600ms
# 		at index 1372: packetNum not sequentially increasing. Current: 21465, Previous: 21463
# 		at index 1372: tick increment greater than timeout. Difference: 600ms
# 		at index 1587: packetNum not sequentially increasing. Current: 21681, Previous: 21679
# 		at index 1587: tick increment greater than timeout. Difference: 600ms
# 		at index 1669: packetNum not sequentially increasing. Current: 21764, Previous: 21762
# 		at index 1669: tick increment greater than timeout. Difference: 600ms
# 		at index 1721: packetNum not sequentially increasing. Current: 21815, Previous: 21815
# 		at index 1721: packet_tick not increasing. Current: 7278484, Previous: 7278484
# 		at index 1744: packetNum not sequentially increasing. Current: 21837, Previous: 21837
# 		at index 1744: packet_tick not increasing. Current: 7285884, Previous: 7285884
# 		at index 2689: packetNum not sequentially increasing. Current: 22783, Previous: 22781
# 		at index 2689: tick increment greater than timeout. Difference: 804ms
# 		at index 3631: packetNum not sequentially increasing. Current: 23726, Previous: 23724
# 		at index 3631: tick increment greater than timeout. Difference: 600ms
# 		at index 3672: packetNum not sequentially increasing. Current: 23766, Previous: 23766
# 		at index 3672: packet_tick not increasing. Current: 7928884, Previous: 7928884
# 		at index 3674: packetNum not sequentially increasing. Current: 23767, Previous: 23767
# 		at index 3674: packet_tick not increasing. Current: 7929284, Previous: 7929284
# 		at index 3675: packetNum not sequentially increasing. Current: 23769, Previous: 23767
# 		at index 3675: tick increment greater than timeout. Difference: 599ms
# 		at index 3878: packetNum not sequentially increasing. Current: 23973, Previous: 23971
# 		at index 3878: tick increment greater than timeout. Difference: 602ms
# 		dropped 1707 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 24.50 seconds
# 		Error (server timestamp vs tick): 0.26 seconds
# 		% drift: -0.037472607742878014
# 	watch processing...
#
#
# Processing Data/P9/P9_sess1/042123_113054_p9_FLOW_CONTD.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 43.90 seconds
# 		Error (server timestamp vs tick): 0.17 seconds
# 		% drift: -0.011798581361050636
# 	gyro processing...
# 		at index 157: packetNum not sequentially increasing. Current: 168, Previous: 168
# 		at index 157: packet_tick not increasing. Current: 8170535, Previous: 8170535
# 		at index 235: packetNum not sequentially increasing. Current: 245, Previous: 245
# 		at index 235: packet_tick not increasing. Current: 8219513, Previous: 8219513
# 		at index 1188: packetNum not sequentially increasing. Current: 173, Previous: 173
# 		at index 1188: packet_tick not increasing. Current: 8822513, Previous: 8822513
# 		at index 1625: packetNum not sequentially increasing. Current: 97, Previous: 97
# 		at index 1625: packet_tick not increasing. Current: 9095546, Previous: 9095546
# 		at index 2365: packetNum not sequentially increasing. Current: 70, Previous: 68
# 		at index 2365: tick increment greater than timeout. Difference: 1267ms
# 		at index 2934: packetNum not sequentially increasing. Current: 128, Previous: 126
# 		at index 2934: tick increment greater than timeout. Difference: 1216ms
# 		at index 3514: packetNum not sequentially increasing. Current: 197, Previous: 195
# 		at index 3514: tick increment greater than timeout. Difference: 1208ms
# 		dropped 208 rows of data due to duplication.
# 		dropped 49 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 43.52 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.0014400916600779546
# 	accelerometer processing...
# 		at index 276: packetNum not sequentially increasing. Current: 138, Previous: 136
# 		at index 276: tick increment greater than timeout. Difference: 1960ms
# 		at index 1025: packetNum not sequentially increasing. Current: 120, Previous: 118
# 		at index 1025: tick increment greater than timeout. Difference: 1908ms
# 		at index 1298: packetNum not sequentially increasing. Current: 136, Previous: 136
# 		at index 1298: packet_tick not increasing. Current: 9367511, Previous: 9367511
# 		at index 1498: packetNum not sequentially increasing. Current: 81, Previous: 79
# 		at index 1498: tick increment greater than timeout. Difference: 2261ms
# 		dropped 39 rows of data due to duplication.
# 		dropped 12 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 43.49 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.0010537481822843855
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 296: packetNum not sequentially increasing. Current: 24492, Previous: 24490
# 		at index 296: tick increment greater than timeout. Difference: 601ms
# 		at index 441: packetNum not sequentially increasing. Current: 24638, Previous: 24636
# 		at index 441: tick increment greater than timeout. Difference: 600ms
# 		at index 579: packetNum not sequentially increasing. Current: 24777, Previous: 24775
# 		at index 579: tick increment greater than timeout. Difference: 599ms
# 		at index 794: packetNum not sequentially increasing. Current: 24993, Previous: 24991
# 		at index 794: tick increment greater than timeout. Difference: 601ms
# 		at index 823: packetNum not sequentially increasing. Current: 25021, Previous: 25021
# 		at index 823: packet_tick not increasing. Current: 8347284, Previous: 8347284
# 		at index 2248: packetNum not sequentially increasing. Current: 26447, Previous: 26445
# 		at index 2248: tick increment greater than timeout. Difference: 600ms
# 		at index 3882: packetNum not sequentially increasing. Current: 28082, Previous: 28080
# 		at index 3882: tick increment greater than timeout. Difference: 600ms
# 		at index 4459: packetNum not sequentially increasing. Current: 69, Previous: 28658
# 		at index 4459: packet_tick not increasing. Current: 9559483, Previous: 9559483
# 		at index 4460: packetNum not sequentially increasing. Current: 28659, Previous: 69
# 		at index 4480: packetNum not sequentially increasing. Current: 28678, Previous: 28678
# 		at index 4480: packet_tick not increasing. Current: 9566284, Previous: 9566284
# 		at index 5247: packetNum not sequentially increasing. Current: 29446, Previous: 29444
# 		at index 5247: tick increment greater than timeout. Difference: 803ms
# 		at index 5248: packetNum not sequentially increasing. Current: 29446, Previous: 29446
# 		at index 5248: packet_tick not increasing. Current: 9822286, Previous: 9822286
# 		at index 5549: packetNum not sequentially increasing. Current: 29746, Previous: 29746
# 		at index 5549: packet_tick not increasing. Current: 9922288, Previous: 9922288
# 		at index 6635: packetNum not sequentially increasing. Current: 196, Previous: 30831
# 		at index 6635: tick increment greater than timeout. Difference: 605ms
# 		at index 6636: packetNum not sequentially increasing. Current: 30832, Previous: 196
# 		at index 6636: packet_tick not increasing. Current: 10284284, Previous: 10284489
# 		at index 7301: packetNum not sequentially increasing. Current: 31498, Previous: 31496
# 		at index 7301: tick increment greater than timeout. Difference: 804ms
# 		at index 7302: packetNum not sequentially increasing. Current: 31498, Previous: 31498
# 		at index 7302: packet_tick not increasing. Current: 10506287, Previous: 10506287
# 		dropped 3584 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 43.50 seconds
# 		Error (server timestamp vs tick): 0.32 seconds
# 		% drift: -0.022760808837656774
# 	watch processing...
# The size of the loaded data is 676.4321746826172 MB
#
#
# Processing Data/P9/P9_sess2/042223_102510_p9_HOME_TETRIS.csv
# got raw data.
# 	thermal processing...
# FAILED TO PROCESS DATA!!!! list index out of range
# 	gyro processing...
# FAILED TO PROCESS DATA!!!! list index out of range
# 	accelerometer processing...
# FAILED TO PROCESS DATA!!!! list index out of range
# 	quaternion extended kalman filter application...
# FAILED TO PROCESS DATA!!!! local variable 'acc_df' referenced before assignment
# 	blink processing...
# FAILED TO PROCESS DATA!!!! list index out of range
# 	watch processing...
# 		no entries
# 		no entries
#
#
# Processing Data/P9/P9_sess2/042223_102521_p9_HOME_TETRIS_RESUME.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 3.90 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: 0.20512820512820512
# 	gyro processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 3.29 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.6690997566909975
# 	accelerometer processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 3.58 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: -0.09780634343998883
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		dropped 2 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 3.20 seconds
# 		Error (server timestamp vs tick): 0.05 seconds
# 		% drift: 1.4848390121913098
# 	watch processing...
# 		no entries
# 		no entries
#
#
# Processing Data/P9/P9_sess2/042223_102539_p9_HOME_TETRIS_RESUME.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 14 minutes and 21.90 seconds
# 		Error (server timestamp vs tick): 0.09 seconds
# 		% drift: -0.009977955679313146
# 	gyro processing...
# 		at index 1725: packetNum not sequentially increasing. Current: 209, Previous: 207
# 		at index 1725: tick increment greater than timeout. Difference: 1181ms
# 		at index 2281: packetNum not sequentially increasing. Current: 252, Previous: 252
# 		at index 2281: packet_tick not increasing. Current: 3445522, Previous: 3445522
# 		dropped 75 rows of data due to duplication.
# 		dropped 11 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 14 minutes and 23.31 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.003011674873480697
# 	accelerometer processing...
# 		at index 1057: packetNum not sequentially increasing. Current: 46, Previous: 44
# 		at index 1057: tick increment greater than timeout. Difference: 1871ms
# 		at index 1147: packetNum not sequentially increasing. Current: 135, Previous: 135
# 		at index 1147: packet_tick not increasing. Current: 3222491, Previous: 3222491
# 		at index 1370: packetNum not sequentially increasing. Current: 103, Previous: 101
# 		at index 1370: tick increment greater than timeout. Difference: 1903ms
# 		at index 1646: packetNum not sequentially increasing. Current: 122, Previous: 122
# 		at index 1646: packet_tick not increasing. Current: 3722543, Previous: 3722543
# 		dropped 80 rows of data due to duplication.
# 		dropped 14 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 14 minutes and 23.02 seconds
# 		Error (server timestamp vs tick): 0.07 seconds
# 		% drift: -0.00863246164782685
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 3119: packetNum not sequentially increasing. Current: 208, Previous: 9307
# 		at index 3120: packetNum not sequentially increasing. Current: 9308, Previous: 208
# 		at index 3120: packet_tick not increasing. Current: 3109489, Previous: 3109519
# 		at index 3186: packetNum not sequentially increasing. Current: 9373, Previous: 9373
# 		at index 3186: packet_tick not increasing. Current: 3131289, Previous: 3131289
# 		at index 3458: packetNum not sequentially increasing. Current: 9646, Previous: 9644
# 		at index 3458: tick increment greater than timeout. Difference: 800ms
# 		at index 4959: packetNum not sequentially increasing. Current: 11148, Previous: 11146
# 		at index 4959: tick increment greater than timeout. Difference: 600ms
# 		dropped 1301 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 14 minutes and 23.50 seconds
# 		Error (server timestamp vs tick): 0.26 seconds
# 		% drift: -0.03022584263221924
# 	watch processing...
#
#
# Processing Data/P9/P9_sess2/042223_104002_p9_RESUME_CONTD.csv
# got raw data.
# 	thermal processing...
# 		at index 356: packetNum not sequentially increasing. Current: 1306, Previous: 1303
# 		at index 356: tick increment greater than timeout. Difference: 12003ms
# 		at index 678: packetNum not sequentially increasing. Current: 1629, Previous: 1627
# 		at index 678: tick increment greater than timeout. Difference: 7993ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 1.90 seconds
# 		Error (server timestamp vs tick): 0.06 seconds
# 		% drift: -0.00426126905919169
# 	gyro processing...
# 		at index 813: packetNum not sequentially increasing. Current: 105, Previous: 103
# 		at index 813: tick increment greater than timeout. Difference: 1152ms
# 		at index 1186: packetNum not sequentially increasing. Current: 223, Previous: 221
# 		at index 1186: tick increment greater than timeout. Difference: 1188ms
# 		at index 1500: packetNum not sequentially increasing. Current: 24, Previous: 24
# 		at index 1500: packet_tick not increasing. Current: 4704518, Previous: 4704518
# 		at index 2325: packetNum not sequentially increasing. Current: 83, Previous: 80
# 		at index 2325: tick increment greater than timeout. Difference: 1904ms
# 		at index 2326: packetNum not sequentially increasing. Current: 85, Previous: 83
# 		at index 2326: tick increment greater than timeout. Difference: 1133ms
# 		at index 2327: packetNum not sequentially increasing. Current: 88, Previous: 85
# 		at index 2327: tick increment greater than timeout. Difference: 1901ms
# 		at index 2328: packetNum not sequentially increasing. Current: 93, Previous: 88
# 		at index 2328: tick increment greater than timeout. Difference: 3028ms
# 		at index 2329: packetNum not sequentially increasing. Current: 102, Previous: 93
# 		at index 2329: tick increment greater than timeout. Difference: 5847ms
# 		at index 2330: packetNum not sequentially increasing. Current: 104, Previous: 102
# 		at index 2330: tick increment greater than timeout. Difference: 1271ms
# 		at index 2339: packetNum not sequentially increasing. Current: 114, Previous: 112
# 		at index 2339: tick increment greater than timeout. Difference: 1329ms
# 		dropped 214 rows of data due to duplication.
# 		dropped 41 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 1.32 seconds
# 		Error (server timestamp vs tick): 0.11 seconds
# 		% drift: -0.007626642225887155
# 	accelerometer processing...
# 		at index 1411: packetNum not sequentially increasing. Current: 72, Previous: 70
# 		at index 1411: tick increment greater than timeout. Difference: 1950ms
# 		at index 1414: packetNum not sequentially increasing. Current: 76, Previous: 74
# 		at index 1414: tick increment greater than timeout. Difference: 1961ms
# 		at index 1415: packetNum not sequentially increasing. Current: 78, Previous: 76
# 		at index 1415: tick increment greater than timeout. Difference: 2012ms
# 		at index 1416: packetNum not sequentially increasing. Current: 84, Previous: 78
# 		at index 1416: tick increment greater than timeout. Difference: 5772ms
# 		at index 1421: packetNum not sequentially increasing. Current: 90, Previous: 88
# 		at index 1421: tick increment greater than timeout. Difference: 1973ms
# 		at index 1422: packetNum not sequentially increasing. Current: 92, Previous: 90
# 		at index 1422: tick increment greater than timeout. Difference: 2099ms
# 		at index 1832: packetNum not sequentially increasing. Current: 247, Previous: 245
# 		at index 1832: tick increment greater than timeout. Difference: 2042ms
# 		at index 2422: packetNum not sequentially increasing. Current: 70, Previous: 68
# 		at index 2422: tick increment greater than timeout. Difference: 2172ms
# 		at index 2448: packetNum not sequentially increasing. Current: 97, Previous: 95
# 		at index 2448: tick increment greater than timeout. Difference: 1949ms
# 		at index 2619: packetNum not sequentially increasing. Current: 13, Previous: 11
# 		at index 2619: tick increment greater than timeout. Difference: 2139ms
# 		at index 2872: packetNum not sequentially increasing. Current: 11, Previous: 9
# 		at index 2872: tick increment greater than timeout. Difference: 2120ms
# 		dropped 25 rows of data due to duplication.
# 		dropped 18 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 1.58 seconds
# 		Error (server timestamp vs tick): 0.06 seconds
# 		% drift: -0.00386259420484336
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 1476: packetNum not sequentially increasing. Current: 104, Previous: 12845
# 		at index 1476: packet_tick not increasing. Current: 4288489, Previous: 4288489
# 		at index 1477: packetNum not sequentially increasing. Current: 12846, Previous: 104
# 		at index 2151: packetNum not sequentially increasing. Current: 222, Previous: 13519
# 		at index 2151: packet_tick not increasing. Current: 4513288, Previous: 4513288
# 		at index 2152: packetNum not sequentially increasing. Current: 13520, Previous: 222
# 		at index 2724: packetNum not sequentially increasing. Current: 14093, Previous: 14091
# 		at index 2724: tick increment greater than timeout. Difference: 600ms
# 		at index 4242: packetNum not sequentially increasing. Current: 15613, Previous: 15610
# 		at index 4242: tick increment greater than timeout. Difference: 999ms
# 		at index 4246: packetNum not sequentially increasing. Current: 15618, Previous: 15616
# 		at index 4246: tick increment greater than timeout. Difference: 599ms
# 		at index 4249: packetNum not sequentially increasing. Current: 15643, Previous: 15620
# 		at index 4249: tick increment greater than timeout. Difference: 7800ms
# 		at index 4250: packetNum not sequentially increasing. Current: 15643, Previous: 15643
# 		at index 4250: packet_tick not increasing. Current: 5221288, Previous: 5221288
# 		at index 4251: packetNum not sequentially increasing. Current: 15645, Previous: 15643
# 		at index 4251: tick increment greater than timeout. Difference: 601ms
# 		at index 4253: packetNum not sequentially increasing. Current: 15651, Previous: 15646
# 		at index 4253: tick increment greater than timeout. Difference: 1599ms
# 		at index 4254: packetNum not sequentially increasing. Current: 15654, Previous: 15651
# 		at index 4254: tick increment greater than timeout. Difference: 1001ms
# 		at index 4256: packetNum not sequentially increasing. Current: 15657, Previous: 15655
# 		at index 4256: tick increment greater than timeout. Difference: 600ms
# 		at index 4264: packetNum not sequentially increasing. Current: 15666, Previous: 15664
# 		at index 4264: tick increment greater than timeout. Difference: 600ms
# 		at index 4269: packetNum not sequentially increasing. Current: 15672, Previous: 15670
# 		at index 4269: tick increment greater than timeout. Difference: 601ms
# 		at index 5040: packetNum not sequentially increasing. Current: 16444, Previous: 16442
# 		at index 5040: tick increment greater than timeout. Difference: 804ms
# 		at index 5041: packetNum not sequentially increasing. Current: 16444, Previous: 16444
# 		at index 5041: packet_tick not increasing. Current: 5488292, Previous: 5488292
# 		at index 5507: packetNum not sequentially increasing. Current: 16909, Previous: 16909
# 		at index 5507: packet_tick not increasing. Current: 5643288, Previous: 5643288
# 		at index 7281: packetNum not sequentially increasing. Current: 18682, Previous: 18682
# 		at index 7281: packet_tick not increasing. Current: 6234288, Previous: 6234288
# 		at index 7363: packetNum not sequentially increasing. Current: 18763, Previous: 18763
# 		at index 7363: packet_tick not increasing. Current: 6261288, Previous: 6261288
# 		dropped 3620 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 25 minutes and 1.00 seconds
# 		Error (server timestamp vs tick): 0.32 seconds
# 		% drift: -0.021319127687917286
# 	watch processing...
#
#
# Processing Data/P9/P9_sess2/042223_110503_p9_HOME_FLOW.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5.90 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.1864406779661017
# 	gyro processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 6.36 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.3615499489114203
# 	accelerometer processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 6.07 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: 0.08238589553468446
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		dropped 5 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 6.50 seconds
# 		Error (server timestamp vs tick): 0.21 seconds
# 		% drift: -3.2384615384615385
# 	watch processing...
# 		no entries
# 		no entries
#
#
# Processing Data/P9/P9_sess2/042223_110522_p9_HOME_TETRIS.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 7.90 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: 0.34177215189873417
# 	gyro processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 7.83 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: 0.12128175667049662
# 	accelerometer processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 7.91 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.08219524532119372
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		dropped 4 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 7.50 seconds
# 		Error (server timestamp vs tick): 0.22 seconds
# 		% drift: -2.967062274969996
# 	watch processing...
#
#
# Processing Data/P9/P9_sess2/042223_110530_p9_TETRIS_CONTD.csv
# got raw data.
# 	thermal processing...
# 		dropped 5 rows of data due to duplication.
# 		dropped 5 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 2 minutes and 31.90 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.013166556945358789
# 	gyro processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 2 minutes and 32.28 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: 0.015760803538300394
# 	accelerometer processing...
# 		dropped 7 rows of data due to duplication.
# 		dropped 5 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 2 minutes and 32.05 seconds
# 		Error (server timestamp vs tick): 0.05 seconds
# 		% drift: -0.03584300107857838
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		dropped 64 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 2 minutes and 32.50 seconds
# 		Error (server timestamp vs tick): 0.23 seconds
# 		% drift: -0.15114754098360655
# 	watch processing...
#
#
# Processing Data/P9/P9_sess2/042223_110802_p9_HOME_FLOW.csv
# got raw data.
# 	thermal processing...
# 		at index 17: packetNum not sequentially increasing. Current: 1806, Previous: 1804
# 		at index 17: tick increment greater than timeout. Difference: 8001ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 16 minutes and 19.90 seconds
# 		Error (server timestamp vs tick): 0.15 seconds
# 		% drift: -0.015409735687315032
# 	gyro processing...
# 		at index 98: packetNum not sequentially increasing. Current: 17, Previous: 17
# 		at index 98: packet_tick not increasing. Current: 7217524, Previous: 7217524
# 		at index 169: packetNum not sequentially increasing. Current: 87, Previous: 87
# 		at index 169: packet_tick not increasing. Current: 7261520, Previous: 7261520
# 		at index 342: packetNum not sequentially increasing. Current: 3, Previous: 3
# 		at index 342: packet_tick not increasing. Current: 7369524, Previous: 7369524
# 		at index 551: packetNum not sequentially increasing. Current: 211, Previous: 211
# 		at index 551: packet_tick not increasing. Current: 7501499, Previous: 7501499
# 		at index 558: packetNum not sequentially increasing. Current: 217, Previous: 217
# 		at index 558: packet_tick not increasing. Current: 7505497, Previous: 7505497
# 		at index 788: packetNum not sequentially increasing. Current: 190, Previous: 190
# 		at index 788: packet_tick not increasing. Current: 7649493, Previous: 7649493
# 		at index 947: packetNum not sequentially increasing. Current: 92, Previous: 92
# 		at index 947: packet_tick not increasing. Current: 7749498, Previous: 7749498
# 		at index 1445: packetNum not sequentially increasing. Current: 79, Previous: 77
# 		at index 1445: tick increment greater than timeout. Difference: 1359ms
# 		at index 1786: packetNum not sequentially increasing. Current: 165, Previous: 163
# 		at index 1786: tick increment greater than timeout. Difference: 1261ms
# 		at index 2394: packetNum not sequentially increasing. Current: 4, Previous: 4
# 		at index 2394: packet_tick not increasing. Current: 8657522, Previous: 8657522
# 		dropped 263 rows of data due to duplication.
# 		dropped 22 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 16 minutes and 18.89 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 0.00040862526203094926
# 	accelerometer processing...
# 		at index 155: packetNum not sequentially increasing. Current: 117, Previous: 115
# 		at index 155: tick increment greater than timeout. Difference: 2046ms
# 		at index 1032: packetNum not sequentially increasing. Current: 225, Previous: 225
# 		at index 1032: packet_tick not increasing. Current: 8192539, Previous: 8192539
# 		dropped 40 rows of data due to duplication.
# 		dropped 9 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 16 minutes and 19.22 seconds
# 		Error (server timestamp vs tick): 0.08 seconds
# 		% drift: 0.008169767774351014
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 181: packetNum not sequentially increasing. Current: 21632, Previous: 21630
# 		at index 181: tick increment greater than timeout. Difference: 600ms
# 		at index 206: packetNum not sequentially increasing. Current: 21656, Previous: 21656
# 		at index 206: packet_tick not increasing. Current: 7225489, Previous: 7225489
# 		at index 313: packetNum not sequentially increasing. Current: 21764, Previous: 21762
# 		at index 313: tick increment greater than timeout. Difference: 600ms
# 		at index 636: packetNum not sequentially increasing. Current: 22088, Previous: 22086
# 		at index 636: tick increment greater than timeout. Difference: 600ms
# 		at index 1030: packetNum not sequentially increasing. Current: 22483, Previous: 22481
# 		at index 1030: tick increment greater than timeout. Difference: 805ms
# 		at index 1041: packetNum not sequentially increasing. Current: 22495, Previous: 22493
# 		at index 1041: tick increment greater than timeout. Difference: 802ms
# 		at index 1438: packetNum not sequentially increasing. Current: 22893, Previous: 22891
# 		at index 1438: tick increment greater than timeout. Difference: 598ms
# 		at index 1471: packetNum not sequentially increasing. Current: 22927, Previous: 22925
# 		at index 1471: tick increment greater than timeout. Difference: 800ms
# 		at index 1770: packetNum not sequentially increasing. Current: 23227, Previous: 23225
# 		at index 1770: tick increment greater than timeout. Difference: 805ms
# 		at index 2431: packetNum not sequentially increasing. Current: 23889, Previous: 23887
# 		at index 2431: tick increment greater than timeout. Difference: 599ms
# 		at index 2712: packetNum not sequentially increasing. Current: 78, Previous: 24169
# 		at index 2712: packet_tick not increasing. Current: 8063288, Previous: 8063288
# 		at index 2713: packetNum not sequentially increasing. Current: 24170, Previous: 78
# 		at index 3100: packetNum not sequentially increasing. Current: 24558, Previous: 24556
# 		at index 3100: tick increment greater than timeout. Difference: 599ms
# 		at index 3147: packetNum not sequentially increasing. Current: 24606, Previous: 24604
# 		at index 3147: tick increment greater than timeout. Difference: 601ms
# 		at index 4152: packetNum not sequentially increasing. Current: 25612, Previous: 25610
# 		at index 4152: tick increment greater than timeout. Difference: 802ms
# 		at index 4153: packetNum not sequentially increasing. Current: 25612, Previous: 25612
# 		at index 4153: packet_tick not increasing. Current: 8544290, Previous: 8544290
# 		at index 4492: packetNum not sequentially increasing. Current: 25952, Previous: 25950
# 		at index 4492: tick increment greater than timeout. Difference: 600ms
# 		at index 4852: packetNum not sequentially increasing. Current: 26313, Previous: 26311
# 		at index 4852: tick increment greater than timeout. Difference: 599ms
# 		dropped 1457 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 16 minutes and 19.00 seconds
# 		Error (server timestamp vs tick): 0.20 seconds
# 		% drift: -0.02048010263544702
# 	watch processing...
#
#
# Processing Data/P9/P9_sess2/042223_112421_p9_FLOW_CONTD.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 22 minutes and 23.90 seconds
# 		Error (server timestamp vs tick): 0.16 seconds
# 		% drift: -0.012054468338418037
# 	gyro processing...
# 		at index 594: packetNum not sequentially increasing. Current: 41, Previous: 39
# 		at index 594: tick increment greater than timeout. Difference: 1308ms
# 		at index 1349: packetNum not sequentially increasing. Current: 29, Previous: 27
# 		at index 1349: tick increment greater than timeout. Difference: 1219ms
# 		at index 1713: packetNum not sequentially increasing. Current: 138, Previous: 136
# 		at index 1713: tick increment greater than timeout. Difference: 1315ms
# 		at index 2146: packetNum not sequentially increasing. Current: 60, Previous: 58
# 		at index 2146: tick increment greater than timeout. Difference: 1306ms
# 		at index 3417: packetNum not sequentially increasing. Current: 52, Previous: 50
# 		at index 3417: tick increment greater than timeout. Difference: 1152ms
# 		at index 3991: packetNum not sequentially increasing. Current: 115, Previous: 113
# 		at index 3991: tick increment greater than timeout. Difference: 1191ms
# 		dropped 212 rows of data due to duplication.
# 		dropped 56 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 22 minutes and 23.75 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.002679065779995118
# 	accelerometer processing...
# 		at index 1669: packetNum not sequentially increasing. Current: 3, Previous: 1
# 		at index 1669: tick increment greater than timeout. Difference: 2110ms
# 		at index 1875: packetNum not sequentially increasing. Current: 210, Previous: 208
# 		at index 1875: tick increment greater than timeout. Difference: 2029ms
# 		at index 2159: packetNum not sequentially increasing. Current: 237, Previous: 237
# 		at index 2159: packet_tick not increasing. Current: 11270544, Previous: 11270544
# 		at index 2282: packetNum not sequentially increasing. Current: 103, Previous: 103
# 		at index 2282: packet_tick not increasing. Current: 11392518, Previous: 11392518
# 		dropped 75 rows of data due to duplication.
# 		dropped 15 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 22 minutes and 23.62 seconds
# 		Error (server timestamp vs tick): 0.08 seconds
# 		% drift: -0.005693569838518452
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 753: packetNum not sequentially increasing. Current: 28078, Previous: 28076
# 		at index 753: tick increment greater than timeout. Difference: 802ms
# 		at index 754: packetNum not sequentially increasing. Current: 28078, Previous: 28078
# 		at index 754: packet_tick not increasing. Current: 9366290, Previous: 9366290
# 		at index 776: packetNum not sequentially increasing. Current: 28101, Previous: 28099
# 		at index 776: tick increment greater than timeout. Difference: 597ms
# 		at index 1129: packetNum not sequentially increasing. Current: 28453, Previous: 28453
# 		at index 1129: packet_tick not increasing. Current: 9491291, Previous: 9491291
# 		at index 2562: packetNum not sequentially increasing. Current: 29885, Previous: 29885
# 		at index 2562: packet_tick not increasing. Current: 9968488, Previous: 9968488
# 		at index 3256: packetNum not sequentially increasing. Current: 137, Previous: 30578
# 		at index 3256: packet_tick not increasing. Current: 10199488, Previous: 10199488
# 		at index 3257: packetNum not sequentially increasing. Current: 30579, Previous: 137
# 		at index 4083: packetNum not sequentially increasing. Current: 59, Previous: 31404
# 		at index 4083: packet_tick not increasing. Current: 10474889, Previous: 10474889
# 		at index 4084: packetNum not sequentially increasing. Current: 31405, Previous: 59
# 		at index 5003: packetNum not sequentially increasing. Current: 2, Previous: 32323
# 		at index 5003: packet_tick not increasing. Current: 10781289, Previous: 10781289
# 		at index 5004: packetNum not sequentially increasing. Current: 32324, Previous: 2
# 		at index 5622: packetNum not sequentially increasing. Current: 32941, Previous: 32941
# 		at index 5622: packet_tick not increasing. Current: 10987290, Previous: 10987290
# 		at index 5753: packetNum not sequentially increasing. Current: 33073, Previous: 33071
# 		at index 5753: tick increment greater than timeout. Difference: 802ms
# 		at index 5754: packetNum not sequentially increasing. Current: 33073, Previous: 33073
# 		at index 5754: packet_tick not increasing. Current: 11031290, Previous: 11031290
# 		at index 6837: packetNum not sequentially increasing. Current: 34157, Previous: 34155
# 		at index 6837: tick increment greater than timeout. Difference: 600ms
# 		at index 7516: packetNum not sequentially increasing. Current: 34835, Previous: 34835
# 		at index 7516: packet_tick not increasing. Current: 11618489, Previous: 11618489
# 		dropped 3966 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 22 minutes and 23.50 seconds
# 		Error (server timestamp vs tick): 0.26 seconds
# 		% drift: -0.01935244486507066
# 	watch processing...
# The size of the loaded data is 647.0661087036133 MB
# /Users/davidramsay/.virtualenvs/pyro/lib/python3.9/site-packages/pympler/asizeof.py:1127: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = _getsizeof(obj, s)
# /Users/davidramsay/.virtualenvs/pyro/lib/python3.9/site-packages/pympler/asizeof.py:1127: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = _getsizeof(obj, s)
# /Users/davidramsay/.virtualenvs/pyro/lib/python3.9/site-packages/pympler/asizeof.py:1127: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = _getsizeof(obj, s)
# ...
# SAVED Data/Flow_Drawings/P15HomeMidSurvey.png
#                                        event
# timestamp
# 2023-04-22 14:54:33.680           START_TEST
# 2023-04-22 15:04:53.791     START_TRANSITION
# 2023-04-22 15:05:47.480  FINISHED_TRANSITION
# 2023-04-22 15:06:08.687              NOTICED
# 2023-04-22 15:10:55.356         START_SURVEY
# GOT UI survey results: {'HomeMidSurvey': {'startSurveyTime': ['4/22/2023', ' 3:06:11 PM'], 'durGuess': '25', 'timeAtDurGuess': ['4/22/2023', ' 3:06:14 PM'], 'durTimeConfidence': '2', 'guessTime': '3:00 PM', 'timeAtGuess': ['4/22/2023', ' 3:06:23 PM'], 'guessTimeConfidence': '2', 'flowPath': ['22.5', '40', '22.5', '40', '22.5', '40', '22.5', '40', '22.5', '40', '22.5', '40', '33', '43', '35.5', '41.5', '37', '39', '39', '36.5', '40.5', '34', '42', '31', '43', '28', '44.5', '25', '45', '22.5', '45.5', '21', '46', '20', '46.5', '19.5', '47', '18.5', '47.5', '17.5', '48', '16.5', '48.5', '16', '49.5', '15.5', '50', '15', '51', '14.5', '52', '14', '52.5', '13.5', '53.5', '13', '54', '12.5', '55', '12', '55.5', '12', '56', '11.5', '56.5', '11', '57', '11', '57.5', '10.5', '58', '9.5', '58.5', '9.5', '59', '9', '60.5', '8.5', '61.5', '8', '64', '8', '65', '7.5', '67.5', '7.5', '69.5', '7.5', '72', '7.5', '74.5', '7.5', '77', '7.5', '79', '7.5', '81', '7.5', '83.5', '7.5', '85', '8', '86.5', '8.5', '88.5', '9', '91', '10.5', '93', '11.5', '95', '12.5', '96.5', '13', '98', '13.5', '99', '14.5', '100', '15', '101.5', '16', '103', '17', '104.5', '18', '106', '19.5', '107', '20.5', '108.5', '21.5', '109.5', '22.5', '110.5', '23.5', '112', '24', '113', '25', '114', '26', '115', '26.5', '116', '27', '117', '28', '118', '29', '118.5', '29.5', '119', '30', '120', '31', '120.5', '31.5', '121.5', '32', '122.5', '32.5', '123.5', '32.5', '124.5', '33', '125', '33', '126', '33', '126.5', '33', '127.5', '33', '128.5', '33', '130', '33', '131', '33', '132', '33', '133', '32.5', '134', '32', '135', '31', '136', '30.5', '136.5', '29.5', '137.5', '28', '138', '27.5', '139', '26.5', '139.5', '26', '140.5', '25', '142', '24', '142.5', '22.5', '143.5', '21', '144', '19', '145', '16.5', '145.5', '14.5', '146', '12.5', '147', '10', '148', '7.5', '148.5', '5.5', '149', '3', '149.5', '1.5', '150', '0', '150.5', '-1', '151', '-1.5', '152', '-2', '153', '-2', '154', '-2.5', '154.5', '-3', '155.5', '-3.5', '156.5', '-4', '158', '-4.5', '159.5', '-5', '161.5', '-5.5', '163.5', '-6.5', '165.5', '-7', '167', '-7.5', '168.5', '-8', '170.5', '-8', '172.5', '-8', '173.5', '-8', '175', '-8', '176', '-8', '177', '-8', '178', '-7.5', '179.5', '-6.5', '181.5', '-5', '183.5', '-3', '185.5', '-1', '188', '1.5', '190', '3', '192.5', '5', '195', '7', '197.5', '9.5', '200.5', '12.5', '203', '15', '205', '18', '207', '20', '208.5', '22', '209.5', '23.5', '210.5', '25', '211.5', '26', '212', '27', '213', '27.5', '213.5', '28', '214', '29', '214.5', '29.5', '215', '29.5', '215.5', '29.5', '216', '29.5', '216.5', '29.5', '217', '29.5', '217.5', '29.5', '217.5', '29.5', '218', '29.5', '218.5', '29.5', '219.5', '29.5', '220', '29.5', '220.5', '29.5', '221', '29.5', '221.5', '29.5', '222', '29.5', '222.5', '29', '223.5', '28', '225', '27.5', '226', '27', '227.5', '26', '229.5', '25.5', '231', '24.5', '232.5', '24', '234.5', '23', '235.5', '22', '237', '21', '239', '19.5', '240.5', '18.5', '242', '17.5', '244.5', '17', '247', '16.5', '250', '16.5', '254', '16', '258.5', '16', '263', '16', '267.5', '16', '271.5', '16', '274.5', '17.5', '278', '19', '280', '20.5', '281.5', '22', '283.5', '24', '285', '26', '287.5', '29', '290', '32', '293.5', '35', '296', '38.5', '299', '41', '301', '43', '302', '44.5', '302', '47'], 'flowCanvasSize': ['327.5', '100'], 'timeExp': '3', 'focus': '4', 'effort': '2', 'deepest': '4', 'flow': 'true', 'durFlow': '3', 'durToFlow': 'Not long too be honest ', 'percentFlow': '30', 'flowDesc': '', 'flowDescA': 'false', 'flowDescB': 'false', 'flowDescC': 'false', 'flowDescD': 'true', 'flowDescE': 'true', 'flowDescF': 'true', 'FSS1': '4', 'FSS2': '3', 'FSS3': '4', 'FSS4': '4', 'FSS5': '4', 'FSS6': '3', 'FSS7': '2', 'FSS8': '2', 'FSS9': '3', 'flowQ1': '2', 'flowQ2': '4', 'flowQ3': '3', 'flowQ4': '4', 'nowAlertness': '5', 'nowStress': '4', 'nowEmotion': '2', 'nowEmoIntensity': '1', 'reactionTimesMs': ['344', '608', '308', '391', '356', '341', '324', '342', '318', '314' ...
# ========== Processing session 2023-04-22 15:10:55 P15 sess2 HOME_FLOW
# 	>> processing HomeMidActivitySurvey
# No BIT Detected
# No Flow Desc Detected
# {'duration': '10', 'actualTimeAtDuration': ['4/22/2023', ' 3:24:48 PM']}
# No flow path data
#                                        event
# timestamp
# 2023-04-22 15:10:55.462           START_TEST
# 2023-04-22 15:22:11.838     START_TRANSITION
# 2023-04-22 15:23:05.531  FINISHED_TRANSITION
# 2023-04-22 15:24:46.155              NOTICED
# 2023-04-22 15:24:49.159         START_SURVEY
# GOT UI survey results: {'HomeMidActivitySurvey': {'duration': '10', 'actualTimeAtDuration': ['4/22/2023', ' 3:24:48 PM']}}
# ========== Processing session 2023-04-22 15:24:49 P15 sess2 FLOW_CONTD
# 	>> processing HomeFinalSurvey
# BIT CODING:	3.50 with std 0.50 -- DESIGNATED "AT RISK"
# 		2 BIT STRENGTHS:
# 		 ['Flow', 'Optimism']
# 		3 BIT WEAKNESSES:
# 		 ['Belonging', 'Self-worth', 'Positive Affect']
# FLOW DESC:	shallow: 3	deep: 2
# {'startSurveyTime': ['4/22/2023', ' 3:37:44 PM'], 'durGuess': '15', 'timeAtDurGuess': ['4/22/2023', ' 3:37:48 PM'], 'durTimeConfidence': '3', 'guessTime': '3:20 PM', 'timeAtGuess': ['4/22/2023', ' 3:37:55 PM'], 'guessTimeConfidence': '2', 'flowPath': ['9', '27', '14.5', '31', '17.5', '31', '21', '31.5', '25', '33', '28.5', '34.5', '31', '36', '34', '37.5', '37', '39', '40', '41.5', '43.5', '44', '47', '46.5', '49.5', '49', '52', '51.5', '54.5', '53.5', '56.5', '55.5', '59', '57', '61', '58.5', '63', '60', '65', '61', '67', '62.5', '68.5', '64.5', '70.5', '66', '72', '67.5', '73.5', '69', '75', '70', '76', '71.5', '77.5', '72.5', '78.5', '73', '79.5', '74', '80.5', '74.5', '81.5', '76', '83.5', '76.5', '85', '77', '86', '77.5', '87.5', '78', '89.5', '78.5', '91', '79', '92.5', '79', '93.5', '79', '94.5', '79', '95.5', '79', '96', '79', '97', '79', '97.5', '79', '98', '79', '98.5', '79', '99', '78', '99.5', '77.5', '100', '76.5', '100.5', '76', '101', '74.5', '101.5', '73.5', '102', '72.5', '102', '71.5', '102', '70', '103', '69', '103', '67.5', '103', '66', '103.5', '65', '103.5', '64.5', '104', '63.5', '104', '63', '104.5', '63', '104.5', '62.5', '105', '62', '105.5', '62', '106', '61.5', '106.5', '61', '107', '61', '107.5', '60.5', '108', '60', '108.5', '59.5', '109', '59.5', '110', '59', '110.5', '58', '111.5', '58', '112.5', '57', '113.5', '56.5', '114.5', '56', '115.5', '55', '116.5', '54.5', '118', '53.5', '119', '52.5', '120', '51.5', '121', '50.5', '122.5', '50', '123.5', '49', '124.5', '48', '126', '46.5', '127', '45.5', '128.5', '44.5', '130', '43.5', '131', '43', '132.5', '42.5', '133.5', '42', '134.5', '41.5', '135.5', '41.5', '137', '41.5', '138', '41.5', '139', '41.5', '140.5', '41.5', '143.5', '41.5', '146', '41.5', '149.5', '43', '153', '46', '157', '49.5', '160.5', '53', '164', '56', '166.5', '59.5', '168.5', '63', '170', '66.5', '171', '70.5', '172', '74', '173.5', '77.5', '175', '80', '176.5', '81.5', '178', '82.5', '179.5', '83', '182', '83.5', '183.5', '83.5', '185', '83.5', '186.5', '83.5', '187.5', '83.5', '188.5', '83.5', '190', '83.5', '191.5', '83.5', '193', '83.5', '194.5', '83.5', '196.5', '83.5', '198.5', '82.5', '201', '81', '202.5', '79.5', '204.5', '77.5', '205.5', '76', '207', '74', '208', '72.5', '209.5', '71', '210.5', '69.5', '211.5', '68', '212.5', '67', '214', '65.5', '215', '64.5', '216.5', '63.5', '218', '62.5', '220', '62.5', '222', '62', '224', '61.5', '225.5', '61.5', '227.5', '61.5', '229.5', '61.5', '231.5', '61.5', '234', '61', '237', '61', '240.5', '61', '243.5', '61', '246', '61', '249', '61', '252', '61', '254.5', '60.5', '257', '60', '259.5', '60', '261', '60', '262.5', '60', '264', '60', '265.5', '60', '267', '61', '268', '62.5', '270', '65', '271.5', '67.5', '273', '69.5', '274', '72', '275.5', '74', '276.5', '76.5', '278', '78', '279.5', '79', '280.5', '79.5', '282', '80.5', '283.5', '81', '285', '81.5', '286.5', '81.5', '288', '81.5', '289', '81.5', '291', '81', '292.5', '79.5', '294', '78', '295.5', '76', '297.5', '73.5', '299', '72', '300', '71', '301', '70.5', '302', '70', '302.5', '69.5', '303.5', '69.5', '305', '69.5', '308.5', '68'], 'flowCanvasSize': ['327.5', '100'], 'timeExp': '4', 'focus': '5', 'effort': '5', 'deepest': '5', 'flow': 'true', 'durFlow': '4', 'durToFlow': ['not long', ' once I started rounds it just felt natural'], 'percentFlow': '60', 'flowDesc': '', 'flowDescA': 'true', 'flowDescB': 'true', 'flowDescC': 'true', 'flowDescD': 'true', 'flowDescE': 'false', 'flowDescF': 'true', 'FSS1': '4', 'FSS2': '5', 'FSS3': '4', 'FSS4': '5', 'FSS5': '5', 'FSS6': '4', 'FSS7': '4', 'FSS8': '4', 'FSS9': '4', 'flowQ1': '5', 'flowQ2': '5', 'flowQ3': '4', 'flowQ4': '3', 'nowAlertness': '5', 'nowStress': '4', 'nowEmotion': '1', 'nowEmoIntensity': '1', 'reactionTimesMs': ['557', '373', '324', '458', '331', '305', '340', '357', '373', '375', '475', '318', '304'], 'BIT0': '4', 'BIT1': '3', 'BIT2': '5', 'BIT3': '4', 'BIT4': '4', 'BIT5': '3', 'BIT6': '4', 'BIT7': '5', 'BIT8': ' ...
# SAVED Data/Flow_Drawings/P15HomeFinalSurvey.png
#                                      event
# timestamp
# 2023-04-22 15:24:49.212         START_TEST
# 2023-04-22 15:36:57.891   START_TRANSITION
# 2023-04-22 15:37:43.084            NOTICED
# 2023-04-22 15:40:58.075          STOP_TEST
# 2023-04-22 15:40:58.149          STOP_TEST
# 2023-04-22 15:40:59.288          STOP_TEST
# 2023-04-22 15:41:54.951       START_SURVEY
# 2023-04-22 15:40:25.000  EMPATICA_END_TIME
# GOT UI survey results: {'HomeFinalSurvey': {'startSurveyTime': ['4/22/2023', ' 3:37:44 PM'], 'durGuess': '15', 'timeAtDurGuess': ['4/22/2023', ' 3:37:48 PM'], 'durTimeConfidence': '3', 'guessTime': '3:20 PM', 'timeAtGuess': ['4/22/2023', ' 3:37:55 PM'], 'guessTimeConfidence': '2', 'flowPath': ['9', '27', '14.5', '31', '17.5', '31', '21', '31.5', '25', '33', '28.5', '34.5', '31', '36', '34', '37.5', '37', '39', '40', '41.5', '43.5', '44', '47', '46.5', '49.5', '49', '52', '51.5', '54.5', '53.5', '56.5', '55.5', '59', '57', '61', '58.5', '63', '60', '65', '61', '67', '62.5', '68.5', '64.5', '70.5', '66', '72', '67.5', '73.5', '69', '75', '70', '76', '71.5', '77.5', '72.5', '78.5', '73', '79.5', '74', '80.5', '74.5', '81.5', '76', '83.5', '76.5', '85', '77', '86', '77.5', '87.5', '78', '89.5', '78.5', '91', '79', '92.5', '79', '93.5', '79', '94.5', '79', '95.5', '79', '96', '79', '97', '79', '97.5', '79', '98', '79', '98.5', '79', '99', '78', '99.5', '77.5', '100', '76.5', '100.5', '76', '101', '74.5', '101.5', '73.5', '102', '72.5', '102', '71.5', '102', '70', '103', '69', '103', '67.5', '103', '66', '103.5', '65', '103.5', '64.5', '104', '63.5', '104', '63', '104.5', '63', '104.5', '62.5', '105', '62', '105.5', '62', '106', '61.5', '106.5', '61', '107', '61', '107.5', '60.5', '108', '60', '108.5', '59.5', '109', '59.5', '110', '59', '110.5', '58', '111.5', '58', '112.5', '57', '113.5', '56.5', '114.5', '56', '115.5', '55', '116.5', '54.5', '118', '53.5', '119', '52.5', '120', '51.5', '121', '50.5', '122.5', '50', '123.5', '49', '124.5', '48', '126', '46.5', '127', '45.5', '128.5', '44.5', '130', '43.5', '131', '43', '132.5', '42.5', '133.5', '42', '134.5', '41.5', '135.5', '41.5', '137', '41.5', '138', '41.5', '139', '41.5', '140.5', '41.5', '143.5', '41.5', '146', '41.5', '149.5', '43', '153', '46', '157', '49.5', '160.5', '53', '164', '56', '166.5', '59.5', '168.5', '63', '170', '66.5', '171', '70.5', '172', '74', '173.5', '77.5', '175', '80', '176.5', '81.5', '178', '82.5', '179.5', '83', '182', '83.5', '183.5', '83.5', '185', '83.5', '186.5', '83.5', '187.5', '83.5', '188.5', '83.5', '190', '83.5', '191.5', '83.5', '193', '83.5', '194.5', '83.5', '196.5', '83.5', '198.5', '82.5', '201', '81', '202.5', '79.5', '204.5', '77.5', '205.5', '76', '207', '74', '208', '72.5', '209.5', '71', '210.5', '69.5', '211.5', '68', '212.5', '67', '214', '65.5', '215', '64.5', '216.5', '63.5', '218', '62.5', '220', '62.5', '222', '62', '224', '61.5', '225.5', '61.5', '227.5', '61.5', '229.5', '61.5', '231.5', '61.5', '234', '61', '237', '61', '240.5', '61', '243.5', '61', '246', '61', '249', '61', '252', '61', '254.5', '60.5', '257', '60', '259.5', '60', '261', '60', '262.5', '60', '264', '60', '265.5', '60', '267', '61', '268', '62.5', '270', '65', '271.5', '67.5', '273', '69.5', '274', '72', '275.5', '74', '276.5', '76.5', '278', '78', '279.5', '79', '280.5', '79.5', '282', '80.5', '283.5', '81', '285', '81.5', '286.5', '81.5', '288', '81.5', '289', '81.5', '291', '81', '292.5', '79.5', '294', '78', '295.5', '76', '297.5', '73.5', '299', '72', '300', '71', '301', '70.5', '302', '70', '302.5', '69.5', '303.5', '69.5', '305', '69.5', '308.5', '68'], 'flowCanvasSize': ['327.5', '100'], 'timeExp': '4', 'focus': '5', 'effort': '5', 'deepest': '5', 'flow': 'true', 'durFlow': '4', 'durToFlow': ['not long', ' once I started rounds it just felt natural'], 'percentFlow': '60', 'flowDesc': '', 'flowDescA': 'true', 'flowDescB': 'true', 'flowDescC': 'true', 'flowDescD': 'true', 'flowDescE': 'false', 'flowDescF': 'true', 'FSS1': '4', 'FSS2': '5', 'FSS3': '4', 'FSS4': '5', 'FSS5': '5', 'FSS6': '4', 'FSS7': '4', 'FSS8': '4', 'FSS9': '4', 'flowQ1': '5', 'flowQ2': '5', 'flowQ3': '4', 'flowQ4': '3', 'nowAlertness': '5', 'nowStress': '4', 'nowEmotion': '1', 'nowEmoIntensity': '1', 'reactionTimesMs': ['557', '373', '324', '458', '331', '305', '340', '357', '373', '375', '475', '318', '304'], 'BIT0': '4', 'BIT1': '3', 'BIT2': '5', 'BIT3': '4', 'BIT4': '4', 'BIT5 ...
# ========== Processing session 2023-04-22 15:55:02 P15 sess2 HOME_TETRIS_RESUME
#                                     event
# timestamp
# 2023-04-22 15:55:02.313        START_TEST
# 2023-04-22 15:55:02.625  START_TRANSITION
# 2023-04-22 15:55:40.393         STOP_TEST
# GOT UI survey results: {}
# ========== Processing session 2023-04-22 15:55:42 P15 sess2 HOME_TETRIS_RESUME
#                               event
# timestamp
# 2023-04-22 15:55:42.438  START_TEST
# 2023-04-22 15:55:44.085     NOTICED
# 2023-04-22 15:55:53.978   STOP_TEST
# GOT UI survey results: {}
# Cleaning survey LabStartSurvey
# Cleaning survey LabMid1Survey
# Cleaning survey LabMidActivitySurvey
# Cleaning survey LabMid2Survey
# Cleaning survey LabMidActivitySurvey
# Cleaning survey LabFinalSurvey
# Cleaning survey HomeStartSurvey
# Cleaning survey HomeMidActivitySurvey
# Cleaning survey HomeMidSurvey
# Cleaning survey HomeMidActivitySurvey
# Cleaning survey HomeFinalSurvey

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# # FIX FLIPPED FLOW DATA
#
# A couple of participants mentioned they flipped the y-axis when drawing the flow data in their minds-- i.e. P15 on session 1.
#
# This section will (1) print possible options to fix in the first cell, and (2) if the data is passed, it will invert the y-axis, save a new image, and replace the flowData in the pickle.

# %%
# NEED TO RUN THE FOLLOWING FOR user 15, i=6 surveyname='HomeMidSurvey'

# %%
def fixFlowData(session_data, i, surveyname, folder, user):
    '''now we're going to replace the session_data[i]['surveys'][surveyname]['flowPath'] with an inverted flowpath,
    remake the call to transformFlowPathPlot to generate/save the image, and save over the session_data for this user.'''

    #grab the flow path
    flowPath = session_data[i]['surveys'][surveyname]['flowPath']
    canvassize_y = int(session_data[i]['surveys'][surveyname]['flowCanvasSize'][1])
    
    #invert the y-axis
    flowPath[1::2] = [str(canvassize_y-float(i)) for i in flowPath[1::2]]  # invert the flowPath y-axis

    #resave the data
    session_data[i]['surveys'][surveyname]['flowPath'] = flowPath
    
    #save a new flow plot
    session_data[i]['surveys'][surveyname] = transformFlowPathPlot(session_data[i]['surveys'][surveyname], folder, 'P' + str(user) + surveyname)
                                           
    return session_data

# %%
#Select the User we need to fix and the Path
folder = 'Data'
user = 15


#let's get a list of options to redo

with open(folder + '/P' + str(user) + '_Processed.pickle', 'rb') as handle:
    session_data, entrance, exit = pickle.load(handle)
    
for i, s in enumerate(session_data):
    for survey in s['surveys']:
        if 'flowPath' in s['surveys'][survey]:
            if len(s['surveys'][survey]['flowPath']):
                print(f'flowPath found in {i}: {s["session_type"]} - {survey}')
                print(f'\t>> call function with ({i}, {survey}')
# Out:
# flowPath found in 4: FLOW_CONTD - LabFinalSurvey
# 	>> call function with (4, LabFinalSurvey
# flowPath found in 6: TETRIS_CONTD - HomeMidSurvey
# 	>> call function with (6, HomeMidSurvey
# flowPath found in 8: FLOW_CONTD - HomeFinalSurvey
# 	>> call function with (8, HomeFinalSurvey

# %%
#redo and resave; make sure we're still using the correct folder/user from above!

folder = folder
user = user
i = 6
surveyname = 'HomeMidSurvey'

#open it
with open(folder + '/P' + str(user) + '_Processed.pickle', 'rb') as handle:
    session_data, entrance, exit = pickle.load(handle)
    
#fix the session_data to invert the y-axis in flowPath and redraw/resave the drawing
session_data = fixFlowData(session_data, i, surveyname, folder, user)

#resave it
with open(folder + '/P' + str(user) + '_Processed.pickle', 'wb') as handle:
        pickle.dump((session_data, entrance, exit), handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# SAVED Data/Flow_Drawings/P15HomeMidSurvey.png

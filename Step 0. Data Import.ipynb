# %% [markdown]
# # Data Import Script
# This script pulls in all relevant data for a session in my PhD experiment in raw form; it will process the data and save it to pickles for use.

# %%
import os
import cv2
import time
import pandas as pd
import numpy as np
import seaborn as sns
import humanize
import re
import glob
import math
import datetime
import pickle
from IPython.display import display, clear_output, HTML
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
import seaborn as sns
from csv import reader
from scipy.stats import beta
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R
from pympler import asizeof
from scipy import interpolate
from ahrs.filters import EKF
from ahrs import QuaternionArray
from dateutil import parser
#%matplotlib inline
# %matplotlib widget


TIMEZONE_OFFSET = 4

# %% [markdown]
# ## E4 Data
#
# by using `df = load_session_data('Data', 'P1', 'sess1')` this script will return a df with three columns: timestamp (ns), datatype (ACC, BVP, EDA, HR, IBI,or TEMP), and data (a list of values; typically a list with one value, but for acc we have three.)
#
# This is one large df with all of the E4 data for that session.  Nicely for us, it is effectively 'done'.
#
# To get dfs for each type of data separately, we can run `df_acc = extract_datatype(df, 'ACC')`.

# %% [markdown]
# What to do with the data here?
#
# #### ACC (32 Hz, m/s^2)
#
# Accelerometer data comes in at 1/64 Gs (ints) and needs to be transformed by 1/64 g (that's equivalent to '1'; 128 should give us 2G, -128 should give us -2G).  We then multiply by 9.8m/s^2 to get a similar value to our accelerometer on the glasses.
#
# For accelerometer data at the wrist, we might want to do a few things: (1) look over a time window and make a judgement about wrist movement-- is it a lot, or a little?  We may want to use that movement as a signal for how much we should trust the other sensors, which are contact based and can be pretty corrupted by motion artifacts.
#
# We can transform these three axes of motion into a vector, and see how different it is from an estimated gravity vector (resting, some stillness assumptions, etc).  Wrist stillness *may* tell us something about focus state, but probably not too much directly unless someone was engaged passively in something.  Perhaps the most interesting thing we could draw from it are patterns in the data, which summary statistics would destroy.  We can do a self-similarity matrix-style approach to build out some statistics on patterns in the accelerometer data
#
# #### BVP (64 Hz, unitless reflectance ratio)
#
# Raw PPG signal.  We may not need to look at this really-- our preference would be to derive HR and HRV/IBI from it anyway.  Maybe there is some interesting stuff in the raw signal, but that's out of scope.  Whats probably useful (if anything) is looking to see if the raw data looks trustworthy, and to check if we trust empatica's derivation of HR and IBI.  By running our own algorithm on the raw data, we might have a sense of confidence in our results.  We can also take into consideration the Accelerometer data once it's been transformed to a simple 'magnitude of motion' measure.
#
# #### HR (1 Hz, BPM)
#
# A derived signal from the BVP, this is grabbing the anticipated HR.  We may want to assess the quality of BVP and their HR algorithm on our own to see how well they're doing; we may also want to throw away data when motion is an issue.  This derived signal lends itself easily to summary stats/time slices.
#
# #### IBI (No Hz-- get them after each detected heartbeat-- so likely between 5 and 25 Hz, milliseconds)
#
# This is a processed signal, we can probably just do some summary stats on it over various windows.  Once again it relies on the BVP raw signal.
#
# #### EDA (4 Hz, uSiemens)
#
# This is one of the signals that needs the most processing work; we typically do quite a bit of cleanup, and split out SCR (transients) from SCL (low-frequency content).  10% of users are estimated to be non-responders.  This one will require a lot of cleaning.
#
# #### TEMP (4 Hz, degrees C)
#
# No cleaning necessary for skin temperature.  We'll use it in concert with the other temperature values we've been collecting.

# %% [raw]
# E4 Processing and DF plotting functions below.  Simply loads data and creates DFs, transforms Accelerometer data to m/s^2.

# %%
def generate_timestamps(length, start_time, sample_rate):
    time_offset = np.arange(length) / sample_rate
    timestamps = pd.to_datetime(start_time, unit='s', origin='unix') + pd.to_timedelta(time_offset, unit='s') - datetime.timedelta(hours=TIMEZONE_OFFSET)
    return timestamps


def process_file(file_path, file_name):
    with open(file_path, 'r') as file:
        # only take the first timestamp
        start_time = float(file.readline().split(',')[0].strip())
        df = pd.DataFrame()
        if 'IBI' in file_name:
            data = pd.read_csv(file, header=None, names=['time', 'ibi']).values.tolist()
            df['timestamp'] = pd.to_datetime([item[0] + start_time for item in data], unit='s', origin='unix')
        else:
            sample_rate = float(file.readline().split(',')[0].strip())
            data = pd.read_csv(file, header=None).values.tolist()
            df['timestamp'] = generate_timestamps(len(data), start_time, sample_rate)
            
            if 'ACC' in file_name:
                #accelerometer data is in 1/64 Gs.  Our glasses data is in m/s^2. Transform it to m/s^2
                data = [[(i/64)*9.8 for i in l] for l in data]
        df['datatype'] = file_name.split('.')[0]
        df['data'] = data
        return df

    
def load_session_data(folder, participant_id, session_id):
    data_dir = f'{folder}/{participant_id}/{participant_id}_{session_id}'
    data_frames = []

    expected_files = ['ACC.csv', 'BVP.csv', 'EDA.csv', 'HR.csv', 'IBI.csv', 'TEMP.csv']

    #load all files, save the output of 'process_file' into data_frames
    for subdir, dirs, files in os.walk(data_dir):
        for file in files:
            if file in expected_files:
                file_path = subdir + os.sep + file
                df = process_file(file_path, file)
                data_frames.append(df)
    
    #turn data_frames into df
    final_df = pd.concat(data_frames)
    final_df.set_index('timestamp', inplace=True)
    final_df.sort_index(inplace=True)
    
    return final_df


def extract_datatype(df, datatype):
    # Filter the dataframe for the given datatype
    df_filtered = df[df['datatype'] == datatype].copy()
    
    # Determine the number of columns based on the length of the 'data' list in the first row
    num_cols = len(df_filtered['data'].iloc[0])
    
    # Create column names
    if datatype == 'ACC':
        col_names = ['x','y','z']
    else:
        col_names = ['d' + str(i + 1) for i in range(num_cols)]
    
    # Split the 'data' list into multiple columns
    df_split = pd.DataFrame(df_filtered['data'].to_list(), columns=col_names)
    
    # Add timestamp back to the dataframe
    df_split.index = df_filtered.index
    
    return df_split

def plot_df(df, title):
    fig, ax = plt.subplots(figsize=(15, 3))

    # Assuming df has timestamp as index
    for column in df.columns:
        if 'tick' not in column:
            sns.lineplot(data=df, x=df.index, y=column, ax=ax, lw=1.5)
        
    # Format the x axis
    ax.xaxis.set_major_locator(mdates.AutoDateLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

    # Set grid
    ax.grid(True, which="both", color='gray', linewidth=0.25)

    # Set title and labels
    ax.set_title(title, fontsize=14)
    ax.set_xlabel('Time', fontsize=11)
    ax.set_ylabel('Value', fontsize=11)

    # Set legend
    #ax.legend(loc='upper left', fontsize=14)

    # Set tick parameters
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    # Improve date tick display
    fig.autofmt_xdate()

    plt.show()

# %% [markdown]
# ## Glasses and Watch Data
#
# We have more work to do on the glasses data, because it doesnt come with the preprocessing completed for us.  We have:
#
# (1) Accelerometer Data.  We can use similar accelerometer code as above.
#
# (2) Gyro Data.  We can combine with Accelerometer in a Kalman filter to get a sense of head orientation.  Potentially very interesting.
#
# (3) Nose and Temple Temp and Ambient Temp/Humidity data.  These come in at different rates and have different calibrations, but once applied this is straightforward to work with (we just have to do the processing).
#
# (4) Blink data.  Potentially a lot of sophisticated stuff to pull out here, but we can just start with a simple script that has some basic hueristics about blink duration and frequency content built into it.
#
# (5) Ambient Light data.  No real hard stuff here, just gotta calibrate correctly.

# %% [raw]
# Glasses processing function below.  Simply loads data and creates session_data object (which has a session per excel file from the app).
#
# Generates timestamp indexed dfs for gyro(x/y/z rad/sec), accel(x/y/z m/s^2), blink(raw analog ~reflectance), nose/temple temp(deg C), ambient temp(deg C) and humidity(%),

# %%
def get_size_mb(obj):
    size_bytes = asizeof.asizeof(obj)
    size_mb = size_bytes / (1024 * 1024)  # Convert bytes to megabytes
    return size_mb

def interpolate_df(df, start_timestamp, end_timestamp, new_freq):
    # Calculate the total time duration of the data in seconds
    total_time = (end_timestamp-start_timestamp).total_seconds()
    
    # Create new timestamp index at the desired frequency
    new_index = pd.date_range(start=start_timestamp, periods=int(total_time * new_freq), freq=f'{1/new_freq*1000}ms')

    # Initialize new DataFrame with the new index
    df_new = pd.DataFrame(index=new_index)

    # For each column in the original DataFrame, interpolate to the new frequency
    for col in df.columns:
        # Create spline interpolator for this column
        interpolator = interpolate.interp1d(df.index.values.astype(float), df[col].values, kind='cubic')

        # Interpolate this column at the new timestamps
        df_new[col] = interpolator(new_index.values.astype(float))

    return df_new

def load_session_excel(folder, participant_id, session_id):
    
    # grab all filepaths in there, in order.
    data_dir = f'{folder}/{participant_id}/{participant_id}_{session_id}'
    filepaths = sorted(glob.glob( data_dir + '/*.csv'))
    print(filepaths)
    session_data = []
    
    # process all of them
    for file in filepaths:
        
        print('\n\nProcessing ' + file)
        # pull out timestamp and session type
        pattern = r".*/(\d{6})_(\d{6})_p\d+_(.*).csv"
        match = re.search(pattern, file)
        
        date_str = match.group(1)
        time_str = match.group(2)
        session_type = match.group(3)
        
        # Convert the date and time to a pandas.Timestamp object
        timestamp = pd.to_datetime(date_str + time_str, format='%m%d%y%H%M%S')
        
        logs, blinks, acc, gyro, thermal, ui, wtemp, wlux = [], [], [], [], [], [], [], []

        with open(file, 'r') as read_obj:
            csv_reader = reader(read_obj)
            for row in csv_reader:
                try:
                    if   (row[0]=='l'):
                        logs.append(row[1:])
                    elif (row[0]=='g'):
                        if   (row[2]=='b'):
                            blinks.append(row[1:])
                        elif (row[2]=='t'):
                            thermal.append(row[1:])
                        elif (row[2]=='a'):
                            acc.append(row[1:])
                        elif (row[2]=='g'):
                            gyro.append(row[1:])
                    elif (row[0]=='u'):
                        ui.append(row[1:])
                    elif (row[0]=='w'):
                        if(row[3] == 'TX_TEMP_HUMD'):
                            wtemp.append(row[1:])
                        elif(row[3] == 'TX_LUX_WHITELUX'):
                            wlux.append(row[1:])
                except Exception as e:
                    print(str(e) + ': ' + str(row))

        print('got raw data.')
        
        session = {
            'user': participant_id,
            'session': session_id,
            'filepath': file,
            'session_type': session_type,
            'timestamp': timestamp,
            'logs': logs,
            'ui': ui
        }
        
        print('\tthermal processing...')
        try:
            check_raw_packets(thermal, timeout_ms=4200)
            thermal_df = pd.DataFrame()
            for t in thermal:
                thermal_df = pd.concat([thermal_df, parseThermalRow(t)], axis=0)    
            thermal_df.reset_index(inplace=True)
            thermal_df = reindex_to_timestamp(thermal_df)
            thermal_df['nose_tp_rolling'] = thermal_df['nose_tp'].rolling(7).mean()
            thermal_df['temple_tp_rolling'] = thermal_df['temple_tp'].rolling(2).mean()
            thermal_df['nose_thermistor_rolling'] = thermal_df['nose_thermistor'].rolling(40).mean()
            thermal_df['temple_thermistor_rolling'] = thermal_df['temple_thermistor'].rolling(40).mean()
            thermal_df['nose_temp_C'] = thermal_df.apply(lambda x: convert_nose_temp(x['nose_tp_rolling'], x['nose_thermistor_rolling']), axis=1)
            thermal_df['temple_temp_C'] = thermal_df.apply(lambda x: convert_temple_temp(x['temple_tp_rolling'], x['temple_thermistor_rolling']), axis=1)
            thermal_df['differential_C'] = thermal_df['nose_temp_C'] - thermal_df['temple_temp_C']
            thermal_df['differential_C_rolling'] = thermal_df['differential_C'].rolling(15).mean() 
            session['thermal']= thermal_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\tgyro processing...')
        try:
            check_raw_packets(gyro, timeout_ms=900)
            gyro_df = parse_xyz_data(gyro)
            gyro_df.reset_index(inplace=True)
            gyro_df = reindex_to_timestamp(gyro_df)
            gyro_df = gyro_df[gyro_df['x'] < 10000]
            gyro_df = gyro_df[gyro_df['y'] < 10000]
            gyro_df = gyro_df[gyro_df['z'] < 10000]

            #convert int16s to floats with q=9.
            #this gives us rad/s (angular velocity), we expect values in the 0.3-3 range.
            #Gyro set to updates every 10ms, or 100Hz
            gyro_df['x'] = gyro_df['x'].astype(float) / 512
            gyro_df['y'] = gyro_df['y'].astype(float) / 512
            gyro_df['z'] = gyro_df['z'].astype(float) / 512
            session['gyro']= gyro_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
       
        print('\taccelerometer processing...')
        try:
            check_raw_packets(acc, timeout_ms=1350)
            acc_df = parse_xyz_data(acc)
            acc_df.reset_index(inplace=True) 
            acc_df = reindex_to_timestamp(acc_df)
            acc_df = acc_df[acc_df['x'] < 10000]
            acc_df = acc_df[acc_df['y'] < 10000]
            acc_df = acc_df[acc_df['z'] < 10000]

            #convert int16s to floats with q=8.
            #this gives us data in m/s^2, so we expect ~9.8 when at rest
            #accelerometer set for every 20ms, or 50Hz
            acc_df['x'] = acc_df['x'].astype(float) / 256
            acc_df['y'] = acc_df['y'].astype(float) / 256
            acc_df['z'] = acc_df['z'].astype(float) / 256
            session['acc']= acc_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\tquaternion extended kalman filter application...')
        try:
            start_timestamp = max(acc_df.index[0], gyro_df.index[0])
            end_timestamp = min(acc_df.index[-1], gyro_df.index[-1])

            acc_inter = interpolate_df(acc_df, start_timestamp, end_timestamp, 100)
            gyro_inter = interpolate_df(gyro_df, start_timestamp, end_timestamp, 100)

            ekf = EKF(gyr=gyro_inter[['x','y','z']].values, acc=acc_inter[['x','y','z']].values, frequency=100.0)
            qs = QuaternionArray(ekf.Q)
            qs.remove_jumps()
            qs_df = pd.DataFrame({'w': qs[:,0], 'i':qs[:,1], 'j':qs[:,2], 'k':qs[:,3]}, index=acc_inter.index)
            session['quaternions']= qs_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\tblink processing...')
        try:
            check_raw_packets(blinks, timeout_ms=500)
            blinks_df = parse_blink_rows(blinks)
            blinks_df.reset_index(inplace=True)
            blinks_df = reindex_to_timestamp(blinks_df)
            session['blinks']= blinks_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\twatch processing...')
        try:
            session['watch_temp']= processWatchTemp(wtemp)
            session['watch_lux'] = processWatchLux(wlux)     
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
        
        session_data.append(session)
    
    print(f"The size of the loaded data is {get_size_mb(session_data)} MB")
    return session_data


def processWatchTemp(watch_data):
    '''Apply simple calibration to temp data based on comparison with cheap temp/humd gauge from amazon.
    Also, process the timestamp and turn it into a df'''
    
    to_df = []    
    
    for item in watch_data:
        to_df.append({
            'timestamp':parser.parse(item[1]), #pd.to_datetime(item[1]),
            'temp': 21.2 + (6.7/5.4) * (float(item[3])-24),
            'humidity': float(item[4])
        })
    
    df = pd.DataFrame(to_df)

    try:
        df['timestamp'] = df['timestamp'].dt.tz_localize(None)
        df.set_index('timestamp', inplace=True)
    except:
        print('\t\tno entries')

    return df

def processWatchLux(watch_data):
    
    to_df = []    
    for item in watch_data:
        to_df.append({
            'timestamp':parser.parse(item[1]), #pd.to_datetime(item[1]),
            'lux': float(item[3]),
            'whitelux': float(item[4])
        })
    
    df = pd.DataFrame(to_df)
    try:
        df['timestamp'] = df['timestamp'].dt.tz_localize(None)
        df.set_index('timestamp', inplace=True)
    except:
        print('\t\tno entries')
    return df

def parse_blink_rows(blinks):
    blink_rows = []
    
    for b in blinks:
        packetLength = int(b[6])
        blink_df_row = pd.DataFrame(data=[b[0:12] for i in range(packetLength)], 
                                    columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 
                                             'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4']) 
        
        
        blink_df_row["data"] = pd.Series([int(v) for v in b[13:]], dtype=np.int32)
        blinkSampleRate = 2000 # 2kHz
        blinkSamplePeriod_ms = 1000 * (1/blinkSampleRate) # 0.5 ms
        blink_df_row["tick_ms"] = blink_df_row['msFromStart'].astype(int)
        blink_df_row["tick_ms"] /= 2
        blink_df_row["tick_ms"] -= (packetLength - np.array(range(1, packetLength+1))) * blinkSamplePeriod_ms
        blink_df_row["saturated"] = blink_df_row["res0"].astype(int)
        blink_rows.append(blink_df_row)   
     
    return pd.concat(blink_rows)
 
    
def parse_xyz_data(data):
    def parseXYZRow(p):
        packetLength = 25
        base_data = p[0:12]
        other_data = np.array(p[13:]).astype('int32').reshape(-1,5)
        return [(base_data + list(row)) for row in other_data]

    data_out = []
    for d in data:
        data_out.extend(parseXYZRow(d))

    df = pd.DataFrame(data_out, columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4', 'x','y','z','imu_tick_ms','tick_ms'])
    
    df["tick_ms"] = df["tick_ms"]/2
    
    return df


def parseThermalRow(t):
    tempSamplePeriod_ms = 100
    numInnerPackets = 4
    rowsInInnerPacket = 5
    # each row has 128 values; 4x 32 value 'packets'; 
    # each 32 has 5 repetitions of 6 values of data + 2 (tick,epoch)
    # these 6 values are interleaved; i.e. the first three are temple numbers, and the first
    # 15 sets of three are temple vals; the second 15 sets of 3 are the corresponding nose vals.
    # to get a timestamped packet, we need [0,1,2] matched with [15,16,17] and so on within each
    # 32 value 'packet'.  
    
    df_row = pd.DataFrame(data=[t[0:12] for i in range(numInnerPackets*rowsInInnerPacket)], columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4']) 
    
    payload = np.array(t[13:]).astype(np.int32).reshape(numInnerPackets, -1)
    
    def flatten(t): return [item for sublist in t for item in sublist]
    reindex = flatten([[*range(i*3,i*3+3)] + [*range(15+i*3, 18+i*3)] + [-2,-1] for i in range(rowsInInnerPacket)])
    proper_payload = payload[:,reindex].reshape(-1,8)
    
    df_row = pd.concat([df_row, pd.DataFrame(data=proper_payload, columns=["temple_tp","temple_thermistor","secondary_temple_tick_ms","nose_tp","nose_thermistor","secondary_nose_tick_ms","tick_ms","epoch"])], axis=1)
    df_row['tick_ms'] -= tempSamplePeriod_ms * np.array([4,3,2,1,0] * numInnerPackets)
    
    return df_row

def convert_thermistor_to_K(raw_value):
    # STEP 1. Calc R_thermistor value given ADC_val
    R_divider = 100000
    ADC_max = 4095
    
    R_t = (R_divider * raw_value/ADC_max) / (1 - raw_value/ADC_max)
    
    # STEP 2. Convert R_t to temp
    R_0 = 100000
    T_0 = 298.15
    Beta = 3960
    R_inf = R_0 * math.exp(-Beta/T_0)
    
    Temp_K = Beta / np.log(R_t / R_inf)
    return Temp_K
    
def convert_thermopile_to_C(raw_val, T_ref_K, A, a_0, a_1):
    #STEP 1. Calc V_thermopile based on preamp gain and bias
    V_tp = (((raw_val / 4095) * 3.3) - (1.15+0.6084))/1000.0
    
    #STEP 2. Solve for Temperature!
    f_V_tp = (V_tp - a_0) + a_1 * (V_tp - a_0)**2
    T_obj = (T_ref_K**4 + f_V_tp/A)**0.25
    return (T_obj - 273.15)
    
def convert_nose_temp(raw_val, raw_thermistor):
    A   =  7.8e-10
    a_0 = -2.31e-01
    a_1 =  3.61e-03
    try:
        return convert_thermopile_to_C(raw_val, 
                                  convert_thermistor_to_K(raw_thermistor), 
                                  A, a_0, a_1)
    except:
        return np.nan
    
def convert_temple_temp(raw_val, raw_thermistor):
    A   =  4.21e-10
    a_0 = -3.62e-01
    a_1 =  8.31e-02
    try:
        return convert_thermopile_to_C(raw_val, 
                                  convert_thermistor_to_K(raw_thermistor), 
                                  A, a_0, a_1)
    except:
        return np.nan
    

def check_raw_packets(data, timeout_ms=500):
    last_seen = pd.to_datetime(data[0][0]) #0 = serverTimestamp
    last_tick = int(data[0][4]) #4 = packet_tick
    last_packet = int(data[0][3]) #3 = packetNum
    packets = set() 
    packets.add(last_packet)

    for i, d in enumerate(data[1:]):

        current_seen = pd.to_datetime(d[0])
        current_packet = int(d[3])
        current_tick = int(d[4])

        # Check if serverTimestamp is proceeding in order, which it should. 
        if current_seen < last_seen:
            print(f"\t\t-- at index {i+1}: Timestamp out of order. Current: {current_seen}, Previous: {last_seen}")

        # Check for duplicate packetNumbers by checking for the number in set packets.
        #if current_packet in packets:
        #    print(f"Error at index {i+1}: Duplicate packetNum detected. packetNum: {current_packet}")

        # Make sure packetNum is one larger than previous.
        if current_packet != last_packet + 1 and current_packet != 0:
            print(f"\t\tat index {i+1}: packetNum not sequentially increasing. Current: {current_packet}, Previous: {last_packet}")

        # Make sure tick has increased from last_tick.
        if current_tick <= last_tick:
            print(f"\t\tat index {i+1}: packet_tick not increasing. Current: {current_tick}, Previous: {last_tick}")

        # Check if the current tick is no more than 500ms greater than last tick.
        if current_tick - last_tick > timeout_ms:
            print(f"\t\tat index {i+1}: tick increment greater than timeout. Difference: {current_tick - last_tick}ms")

        # Update last_seen, last_tick, last_packet, packets
        last_seen = current_seen
        last_tick = current_tick
        last_packet = current_packet

        
        
def check_time_deltas(data):
    ''' feed in raw data after reading it into a list, this will just check
    server timestamps vs packet vs ticks and look at the differences elapsed 
    from packet to packet.  For debugging. '''
    prev_server = pd.to_datetime(data[0][0])
    prev_packet = int(data[0][3])
    prev_tick   = int(data[0][4])

    for d in data[1:200]:
        cs = pd.to_datetime(d[0])
        cp = int(d[3])
        ct = int(d[4])
        
        print(f'Differences: PACKET:{cp-prev_packet}\tSERVER:{humanize.precisedelta(cs-prev_server)}\tTICK:{(ct-prev_tick)/1000}')
        
        prev_server = cs
        prev_packet = cp
        prev_tick   = ct
        

def reindex_to_timestamp(df, column='tick_ms'):
    '''assumes a serverTS and tick_ms.  grabs first serverTS, assumes it marks 
    the tick_ms of the last row in the first packet, and then uses the tick_ms
    as the gold standard for all other timestamps'''
    
    df = df.copy()

    #make sure column is a datetime type
    df[column] = pd.to_datetime(df[column], unit='ms')
    
    # Set the first serverTS as the base timestamp
    base_timestamp = pd.to_datetime(df.loc[0, 'serverTS'])

    # Find the tick_ms of the last entry in the first packet by looking at the change in packetNum
    first_packet_num = df.loc[0, 'packetNum']
    zero_time_index = np.where(df['packetNum'].shift(-1) != first_packet_num)[0]
    
    if len(zero_time_index) > 0:
        zero_time = df.loc[zero_time_index[0], column]
    else:
        zero_time = df.loc[0, column]

    # Adjust tick_ms to get the correct offset
    df.loc[:, column] -= zero_time
    df.loc[:, column] = pd.to_timedelta(df[column], unit='ms')

    
    # Create new timestamp and set as index
    df['timestamp'] = base_timestamp + df[column]
    
    # Drop duplicates
    l = len(df)
    df.drop_duplicates(subset='timestamp', keep='first', inplace=True)
    print(f'\t\tdropped {l-len(df)} rows of data due to duplication.')
    
    # Drop data that's not within 10 sec of first and last server timestamp
    l = len(df)
    cutoff = pd.to_datetime(df.iloc[0]['serverTS']) - datetime.timedelta(seconds=10)
    df = df[df['timestamp'] > cutoff]
    cutoff = pd.to_datetime(df.iloc[-1]['serverTS']) + datetime.timedelta(seconds=10)
    df = df[df['timestamp'] < cutoff]
    print(f'\t\tdropped {l-len(df)} rows of data due to weird timestamps.')
    
    df['timestamp'] -= datetime.timedelta(hours=TIMEZONE_OFFSET)
    
    df.set_index('timestamp', inplace=True)
    
    print('\t\t-----------------------------')
    #print('\t\t-- reindexed timestamps based on first packet server timestamp and last tick_ms of first packet')
    #print('\t\t-- there is the possibility of drift with this technique; check that these values of the')
    #print('\t\t-- final packet are roughly in sync.')
    #print('\t\t-- First server time: ' + pd.to_datetime(df['serverTS'].iloc[0]).time().isoformat())
    #print('\t\t-- Last server time: ' + pd.to_datetime(df['serverTS'].iloc[-1]).time().isoformat())
    #print('\t\t-- First timestamp: ' + df.index[0].time().isoformat())
    #print('\t\t-- Last timestamp: ' + df.index[-1].time().isoformat())
    #print('\t\t-- Duration serverTS:  ' + humanize.precisedelta(pd.to_datetime(df['serverTS'].iloc[-1])-pd.to_datetime(df['serverTS'].iloc[0])))
    #print('\t\t-- Duration timestamp: ' + humanize.precisedelta(df.index[-1]-df.index[0]))
    print('\t\tDuration: ' + humanize.precisedelta(df.index[-1]-df.index[0]))
    print('\t\tError (server timestamp vs tick): ' + humanize.precisedelta(pd.to_datetime(df['serverTS'].iloc[-1]) - df.index[-1] - datetime.timedelta(hours=TIMEZONE_OFFSET)))
    print('\t\t% drift: ' + str(100.0*(pd.to_datetime(df['serverTS'].iloc[-1]) - df.index[-1] - datetime.timedelta(hours=TIMEZONE_OFFSET))/(df.index[-1]- df.index[0])))
     
    df.drop([column, 'serverTS', 'msFromStart','index','packetTypeLetter','packetType','packetNum','epoch','packetSize','res0','res1','res2','res3','res4'], axis=1, inplace=True)

    return df

# %% [raw]
# Functions to chop up and append E4 to session data extracted from glasses is below.

# %%
def chop_df(df, taskbounds):
    """
    This function filters a dataframe based on the provided start and end times.
    The dataframe should have timestamps as the index.
    
    Args:
        df (pd.DataFrame): Input dataframe with timestamps as the index.
        taskbounds: Tuple of (start_time, end_time), where each is an (np.datetime64)
        
    Returns:
        pd.DataFrame: A new dataframe with only the data between the provided start and end times.
    """
    start_time, end_time = taskbounds
    
    start_time = pd.to_datetime(start_time).replace(tzinfo=None)
    end_time = pd.to_datetime(end_time).replace(tzinfo=None)

    # Filter the dataframe
    df_filtered = df[(df.index >= start_time) & (df.index <= end_time)]

    return df_filtered


#process E4 data into sessions
def update_sessions_with_E4_data(session_data, folder, user, session):
    
    #load E4 data
    df = load_session_data(folder, 'P' + str(user), 'sess' + str(session))
    
    df_names = ['ACC', 'IBI', 'TEMP', 'EDA', 'BVP', 'HR']
    
    #iterate over each data_type in the E4 session
    for df_type in df_names:
        
        #get just that data
        df_temp = extract_datatype(df, df_type)
        
        #now iterate over sessions in session_data
        for i, session in enumerate(session_data):
            
            try:
                #grab start/end timestamps; let's base it on blink data, which is sampled the fastest
                start_time = session['blinks'].index[0]
                end_time = session['blinks'].index[-1]

                #grab just the relevant section for this session of this datatype and append it into the session_data
                session_data[i]['E4_' + df_type] = chop_df(df_temp, (start_time, end_time))
            except Exception as e:
                print(f'Failed to add E4 {df_type} for session {session["session_type"]}')
                print(e)
    return session_data

# %% [markdown]
# ## Behavioral and Survey Data
#
# We need to process some data that will be useful for us to make estimates about what's going on here.  Below we'll start to group the data from the surveys by section:
#
# These have specific ways to process.
#
# - standard flow test data for each section (FSS, etc)
# - standard wellbeing questionaire
# - standard TAS (absorption trait)
#
# These do not:
# - standard affect (affect model of flow) -- alertness and valence, reaction times, stress (interesting work to look at alertness vs. reaction time).
# - free text answers about caffeine, life, stress, factors that matter that we're not measuring.
# - enjoyment of tetris, enjoyment of games, self-perceived skill
#
# Things that are going to get interesting to model and definitely don't have prior art for processing them:
#
# - time perception data (durations, clock time, confidence)
# - duration voluntarily continuing the task
# - duration until noticing of light
# - additional flow datapoints, including the drawn data.
#
# In this section, we'll just organize the data.

# %% [raw]
# Survey Data Processing functions below.

# %%
#All combined

def get_user_entrance_responses(folder, user):
    '''grab the entrance survey results from google form csv'''
    
    df = pd.read_csv(folder + '/Flow_Entrance_Survey.csv')

    # Filter DataFrame to get row of specified user  
    user_row = df[df['Participant number (from the email you received):'] == user]
    
    # Ignore the timestamp and participant ID column
    user_responses = user_row.iloc[:, 2:].values.tolist()
    
    # user_responses is a list of lists, we flatten it to a single list
    user_responses = [item for sublist in user_responses for item in sublist]
    
    
    survey_data = {}
    
    #TAS : scale 1-5
    TAS_responses = user_responses[21:55]
    #BIT : scale 1-7
    BIT_responses = [v* 5 / 7 for v in user_responses[55:65]]
    del user_responses[21:65]
    #Flow Desc : Y/N
    FlowDesc_responses = user_responses[11:17]
    del user_responses[11:17]
    
    #CODE TAS
    #TAS just sum for likert 5 point version
    # based on prior work, avg ~80, std-dev ~18 (Glisky et al., 1991, Studies 2 and 3)
    survey_data['TAS'] = sum(TAS_responses)
    survey_data['TAS_stdevs'] = (sum(TAS_responses) - 80) / 18.0
    #CODE BIT
    BIT_codes = [
     'Support', 
     'Belonging',
     'Flow',
     'Accomplishment',
     'Self-efficacy',
     'Self-worth',
     'Meaning and Purpose',
     'Optimism',
     'Life Satisfaction',
     'Positive Affect'
    ]    
    strengths, weaknesses = [],[]

    for i, v in enumerate(BIT_responses):
        if v > 4.2:
            strengths.append(BIT_codes[i])
        elif v < 3.3:
            weaknesses.append(BIT_codes[i])

    BIT_mean = np.mean(BIT_responses)
    BIT_std = np.std(BIT_responses)
    print(f'BIT CODING:\t{BIT_mean:.2f} with std {BIT_std:.2f}', end='')

    if BIT_mean > 4.2:
            print(' -- DESIGNATED "STRONG"')
    elif BIT_std < 3.3:
            print(' -- DESIGNATED "AT RISK"')

    print(f'\t\t{len(strengths)} BIT STRENGTHS:\n\t\t {strengths}')
    print(f'\t\t{len(weaknesses)} BIT WEAKNESSES:\n\t\t {weaknesses}')

    survey_data['BIT_score'] = BIT_mean
    survey_data['BIT_std'] = BIT_std
    survey_data['BIT_strengths'] = strengths
    survey_data['BIT_weaknesses'] = weaknesses
    
    
    #CODE FQ
    s_score, d_score = 0, 0
    
    for r in FlowDesc_responses[:3]:
        if r == 'Yes':
            s_score +=1
    for r in FlowDesc_responses[3:]:
        if r == 'Yes':
            d_score +=1
    
    print(f'FLOW DESC:\tshallow: {s_score}\tdeep: {d_score}')
    survey_data['shallowFQ'] = s_score
    survey_data['deepFQ'] = d_score
    
    #remaining responses
    resp_keys = ['sex', 'job', 'typical_day', 'focus_best', 
     'vidgame_experience', 'vidgame_enjoy_1to7', 'vidgame_experience', 'vidgame_favtypes',
     'tetris_experience',  'tetris_enjoy_1to7',  'tetris_experience', 'flow_experiences',
     'flow_freq', 'flow_reliability', 'flow_recognition', 'flow_activity']
    
    for i, k in enumerate(resp_keys):
        survey_data[k] = user_responses[i]
        
    return survey_data


def get_user_exit_responses(folder, user):
    '''get user results for the final session, hand coded from their booklet into Final_PhD_Survey_Results.csv'''
    
    df = pd.read_csv(folder + '/Final_PhD_Survey_Results.csv')

    questions = list(df['Question'].values)
    user_responses = list(df['P' + str(user)].values)
    
    survey_data = {}
    
    #BIT : scale 1-7
    BIT_responses = [(int(v)+1)* 5 / 7 for v in user_responses[39:49]]
    del questions[39:49]
    del user_responses[39:49]
    #Flow Desc : Y/N
    FlowDesc_responses = user_responses[26:32]
    del questions[26:32]
    del user_responses[26:32]
    
    #CODE BIT
    BIT_codes = [
     'Support', 
     'Belonging',
     'Flow',
     'Accomplishment',
     'Self-efficacy',
     'Self-worth',
     'Meaning and Purpose',
     'Optimism',
     'Life Satisfaction',
     'Positive Affect'
    ]    
    strengths, weaknesses = [],[]

    for i, v in enumerate(BIT_responses):
        if v > 4.2:
            strengths.append(BIT_codes[i])
        elif v < 3.3:
            weaknesses.append(BIT_codes[i])

    BIT_mean = np.mean(BIT_responses)
    BIT_std = np.std(BIT_responses)
    print(f'BIT CODING:\t{BIT_mean:.2f} with std {BIT_std:.2f}', end='')

    if BIT_mean > 4.2:
            print(' -- DESIGNATED "STRONG"')
    elif BIT_std < 3.3:
            print(' -- DESIGNATED "AT RISK"')

    print(f'\t\t{len(strengths)} BIT STRENGTHS:\n\t\t {strengths}')
    print(f'\t\t{len(weaknesses)} BIT WEAKNESSES:\n\t\t {weaknesses}')

    survey_data['BIT_score'] = BIT_mean
    survey_data['BIT_std'] = BIT_std
    survey_data['BIT_strengths'] = strengths
    survey_data['BIT_weaknesses'] = weaknesses
    
    #CODE FQ
    s_score, d_score = 0, 0
    
    for r in FlowDesc_responses[:3]:
        if r == 'y':
            s_score +=1
    for r in FlowDesc_responses[3:]:
        if r == 'y':
            d_score +=1
    
    print(f'FLOW DESC:\tshallow: {s_score}\tdeep: {d_score}')
    survey_data['shallowFQ'] = s_score
    survey_data['deepFQ'] = d_score
    
    #remaining responses
    
    resp_keys = ['durGuess','durTimeConfidence','guessTime','guessTimeConfidence','timeExp',
    'focus','effort','deepest','flow','durFlow','durToFlow','percentFlow',
    'flowDesc','flowQ1','flowQ2','flowQ3','flowQ4','FSS1','FSS2','FSS3','FSS4',
    'FSS5','FSS6','FSS7','FSS8','FSS9','nowAlertness','nowStress','nowEmotion',
    'nowEmoIntensity','written_description','written_food_caff_exercise_sleep',
    'written_other_relevant','written_comments','written_homevlab','written_timechoice',
    'written_iphonepaper','written_observed','written_naturalwearables']
    #missing (obviously) timeAtGuess and timeAtDurGuess.  We'll use the last timestamp of the wearables for the time at guess.
    #we don't really care about the timeAtDurGuess (just use duration of flow activity-- we do care about timeAtGuess.

    
    for i, k in enumerate(resp_keys):
        survey_data[k] = user_responses[i]
        
    return survey_data


def process_ui_data(data, user):
    '''process the ui data from the session_data into a DF of important timestamps and a dictionary of survey data'''
    
    SURVEY_NAMES = ['LabStartSurvey', 
                    'LabMid1Survey', 
                    'LabMidActivitySurvey', 
                    'LabMid2Survey', 
                    'LabFinalSurvey',
                    'HomeStartSurvey', 
                    'HomeMidSurvey', 
                    'HomeMidActivitySurvey',  
                    'HomeFinalSurvey']          
                    
    # Define lists for two dataframes
    timestamps = []
    surveys = {}
    current_survey = 'UNKNOWN'
    # Traverse through data
    for row in data:
        if row[2] in ['START_TEST', 'STOP_TEST', 'START_TRANSITION', 'FINISHED_TRANSITION', 'NOTICED']:
            timestamps.append([pd.to_datetime(row[0])-datetime.timedelta(hours=TIMEZONE_OFFSET), row[2]])
        elif row[2] == 'SURVEY':
            if 'empaticaStartTime' == row[3]:
                timestamps.append([pd.to_datetime(row[4]+row[5]), 'EMPATICA_START_TIME'])
            elif 'empaticaEndTime' == row[3]:
                timestamps.append([pd.to_datetime(row[4]+row[5]), 'EMPATICA_END_TIME'])
            elif 'recordingStartTime' == row[3]:
                timestamps.append([pd.to_datetime(row[4]+row[5]), 'RECORDING_START_TIME'])
            elif row[4] in SURVEY_NAMES:
                timestamps.append([pd.to_datetime(int(row[3]), unit='ms')-datetime.timedelta(hours=TIMEZONE_OFFSET), 'START_SURVEY'])
                current_survey = row[4]
                surveys[current_survey]={}
            else:
                try:
                    surveys[current_survey][row[3]] = (row[4] if len(row)==5 else row[4:])
                except:
                    print(f'GOT unknown survey: {row}')
    
    # Create dataframes
    df_times = pd.DataFrame(timestamps, columns=['timestamp', 'event'])
    df_times['timestamp'] = pd.to_datetime(df_times['timestamp'], utc=True)
    df_times['timestamp'] = df_times['timestamp'].dt.tz_localize(None)
    df_times.set_index('timestamp', inplace=True)

    for s in surveys:
        print('\t>> processing ' + s)
        surveys[s] = codeBIT(surveys[s])
        surveys[s] = codeFlowDesc(surveys[s])
        print(surveys[s])
        surveys[s] = transformFlowPathPlot(surveys[s], folder, 'P' + str(user) + s)
        
    return df_times, surveys


def codeBIT(survey_data):
    BIT_codes = {
     'BIT0':'Support', 
     'BIT1':'Belonging',
     'BIT2':'Flow',
     'BIT3':'Accomplishment',
     'BIT4':'Self-efficacy',
     'BIT5':'Self-worth',
     'BIT6':'Meaning and Purpose',
     'BIT7':'Optimism',
     'BIT8':'Life Satisfaction',
     'BIT9':'Positive Affect'
    }
    
    all_items=[]
    strengths = []
    weaknesses = []
    
    try:
        for k in BIT_codes.keys():
            score = (int(survey_data[k]) + 1) * 5 / 7
            all_items.append(score)
            if score > 4.2:
                strengths.append(BIT_codes[k])
            elif score < 3.3:
                weaknesses.append(BIT_codes[k])

        BIT_mean = np.mean(all_items)
        BIT_std = np.std(all_items)

        print(f'BIT CODING:\t{BIT_mean:.2f} with std {BIT_std:.2f}', end='')

        if BIT_mean > 4.2:
                print(' -- DESIGNATED "STRONG"')
        elif BIT_std < 3.3:
                print(' -- DESIGNATED "AT RISK"')
                
        print(f'\t\t{len(strengths)} BIT STRENGTHS:\n\t\t {strengths}')
        print(f'\t\t{len(weaknesses)} BIT WEAKNESSES:\n\t\t {weaknesses}')
        
        survey_data['BIT_score'] = BIT_mean
        survey_data['BIT_std'] = BIT_std
        survey_data['BIT_strengths'] = strengths
        survey_data['BIT_weaknesses'] = weaknesses
        
    except:
        print('No BIT Detected')
    
    return survey_data


def codeFlowDesc(survey_data):
    ''' we need all data across all sessions in order to properly z-score flow data.
    instead of doing anything, we'll just process the one bit of data we need to
    preprocess, which is the flowDesc.
    '''
    shallow_flow = ['flowDescA','flowDescB','flowDescC']
    deep_flow = ['flowDescD','flowDescE','flowDescF']
    
    s_score = 0
    d_score = 0
    
    try:
        for k in shallow_flow:
            if survey_data[k] == 'true':
                s_score += 1
        for k in deep_flow:
            if survey_data[k] == 'true':
                d_score += 1
        
        print(f'FLOW DESC:\tshallow: {s_score}\tdeep: {d_score}')
        survey_data['shallowFQ'] = s_score
        survey_data['deepFQ'] = d_score
            
    except:
        print('No Flow Desc Detected')

    return survey_data


def transformFlowPathPlot(survey_data, folder, filename):
    
    try:
        xy = survey_data['flowPath']
        canvassize = survey_data['flowCanvasSize']
    except:
        print('No flow path data')
        return survey_data
    
    if xy=='':
        print('No flow path data')
        return survey_data
    
    xy_float = [float(i) for i in xy]

    # Create list of dictionaries representing coordinates
    coordinates = [{'x': xy_float[i], 'y': xy_float[i + 1]} for i in range(0, len(xy_float), 2)]

    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(coordinates)

    # Define the size of the plot to match your canvas size (converted to inches)
    fig, ax = plt.subplots(figsize=(float(canvassize[0]) / 40, float(canvassize[1]) / 40))

    # Create the scatterplot
    sns.lineplot(data=df, x='x', y='y', lw=5, ax=ax)
    
    # Set title and labels
    plt.title('Flow Drawing', fontsize=12)
    #plt.set_xlabel('Time', fontsize=22)
    #plt.set_ylabel('Value', fontsize=22)
    
    ax.set_xticks([0, 5, float(canvassize[0])-5, float(canvassize[0])])
    ax.set_xticklabels(['','Start of Activity', 'End of Activity',''], fontsize=8)
    ax.set_yticks([0, 2, float(canvassize[1])/2, float(canvassize[1])-2, float(canvassize[1])])
    ax.set_yticklabels(['','Distracted', 'Light Focus', 'Deep Focus',''], fontsize=10)

    # Add x and y labels
    ax.set_xlabel('Time', fontsize=8)
    
    plt.xlim([0, 327.5])
    plt.ylim([0, 100])
    
    # Invert the y axis to match the typical screen/canvas coordinate system
    ax.invert_yaxis()

    # Remove tick marks
    plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, left=False, right=False, labelleft=False)

    survey_data['flowDrawing'] = folder + '/Flow_Drawings/' + filename + '.png'
    plt.savefig(survey_data['flowDrawing'], dpi=300)
    plt.close()
    
    print('SAVED ' + survey_data['flowDrawing'])
    
    return survey_data 


def clean_survey_types(session_data):

    #iterate over sessions
    for i, session in enumerate(session_data):
        #iterate over surveys in this session
        if 'surveys' in session:
            for survey in session['surveys']:
                print(f'Cleaning survey {survey}')
                clean_survey(session['surveys'][survey])

    
def clean_survey(survey): 
    #all out of seven EXCEPT nowEmotion and nowEmoIntensity, which are 5 for SAM
    #all start as zero indexed, move to one indexed
    likert_ints = ['FSS', 'flowQ', 'now', 'timeExp', 'focus', 'effort', 'deepest']        

    #these are one indexed and have a map in the data (except percentFlow/duration/durGuess, which are just mapped directly to an int
    map_ints = ['durFlow', 'durTimeConfidence', 'guessTimeConfidence', 'percentFlow', 'duration', 'durGuess']

    times = ['LastSeenTimeStartSurvey','actualTimeAtDuration','startSurveyTime','timeAtDurGuess','timeAtGuess']

    try:
        d = survey['timeAtGuess'][0]
    except:
        pass
    
    #iterate over each key in this survey
    for k in survey.keys():
        try:
            if k == 'reactionTimesMs':
                survey['reactionTimesMs'] = [int(t) for t in survey['reactionTimesMs']]
            elif k in map_ints:
                survey[k] = int(survey[k])
            elif k in times:
                survey[k] = datetime.datetime.strptime(''.join(survey[k]), '%m/%d/%Y %I:%M:%S %p')
            elif k == 'guessTime':
                try:
                    survey['guessTime'] = datetime.datetime.strptime(d + ' ' + survey['guessTime'], '%m/%d/%Y %I:%M %p')
                except:
                    print('Failed on guessTime; no timeAtGuess date to transform')
            else:
                #iterate over likert_ints, because some are partial names
                for st in likert_ints:
                    #with partial match to k
                    if st in k:
                        #match plus 1
                        survey[k] = int(survey[k])+1
        except:
            print(f'\tfailed on {k} with value {survey[k]}')

def process_surveys(folder, user, session_data):
 
    entrance_survey, exit_survey = {}, {}
    
    print('='*10 + ' Entrance Survey Processing')
    try:
        entrance_survey = get_user_entrance_responses(folder, user)
        print('GOT ENTRANCE SURVEY: ' + str(entrance_survey))
        clean_survey(entrance_survey)
    except Exception as e:
        print(e)
        print('NO ENTRANCE SURVEY FOR THIS PARTICIPANT!!!')
 
    print('='*10 + ' Exit Survey Processing')
    try:
        exit_survey = get_user_exit_responses(folder, user)
        print('GOT EXIT SURVEY: ' + str(exit_survey))
        clean_survey(exit_survey)
    except Exception as e:
        print(e)
        print('NO EXIT SURVEY FOR THIS PARTICIPANT!!!')

        
    for session in session_data:
        try:
            print('='*10, end=' ')
            print(f"Processing session {session['timestamp']} {session['user']} {session['session']} {session['session_type']}")
            df_times, survey_results = process_ui_data(session['ui'], user)
            print(df_times)
            print('GOT UI survey results: ' + str(survey_results))
            del session['ui']
            session['surveys'] = survey_results
            session['timings'] = df_times
        except Exception as e:
            print(e)
            print('FAILED SESSION PROCESSING')
            
    clean_survey_types(session_data)
    
    return session_data, entrance_survey, exit_survey
    return session_data, entrance_survey, exit_survey

# %% [markdown]
# # Runs the above scripts to generate our data!!

# %%
users_to_process = [2,3,5,6,7,11,13,15,16,17,19,22,23,24,25]
#users_to_process = [12, 18, 20, 21] #missing one session of E4 data in [sess1, sess2]

#TODO = 4, 8, 10, 14
#DONE = 1, 9

folder = '/Volumes/Secondary/PhDStudy_Results'

for user in users_to_process:
    try:
        #grab all sections of Session 1 for that user (glasses CSVs, each separated by task/env')
        session_data = load_session_excel(folder, 'P' + str(user), 'sess1')
        session_data = update_sessions_with_E4_data(session_data, folder, user, 1)
        print('Successfully processed P' + str(user) + ' sess1.')
        
        #grab all sections of Session 2
        sess2_data = load_session_excel(folder, 'P' + str(user), 'sess2')
        sess2_data = update_sessions_with_E4_data(sess2_data, folder, user, 2)
        print('Successfully processed P' + str(user) + ' sess2.')
        
        #combine into one
        session_data.extend(sess2_data)
        print('Successfully combined P' + str(user) + ' sess1 and sess2.')
        
        #process the survey data for each session
        session_data, entrance, exit = process_surveys(folder, user, session_data)
        print('Successfully processed surveys for P' + str(user) + '.')
        
        #save to a pickle
        with open(folder + '/P' + str(user) + '_Processed.pickle', 'wb') as handle:
            pickle.dump((session_data, entrance, exit), handle, protocol=pickle.HIGHEST_PROTOCOL)
        print('Successfully saved P' + str(user) + ' data.')
        
    except Exception as e:
        print(f'ERROR WITH USER {user}: {e}')
# Out:
# ['/Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_140412_p2_LAB_DEMO.csv', '/Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_140752_p2_LAB_TETRIS.csv', '/Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_142039_p2_TETRIS_CONTD.csv', '/Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_144817_p2_LAB_FLOW.csv', '/Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_145936_p2_FLOW_CONTD.csv']
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_140412_p2_LAB_DEMO.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 3 minutes and 39.90 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.005457025920873124
# 	gyro processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 3 minutes and 39.68 seconds
# 		Error (server timestamp vs tick): 0.05 seconds
# 		% drift: 0.020939929714670697
# 	accelerometer processing...
# 		at index 57: packetNum not sequentially increasing. Current: 160, Previous: 160
# 		at index 57: packet_tick not increasing. Current: 412492, Previous: 412492
# 		dropped 46 rows of data due to duplication.
# 		dropped 4 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 3 minutes and 39.77 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: 0.011830307883762674
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 162: packetNum not sequentially increasing. Current: 1216, Previous: 1214
# 		at index 162: tick increment greater than timeout. Difference: 800ms
# 		dropped 14 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 3 minutes and 40.00 seconds
# 		Error (server timestamp vs tick): 0.28 seconds
# 		% drift: -0.1254548305791604
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_140752_p2_LAB_TETRIS.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 47.90 seconds
# 		Error (server timestamp vs tick): 0.12 seconds
# 		% drift: -0.015627034770152363
# 	gyro processing...
# 		at index 1816: packetNum not sequentially increasing. Current: 32, Previous: 30
# 		at index 1816: tick increment greater than timeout. Difference: 1223ms
# 		dropped 43 rows of data due to duplication.
# 		dropped 7 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 46.48 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.00456635004465238
# 	accelerometer processing...
# 		dropped 22 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 46.67 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.004108691186205232
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 3317: packetNum not sequentially increasing. Current: 5689, Previous: 5689
# 		at index 3317: packet_tick not increasing. Current: 1903291, Previous: 1903291
# 		dropped 455 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 46.50 seconds
# 		Error (server timestamp vs tick): 0.36 seconds
# 		% drift: -0.04709722576466129
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_142039_p2_TETRIS_CONTD.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 27 minutes and 37.90 seconds
# 		Error (server timestamp vs tick): 0.11 seconds
# 		% drift: -0.006755534109415526
# 	gyro processing...
# 		at index 4952: packetNum not sequentially increasing. Current: 56, Previous: 56
# 		at index 4952: packet_tick not increasing. Current: 5336525, Previous: 5336525
# 		dropped 233 rows of data due to duplication.
# 		dropped 26 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 27 minutes and 37.85 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.0022921239604765447
# 	accelerometer processing...
# 		at index 2825: packetNum not sequentially increasing. Current: 65, Previous: 65
# 		at index 2825: packet_tick not increasing. Current: 5108545, Previous: 5108545
# 		dropped 64 rows of data due to duplication.
# 		dropped 5 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 27 minutes and 37.73 seconds
# 		Error (server timestamp vs tick): 0.06 seconds
# 		% drift: -0.003528930595285349
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 4063: packetNum not sequentially increasing. Current: 11036, Previous: 11034
# 		at index 4063: tick increment greater than timeout. Difference: 600ms
# 		at index 4064: packetNum not sequentially increasing. Current: 11036, Previous: 11036
# 		at index 4064: packet_tick not increasing. Current: 3685491, Previous: 3685491
# 		at index 6215: packetNum not sequentially increasing. Current: 13188, Previous: 13186
# 		at index 6215: tick increment greater than timeout. Difference: 600ms
# 		at index 8332: packetNum not sequentially increasing. Current: 15306, Previous: 15304
# 		at index 8332: tick increment greater than timeout. Difference: 600ms
# 		at index 9014: packetNum not sequentially increasing. Current: 15989, Previous: 15987
# 		at index 9014: tick increment greater than timeout. Difference: 600ms
# 		dropped 265 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 27 minutes and 38.00 seconds
# 		Error (server timestamp vs tick): 0.30 seconds
# 		% drift: -0.017852840124499433
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_144817_p2_LAB_FLOW.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 17.90 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.006195604071396961
# 	gyro processing...
# 		at index 1: packetNum not sequentially increasing. Current: 56, Previous: 54
# 		at index 1: tick increment greater than timeout. Difference: 1173ms
# 		at index 743: packetNum not sequentially increasing. Current: 29, Previous: 29
# 		at index 743: packet_tick not increasing. Current: 6105548, Previous: 6105548
# 		at index 907: packetNum not sequentially increasing. Current: 192, Previous: 192
# 		at index 907: packet_tick not increasing. Current: 6205540, Previous: 6205540
# 		at index 1484: packet_tick not increasing. Current: 6557528, Previous: 6557528
# 		at index 1976: packetNum not sequentially increasing. Current: 237, Previous: 235
# 		at index 1976: tick increment greater than timeout. Difference: 1188ms
# 		at index 2204: packetNum not sequentially increasing. Current: 210, Previous: 208
# 		at index 2204: tick increment greater than timeout. Difference: 1199ms
# 		dropped 133 rows of data due to duplication.
# 		dropped 12 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 18.99 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.0020618738899018255
# 	accelerometer processing...
# 		at index 2: packetNum not sequentially increasing. Current: 102, Previous: 102
# 		at index 2: packet_tick not increasing. Current: 5647504, Previous: 5647504
# 		dropped 25 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 19.33 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.004636928498562553
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 1376: packetNum not sequentially increasing. Current: 18297, Previous: 18295
# 		at index 1376: tick increment greater than timeout. Difference: 600ms
# 		at index 1675: packetNum not sequentially increasing. Current: 18597, Previous: 18595
# 		at index 1675: tick increment greater than timeout. Difference: 600ms
# 		at index 2729: packetNum not sequentially increasing. Current: 19652, Previous: 19650
# 		at index 2729: tick increment greater than timeout. Difference: 600ms
# 		at index 3628: packetNum not sequentially increasing. Current: 20550, Previous: 20550
# 		at index 3628: packet_tick not increasing. Current: 6856891, Previous: 6856891
# 		dropped 490 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 19.00 seconds
# 		Error (server timestamp vs tick): 0.29 seconds
# 		% drift: -0.04256262338926612
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P2/P2_sess1/032923_145936_p2_FLOW_CONTD.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 27 minutes and 5.90 seconds
# 		Error (server timestamp vs tick): 0.18 seconds
# 		% drift: -0.010947782766467802
# 	gyro processing...
# 		at index 1338: packetNum not sequentially increasing. Current: 24, Previous: 22
# 		at index 1338: tick increment greater than timeout. Difference: 1211ms
# 		at index 1993: packetNum not sequentially increasing. Current: 168, Previous: 166
# 		at index 1993: tick increment greater than timeout. Difference: 1067ms
# 		at index 2465: packetNum not sequentially increasing. Current: 129, Previous: 127
# 		at index 2465: tick increment greater than timeout. Difference: 1168ms
# 		at index 2787: packetNum not sequentially increasing. Current: 196, Previous: 194
# 		at index 2787: tick increment greater than timeout. Difference: 1166ms
# 		at index 4886: packetNum not sequentially increasing. Current: 248, Previous: 246
# 		at index 4886: tick increment greater than timeout. Difference: 1304ms
# 		at index 5161: packetNum not sequentially increasing. Current: 12, Previous: 10
# 		at index 5161: tick increment greater than timeout. Difference: 1259ms
# 		dropped 96 rows of data due to duplication.
# 		dropped 16 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 27 minutes and 6.39 seconds
# 		Error (server timestamp vs tick): 0.09 seconds
# 		% drift: -0.005656710241781323
# 	accelerometer processing...
# 		dropped 60 rows of data due to duplication.
# 		dropped 5 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 27 minutes and 6.42 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.001598599135280837
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 1178: packetNum not sequentially increasing. Current: 22173, Previous: 22171
# 		at index 1178: tick increment greater than timeout. Difference: 600ms
# 		at index 2443: packetNum not sequentially increasing. Current: 23437, Previous: 23437
# 		at index 2443: packet_tick not increasing. Current: 7819291, Previous: 7819291
# 		at index 3642: packetNum not sequentially increasing. Current: 24635, Previous: 24635
# 		at index 3642: packet_tick not increasing. Current: 8218491, Previous: 8218491
# 		at index 4509: packetNum not sequentially increasing. Current: 25501, Previous: 25501
# 		at index 4509: packet_tick not increasing. Current: 8507291, Previous: 8507291
# 		at index 5098: packetNum not sequentially increasing. Current: 26089, Previous: 26089
# 		at index 5098: packet_tick not increasing. Current: 8703291, Previous: 8703291
# 		at index 8945: packetNum not sequentially increasing. Current: 29935, Previous: 29935
# 		at index 8945: packet_tick not increasing. Current: 9985291, Previous: 9985291
# 		at index 9466: packetNum not sequentially increasing. Current: 30455, Previous: 30455
# 		at index 9466: packet_tick not increasing. Current: 10158491, Previous: 10158491
# 		dropped 2122 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 27 minutes and 6.00 seconds
# 		Error (server timestamp vs tick): 0.28 seconds
# 		% drift: -0.0170356755952262
# 	watch processing...
# The size of the loaded data is 661.3025131225586 MB
# Successfully processed P2 sess1.
# ['/Volumes/Secondary/PhDStudy_Results/P2/P2_sess2/060323_124640_p2_HOME_TETRIS.csv', '/Volumes/Secondary/PhDStudy_Results/P2/P2_sess2/060323_130018_p2_TETRIS_CONTD.csv', '/Volumes/Secondary/PhDStudy_Results/P2/P2_sess2/060323_134547_p2_HOME_FLOW.csv', '/Volumes/Secondary/PhDStudy_Results/P2/P2_sess2/060323_135741_p2_RESUME_CONTD.csv']
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P2/P2_sess2/060323_124640_p2_HOME_TETRIS.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 13 minutes and 37.90 seconds
# 		Error (server timestamp vs tick): 0.09 seconds
# 		% drift: -0.011003790194400294
# 	gyro processing...
# 		at index 998: packetNum not sequentially increasing. Current: 200, Previous: 198
# 		at index 998: tick increment greater than timeout. Difference: 1247ms
# 		at index 1921: packetNum not sequentially increasing. Current: 100, Previous: 98
# 		at index 1921: tick increment greater than timeout. Difference: 1245ms
# 		dropped 87 rows of data due to duplication.
# 		dropped 11 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 13 minutes and 37.66 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: -0.0003669022382871047
# 	accelerometer processing...
# 		at index 737: packetNum not sequentially increasing. Current: 58, Previous: 56
# 		at index 737: tick increment greater than timeout. Difference: 1834ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 13 minutes and 37.76 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.002995990875067792
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 1824: packetNum not sequentially increasing. Current: 199, Previous: 8861
# 		at index 1824: packet_tick not increasing. Current: 2960496, Previous: 2960496
# 		at index 1825: packetNum not sequentially increasing. Current: 8862, Previous: 199
# 		at index 2177: packetNum not sequentially increasing. Current: 57, Previous: 9213
# 		at index 2177: packet_tick not increasing. Current: 3077897, Previous: 3077897
# 		at index 2178: packetNum not sequentially increasing. Current: 9214, Previous: 57
# 		at index 3515: packetNum not sequentially increasing. Current: 10550, Previous: 10550
# 		at index 3515: packet_tick not increasing. Current: 3523496, Previous: 3523496
# 		dropped 1392 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 13 minutes and 37.50 seconds
# 		Error (server timestamp vs tick): 0.27 seconds
# 		% drift: -0.03357798165137615
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P2/P2_sess2/060323_130018_p2_TETRIS_CONTD.csv
# got raw data.
# 	thermal processing...
# 		at index 24: packet_tick not increasing. Current: 5962, Previous: 4081683
# 		dropped 0 rows of data due to duplication.
# 		dropped 17660 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 47.90 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: -0.006263048016701462
# 	gyro processing...
# 		at index 156: packet_tick not increasing. Current: 6392, Previous: 4083013
# 		at index 1714: packetNum not sequentially increasing. Current: 21, Previous: 21
# 		at index 1714: packet_tick not increasing. Current: 949524, Previous: 949524
# 		at index 3763: packetNum not sequentially increasing. Current: 23, Previous: 21
# 		at index 3763: tick increment greater than timeout. Difference: 1295ms
# 		dropped 110 rows of data due to duplication.
# 		dropped 143815 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 47.52 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.04314063848144953
# 	accelerometer processing...
# 		at index 97: packet_tick not increasing. Current: 6805, Previous: 4082771
# 		dropped 2 rows of data due to duplication.
# 		dropped 89677 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 47.65 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.02623184756148745
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 285: packet_tick not increasing. Current: 6892, Previous: 4082496
# 		at index 3112: packetNum not sequentially increasing. Current: 2828, Previous: 2826
# 		at index 3112: tick increment greater than timeout. Difference: 600ms
# 		at index 6910: packetNum not sequentially increasing. Current: 6625, Previous: 6625
# 		at index 6910: packet_tick not increasing. Current: 2215292, Previous: 2215292
# 		dropped 1344 rows of data due to duplication.
# 		dropped 3527681 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 47.50 seconds
# 		Error (server timestamp vs tick): 0.25 seconds
# 		% drift: -0.5221107590606217
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P2/P2_sess2/060323_134547_p2_HOME_FLOW.csv
# got raw data.
# 	thermal processing...
# 		at index 134: packetNum not sequentially increasing. Current: 1474, Previous: 1472
# 		at index 134: tick increment greater than timeout. Difference: 8018ms
# 		dropped 15 rows of data due to duplication.
# 		dropped 5 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 53.90 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.0019610589718447964
# 	gyro processing...
# 		at index 298: packetNum not sequentially increasing. Current: 21, Previous: 19
# 		at index 298: tick increment greater than timeout. Difference: 1136ms
# 		at index 2238: packetNum not sequentially increasing. Current: 168, Previous: 168
# 		at index 2238: packet_tick not increasing. Current: 6729530, Previous: 6729530
# 		dropped 38 rows of data due to duplication.
# 		dropped 10 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 53.82 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.004482935426117021
# 	accelerometer processing...
# 		at index 437: packetNum not sequentially increasing. Current: 2, Previous: 0
# 		at index 437: tick increment greater than timeout. Difference: 1919ms
# 		at index 520: packetNum not sequentially increasing. Current: 86, Previous: 84
# 		at index 520: tick increment greater than timeout. Difference: 1959ms
# 		at index 522: packetNum not sequentially increasing. Current: 89, Previous: 87
# 		at index 522: tick increment greater than timeout. Difference: 2097ms
# 		at index 533: packetNum not sequentially increasing. Current: 99, Previous: 99
# 		at index 533: packet_tick not increasing. Current: 5888498, Previous: 5888498
# 		at index 1005: packetNum not sequentially increasing. Current: 60, Previous: 58
# 		at index 1005: tick increment greater than timeout. Difference: 1868ms
# 		dropped 31 rows of data due to duplication.
# 		dropped 4 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 53.98 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.003641556036894565
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 559: packetNum not sequentially increasing. Current: 16620, Previous: 16620
# 		at index 559: packet_tick not increasing. Current: 5546893, Previous: 5546893
# 		at index 1294: packetNum not sequentially increasing. Current: 17354, Previous: 17354
# 		at index 1294: packet_tick not increasing. Current: 5791492, Previous: 5791492
# 		at index 1543: packetNum not sequentially increasing. Current: 17602, Previous: 17602
# 		at index 1543: packet_tick not increasing. Current: 5874292, Previous: 5874292
# 		at index 1584: packetNum not sequentially increasing. Current: 17644, Previous: 17642
# 		at index 1584: tick increment greater than timeout. Difference: 799ms
# 		at index 2997: packetNum not sequentially increasing. Current: 19056, Previous: 19056
# 		at index 2997: packet_tick not increasing. Current: 6358893, Previous: 6358893
# 		at index 4108: packetNum not sequentially increasing. Current: 20168, Previous: 20166
# 		at index 4108: tick increment greater than timeout. Difference: 600ms
# 		dropped 1726 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 54.00 seconds
# 		Error (server timestamp vs tick): 0.23 seconds
# 		% drift: -0.032493019953095205
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P2/P2_sess2/060323_135741_p2_RESUME_CONTD.csv
# got raw data.
# 	thermal processing...
# 		dropped 5 rows of data due to duplication.
# 		dropped 10 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 53.90 seconds
# 		Error (server timestamp vs tick): 0.25 seconds
# 		% drift: -0.016935537853939354
# 	gyro processing...
# 		at index 46: packetNum not sequentially increasing. Current: 55, Previous: 55
# 		at index 46: packet_tick not increasing. Current: 6817521, Previous: 6817521
# 		at index 177: packetNum not sequentially increasing. Current: 187, Previous: 185
# 		at index 177: tick increment greater than timeout. Difference: 1130ms
# 		at index 592: packetNum not sequentially increasing. Current: 89, Previous: 89
# 		at index 592: packet_tick not increasing. Current: 7149503, Previous: 7149503
# 		at index 889: packetNum not sequentially increasing. Current: 129, Previous: 129
# 		at index 889: packet_tick not increasing. Current: 7329555, Previous: 7329555
# 		at index 1228: packetNum not sequentially increasing. Current: 211, Previous: 211
# 		at index 1228: packet_tick not increasing. Current: 7534494, Previous: 7534494
# 		at index 1522: packetNum not sequentially increasing. Current: 250, Previous: 248
# 		at index 1522: tick increment greater than timeout. Difference: 1203ms
# 		at index 1546: packetNum not sequentially increasing. Current: 19, Previous: 17
# 		at index 1546: tick increment greater than timeout. Difference: 1267ms
# 		at index 1578: packetNum not sequentially increasing. Current: 52, Previous: 50
# 		at index 1578: tick increment greater than timeout. Difference: 1242ms
# 		at index 1624: packetNum not sequentially increasing. Current: 99, Previous: 97
# 		at index 1624: tick increment greater than timeout. Difference: 1199ms
# 		at index 1963: packetNum not sequentially increasing. Current: 181, Previous: 181
# 		at index 1963: packet_tick not increasing. Current: 7984548, Previous: 7984548
# 		at index 2599: packetNum not sequentially increasing. Current: 50, Previous: 48
# 		at index 2599: tick increment greater than timeout. Difference: 1270ms
# 		at index 4104: packetNum not sequentially increasing. Current: 20, Previous: 18
# 		at index 4104: tick increment greater than timeout. Difference: 1201ms
# 		dropped 171 rows of data due to duplication.
# 		dropped 15 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 52.72 seconds
# 		Error (server timestamp vs tick): 0.09 seconds
# 		% drift: -0.006330731480851882
# 	accelerometer processing...
# 		at index 305: packetNum not sequentially increasing. Current: 25, Previous: 25
# 		at index 305: packet_tick not increasing. Current: 7093495, Previous: 7093495
# 		at index 310: packetNum not sequentially increasing. Current: 29, Previous: 29
# 		at index 310: packet_tick not increasing. Current: 7097495, Previous: 7097495
# 		at index 1143: packetNum not sequentially increasing. Current: 93, Previous: 93
# 		at index 1143: packet_tick not increasing. Current: 7919497, Previous: 7919497
# 		at index 2005: packetNum not sequentially increasing. Current: 188, Previous: 186
# 		at index 2005: tick increment greater than timeout. Difference: 2092ms
# 		at index 2963: packetNum not sequentially increasing. Current: 121, Previous: 121
# 		at index 2963: packet_tick not increasing. Current: 9706501, Previous: 9706501
# 		dropped 129 rows of data due to duplication.
# 		dropped 8 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 52.61 seconds
# 		Error (server timestamp vs tick): 0.14 seconds
# 		% drift: -0.009446530460203476
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 2: packetNum not sequentially increasing. Current: 20349, Previous: 20347
# 		at index 2: tick increment greater than timeout. Difference: 600ms
# 		at index 84: packetNum not sequentially increasing. Current: 20432, Previous: 20430
# 		at index 84: tick increment greater than timeout. Difference: 600ms
# 		at index 876: packetNum not sequentially increasing. Current: 21225, Previous: 21223
# 		at index 876: tick increment greater than timeout. Difference: 600ms
# 		at index 909: packetNum not sequentially increasing. Current: 21259, Previous: 21257
# 		at index 909: tick increment greater than timeout. Difference: 800ms
# 		at index 920: packetNum not sequentially increasing. Current: 21271, Previous: 21269
# 		at index 920: tick increment greater than timeout. Difference: 800ms
# 		at index 921: packetNum not sequentially increasing. Current: 21273, Previous: 21271
# 		at index 921: tick increment greater than timeout. Difference: 600ms
# 		at index 1074: packetNum not sequentially increasing. Current: 21427, Previous: 21425
# 		at index 1074: tick increment greater than timeout. Difference: 804ms
# 		at index 1387: packetNum not sequentially increasing. Current: 21741, Previous: 21739
# 		at index 1387: tick increment greater than timeout. Difference: 602ms
# 		at index 1614: packetNum not sequentially increasing. Current: 21969, Previous: 21967
# 		at index 1614: tick increment greater than timeout. Difference: 600ms
# 		at index 2226: packetNum not sequentially increasing. Current: 22582, Previous: 22580
# 		at index 2226: tick increment greater than timeout. Difference: 800ms
# 		at index 2536: packetNum not sequentially increasing. Current: 22893, Previous: 22891
# 		at index 2536: tick increment greater than timeout. Difference: 601ms
# 		at index 2764: packetNum not sequentially increasing. Current: 23120, Previous: 23120
# 		at index 2764: packet_tick not increasing. Current: 7713492, Previous: 7713492
# 		at index 2808: packetNum not sequentially increasing. Current: 23163, Previous: 23163
# 		at index 2808: packet_tick not increasing. Current: 7727893, Previous: 7727893
# 		at index 2871: packetNum not sequentially increasing. Current: 23225, Previous: 23225
# 		at index 2871: packet_tick not increasing. Current: 7748493, Previous: 7748493
# 		at index 2959: packetNum not sequentially increasing. Current: 23312, Previous: 23312
# 		at index 2959: packet_tick not increasing. Current: 7777493, Previous: 7777493
# 		at index 3383: packetNum not sequentially increasing. Current: 23737, Previous: 23735
# 		at index 3383: tick increment greater than timeout. Difference: 801ms
# 		at index 3426: packetNum not sequentially increasing. Current: 23781, Previous: 23779
# 		at index 3426: tick increment greater than timeout. Difference: 599ms
# 		at index 3578: packetNum not sequentially increasing. Current: 23934, Previous: 23932
# 		at index 3578: tick increment greater than timeout. Difference: 600ms
# 		at index 4736: packetNum not sequentially increasing. Current: 25091, Previous: 25091
# 		at index 4736: packet_tick not increasing. Current: 8370493, Previous: 8370493
# 		at index 5929: packetNum not sequentially increasing. Current: 26283, Previous: 26283
# 		at index 5929: packet_tick not increasing. Current: 8767893, Previous: 8767893
# 		at index 6169: packetNum not sequentially increasing. Current: 26524, Previous: 26522
# 		at index 6169: tick increment greater than timeout. Difference: 804ms
# 		at index 6170: packetNum not sequentially increasing. Current: 26524, Previous: 26524
# 		at index 6170: packet_tick not increasing. Current: 8848296, Previous: 8848296
# 		at index 7505: packetNum not sequentially increasing. Current: 19, Previous: 27858
# 		at index 7505: packet_tick not increasing. Current: 9292893, Previous: 9292893
# 		at index 7506: packetNum not sequentially increasing. Current: 27859, Previous: 19
# 		at index 8744: packetNum not sequentially increasing. Current: 29098, Previous: 29096
# 		at index 8744: tick increment greater than timeout. Difference: 802ms
# 		dropped 3146 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 53.00 seconds
# 		Error (server timestamp vs tick): 0.37 seconds
# 		% drift: -0.025016761565145054
# 	watch processing...
# The size of the loaded data is 410.15724182128906 MB
# Successfully processed P2 sess2.
# Successfully combined P2 sess1 and sess2.
# ========== Entrance Survey Processing
# BIT CODING:	nan with std nan		0 BIT STRENGTHS:
# 		 []
# 		0 BIT WEAKNESSES:
# 		 []
# FLOW DESC:	shallow: 0	deep: 0
# list index out of range
# NO ENTRANCE SURVEY FOR THIS PARTICIPANT!!!
# ========== Exit Survey Processing
# BIT CODING:	3.29 with std 1.20 -- DESIGNATED "AT RISK"
# 		4 BIT STRENGTHS:
# 		 ['Support', 'Optimism', 'Life Satisfaction', 'Positive Affect']
# 		4 BIT WEAKNESSES:
# 		 ['Accomplishment', 'Self-efficacy', 'Self-worth', 'Meaning and Purpose']
# FLOW DESC:	shallow: 1	deep: 1
# GOT EXIT SURVEY: {'BIT_score': 3.285714285714286, 'BIT_std': 1.2037356818823368, 'BIT_strengths': ['Support', 'Optimism', 'Life Satisfaction', 'Positive Affect'], 'BIT_weaknesses': ['Accomplishment', 'Self-efficacy', 'Self-worth', 'Meaning and Purpose'], 'shallowFQ': 1, 'deepFQ': 1, 'durGuess': '20', 'durTimeConfidence': '1', 'guessTime': '5:00 PM', 'guessTimeConfidence': '1', 'timeExp': '4', 'focus': '5', 'effort': '5', 'deepest': '5', 'flow': 'Y', 'durFlow': '1', 'durToFlow': '2-3min', 'percentFlow': '10', 'flowDesc': 'At first I was focused on my task.  After about 10 min, I think I worried about the system of the experiment was working correctly or not.', 'flowQ1': '2', 'flowQ2': '5', 'flowQ3': '4', 'flowQ4': '5', 'FSS1': '2', 'FSS2': '2', 'FSS3': '5', 'FSS4': '4', 'FSS5': '4', 'FSS6': '2', 'FSS7': '5', 'FSS8': '3', 'FSS9': '2', 'nowAlertness': '3', 'nowStress': '1', 'nowEmotion': '2', 'nowEmoIntensity': '3', 'written_description': 'Calm as usual.', 'written_food_caff_exercise_sleep': 'No caffeine, no exercise.  Sleep well.', 'written_other_relevant': 'I was a little hungy on the way', 'written_comments': 'na', 'written_homevlab': "I think I was able to focus more strongly on the experiment at home than in the lab.  I'm not sure about the time of day", 'written_timechoice': "I think it's important to do it habitually at a particular time because if I don't have a chance to start, I will skip it.", 'written_iphonepaper': 'I could focus my activities, but, I was worried about whether the system was working correctly.', 'written_observed': "I don't usually wear glasses so I felt very uncomfortable during the experiment.  However, I think I will get used to it after a month.", 'written_naturalwearables': "I don't think I would be able to live a relaxed life if I wore a microphone or camera."}
# Failed on guessTime; no timeAtGuess date to transform
# ========== Processing session 2023-03-29 14:04:12 P2 sess1 LAB_DEMO
# 	>> processing LabStartSurvey
# No BIT Detected
# No Flow Desc Detected
# {'age': '18-25', 'sex': '0', 'occupation': '', 'dailyActivities': '', 'timeMostAlert': '', 'vidgameExp': 'none', 'tetrisExp': 'none', 'vidgameEnjoyment': '', 'tetrisEnjoyment': '', 'gameExperience': '', 'gamesEnjoyed': '', 'tetrisExperience': '', 'flowBackgroundDescA': '', 'flowBackgroundDescB': '', 'flowBackgroundDescC': '', 'flowBackgroundDescD': '', 'flowBackgroundDescE': '', 'flowBackgroundDescF': '', 'flowBackgroundQ1': '', 'flowBackgroundQ2': '', 'flowBackgroundQ3': '', 'flowBackgroundQ4': '', 'TAS0': '', 'TAS1': '', 'TAS2': '', 'TAS3': '', 'TAS4': '', 'TAS5': '', 'TAS6': '', 'TAS7': '', 'TAS8': '', 'TAS9': '', 'TAS10': '', 'TAS11': '', 'TAS12': '', 'TAS13': '', 'TAS14': '', 'TAS15': '', 'TAS16': '', 'TAS17': '', 'TAS18': '', 'TAS19': '', 'TAS20': '', 'TAS21': '', 'TAS22': '', 'TAS23': '', 'TAS24': '', 'TAS25': '', 'TAS26': '', 'TAS27': '', 'TAS28': '', 'TAS29': '', 'TAS30': '', 'TAS31': '', 'TAS32': '', 'TAS33': '', 'BIT0': '', 'BIT1': '', 'BIT2': '', 'BIT3': '', 'BIT4': '', 'BIT5': '', 'BIT6': '', 'BIT7': '', 'BIT8': '', 'BIT9': ''}
# No flow path data
#                                         event
# timestamp
# 2023-03-29 14:04:12.589          START_SURVEY
# 2023-03-29 14:02:51.000   EMPATICA_START_TIME
# 2023-03-29 14:04:10.000  RECORDING_START_TIME
# 2023-03-29 14:04:12.712            START_TEST
# 2023-03-29 14:05:12.714      START_TRANSITION
# 2023-03-29 14:05:45.280               NOTICED
# GOT UI survey results: {'LabStartSurvey': {'age': '18-25', 'sex': '0', 'occupation': '', 'dailyActivities': '', 'timeMostAlert': '', 'vidgameExp': 'none', 'tetrisExp': 'none', 'vidgameEnjoyment': '', 'tetrisEnjoyment': '', 'gameExperience': '', 'gamesEnjoyed': '', 'tetrisExperience': '', 'flowBackgroundDescA': '', 'flowBackgroundDescB': '', 'flowBackgroundDescC': '', 'flowBackgroundDescD': '', 'flowBackgroundDescE': '', 'flowBackgroundDescF': '', 'flowBackgroundQ1': '', 'flowBackgroundQ2': '', 'flowBackgroundQ3': '', 'flowBackgroundQ4': '', 'TAS0': '', 'TAS1': '', 'TAS2': '', 'TAS3': '', 'TAS4': '', 'TAS5': '', 'TAS6': '', 'TAS7': '', 'TAS8': '', 'TAS9': '', 'TAS10': '', 'TAS11': '', 'TAS12': '', 'TAS13': '', 'TAS14': '', 'TAS15': '', 'TAS16': '', 'TAS17': '', 'TAS18': '', 'TAS19': '', 'TAS20': '', 'TAS21': '', 'TAS22': '', 'TAS23': '', 'TAS24': '', 'TAS25': '', 'TAS26': '', 'TAS27': '', 'TAS28': '', 'TAS29': '', 'TAS30': '', 'TAS31': '', 'TAS32': '', 'TAS33': '', 'BIT0': '', 'BIT1': '', 'BIT2': '', 'BIT3': '', 'BIT4': '', 'BIT5': '', 'BIT6': '', 'BIT7': '', 'BIT8': '', 'BIT9': ''}}
# ========== Processing session 2023-03-29 14:07:52 P2 sess1 LAB_TETRIS
# 	>> processing LabMid1Survey
# No BIT Detected
# No Flow Desc Detected
# {'nowAlertness': '3', 'nowStress': '1', 'nowEmotion': '1', 'nowEmoIntensity': '2', 'freeEmotion': '', 'freeFood': '', 'freeAdditional': '', 'reactionTimesMs': ['1341', '1710', '55', '428', '375', '1630', '1541', '442', '7091', '907', '673', '440', '524'], 'LastSeenTimeStartSurvey': ['3/29/2023', ' 2:07:51 PM']}
# No flow path data
# 	>> processing LabMidActivitySurvey
# No BIT Detected
# No Flow Desc Detected
# {'duration': '13', 'actualTimeAtDuration': ['3/29/2023', ' 2:20:37 PM']}
# No flow path data
#                                     event
# timestamp
# 2023-03-29 14:07:52.575      START_SURVEY
# 2023-03-29 14:07:52.646        START_TEST
# 2023-03-29 14:19:40.890  START_TRANSITION
# 2023-03-29 14:20:00.021           NOTICED
# 2023-03-29 14:20:39.214      START_SURVEY
# GOT UI survey results: {'LabMid1Survey': {'nowAlertness': '3', 'nowStress': '1', 'nowEmotion': '1', 'nowEmoIntensity': '2', 'freeEmotion': '', 'freeFood': '', 'freeAdditional': '', 'reactionTimesMs': ['1341', '1710', '55', '428', '375', '1630', '1541', '442', '7091', '907', '673', '440', '524'], 'LastSeenTimeStartSurvey': ['3/29/2023', ' 2:07:51 PM']}, 'LabMidActivitySurvey': {'duration': '13', 'actualTimeAtDuration': ['3/29/2023', ' 2:20:37 PM']}}
# ========== Processing session 2023-03-29 14:20:39 P2 sess1 TETRIS_CONTD
# 	>> processing LabMid2Survey
# No BIT Detected
# FLOW DESC:	shallow: 2	deep: 1
# {'startSurveyTime': ['3/29/2023', ' 2:35:43 PM'], 'durGuess': '20', 'timeAtDurGuess': ['3/29/2023', ' 2:36:36 PM'], 'durTimeConfidence': '3', 'guessTime': '03:00 PM', 'timeAtGuess': ['3/29/2023', ' 2:36:51 PM'], 'guessTimeConfidence': '2', 'flowPath': ['11', '2', '11', '2', '18.5', '2.5', '21.5', '2.5', '25', '3.5', '28', '5.5', '31', '7', '34.5', '10', '38.5', '14', '41.5', '17.5', '45.5', '21.5', '49', '25.5', '52.5', '29', '56.5', '32', '61', '34.5', '66', '37', '70', '39', '74', '41.5', '78', '43', '81.5', '44.5', '85.5', '46', '89.5', '47.5', '93.5', '48.5', '97', '49.5', '100', '50', '104', '50.5', '107', '51', '110', '51.5', '113.5', '52', '117', '52', '120', '52.5', '123.5', '53', '127', '53', '130', '53', '133', '53', '135.5', '53', '138', '53', '140.5', '53', '144', '53', '147', '52.5', '150.5', '51.5', '153', '51', '156', '50.5', '158.5', '49.5', '161.5', '49', '164', '48.5', '167', '47.5', '170', '45.5', '173.5', '44.5', '177', '43', '181', '42', '184', '41', '187', '40', '190', '39', '193', '38', '196', '37', '199', '35.5', '203', '34.5', '207', '34', '211', '33', '215.5', '31.5', '220', '30', '224', '28.5', '227', '27', '230', '26', '232.5', '25', '235.5', '24', '239.5', '23', '242', '22', '244.5', '21.5', '247', '20.5', '249', '20', '251', '19.5', '252', '19', '253.5', '17.5', '254.5', '17', '256', '16', '257', '15.5', '257.5', '14.5', '259', '14.5', '259.5', '14', '261', '14', '261.5', '13.5', '262', '13.5', '263', '13', '264.5', '12.5', '265.5', '12', '266.5', '11', '267', '11', '267.5', '10.5', '268', '10.5', '268.5', '10.5', '268.5', '10.5', '269.5', '10.5'], 'flowCanvasSize': ['327.5', '100'], 'timeExp': '1', 'focus': '1', 'effort': '3', 'deepest': '1', 'flow': 'false', 'durFlow': '-1', 'durToFlow': '', 'percentFlow': '0', 'flowDesc': '', 'flowDescA': 'true', 'flowDescB': 'false', 'flowDescC': 'true', 'flowDescD': 'true', 'flowDescE': 'false', 'flowDescF': 'false', 'FSS1': '5', 'FSS2': '5', 'FSS3': '3', 'FSS4': '4', 'FSS5': '5', 'FSS6': '1', 'FSS7': '1', 'FSS8': '5', 'FSS9': '4', 'flowQ1': '4', 'flowQ2': '1', 'flowQ3': '2', 'flowQ4': '3', 'nowAlertness': '1', 'nowStress': '4', 'nowEmotion': '3', 'nowEmoIntensity': '3', 'reactionTimesMs': ['457', '1645', '414', '431', '719', '430', '438', '415', '641', '724', '420', '407', '590'], 'shallowFQ': 2, 'deepFQ': 1}
# /Users/davidramsay/.virtualenvs/pyro/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/davidramsay/.virtualenvs/pyro/lib/python3.9/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/davidramsay/.virtualenvs/pyro/lib/python3.9/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/davidramsay/.virtualenvs/pyro/lib/python3.9/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /Users/davidramsay/.virtualenvs/pyro/lib/python3.9/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# SAVED /Volumes/Secondary/PhDStudy_Results/Flow_Drawings/P2LabMid2Survey.png
#                                     event
# timestamp
# 2023-03-29 14:20:39.275        START_TEST
# 2023-03-29 14:34:36.868  START_TRANSITION
# 2023-03-29 14:35:00.246           NOTICED
# 2023-03-29 14:48:16.955      START_SURVEY
# GOT UI survey results: {'LabMid2Survey': {'startSurveyTime': ['3/29/2023', ' 2:35:43 PM'], 'durGuess': '20', 'timeAtDurGuess': ['3/29/2023', ' 2:36:36 PM'], 'durTimeConfidence': '3', 'guessTime': '03:00 PM', 'timeAtGuess': ['3/29/2023', ' 2:36:51 PM'], 'guessTimeConfidence': '2', 'flowPath': ['11', '2', '11', '2', '18.5', '2.5', '21.5', '2.5', '25', '3.5', '28', '5.5', '31', '7', '34.5', '10', '38.5', '14', '41.5', '17.5', '45.5', '21.5', '49', '25.5', '52.5', '29', '56.5', '32', '61', '34.5', '66', '37', '70', '39', '74', '41.5', '78', '43', '81.5', '44.5', '85.5', '46', '89.5', '47.5', '93.5', '48.5', '97', '49.5', '100', '50', '104', '50.5', '107', '51', '110', '51.5', '113.5', '52', '117', '52', '120', '52.5', '123.5', '53', '127', '53', '130', '53', '133', '53', '135.5', '53', '138', '53', '140.5', '53', '144', '53', '147', '52.5', '150.5', '51.5', '153', '51', '156', '50.5', '158.5', '49.5', '161.5', '49', '164', '48.5', '167', '47.5', '170', '45.5', '173.5', '44.5', '177', '43', '181', '42', '184', '41', '187', '40', '190', '39', '193', '38', '196', '37', '199', '35.5', '203', '34.5', '207', '34', '211', '33', '215.5', '31.5', '220', '30', '224', '28.5', '227', '27', '230', '26', '232.5', '25', '235.5', '24', '239.5', '23', '242', '22', '244.5', '21.5', '247', '20.5', '249', '20', '251', '19.5', '252', '19', '253.5', '17.5', '254.5', '17', '256', '16', '257', '15.5', '257.5', '14.5', '259', '14.5', '259.5', '14', '261', '14', '261.5', '13.5', '262', '13.5', '263', '13', '264.5', '12.5', '265.5', '12', '266.5', '11', '267', '11', '267.5', '10.5', '268', '10.5', '268.5', '10.5', '268.5', '10.5', '269.5', '10.5'], 'flowCanvasSize': ['327.5', '100'], 'timeExp': '1', 'focus': '1', 'effort': '3', 'deepest': '1', 'flow': 'false', 'durFlow': '-1', 'durToFlow': '', 'percentFlow': '0', 'flowDesc': '', 'flowDescA': 'true', 'flowDescB': 'false', 'flowDescC': 'true', 'flowDescD': 'true', 'flowDescE': 'false', 'flowDescF': 'false', 'FSS1': '5', 'FSS2': '5', 'FSS3': '3', 'FSS4': '4', 'FSS5': '5', 'FSS6': '1', 'FSS7': '1', 'FSS8': '5', 'FSS9': '4', 'flowQ1': '4', 'flowQ2': '1', 'flowQ3': '2', 'flowQ4': '3', 'nowAlertness': '1', 'nowStress': '4', 'nowEmotion': '3', 'nowEmoIntensity': '3', 'reactionTimesMs': ['457', '1645', '414', '431', '719', '430', '438', '415', '641', '724', '420', '407', '590'], 'shallowFQ': 2, 'deepFQ': 1, 'flowDrawing': '/Volumes/Secondary/PhDStudy_Results/Flow_Drawings/P2LabMid2Survey.png'}}
# ========== Processing session 2023-03-29 14:48:17 P2 sess1 LAB_FLOW
# 	>> processing LabMidActivitySurvey
# No BIT Detected
# No Flow Desc Detected
# {'duration': '15', 'actualTimeAtDuration': ['3/29/2023', ' 2:59:35 PM']}
# No flow path data
#                                     event
# timestamp
# 2023-03-29 14:48:17.063        START_TEST
# 2023-03-29 14:58:50.520  START_TRANSITION
# 2023-03-29 14:59:26.298           NOTICED
# 2023-03-29 14:59:36.140      START_SURVEY
# GOT UI survey results: {'LabMidActivitySurvey': {'duration': '15', 'actualTimeAtDuration': ['3/29/2023', ' 2:59:35 PM']}}
# ========== Processing session 2023-03-29 14:59:36 P2 sess1 FLOW_CONTD
# 	>> processing LabFinalSurvey
# BIT CODING:	3.57 with std 0.90 -- DESIGNATED "AT RISK"
# 		5 BIT STRENGTHS:
# 		 ['Support', 'Self-efficacy', 'Self-worth', 'Optimism', 'Positive Affect']
# 		3 BIT WEAKNESSES:
# 		 ['Belonging', 'Accomplishment', 'Meaning and Purpose']
# FLOW DESC:	shallow: 2	deep: 1
# {'startSurveyTime': ['3/29/2023', ' 3:16:26 PM'], 'durGuess': '15', 'timeAtDurGuess': ['3/29/2023', ' 3:16:45 PM'], 'durTimeConfidence': '2', 'guessTime': '3:30 PM', 'timeAtGuess': ['3/29/2023', ' 3:17:07 PM'], 'guessTimeConfidence': '2', 'flowPath': ['37.5', '27.5', '37.5', '27.5', '37.5', '27.5', '37.5', '27.5', '37.5', '27.5', '38.5', '28.5', '41.5', '28.5', '44.5', '28.5', '48', '28.5', '51.5', '28.5', '55', '29', '59', '29.5', '62.5', '30', '66', '31', '68.5', '32.5', '71', '34', '72.5', '36', '74', '37.5', '75', '39', '76.5', '40', '77.5', '41', '78', '41.5', '78.5', '42', '79.5', '42.5', '80', '43', '80.5', '43.5', '81', '44', '81.5', '44', '82', '44', '83.5', '44.5', '84.5', '44.5', '85', '44.5', '86', '44.5', '87', '45', '88', '45', '89.5', '45', '90', '45', '91', '45', '92.5', '45', '94', '45.5', '95.5', '45.5', '97', '45.5', '98.5', '45.5', '100', '45.5', '102', '45.5', '104.5', '45.5', '106.5', '45.5', '109', '45.5', '111', '45.5', '113.5', '45.5', '115.5', '45.5', '118', '45.5', '120', '45.5', '123', '45.5', '125.5', '45.5', '127.5', '45.5', '129.5', '46', '131.5', '46', '133.5', '46', '135.5', '46', '137.5', '46', '139.5', '46', '141', '46', '143.5', '46', '145.5', '46', '147', '46', '149', '46', '150.5', '46', '152.5', '46', '154', '46', '155', '46', '156.5', '46', '157.5', '46', '158.5', '46', '160', '46', '161.5', '46', '162.5', '46', '163.5', '46', '164.5', '46.5', '166', '46.5', '167.5', '47', '168.5', '47.5', '169', '48', '170', '48.5', '171', '49', '172.5', '49.5', '173.5', '50.5', '174.5', '51', '176', '52', '177', '53', '178.5', '54', '179.5', '55', '181.5', '56.5', '183', '58', '185', '59', '186.5', '60.5', '188', '61.5', '190', '63', '192', '65', '193.5', '66.5', '195.5', '68', '196.5', '69.5', '198.5', '71', '200', '72', '201', '73.5', '202.5', '74.5', '204', '75.5', '205', '76.5', '206.5', '77.5', '207.5', '78.5', '208.5', '79', '210', '79.5', '211.5', '80', '213.5', '80.5', '215', '80.5', '216.5', '80.5', '218', '80.5', '221', '80.5', '222.5', '80.5', '224.5', '80.5', '227', '80.5', '229', '80.5', '231.5', '80.5', '233.5', '80.5', '236', '80.5', '238', '80.5', '240.5', '81', '243', '81.5', '245', '81.5', '246.5', '82', '249.5', '82.5', '252.5', '83', '257', '83'], 'flowCanvasSize': ['327.5', '100'], 'timeExp': '5', 'focus': '5', 'effort': '4', 'deepest': '5', 'flow': 'true', 'durFlow': '2', 'durToFlow': '10min', 'percentFlow': '20', 'flowDesc': '', 'flowDescA': 'true', 'flowDescB': 'false', 'flowDescC': 'true', 'flowDescD': 'true', 'flowDescE': 'false', 'flowDescF': 'false', 'FSS1': '6', 'FSS2': '5', 'FSS3': '5', 'FSS4': '4', 'FSS5': '6', 'FSS6': '4', 'FSS7': '5', 'FSS8': '6', 'FSS9': '3', 'flowQ1': '3', 'flowQ2': '4', 'flowQ3': '5', 'flowQ4': '5', 'nowAlertness': '1', 'nowStress': '3', 'nowEmotion': '1', 'nowEmoIntensity': '3', 'reactionTimesMs': ['420', '445', '424', '403', '430', '574', '451', '375', '457', '481', '516', '516', '445'], 'BIT0': '5', 'BIT1': '3', 'BIT2': '4', 'BIT3': '3', 'BIT4': '5', 'BIT5': '5', 'BIT6': '1', 'BIT7': '5', 'BIT8': '4', 'BIT9': '5', 'BIT_score': 3.5714285714285716, 'BIT_std': 0.9035079029052513, 'BIT_strengths': ['Support', 'Self-efficacy', 'Self-worth', 'Optimism', 'Positive Affect'], 'BIT_weaknesses': ['Belonging', 'Accomplishment', 'Meaning and Purpose'], 'shallowFQ': 2, 'deepFQ': 1}
# SAVED /Volumes/Secondary/PhDStudy_Results/Flow_Drawings/P2LabFinalSurvey.png
#                                        event
# timestamp
# 2023-03-29 14:59:36.193           START_TEST
# 2023-03-29 15:13:58.702     START_TRANSITION
# 2023-03-29 15:14:52.386  FINISHED_TRANSITION
# 2023-03-29 15:15:10.883              NOTICED
# 2023-03-29 15:26:42.210         START_SURVEY
# 2023-03-29 15:26:33.000    EMPATICA_END_TIME
# ...
# 		at index 1670: packetNum not sequentially increasing. Current: 59, Previous: 57
# 		at index 1670: tick increment greater than timeout. Difference: 1217ms
# 		dropped 161 rows of data due to duplication.
# 		dropped 27 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 17 minutes and 52.71 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.002750040434916564
# 	accelerometer processing...
# 		at index 396: packetNum not sequentially increasing. Current: 207, Previous: 205
# 		at index 396: tick increment greater than timeout. Difference: 1863ms
# 		at index 570: packetNum not sequentially increasing. Current: 126, Previous: 124
# 		at index 570: tick increment greater than timeout. Difference: 1984ms
# 		at index 1203: packetNum not sequentially increasing. Current: 246, Previous: 246
# 		at index 1203: packet_tick not increasing. Current: 3786502, Previous: 3786502
# 		at index 2150: packetNum not sequentially increasing. Current: 170, Previous: 168
# 		at index 2150: tick increment greater than timeout. Difference: 1967ms
# 		dropped 36 rows of data due to duplication.
# 		dropped 1 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 17 minutes and 52.86 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.0038681708724869123
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 1174: packetNum not sequentially increasing. Current: 8943, Previous: 8943
# 		at index 1174: packet_tick not increasing. Current: 2987891, Previous: 2987891
# 		at index 3007: packetNum not sequentially increasing. Current: 10775, Previous: 10775
# 		at index 3007: packet_tick not increasing. Current: 3598491, Previous: 3598491
# 		at index 3569: packetNum not sequentially increasing. Current: 11338, Previous: 11336
# 		at index 3569: tick increment greater than timeout. Difference: 803ms
# 		at index 6379: packetNum not sequentially increasing. Current: 14147, Previous: 14147
# 		at index 6379: packet_tick not increasing. Current: 4722490, Previous: 4722490
# 		dropped 1463 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 17 minutes and 52.50 seconds
# 		Error (server timestamp vs tick): 0.27 seconds
# 		% drift: -0.025407949098320837
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P17/P17_sess1/041523_104424_p17_LAB_FLOW.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 14 minutes and 9.90 seconds
# 		Error (server timestamp vs tick): 0.11 seconds
# 		% drift: -0.012707377338510413
# 	gyro processing...
# 		at index 116: packetNum not sequentially increasing. Current: 19, Previous: 17
# 		at index 116: tick increment greater than timeout. Difference: 1221ms
# 		at index 1588: packetNum not sequentially increasing. Current: 212, Previous: 210
# 		at index 1588: tick increment greater than timeout. Difference: 1289ms
# 		at index 2059: packetNum not sequentially increasing. Current: 172, Previous: 170
# 		at index 2059: tick increment greater than timeout. Difference: 1230ms
# 		at index 2388: packetNum not sequentially increasing. Current: 246, Previous: 244
# 		at index 2388: tick increment greater than timeout. Difference: 1123ms
# 		at index 2399: packetNum not sequentially increasing. Current: 2, Previous: 0
# 		at index 2399: tick increment greater than timeout. Difference: 1127ms
# 		at index 2690: packetNum not sequentially increasing. Current: 38, Previous: 36
# 		at index 2690: tick increment greater than timeout. Difference: 1206ms
# 		dropped 22 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 14 minutes and 9.92 seconds
# 		Error (server timestamp vs tick): 0.06 seconds
# 		% drift: -0.007177137639851233
# 	accelerometer processing...
# 		at index 60: packetNum not sequentially increasing. Current: 251, Previous: 249
# 		at index 60: tick increment greater than timeout. Difference: 1895ms
# 		at index 448: packetNum not sequentially increasing. Current: 128, Previous: 126
# 		at index 448: tick increment greater than timeout. Difference: 2002ms
# 		at index 1592: packetNum not sequentially increasing. Current: 249, Previous: 247
# 		at index 1592: tick increment greater than timeout. Difference: 2042ms
# 		at index 1678: packetNum not sequentially increasing. Current: 78, Previous: 78
# 		at index 1678: packet_tick not increasing. Current: 6392527, Previous: 6392527
# 		dropped 56 rows of data due to duplication.
# 		dropped 19 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 14 minutes and 10.22 seconds
# 		Error (server timestamp vs tick): 0.09 seconds
# 		% drift: -0.01093833250413716
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 179: packetNum not sequentially increasing. Current: 14383, Previous: 14383
# 		at index 179: packet_tick not increasing. Current: 4801291, Previous: 4801291
# 		at index 222: packetNum not sequentially increasing. Current: 14425, Previous: 14425
# 		at index 222: packet_tick not increasing. Current: 4815290, Previous: 4815290
# 		at index 1326: packetNum not sequentially increasing. Current: 15528, Previous: 15528
# 		at index 1326: packet_tick not increasing. Current: 5182891, Previous: 5182891
# 		at index 2927: packetNum not sequentially increasing. Current: 17128, Previous: 17128
# 		at index 2927: packet_tick not increasing. Current: 5716290, Previous: 5716290
# 		at index 3799: packetNum not sequentially increasing. Current: 17999, Previous: 17999
# 		at index 3799: packet_tick not increasing. Current: 6006490, Previous: 6006490
# 		at index 4406: packetNum not sequentially increasing. Current: 18605, Previous: 18605
# 		at index 4406: packet_tick not increasing. Current: 6208491, Previous: 6208491
# 		at index 4427: packetNum not sequentially increasing. Current: 18625, Previous: 18625
# 		at index 4427: packet_tick not increasing. Current: 6215290, Previous: 6215290
# 		at index 4704: packetNum not sequentially increasing. Current: 18901, Previous: 18901
# 		at index 4704: packet_tick not increasing. Current: 6307290, Previous: 6307290
# 		dropped 3297 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 14 minutes and 10.20 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.0041166856916355415
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P17/P17_sess1/041523_105834_p17_FLOW_CONTD.csv
# got raw data.
# 	thermal processing...
# 		at index 377: packetNum not sequentially increasing. Current: 1988, Previous: 1986
# 		at index 377: tick increment greater than timeout. Difference: 7999ms
# 		dropped 5 rows of data due to duplication.
# 		dropped 35 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 22 minutes and 1.90 seconds
# 		Error (server timestamp vs tick): 0.22 seconds
# 		% drift: -0.016794008623950373
# /var/folders/5b/dtlkvmxj37133_hrqx2r93qr0000gn/T/ipykernel_13712/2044786997.py:305: RuntimeWarning: invalid value encountered in log
#   Temp_K = Beta / np.log(R_t / R_inf)
# 	gyro processing...
# 		at index 75: packetNum not sequentially increasing. Current: 195, Previous: 193
# 		at index 75: tick increment greater than timeout. Difference: 1147ms
# 		at index 110: packetNum not sequentially increasing. Current: 231, Previous: 229
# 		at index 110: tick increment greater than timeout. Difference: 1222ms
# 		at index 411: packetNum not sequentially increasing. Current: 21, Previous: 19
# 		at index 411: tick increment greater than timeout. Difference: 1095ms
# 		at index 816: packetNum not sequentially increasing. Current: 169, Previous: 169
# 		at index 816: packet_tick not increasing. Current: 6941553, Previous: 6941553
# 		at index 1190: packetNum not sequentially increasing. Current: 30, Previous: 30
# 		at index 1190: packet_tick not increasing. Current: 7166523, Previous: 7166523
# 		at index 1226: packetNum not sequentially increasing. Current: 67, Previous: 65
# 		at index 1226: tick increment greater than timeout. Difference: 1248ms
# 		at index 2259: packetNum not sequentially increasing. Current: 77, Previous: 75
# 		at index 2259: tick increment greater than timeout. Difference: 1239ms
# 		at index 2623: packetNum not sequentially increasing. Current: 184, Previous: 184
# 		at index 2623: packet_tick not increasing. Current: 8037543, Previous: 8037543
# 		at index 3138: packetNum not sequentially increasing. Current: 188, Previous: 186
# 		at index 3138: tick increment greater than timeout. Difference: 1272ms
# 		at index 3594: packetNum not sequentially increasing. Current: 131, Previous: 131
# 		at index 3594: packet_tick not increasing. Current: 8625496, Previous: 8625496
# 		at index 3694: packetNum not sequentially increasing. Current: 232, Previous: 230
# 		at index 3694: tick increment greater than timeout. Difference: 1149ms
# 		dropped 166 rows of data due to duplication.
# 		dropped 13 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 22 minutes and 2.76 seconds
# 		Error (server timestamp vs tick): 0.07 seconds
# 		% drift: -0.004989557838236267
# 	accelerometer processing...
# 		at index 46: packetNum not sequentially increasing. Current: 174, Previous: 174
# 		at index 46: packet_tick not increasing. Current: 6487524, Previous: 6487524
# 		at index 64: packetNum not sequentially increasing. Current: 191, Previous: 191
# 		at index 64: packet_tick not increasing. Current: 6504546, Previous: 6504546
# 		at index 508: packetNum not sequentially increasing. Current: 124, Previous: 122
# 		at index 508: tick increment greater than timeout. Difference: 1983ms
# 		at index 943: packetNum not sequentially increasing. Current: 48, Previous: 46
# 		at index 943: tick increment greater than timeout. Difference: 1835ms
# 		at index 1391: packetNum not sequentially increasing. Current: 239, Previous: 239
# 		at index 1391: packet_tick not increasing. Current: 7817550, Previous: 7817550
# 		at index 2028: packetNum not sequentially increasing. Current: 107, Previous: 107
# 		at index 2028: packet_tick not increasing. Current: 8453524, Previous: 8453524
# 		dropped 148 rows of data due to duplication.
# 		dropped 21 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 22 minutes and 2.09 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 0.0003403690129563356
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 187: packetNum not sequentially increasing. Current: 19494, Previous: 19492
# 		at index 187: tick increment greater than timeout. Difference: 600ms
# 		at index 202: packetNum not sequentially increasing. Current: 19508, Previous: 19508
# 		at index 202: packet_tick not increasing. Current: 6509490, Previous: 6509490
# 		at index 755: packetNum not sequentially increasing. Current: 20060, Previous: 20060
# 		at index 755: packet_tick not increasing. Current: 6693491, Previous: 6693491
# 		at index 2173: packetNum not sequentially increasing. Current: 21479, Previous: 21477
# 		at index 2173: tick increment greater than timeout. Difference: 600ms
# 		at index 2239: packetNum not sequentially increasing. Current: 21544, Previous: 21544
# 		at index 2239: packet_tick not increasing. Current: 7188291, Previous: 7188291
# 		at index 4091: packetNum not sequentially increasing. Current: 23397, Previous: 23395
# 		at index 4091: tick increment greater than timeout. Difference: 601ms
# 		at index 4126: packetNum not sequentially increasing. Current: 23433, Previous: 23431
# 		at index 4126: tick increment greater than timeout. Difference: 600ms
# 		at index 4785: packetNum not sequentially increasing. Current: 24093, Previous: 24091
# 		at index 4785: tick increment greater than timeout. Difference: 599ms
# 		at index 5492: packetNum not sequentially increasing. Current: 24801, Previous: 24799
# 		at index 5492: tick increment greater than timeout. Difference: 600ms
# 		at index 5527: packetNum not sequentially increasing. Current: 24837, Previous: 24835
# 		at index 5527: tick increment greater than timeout. Difference: 600ms
# 		at index 5718: packetNum not sequentially increasing. Current: 25027, Previous: 25027
# 		at index 5718: packet_tick not increasing. Current: 8349291, Previous: 8349291
# 		at index 6030: packetNum not sequentially increasing. Current: 25341, Previous: 25338
# 		at index 6030: tick increment greater than timeout. Difference: 1000ms
# 		at index 6041: packetNum not sequentially increasing. Current: 25353, Previous: 25351
# 		at index 6041: tick increment greater than timeout. Difference: 600ms
# 		at index 6542: packetNum not sequentially increasing. Current: 25855, Previous: 25853
# 		at index 6542: tick increment greater than timeout. Difference: 801ms
# 		at index 6723: packetNum not sequentially increasing. Current: 26035, Previous: 26035
# 		at index 6723: packet_tick not increasing. Current: 8685291, Previous: 8685291
# 		at index 6940: packetNum not sequentially increasing. Current: 26253, Previous: 26251
# 		at index 6940: tick increment greater than timeout. Difference: 600ms
# 		at index 7455: packetNum not sequentially increasing. Current: 26769, Previous: 26767
# 		at index 7455: tick increment greater than timeout. Difference: 599ms
# 		at index 7538: packetNum not sequentially increasing. Current: 26853, Previous: 26851
# 		at index 7538: tick increment greater than timeout. Difference: 600ms
# 		dropped 2252 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 22 minutes and 2.30 seconds
# 		Error (server timestamp vs tick): 0.10 seconds
# 		% drift: -0.007486957379927921
# 	watch processing...
# The size of the loaded data is 585.6925277709961 MB
# Successfully processed P17 sess1.
# ['/Volumes/Secondary/PhDStudy_Results/P17/P17_sess2/042123_121227_p17_HOME_TETRIS.csv', '/Volumes/Secondary/PhDStudy_Results/P17/P17_sess2/042123_122758_p17_TETRIS_CONTD.csv', '/Volumes/Secondary/PhDStudy_Results/P17/P17_sess2/042123_125044_p17_HOME_FLOW.csv', '/Volumes/Secondary/PhDStudy_Results/P17/P17_sess2/042123_130329_p17_FLOW_CONTD.csv']
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P17/P17_sess2/042123_121227_p17_HOME_TETRIS.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 15 minutes and 29.90 seconds
# 		Error (server timestamp vs tick): 0.10 seconds
# 		% drift: -0.010323690719432198
# 	gyro processing...
# 		at index 57: packetNum not sequentially increasing. Current: 33, Previous: 31
# 		at index 57: tick increment greater than timeout. Difference: 1166ms
# 		at index 1491: packetNum not sequentially increasing. Current: 188, Previous: 186
# 		at index 1491: tick increment greater than timeout. Difference: 1365ms
# 		at index 2630: packetNum not sequentially increasing. Current: 48, Previous: 46
# 		at index 2630: tick increment greater than timeout. Difference: 1202ms
# 		at index 2811: packetNum not sequentially increasing. Current: 230, Previous: 228
# 		at index 2811: tick increment greater than timeout. Difference: 1239ms
# 		dropped 42 rows of data due to duplication.
# 		dropped 7 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 15 minutes and 30.31 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.0029559991465224283
# 	accelerometer processing...
# 		at index 318: packetNum not sequentially increasing. Current: 205, Previous: 203
# 		at index 318: tick increment greater than timeout. Difference: 2061ms
# 		dropped 22 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 15 minutes and 30.56 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.0015582073737596804
# 	quaternion extended kalman filter application...

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# # FIX FLIPPED FLOW DATA
#
# A couple of participants mentioned they flipped the y-axis when drawing the flow data in their minds-- i.e. P15 on session 1.
#
# This section will (1) print possible options to fix in the first cell, and (2) if the data is passed, it will invert the y-axis, save a new image, and replace the flowData in the pickle.

# %%
# NEED TO RUN THE FOLLOWING FOR user 15, i=6 surveyname='HomeMidSurvey'

# %%
def fixFlowData(session_data, i, surveyname, folder, user):
    '''now we're going to replace the session_data[i]['surveys'][surveyname]['flowPath'] with an inverted flowpath,
    remake the call to transformFlowPathPlot to generate/save the image, and save over the session_data for this user.'''

    #grab the flow path
    flowPath = session_data[i]['surveys'][surveyname]['flowPath']
    canvassize_y = int(session_data[i]['surveys'][surveyname]['flowCanvasSize'][1])
    
    #invert the y-axis
    flowPath[1::2] = [str(canvassize_y-float(i)) for i in flowPath[1::2]]  # invert the flowPath y-axis

    #resave the data
    session_data[i]['surveys'][surveyname]['flowPath'] = flowPath
    
    #save a new flow plot
    session_data[i]['surveys'][surveyname] = transformFlowPathPlot(session_data[i]['surveys'][surveyname], folder, 'P' + str(user) + surveyname)
                                           
    return session_data

# %%
#Select the User we need to fix and the Path
folder = 'Data'
user = 15


#let's get a list of options to redo

with open(folder + '/P' + str(user) + '_Processed.pickle', 'rb') as handle:
    session_data, entrance, exit = pickle.load(handle)
    
for i, s in enumerate(session_data):
    for survey in s['surveys']:
        if 'flowPath' in s['surveys'][survey]:
            if len(s['surveys'][survey]['flowPath']):
                print(f'flowPath found in {i}: {s["session_type"]} - {survey}')
                print(f'\t>> call function with ({i}, {survey}')
# Out:
# flowPath found in 4: FLOW_CONTD - LabFinalSurvey
# 	>> call function with (4, LabFinalSurvey
# flowPath found in 6: TETRIS_CONTD - HomeMidSurvey
# 	>> call function with (6, HomeMidSurvey
# flowPath found in 8: FLOW_CONTD - HomeFinalSurvey
# 	>> call function with (8, HomeFinalSurvey

# %%
#redo and resave; make sure we're still using the correct folder/user from above!

folder = folder
user = user
i = 6
surveyname = 'HomeMidSurvey'

#open it
with open(folder + '/P' + str(user) + '_Processed.pickle', 'rb') as handle:
    session_data, entrance, exit = pickle.load(handle)
    
#fix the session_data to invert the y-axis in flowPath and redraw/resave the drawing
session_data = fixFlowData(session_data, i, surveyname, folder, user)

#resave it
with open(folder + '/P' + str(user) + '_Processed.pickle', 'wb') as handle:
        pickle.dump((session_data, entrance, exit), handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# SAVED Data/Flow_Drawings/P15HomeMidSurvey.png

# %% [markdown]
# # Data Import Script
# This script pulls in all relevant data for a session in my PhD experiment in raw form; it will process the data and save it to pickles for use.

# %%
import os
import cv2
import time
import pandas as pd
import numpy as np
import seaborn as sns
import humanize
import re
import glob
import math
import datetime
import pickle
from IPython.display import display, clear_output, HTML
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
import seaborn as sns
from csv import reader
from scipy.stats import beta
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R
from pympler import asizeof
from scipy import interpolate
from ahrs.filters import EKF
from ahrs import QuaternionArray
from dateutil import parser
#%matplotlib inline
# %matplotlib widget


TIMEZONE_OFFSET = 4

# %% [markdown]
# ## E4 Data
#
# by using `df = load_session_data('Data', 'P1', 'sess1')` this script will return a df with three columns: timestamp (ns), datatype (ACC, BVP, EDA, HR, IBI,or TEMP), and data (a list of values; typically a list with one value, but for acc we have three.)
#
# This is one large df with all of the E4 data for that session.  Nicely for us, it is effectively 'done'.
#
# To get dfs for each type of data separately, we can run `df_acc = extract_datatype(df, 'ACC')`.

# %% [markdown]
# What to do with the data here?
#
# #### ACC (32 Hz, m/s^2)
#
# Accelerometer data comes in at 1/64 Gs (ints) and needs to be transformed by 1/64 g (that's equivalent to '1'; 128 should give us 2G, -128 should give us -2G).  We then multiply by 9.8m/s^2 to get a similar value to our accelerometer on the glasses.
#
# For accelerometer data at the wrist, we might want to do a few things: (1) look over a time window and make a judgement about wrist movement-- is it a lot, or a little?  We may want to use that movement as a signal for how much we should trust the other sensors, which are contact based and can be pretty corrupted by motion artifacts.
#
# We can transform these three axes of motion into a vector, and see how different it is from an estimated gravity vector (resting, some stillness assumptions, etc).  Wrist stillness *may* tell us something about focus state, but probably not too much directly unless someone was engaged passively in something.  Perhaps the most interesting thing we could draw from it are patterns in the data, which summary statistics would destroy.  We can do a self-similarity matrix-style approach to build out some statistics on patterns in the accelerometer data
#
# #### BVP (64 Hz, unitless reflectance ratio)
#
# Raw PPG signal.  We may not need to look at this really-- our preference would be to derive HR and HRV/IBI from it anyway.  Maybe there is some interesting stuff in the raw signal, but that's out of scope.  Whats probably useful (if anything) is looking to see if the raw data looks trustworthy, and to check if we trust empatica's derivation of HR and IBI.  By running our own algorithm on the raw data, we might have a sense of confidence in our results.  We can also take into consideration the Accelerometer data once it's been transformed to a simple 'magnitude of motion' measure.
#
# #### HR (1 Hz, BPM)
#
# A derived signal from the BVP, this is grabbing the anticipated HR.  We may want to assess the quality of BVP and their HR algorithm on our own to see how well they're doing; we may also want to throw away data when motion is an issue.  This derived signal lends itself easily to summary stats/time slices.
#
# #### IBI (No Hz-- get them after each detected heartbeat-- so likely between 5 and 25 Hz, milliseconds)
#
# This is a processed signal, we can probably just do some summary stats on it over various windows.  Once again it relies on the BVP raw signal.
#
# #### EDA (4 Hz, uSiemens)
#
# This is one of the signals that needs the most processing work; we typically do quite a bit of cleanup, and split out SCR (transients) from SCL (low-frequency content).  10% of users are estimated to be non-responders.  This one will require a lot of cleaning.
#
# #### TEMP (4 Hz, degrees C)
#
# No cleaning necessary for skin temperature.  We'll use it in concert with the other temperature values we've been collecting.

# %% [raw]
# E4 Processing and DF plotting functions below.  Simply loads data and creates DFs, transforms Accelerometer data to m/s^2.

# %%
def generate_timestamps(length, start_time, sample_rate):
    time_offset = np.arange(length) / sample_rate
    timestamps = pd.to_datetime(start_time, unit='s', origin='unix') + pd.to_timedelta(time_offset, unit='s') - datetime.timedelta(hours=TIMEZONE_OFFSET)
    return timestamps


def process_file(file_path, file_name):
    with open(file_path, 'r') as file:
        # only take the first timestamp
        start_time = float(file.readline().split(',')[0].strip())
        df = pd.DataFrame()
        if 'IBI' in file_name:
            data = pd.read_csv(file, header=None, names=['time', 'ibi']).values.tolist()
            df['timestamp'] = pd.to_datetime([item[0] + start_time for item in data], unit='s', origin='unix')
        else:
            sample_rate = float(file.readline().split(',')[0].strip())
            data = pd.read_csv(file, header=None).values.tolist()
            df['timestamp'] = generate_timestamps(len(data), start_time, sample_rate)
            
            if 'ACC' in file_name:
                #accelerometer data is in 1/64 Gs.  Our glasses data is in m/s^2. Transform it to m/s^2
                data = [[(i/64)*9.8 for i in l] for l in data]
        df['datatype'] = file_name.split('.')[0]
        df['data'] = data
        return df

    
def load_session_data(folder, participant_id, session_id):
    data_dir = f'{folder}/{participant_id}/{participant_id}_{session_id}'
    data_frames = []

    expected_files = ['ACC.csv', 'BVP.csv', 'EDA.csv', 'HR.csv', 'IBI.csv', 'TEMP.csv']

    #load all files, save the output of 'process_file' into data_frames
    for subdir, dirs, files in os.walk(data_dir):
        for file in files:
            if file in expected_files:
                file_path = subdir + os.sep + file
                df = process_file(file_path, file)
                data_frames.append(df)
    
    #turn data_frames into df
    final_df = pd.concat(data_frames)
    final_df.set_index('timestamp', inplace=True)
    final_df.sort_index(inplace=True)
    
    return final_df


def extract_datatype(df, datatype):
    # Filter the dataframe for the given datatype
    df_filtered = df[df['datatype'] == datatype].copy()
    
    # Determine the number of columns based on the length of the 'data' list in the first row
    num_cols = len(df_filtered['data'].iloc[0])
    
    # Create column names
    if datatype == 'ACC':
        col_names = ['x','y','z']
    else:
        col_names = ['d' + str(i + 1) for i in range(num_cols)]
    
    # Split the 'data' list into multiple columns
    df_split = pd.DataFrame(df_filtered['data'].to_list(), columns=col_names)
    
    # Add timestamp back to the dataframe
    df_split.index = df_filtered.index
    
    return df_split

def plot_df(df, title):
    fig, ax = plt.subplots(figsize=(15, 3))

    # Assuming df has timestamp as index
    for column in df.columns:
        if 'tick' not in column:
            sns.lineplot(data=df, x=df.index, y=column, ax=ax, lw=1.5)
        
    # Format the x axis
    ax.xaxis.set_major_locator(mdates.AutoDateLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

    # Set grid
    ax.grid(True, which="both", color='gray', linewidth=0.25)

    # Set title and labels
    ax.set_title(title, fontsize=14)
    ax.set_xlabel('Time', fontsize=11)
    ax.set_ylabel('Value', fontsize=11)

    # Set legend
    #ax.legend(loc='upper left', fontsize=14)

    # Set tick parameters
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    # Improve date tick display
    fig.autofmt_xdate()

    plt.show()

# %% [markdown]
# ## Glasses and Watch Data
#
# We have more work to do on the glasses data, because it doesnt come with the preprocessing completed for us.  We have:
#
# (1) Accelerometer Data.  We can use similar accelerometer code as above.
#
# (2) Gyro Data.  We can combine with Accelerometer in a Kalman filter to get a sense of head orientation.  Potentially very interesting.
#
# (3) Nose and Temple Temp and Ambient Temp/Humidity data.  These come in at different rates and have different calibrations, but once applied this is straightforward to work with (we just have to do the processing).
#
# (4) Blink data.  Potentially a lot of sophisticated stuff to pull out here, but we can just start with a simple script that has some basic hueristics about blink duration and frequency content built into it.
#
# (5) Ambient Light data.  No real hard stuff here, just gotta calibrate correctly.

# %% [raw]
# Glasses processing function below.  Simply loads data and creates session_data object (which has a session per excel file from the app).
#
# Generates timestamp indexed dfs for gyro(x/y/z rad/sec), accel(x/y/z m/s^2), blink(raw analog ~reflectance), nose/temple temp(deg C), ambient temp(deg C) and humidity(%),

# %%
def get_size_mb(obj):
    size_bytes = asizeof.asizeof(obj)
    size_mb = size_bytes / (1024 * 1024)  # Convert bytes to megabytes
    return size_mb

def interpolate_df(df, start_timestamp, end_timestamp, new_freq):
    # Calculate the total time duration of the data in seconds
    total_time = (end_timestamp-start_timestamp).total_seconds()
    
    # Create new timestamp index at the desired frequency
    new_index = pd.date_range(start=start_timestamp, periods=int(total_time * new_freq), freq=f'{1/new_freq*1000}ms')

    # Initialize new DataFrame with the new index
    df_new = pd.DataFrame(index=new_index)

    # For each column in the original DataFrame, interpolate to the new frequency
    for col in df.columns:
        # Create spline interpolator for this column
        interpolator = interpolate.interp1d(df.index.values.astype(float), df[col].values, kind='cubic')

        # Interpolate this column at the new timestamps
        df_new[col] = interpolator(new_index.values.astype(float))

    return df_new

def load_session_excel(folder, participant_id, session_id):
    
    # grab all filepaths in there, in order.
    data_dir = f'{folder}/{participant_id}/{participant_id}_{session_id}'
    filepaths = sorted(glob.glob( data_dir + '/*.csv'))
    print(filepaths)
    session_data = []
    
    # process all of them
    for file in filepaths:
        
        print('\n\nProcessing ' + file)
        # pull out timestamp and session type
        pattern = r".*/(\d{6})_(\d{6})_p\d+_(.*).csv"
        match = re.search(pattern, file)
        
        date_str = match.group(1)
        time_str = match.group(2)
        session_type = match.group(3)
        
        # Convert the date and time to a pandas.Timestamp object
        timestamp = pd.to_datetime(date_str + time_str, format='%m%d%y%H%M%S')
        
        logs, blinks, acc, gyro, thermal, ui, wtemp, wlux = [], [], [], [], [], [], [], []

        with open(file, 'r') as read_obj:
            csv_reader = reader(read_obj)
            for row in csv_reader:
                try:
                    if   (row[0]=='l'):
                        logs.append(row[1:])
                    elif (row[0]=='g'):
                        if   (row[2]=='b'):
                            blinks.append(row[1:])
                        elif (row[2]=='t'):
                            thermal.append(row[1:])
                        elif (row[2]=='a'):
                            acc.append(row[1:])
                        elif (row[2]=='g'):
                            gyro.append(row[1:])
                    elif (row[0]=='u'):
                        ui.append(row[1:])
                    elif (row[0]=='w'):
                        if(row[3] == 'TX_TEMP_HUMD'):
                            wtemp.append(row[1:])
                        elif(row[3] == 'TX_LUX_WHITELUX'):
                            wlux.append(row[1:])
                except Exception as e:
                    print(str(e) + ': ' + str(row))

        print('got raw data.')
        
        session = {
            'user': participant_id,
            'session': session_id,
            'filepath': file,
            'session_type': session_type,
            'timestamp': timestamp,
            'logs': logs,
            'ui': ui
        }
        
        print('\tthermal processing...')
        try:
            check_raw_packets(thermal, timeout_ms=4200)
            thermal_df = pd.DataFrame()
            for t in thermal:
                thermal_df = pd.concat([thermal_df, parseThermalRow(t)], axis=0)    
            thermal_df.reset_index(inplace=True)
            thermal_df = reindex_to_timestamp(thermal_df)
            thermal_df['nose_tp_rolling'] = thermal_df['nose_tp'].rolling(7).mean()
            thermal_df['temple_tp_rolling'] = thermal_df['temple_tp'].rolling(2).mean()
            thermal_df['nose_thermistor_rolling'] = thermal_df['nose_thermistor'].rolling(40).mean()
            thermal_df['temple_thermistor_rolling'] = thermal_df['temple_thermistor'].rolling(40).mean()
            thermal_df['nose_temp_C'] = thermal_df.apply(lambda x: convert_nose_temp(x['nose_tp_rolling'], x['nose_thermistor_rolling']), axis=1)
            thermal_df['temple_temp_C'] = thermal_df.apply(lambda x: convert_temple_temp(x['temple_tp_rolling'], x['temple_thermistor_rolling']), axis=1)
            thermal_df['differential_C'] = thermal_df['nose_temp_C'] - thermal_df['temple_temp_C']
            thermal_df['differential_C_rolling'] = thermal_df['differential_C'].rolling(15).mean() 
            session['thermal']= thermal_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\tgyro processing...')
        try:
            check_raw_packets(gyro, timeout_ms=900)
            gyro_df = parse_xyz_data(gyro)
            gyro_df.reset_index(inplace=True)
            gyro_df = reindex_to_timestamp(gyro_df)
            gyro_df = gyro_df[gyro_df['x'] < 10000]
            gyro_df = gyro_df[gyro_df['y'] < 10000]
            gyro_df = gyro_df[gyro_df['z'] < 10000]

            #convert int16s to floats with q=9.
            #this gives us rad/s (angular velocity), we expect values in the 0.3-3 range.
            #Gyro set to updates every 10ms, or 100Hz
            gyro_df['x'] = gyro_df['x'].astype(float) / 512
            gyro_df['y'] = gyro_df['y'].astype(float) / 512
            gyro_df['z'] = gyro_df['z'].astype(float) / 512
            session['gyro']= gyro_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
       
        print('\taccelerometer processing...')
        try:
            check_raw_packets(acc, timeout_ms=1350)
            acc_df = parse_xyz_data(acc)
            acc_df.reset_index(inplace=True) 
            acc_df = reindex_to_timestamp(acc_df)
            acc_df = acc_df[acc_df['x'] < 10000]
            acc_df = acc_df[acc_df['y'] < 10000]
            acc_df = acc_df[acc_df['z'] < 10000]

            #convert int16s to floats with q=8.
            #this gives us data in m/s^2, so we expect ~9.8 when at rest
            #accelerometer set for every 20ms, or 50Hz
            acc_df['x'] = acc_df['x'].astype(float) / 256
            acc_df['y'] = acc_df['y'].astype(float) / 256
            acc_df['z'] = acc_df['z'].astype(float) / 256
            session['acc']= acc_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\tquaternion extended kalman filter application...')
        try:
            start_timestamp = max(acc_df.index[0], gyro_df.index[0])
            end_timestamp = min(acc_df.index[-1], gyro_df.index[-1])

            acc_inter = interpolate_df(acc_df, start_timestamp, end_timestamp, 100)
            gyro_inter = interpolate_df(gyro_df, start_timestamp, end_timestamp, 100)

            ekf = EKF(gyr=gyro_inter[['x','y','z']].values, acc=acc_inter[['x','y','z']].values, frequency=100.0)
            qs = QuaternionArray(ekf.Q)
            qs.remove_jumps()
            qs_df = pd.DataFrame({'w': qs[:,0], 'i':qs[:,1], 'j':qs[:,2], 'k':qs[:,3]}, index=acc_inter.index)
            session['quaternions']= qs_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\tblink processing...')
        try:
            check_raw_packets(blinks, timeout_ms=500)
            blinks_df = parse_blink_rows(blinks)
            blinks_df.reset_index(inplace=True)
            blinks_df = reindex_to_timestamp(blinks_df)
            session['blinks']= blinks_df
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
            
        print('\twatch processing...')
        try:
            session['watch_temp']= processWatchTemp(wtemp)
            session['watch_lux'] = processWatchLux(wlux)     
        except Exception as e:
            print('FAILED TO PROCESS DATA!!!! ' + str(e))
        
        session_data.append(session)
    
    print(f"The size of the loaded data is {get_size_mb(session_data)} MB")
    return session_data


def processWatchTemp(watch_data):
    '''Apply simple calibration to temp data based on comparison with cheap temp/humd gauge from amazon.
    Also, process the timestamp and turn it into a df'''
    
    to_df = []    
    
    for item in watch_data:
        to_df.append({
            'timestamp':parser.parse(item[1]), #pd.to_datetime(item[1]),
            'temp': 21.2 + (6.7/5.4) * (float(item[3])-24),
            'humidity': float(item[4])
        })
    
    df = pd.DataFrame(to_df)

    try:
        df['timestamp'] = df['timestamp'].dt.tz_localize(None)
        df.set_index('timestamp', inplace=True)
    except:
        print('\t\tno entries')

    return df

def processWatchLux(watch_data):
    
    to_df = []    
    for item in watch_data:
        to_df.append({
            'timestamp':parser.parse(item[1]), #pd.to_datetime(item[1]),
            'lux': float(item[3]),
            'whitelux': float(item[4])
        })
    
    df = pd.DataFrame(to_df)
    try:
        df['timestamp'] = df['timestamp'].dt.tz_localize(None)
        df.set_index('timestamp', inplace=True)
    except:
        print('\t\tno entries')
    return df

def parse_blink_rows(blinks):
    blink_rows = []
    
    for b in blinks:
        packetLength = int(b[6])
        blink_df_row = pd.DataFrame(data=[b[0:12] for i in range(packetLength)], 
                                    columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 
                                             'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4']) 
        
        
        blink_df_row["data"] = pd.Series([int(v) for v in b[13:]], dtype=np.int32)
        blinkSampleRate = 2000 # 2kHz
        blinkSamplePeriod_ms = 1000 * (1/blinkSampleRate) # 0.5 ms
        blink_df_row["tick_ms"] = blink_df_row['msFromStart'].astype(int)
        blink_df_row["tick_ms"] /= 2
        blink_df_row["tick_ms"] -= (packetLength - np.array(range(1, packetLength+1))) * blinkSamplePeriod_ms
        blink_df_row["saturated"] = blink_df_row["res0"].astype(int)
        blink_rows.append(blink_df_row)   
     
    return pd.concat(blink_rows)
 
    
def parse_xyz_data(data):
    def parseXYZRow(p):
        packetLength = 25
        base_data = p[0:12]
        other_data = np.array(p[13:]).astype('int32').reshape(-1,5)
        return [(base_data + list(row)) for row in other_data]

    data_out = []
    for d in data:
        data_out.extend(parseXYZRow(d))

    df = pd.DataFrame(data_out, columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4', 'x','y','z','imu_tick_ms','tick_ms'])
    
    df["tick_ms"] = df["tick_ms"]/2
    
    return df


def parseThermalRow(t):
    tempSamplePeriod_ms = 100
    numInnerPackets = 4
    rowsInInnerPacket = 5
    # each row has 128 values; 4x 32 value 'packets'; 
    # each 32 has 5 repetitions of 6 values of data + 2 (tick,epoch)
    # these 6 values are interleaved; i.e. the first three are temple numbers, and the first
    # 15 sets of three are temple vals; the second 15 sets of 3 are the corresponding nose vals.
    # to get a timestamped packet, we need [0,1,2] matched with [15,16,17] and so on within each
    # 32 value 'packet'.  
    
    df_row = pd.DataFrame(data=[t[0:12] for i in range(numInnerPackets*rowsInInnerPacket)], columns=['serverTS', 'packetTypeLetter', 'packetType', 'packetNum', 'msFromStart', 'epoch', 'packetSize', 'res0', 'res1', 'res2','res3','res4']) 
    
    payload = np.array(t[13:]).astype(np.int32).reshape(numInnerPackets, -1)
    
    def flatten(t): return [item for sublist in t for item in sublist]
    reindex = flatten([[*range(i*3,i*3+3)] + [*range(15+i*3, 18+i*3)] + [-2,-1] for i in range(rowsInInnerPacket)])
    proper_payload = payload[:,reindex].reshape(-1,8)
    
    df_row = pd.concat([df_row, pd.DataFrame(data=proper_payload, columns=["temple_tp","temple_thermistor","secondary_temple_tick_ms","nose_tp","nose_thermistor","secondary_nose_tick_ms","tick_ms","epoch"])], axis=1)
    df_row['tick_ms'] -= tempSamplePeriod_ms * np.array([4,3,2,1,0] * numInnerPackets)
    
    return df_row

def convert_thermistor_to_K(raw_value):
    # STEP 1. Calc R_thermistor value given ADC_val
    R_divider = 100000
    ADC_max = 4095
    
    R_t = (R_divider * raw_value/ADC_max) / (1 - raw_value/ADC_max)
    
    # STEP 2. Convert R_t to temp
    R_0 = 100000
    T_0 = 298.15
    Beta = 3960
    R_inf = R_0 * math.exp(-Beta/T_0)
    
    Temp_K = Beta / np.log(R_t / R_inf)
    return Temp_K
    
def convert_thermopile_to_C(raw_val, T_ref_K, A, a_0, a_1):
    #STEP 1. Calc V_thermopile based on preamp gain and bias
    V_tp = (((raw_val / 4095) * 3.3) - (1.15+0.6084))/1000.0
    
    #STEP 2. Solve for Temperature!
    f_V_tp = (V_tp - a_0) + a_1 * (V_tp - a_0)**2
    T_obj = (T_ref_K**4 + f_V_tp/A)**0.25
    return (T_obj - 273.15)
    
def convert_nose_temp(raw_val, raw_thermistor):
    A   =  7.8e-10
    a_0 = -2.31e-01
    a_1 =  3.61e-03
    try:
        return convert_thermopile_to_C(raw_val, 
                                  convert_thermistor_to_K(raw_thermistor), 
                                  A, a_0, a_1)
    except:
        return np.nan
    
def convert_temple_temp(raw_val, raw_thermistor):
    A   =  4.21e-10
    a_0 = -3.62e-01
    a_1 =  8.31e-02
    try:
        return convert_thermopile_to_C(raw_val, 
                                  convert_thermistor_to_K(raw_thermistor), 
                                  A, a_0, a_1)
    except:
        return np.nan
    

def check_raw_packets(data, timeout_ms=500):
    last_seen = pd.to_datetime(data[0][0]) #0 = serverTimestamp
    last_tick = int(data[0][4]) #4 = packet_tick
    last_packet = int(data[0][3]) #3 = packetNum
    packets = set() 
    packets.add(last_packet)

    for i, d in enumerate(data[1:]):

        current_seen = pd.to_datetime(d[0])
        current_packet = int(d[3])
        current_tick = int(d[4])

        # Check if serverTimestamp is proceeding in order, which it should. 
        if current_seen < last_seen:
            print(f"\t\t-- at index {i+1}: Timestamp out of order. Current: {current_seen}, Previous: {last_seen}")

        # Check for duplicate packetNumbers by checking for the number in set packets.
        #if current_packet in packets:
        #    print(f"Error at index {i+1}: Duplicate packetNum detected. packetNum: {current_packet}")

        # Make sure packetNum is one larger than previous.
        if current_packet != last_packet + 1 and current_packet != 0:
            print(f"\t\tat index {i+1}: packetNum not sequentially increasing. Current: {current_packet}, Previous: {last_packet}")

        # Make sure tick has increased from last_tick.
        if current_tick <= last_tick:
            print(f"\t\tat index {i+1}: packet_tick not increasing. Current: {current_tick}, Previous: {last_tick}")

        # Check if the current tick is no more than 500ms greater than last tick.
        if current_tick - last_tick > timeout_ms:
            print(f"\t\tat index {i+1}: tick increment greater than timeout. Difference: {current_tick - last_tick}ms")

        # Update last_seen, last_tick, last_packet, packets
        last_seen = current_seen
        last_tick = current_tick
        last_packet = current_packet

        
        
def check_time_deltas(data):
    ''' feed in raw data after reading it into a list, this will just check
    server timestamps vs packet vs ticks and look at the differences elapsed 
    from packet to packet.  For debugging. '''
    prev_server = pd.to_datetime(data[0][0])
    prev_packet = int(data[0][3])
    prev_tick   = int(data[0][4])

    for d in data[1:200]:
        cs = pd.to_datetime(d[0])
        cp = int(d[3])
        ct = int(d[4])
        
        print(f'Differences: PACKET:{cp-prev_packet}\tSERVER:{humanize.precisedelta(cs-prev_server)}\tTICK:{(ct-prev_tick)/1000}')
        
        prev_server = cs
        prev_packet = cp
        prev_tick   = ct
        

def reindex_to_timestamp(df, column='tick_ms'):
    '''assumes a serverTS and tick_ms.  grabs first serverTS, assumes it marks 
    the tick_ms of the last row in the first packet, and then uses the tick_ms
    as the gold standard for all other timestamps'''
    
    df = df.copy()

    #make sure column is a datetime type
    df[column] = pd.to_datetime(df[column], unit='ms')
    
    # Set the first serverTS as the base timestamp
    base_timestamp = pd.to_datetime(df.loc[0, 'serverTS'])

    # Find the tick_ms of the last entry in the first packet by looking at the change in packetNum
    first_packet_num = df.loc[0, 'packetNum']
    zero_time_index = np.where(df['packetNum'].shift(-1) != first_packet_num)[0]
    
    if len(zero_time_index) > 0:
        zero_time = df.loc[zero_time_index[0], column]
    else:
        zero_time = df.loc[0, column]

    # Adjust tick_ms to get the correct offset
    df.loc[:, column] -= zero_time
    df.loc[:, column] = pd.to_timedelta(df[column], unit='ms')

    
    # Create new timestamp and set as index
    df['timestamp'] = base_timestamp + df[column]
    
    # Drop duplicates
    l = len(df)
    df.drop_duplicates(subset='timestamp', keep='first', inplace=True)
    print(f'\t\tdropped {l-len(df)} rows of data due to duplication.')
    
    # Drop data that's not within 10 sec of first and last server timestamp
    l = len(df)
    cutoff = pd.to_datetime(df.iloc[0]['serverTS']) - datetime.timedelta(seconds=10)
    df = df[df['timestamp'] > cutoff]
    cutoff = pd.to_datetime(df.iloc[-1]['serverTS']) + datetime.timedelta(seconds=10)
    df = df[df['timestamp'] < cutoff]
    print(f'\t\tdropped {l-len(df)} rows of data due to weird timestamps.')
    
    df['timestamp'] -= datetime.timedelta(hours=TIMEZONE_OFFSET)
    
    df.set_index('timestamp', inplace=True)
    
    print('\t\t-----------------------------')
    #print('\t\t-- reindexed timestamps based on first packet server timestamp and last tick_ms of first packet')
    #print('\t\t-- there is the possibility of drift with this technique; check that these values of the')
    #print('\t\t-- final packet are roughly in sync.')
    #print('\t\t-- First server time: ' + pd.to_datetime(df['serverTS'].iloc[0]).time().isoformat())
    #print('\t\t-- Last server time: ' + pd.to_datetime(df['serverTS'].iloc[-1]).time().isoformat())
    #print('\t\t-- First timestamp: ' + df.index[0].time().isoformat())
    #print('\t\t-- Last timestamp: ' + df.index[-1].time().isoformat())
    #print('\t\t-- Duration serverTS:  ' + humanize.precisedelta(pd.to_datetime(df['serverTS'].iloc[-1])-pd.to_datetime(df['serverTS'].iloc[0])))
    #print('\t\t-- Duration timestamp: ' + humanize.precisedelta(df.index[-1]-df.index[0]))
    print('\t\tDuration: ' + humanize.precisedelta(df.index[-1]-df.index[0]))
    print('\t\tError (server timestamp vs tick): ' + humanize.precisedelta(pd.to_datetime(df['serverTS'].iloc[-1]) - df.index[-1] - datetime.timedelta(hours=TIMEZONE_OFFSET)))
    print('\t\t% drift: ' + str(100.0*(pd.to_datetime(df['serverTS'].iloc[-1]) - df.index[-1] - datetime.timedelta(hours=TIMEZONE_OFFSET))/(df.index[-1]- df.index[0])))
     
    df.drop([column, 'serverTS', 'msFromStart','index','packetTypeLetter','packetType','packetNum','epoch','packetSize','res0','res1','res2','res3','res4'], axis=1, inplace=True)

    return df

# %% [raw]
# Functions to chop up and append E4 to session data extracted from glasses is below.

# %%
def chop_df(df, taskbounds):
    """
    This function filters a dataframe based on the provided start and end times.
    The dataframe should have timestamps as the index.
    
    Args:
        df (pd.DataFrame): Input dataframe with timestamps as the index.
        taskbounds: Tuple of (start_time, end_time), where each is an (np.datetime64)
        
    Returns:
        pd.DataFrame: A new dataframe with only the data between the provided start and end times.
    """
    start_time, end_time = taskbounds
    
    start_time = pd.to_datetime(start_time).replace(tzinfo=None)
    end_time = pd.to_datetime(end_time).replace(tzinfo=None)

    # Filter the dataframe
    df_filtered = df[(df.index >= start_time) & (df.index <= end_time)]

    return df_filtered


#process E4 data into sessions
def update_sessions_with_E4_data(session_data, folder, user, session):
    
    #load E4 data
    df = load_session_data(folder, 'P' + str(user), 'sess' + str(session))
    
    df_names = ['ACC', 'IBI', 'TEMP', 'EDA', 'BVP', 'HR']
    
    #iterate over each data_type in the E4 session
    for df_type in df_names:
        
        #get just that data
        df_temp = extract_datatype(df, df_type)
        
        #now iterate over sessions in session_data
        for i, session in enumerate(session_data):
            
            try:
                #grab start/end timestamps; let's base it on blink data, which is sampled the fastest
                start_time = session['blinks'].index[0]
                end_time = session['blinks'].index[-1]

                #grab just the relevant section for this session of this datatype and append it into the session_data
                session_data[i]['E4_' + df_type] = chop_df(df_temp, (start_time, end_time))
            except Exception as e:
                print(f'Failed to add E4 {df_type} for session {session["session_type"]}')
                print(e)
    return session_data

# %% [markdown]
# ## Behavioral and Survey Data
#
# We need to process some data that will be useful for us to make estimates about what's going on here.  Below we'll start to group the data from the surveys by section:
#
# These have specific ways to process.
#
# - standard flow test data for each section (FSS, etc)
# - standard wellbeing questionaire
# - standard TAS (absorption trait)
#
# These do not:
# - standard affect (affect model of flow) -- alertness and valence, reaction times, stress (interesting work to look at alertness vs. reaction time).
# - free text answers about caffeine, life, stress, factors that matter that we're not measuring.
# - enjoyment of tetris, enjoyment of games, self-perceived skill
#
# Things that are going to get interesting to model and definitely don't have prior art for processing them:
#
# - time perception data (durations, clock time, confidence)
# - duration voluntarily continuing the task
# - duration until noticing of light
# - additional flow datapoints, including the drawn data.
#
# In this section, we'll just organize the data.

# %% [raw]
# Survey Data Processing functions below.

# %%
#All combined

def get_user_entrance_responses(folder, user):
    '''grab the entrance survey results from google form csv'''
    
    df = pd.read_csv(folder + '/Flow_Entrance_Survey.csv')

    # Filter DataFrame to get row of specified user  
    user_row = df[df['Participant number (from the email you received):'] == user]
    
    # Ignore the timestamp and participant ID column
    user_responses = user_row.iloc[:, 2:].values.tolist()
    
    # user_responses is a list of lists, we flatten it to a single list
    user_responses = [item for sublist in user_responses for item in sublist]
    
    
    survey_data = {}
    
    #TAS : scale 1-5
    TAS_responses = user_responses[21:55]
    #BIT : scale 1-7
    BIT_responses = [v* 5 / 7 for v in user_responses[55:65]]
    del user_responses[21:65]
    #Flow Desc : Y/N
    FlowDesc_responses = user_responses[11:17]
    del user_responses[11:17]
    
    #CODE TAS
    #TAS just sum for likert 5 point version
    # based on prior work, avg ~80, std-dev ~18 (Glisky et al., 1991, Studies 2 and 3)
    survey_data['TAS'] = sum(TAS_responses)
    survey_data['TAS_stdevs'] = (sum(TAS_responses) - 80) / 18.0
    #CODE BIT
    BIT_codes = [
     'Support', 
     'Belonging',
     'Flow',
     'Accomplishment',
     'Self-efficacy',
     'Self-worth',
     'Meaning and Purpose',
     'Optimism',
     'Life Satisfaction',
     'Positive Affect'
    ]    
    strengths, weaknesses = [],[]

    for i, v in enumerate(BIT_responses):
        if v > 4.2:
            strengths.append(BIT_codes[i])
        elif v < 3.3:
            weaknesses.append(BIT_codes[i])

    BIT_mean = np.mean(BIT_responses)
    BIT_std = np.std(BIT_responses)
    print(f'BIT CODING:\t{BIT_mean:.2f} with std {BIT_std:.2f}', end='')

    if BIT_mean > 4.2:
            print(' -- DESIGNATED "STRONG"')
    elif BIT_std < 3.3:
            print(' -- DESIGNATED "AT RISK"')

    print(f'\t\t{len(strengths)} BIT STRENGTHS:\n\t\t {strengths}')
    print(f'\t\t{len(weaknesses)} BIT WEAKNESSES:\n\t\t {weaknesses}')

    survey_data['BIT_score'] = BIT_mean
    survey_data['BIT_std'] = BIT_std
    survey_data['BIT_strengths'] = strengths
    survey_data['BIT_weaknesses'] = weaknesses
    
    
    #CODE FQ
    s_score, d_score = 0, 0
    
    for r in FlowDesc_responses[:3]:
        if r == 'Yes':
            s_score +=1
    for r in FlowDesc_responses[3:]:
        if r == 'Yes':
            d_score +=1
    
    print(f'FLOW DESC:\tshallow: {s_score}\tdeep: {d_score}')
    survey_data['shallowFQ'] = s_score
    survey_data['deepFQ'] = d_score
    
    #remaining responses
    resp_keys = ['sex', 'job', 'typical_day', 'focus_best', 
     'vidgame_experience', 'vidgame_enjoy_1to7', 'vidgame_experience', 'vidgame_favtypes',
     'tetris_experience',  'tetris_enjoy_1to7',  'tetris_experience', 'flow_experiences',
     'flow_freq', 'flow_reliability', 'flow_recognition', 'flow_activity']
    
    for i, k in enumerate(resp_keys):
        survey_data[k] = user_responses[i]
        
    return survey_data


def get_user_exit_responses(folder, user):
    '''get user results for the final session, hand coded from their booklet into Final_PhD_Survey_Results.csv'''
    
    df = pd.read_csv(folder + '/Final_PhD_Survey_Results.csv')

    questions = list(df['Question'].values)
    user_responses = list(df['P' + str(user)].values)
    
    survey_data = {}
    
    #BIT : scale 1-7
    BIT_responses = [(int(v)+1)* 5 / 7 for v in user_responses[39:49]]
    del questions[39:49]
    del user_responses[39:49]
    #Flow Desc : Y/N
    FlowDesc_responses = user_responses[26:32]
    del questions[26:32]
    del user_responses[26:32]
    
    #CODE BIT
    BIT_codes = [
     'Support', 
     'Belonging',
     'Flow',
     'Accomplishment',
     'Self-efficacy',
     'Self-worth',
     'Meaning and Purpose',
     'Optimism',
     'Life Satisfaction',
     'Positive Affect'
    ]    
    strengths, weaknesses = [],[]

    for i, v in enumerate(BIT_responses):
        if v > 4.2:
            strengths.append(BIT_codes[i])
        elif v < 3.3:
            weaknesses.append(BIT_codes[i])

    BIT_mean = np.mean(BIT_responses)
    BIT_std = np.std(BIT_responses)
    print(f'BIT CODING:\t{BIT_mean:.2f} with std {BIT_std:.2f}', end='')

    if BIT_mean > 4.2:
            print(' -- DESIGNATED "STRONG"')
    elif BIT_std < 3.3:
            print(' -- DESIGNATED "AT RISK"')

    print(f'\t\t{len(strengths)} BIT STRENGTHS:\n\t\t {strengths}')
    print(f'\t\t{len(weaknesses)} BIT WEAKNESSES:\n\t\t {weaknesses}')

    survey_data['BIT_score'] = BIT_mean
    survey_data['BIT_std'] = BIT_std
    survey_data['BIT_strengths'] = strengths
    survey_data['BIT_weaknesses'] = weaknesses
    
    #CODE FQ
    s_score, d_score = 0, 0
    
    for r in FlowDesc_responses[:3]:
        if r == 'y':
            s_score +=1
    for r in FlowDesc_responses[3:]:
        if r == 'y':
            d_score +=1
    
    print(f'FLOW DESC:\tshallow: {s_score}\tdeep: {d_score}')
    survey_data['shallowFQ'] = s_score
    survey_data['deepFQ'] = d_score
    
    #remaining responses
    
    resp_keys = ['durGuess','durTimeConfidence','guessTime','guessTimeConfidence','timeExp',
    'focus','effort','deepest','flow','durFlow','durToFlow','percentFlow',
    'flowDesc','flowQ1','flowQ2','flowQ3','flowQ4','FSS1','FSS2','FSS3','FSS4',
    'FSS5','FSS6','FSS7','FSS8','FSS9','nowAlertness','nowStress','nowEmotion',
    'nowEmoIntensity','written_description','written_food_caff_exercise_sleep',
    'written_other_relevant','written_comments','written_homevlab','written_timechoice',
    'written_iphonepaper','written_observed','written_naturalwearables']
    #missing (obviously) timeAtGuess and timeAtDurGuess.  We'll use the last timestamp of the wearables for the time at guess.
    #we don't really care about the timeAtDurGuess (just use duration of flow activity-- we do care about timeAtGuess.

    
    for i, k in enumerate(resp_keys):
        survey_data[k] = user_responses[i]
        
    return survey_data


def process_ui_data(data, user):
    '''process the ui data from the session_data into a DF of important timestamps and a dictionary of survey data'''
    
    SURVEY_NAMES = ['LabStartSurvey', 
                    'LabMid1Survey', 
                    'LabMidActivitySurvey', 
                    'LabMid2Survey', 
                    'LabFinalSurvey',
                    'HomeStartSurvey', 
                    'HomeMidSurvey', 
                    'HomeMidActivitySurvey',  
                    'HomeFinalSurvey']          
                    
    # Define lists for two dataframes
    timestamps = []
    surveys = {}
    current_survey = 'UNKNOWN'
    # Traverse through data
    for row in data:
        if row[2] in ['START_TEST', 'STOP_TEST', 'START_TRANSITION', 'FINISHED_TRANSITION', 'NOTICED']:
            timestamps.append([pd.to_datetime(row[0])-datetime.timedelta(hours=TIMEZONE_OFFSET), row[2]])
        elif row[2] == 'SURVEY':
            try:
                if 'empaticaStartTime' == row[3]:
                    timestamps.append([pd.to_datetime(row[4]+row[5]), 'EMPATICA_START_TIME'])
                elif 'empaticaEndTime' == row[3]:
                    timestamps.append([pd.to_datetime(row[4]+row[5]), 'EMPATICA_END_TIME'])
                elif 'recordingStartTime' == row[3]:
                    timestamps.append([pd.to_datetime(row[4]+row[5]), 'RECORDING_START_TIME'])
                elif row[4] in SURVEY_NAMES:
                    timestamps.append([pd.to_datetime(int(row[3]), unit='ms')-datetime.timedelta(hours=TIMEZONE_OFFSET), 'START_SURVEY'])
                    current_survey = row[4]
                    surveys[current_survey]={}
                else:
                    surveys[current_survey][row[3]] = (row[4] if len(row)==5 else row[4:])
            except:
                print(f'GOT unknown survey: {row}')
    
    # Create dataframes
    df_times = pd.DataFrame(timestamps, columns=['timestamp', 'event'])
    df_times['timestamp'] = pd.to_datetime(df_times['timestamp'], utc=True)
    df_times['timestamp'] = df_times['timestamp'].dt.tz_localize(None)
    df_times.set_index('timestamp', inplace=True)

    for s in surveys:
        print('\t>> processing ' + s)
        surveys[s] = codeBIT(surveys[s])
        surveys[s] = codeFlowDesc(surveys[s])
        print(surveys[s])
        surveys[s] = transformFlowPathPlot(surveys[s], folder, 'P' + str(user) + s)
        
    return df_times, surveys


def codeBIT(survey_data):
    BIT_codes = {
     'BIT0':'Support', 
     'BIT1':'Belonging',
     'BIT2':'Flow',
     'BIT3':'Accomplishment',
     'BIT4':'Self-efficacy',
     'BIT5':'Self-worth',
     'BIT6':'Meaning and Purpose',
     'BIT7':'Optimism',
     'BIT8':'Life Satisfaction',
     'BIT9':'Positive Affect'
    }
    
    all_items=[]
    strengths = []
    weaknesses = []
    
    try:
        for k in BIT_codes.keys():
            score = (int(survey_data[k]) + 1) * 5 / 7
            all_items.append(score)
            if score > 4.2:
                strengths.append(BIT_codes[k])
            elif score < 3.3:
                weaknesses.append(BIT_codes[k])

        BIT_mean = np.mean(all_items)
        BIT_std = np.std(all_items)

        print(f'BIT CODING:\t{BIT_mean:.2f} with std {BIT_std:.2f}', end='')

        if BIT_mean > 4.2:
                print(' -- DESIGNATED "STRONG"')
        elif BIT_std < 3.3:
                print(' -- DESIGNATED "AT RISK"')
                
        print(f'\t\t{len(strengths)} BIT STRENGTHS:\n\t\t {strengths}')
        print(f'\t\t{len(weaknesses)} BIT WEAKNESSES:\n\t\t {weaknesses}')
        
        survey_data['BIT_score'] = BIT_mean
        survey_data['BIT_std'] = BIT_std
        survey_data['BIT_strengths'] = strengths
        survey_data['BIT_weaknesses'] = weaknesses
        
    except:
        print('No BIT Detected')
    
    return survey_data


def codeFlowDesc(survey_data):
    ''' we need all data across all sessions in order to properly z-score flow data.
    instead of doing anything, we'll just process the one bit of data we need to
    preprocess, which is the flowDesc.
    '''
    shallow_flow = ['flowDescA','flowDescB','flowDescC']
    deep_flow = ['flowDescD','flowDescE','flowDescF']
    
    s_score = 0
    d_score = 0
    
    try:
        for k in shallow_flow:
            if survey_data[k] == 'true':
                s_score += 1
        for k in deep_flow:
            if survey_data[k] == 'true':
                d_score += 1
        
        print(f'FLOW DESC:\tshallow: {s_score}\tdeep: {d_score}')
        survey_data['shallowFQ'] = s_score
        survey_data['deepFQ'] = d_score
            
    except:
        print('No Flow Desc Detected')

    return survey_data


def transformFlowPathPlot(survey_data, folder, filename):
    
    try:
        xy = survey_data['flowPath']
        canvassize = survey_data['flowCanvasSize']
    except:
        print('No flow path data')
        return survey_data
    
    if xy=='':
        print('No flow path data')
        return survey_data
    
    xy_float = [float(i) for i in xy]

    # Create list of dictionaries representing coordinates
    coordinates = [{'x': xy_float[i], 'y': xy_float[i + 1]} for i in range(0, len(xy_float), 2)]

    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(coordinates)

    # Define the size of the plot to match your canvas size (converted to inches)
    fig, ax = plt.subplots(figsize=(float(canvassize[0]) / 40, float(canvassize[1]) / 40))

    # Create the scatterplot
    sns.lineplot(data=df, x='x', y='y', lw=5, ax=ax)
    
    # Set title and labels
    plt.title('Flow Drawing', fontsize=12)
    #plt.set_xlabel('Time', fontsize=22)
    #plt.set_ylabel('Value', fontsize=22)
    
    ax.set_xticks([0, 5, float(canvassize[0])-5, float(canvassize[0])])
    ax.set_xticklabels(['','Start of Activity', 'End of Activity',''], fontsize=8)
    ax.set_yticks([0, 2, float(canvassize[1])/2, float(canvassize[1])-2, float(canvassize[1])])
    ax.set_yticklabels(['','Distracted', 'Light Focus', 'Deep Focus',''], fontsize=10)

    # Add x and y labels
    ax.set_xlabel('Time', fontsize=8)
    
    plt.xlim([0, 327.5])
    plt.ylim([0, 100])
    
    # Invert the y axis to match the typical screen/canvas coordinate system
    ax.invert_yaxis()

    # Remove tick marks
    plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, left=False, right=False, labelleft=False)

    survey_data['flowDrawing'] = folder + '/Flow_Drawings/' + filename + '.png'
    plt.savefig(survey_data['flowDrawing'], dpi=300)
    plt.close()
    
    print('SAVED ' + survey_data['flowDrawing'])
    
    return survey_data 


def clean_survey_types(session_data):

    #iterate over sessions
    for i, session in enumerate(session_data):
        #iterate over surveys in this session
        if 'surveys' in session:
            for survey in session['surveys']:
                print(f'Cleaning survey {survey}')
                clean_survey(session['surveys'][survey])

    
def clean_survey(survey): 
    #all out of seven EXCEPT nowEmotion and nowEmoIntensity, which are 5 for SAM
    #all start as zero indexed, move to one indexed
    likert_ints = ['FSS', 'flowQ', 'now', 'timeExp', 'focus', 'effort', 'deepest']        

    #these are one indexed and have a map in the data (except percentFlow/duration/durGuess, which are just mapped directly to an int
    map_ints = ['durFlow', 'durTimeConfidence', 'guessTimeConfidence', 'percentFlow', 'duration', 'durGuess']

    times = ['LastSeenTimeStartSurvey','actualTimeAtDuration','startSurveyTime','timeAtDurGuess','timeAtGuess']

    try:
        d = survey['timeAtGuess'][0]
    except:
        pass
    
    #iterate over each key in this survey
    for k in survey.keys():
        try:
            if k == 'reactionTimesMs':
                survey['reactionTimesMs'] = [int(t) for t in survey['reactionTimesMs']]
            elif k in map_ints:
                survey[k] = int(survey[k])
            elif k in times:
                survey[k] = datetime.datetime.strptime(''.join(survey[k]), '%m/%d/%Y %I:%M:%S %p')
            elif k == 'guessTime':
                try:
                    survey['guessTime'] = datetime.datetime.strptime(d + ' ' + survey['guessTime'], '%m/%d/%Y %I:%M %p')
                except:
                    print('Failed on guessTime; no timeAtGuess date to transform')
            else:
                #iterate over likert_ints, because some are partial names
                for st in likert_ints:
                    #with partial match to k
                    if st in k:
                        #match plus 1
                        survey[k] = int(survey[k])+1
        except:
            print(f'\tfailed on {k} with value {survey[k]}')

def process_surveys(folder, user, session_data):
 
    entrance_survey, exit_survey = {}, {}
    
    print('='*10 + ' Entrance Survey Processing')
    try:
        entrance_survey = get_user_entrance_responses(folder, user)
        print('GOT ENTRANCE SURVEY: ' + str(entrance_survey))
        clean_survey(entrance_survey)
    except Exception as e:
        print(e)
        print('NO ENTRANCE SURVEY FOR THIS PARTICIPANT!!!')
 
    print('='*10 + ' Exit Survey Processing')
    try:
        exit_survey = get_user_exit_responses(folder, user)
        print('GOT EXIT SURVEY: ' + str(exit_survey))
        clean_survey(exit_survey)
    except Exception as e:
        print(e)
        print('NO EXIT SURVEY FOR THIS PARTICIPANT!!!')

        
    for session in session_data:
        try:
            print('='*10, end=' ')
            print(f"Processing session {session['timestamp']} {session['user']} {session['session']} {session['session_type']}")
            df_times, survey_results = process_ui_data(session['ui'], user)
            print(df_times)
            print('GOT UI survey results: ' + str(survey_results))
            del session['ui']
            session['surveys'] = survey_results
            session['timings'] = df_times
        except Exception as e:
            print(e)
            print('FAILED SESSION PROCESSING')
            
    clean_survey_types(session_data)
    
    return session_data, entrance_survey, exit_survey
    return session_data, entrance_survey, exit_survey

# %% [markdown]
# # Runs the above scripts to generate our data!!

# %%
users_to_process = [1, 19, 23]
#users_to_process = [2,3,5,6,7,11,13,15,16,17,19,22,23,24,25]
#users_to_process = [12, 18, 20, 21] #missing one session of E4 data in [sess1, sess2]

#TODO = 4, 8, 10, 14
#DONE = 1, 9

folder = '/Volumes/Secondary/PhDStudy_Results'

for user in users_to_process:
    try:
        #grab all sections of Session 1 for that user (glasses CSVs, each separated by task/env')
        session_data = load_session_excel(folder, 'P' + str(user), 'sess1')
        session_data = update_sessions_with_E4_data(session_data, folder, user, 1)
        print('Successfully processed P' + str(user) + ' sess1.')
        
        #grab all sections of Session 2
        sess2_data = load_session_excel(folder, 'P' + str(user), 'sess2')
        sess2_data = update_sessions_with_E4_data(sess2_data, folder, user, 2)
        print('Successfully processed P' + str(user) + ' sess2.')
        
        #combine into one
        session_data.extend(sess2_data)
        print('Successfully combined P' + str(user) + ' sess1 and sess2.')
        
        #process the survey data for each session
        session_data, entrance, exit = process_surveys(folder, user, session_data)
        print('Successfully processed surveys for P' + str(user) + '.')
        
        #save to a pickle
        with open(folder + '/P' + str(user) + '_Processed.pickle', 'wb') as handle:
            pickle.dump((session_data, entrance, exit), handle, protocol=pickle.HIGHEST_PROTOCOL)
        print('Successfully saved P' + str(user) + ' data.')
        
    except Exception as e:
        print(f'ERROR WITH USER {user}: {e}')
# Out:
# ['/Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_150928_p1_LAB_DEMO.csv', '/Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_151433_p1_LAB_TETRIS.csv', '/Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_153023_p1_TETRIS_CONTD.csv', '/Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_160419_p1_LAB_FLOW.csv', '/Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_162311_p1_FLOW_CONTD.csv']
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_150928_p1_LAB_DEMO.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 3.90 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.003948667324777887
# 	gyro processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 4.35 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.005421336408709623
# 	accelerometer processing...
# 		at index 299: packetNum not sequentially increasing. Current: 147, Previous: 145
# 		at index 299: tick increment greater than timeout. Difference: 1978ms
# 		dropped 10 rows of data due to duplication.
# 		dropped 2 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 4.24 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: 0.004108665998323664
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 888: packetNum not sequentially increasing. Current: 1934, Previous: 1934
# 		at index 888: packet_tick not increasing. Current: 651490, Previous: 651490
# 		dropped 370 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 4.50 seconds
# 		Error (server timestamp vs tick): 0.29 seconds
# 		% drift: -0.09540261215964585
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_151433_p1_LAB_TETRIS.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 15 minutes and 49.90 seconds
# 		Error (server timestamp vs tick): 0.07 seconds
# 		% drift: -0.007579745236340667
# 	gyro processing...
# 		at index 147: packetNum not sequentially increasing. Current: 181, Previous: 179
# 		at index 147: tick increment greater than timeout. Difference: 1274ms
# 		at index 1697: packetNum not sequentially increasing. Current: 196, Previous: 194
# 		at index 1697: tick increment greater than timeout. Difference: 1120ms
# 		at index 2522: packetNum not sequentially increasing. Current: 254, Previous: 252
# 		at index 2522: tick increment greater than timeout. Difference: 1361ms
# 		at index 2562: packetNum not sequentially increasing. Current: 37, Previous: 37
# 		at index 2562: packet_tick not increasing. Current: 2509544, Previous: 2509544
# 		at index 2674: packetNum not sequentially increasing. Current: 150, Previous: 148
# 		at index 2674: tick increment greater than timeout. Difference: 1184ms
# 		dropped 47 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 15 minutes and 50.29 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.002525551477842232
# 	accelerometer processing...
# 		at index 287: packetNum not sequentially increasing. Current: 240, Previous: 238
# 		at index 287: tick increment greater than timeout. Difference: 1814ms
# 		at index 727: packetNum not sequentially increasing. Current: 169, Previous: 167
# 		at index 727: tick increment greater than timeout. Difference: 2005ms
# 		at index 1038: packetNum not sequentially increasing. Current: 223, Previous: 223
# 		at index 1038: packet_tick not increasing. Current: 1989526, Previous: 1989526
# 		dropped 25 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 15 minutes and 50.17 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: 0.0019470159086986355
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 269: packetNum not sequentially increasing. Current: 3142, Previous: 3142
# 		at index 269: packet_tick not increasing. Current: 1054289, Previous: 1054289
# 		at index 851: packetNum not sequentially increasing. Current: 3723, Previous: 3723
# 		at index 851: packet_tick not increasing. Current: 1247890, Previous: 1247890
# 		at index 2160: packetNum not sequentially increasing. Current: 168, Previous: 5031
# 		at index 2160: tick increment greater than timeout. Difference: 605ms
# 		at index 2161: packetNum not sequentially increasing. Current: 5032, Previous: 168
# 		at index 2161: packet_tick not increasing. Current: 1684290, Previous: 1684495
# 		at index 4564: packetNum not sequentially increasing. Current: 253, Previous: 7434
# 		at index 4564: packet_tick not increasing. Current: 2484890, Previous: 2484890
# 		at index 4565: packetNum not sequentially increasing. Current: 7435, Previous: 253
# 		at index 4638: packetNum not sequentially increasing. Current: 7509, Previous: 7507
# 		at index 4638: tick increment greater than timeout. Difference: 599ms
# 		at index 4838: packetNum not sequentially increasing. Current: 7708, Previous: 7708
# 		at index 4838: packet_tick not increasing. Current: 2576290, Previous: 2576290
# 		dropped 2540 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 15 minutes and 50.00 seconds
# 		Error (server timestamp vs tick): 0.25 seconds
# 		% drift: -0.026105276897514157
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_153023_p1_TETRIS_CONTD.csv
# got raw data.
# 	thermal processing...
# 		at index 1010: packet_tick not increasing. Current: 5996, Previous: 6901537
# 		dropped 0 rows of data due to duplication.
# 		dropped 120 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 33 minutes and 39.90 seconds
# 		Error (server timestamp vs tick): 0.14 seconds
# 		% drift: -0.007030050992623397
# 	gyro processing...
# 		at index 1732: packetNum not sequentially increasing. Current: 56, Previous: 54
# 		at index 1732: tick increment greater than timeout. Difference: 1150ms
# 		at index 3488: packetNum not sequentially increasing. Current: 21, Previous: 19
# 		at index 3488: tick increment greater than timeout. Difference: 1271ms
# 		at index 4700: packetNum not sequentially increasing. Current: 210, Previous: 208
# 		at index 4700: tick increment greater than timeout. Difference: 1209ms
# 		at index 5892: packetNum not sequentially increasing. Current: 123, Previous: 121
# 		at index 5892: tick increment greater than timeout. Difference: 1214ms
# 		at index 6139: packetNum not sequentially increasing. Current: 115, Previous: 113
# 		at index 6139: tick increment greater than timeout. Difference: 1218ms
# 		at index 6187: packetNum not sequentially increasing. Current: 164, Previous: 162
# 		at index 6187: tick increment greater than timeout. Difference: 1148ms
# 		at index 6710: packet_tick not increasing. Current: 6448, Previous: 6902094
# 		dropped 22 rows of data due to duplication.
# 		dropped 955 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 33 minutes and 38.55 seconds
# 		Error (server timestamp vs tick): 0.05 seconds
# 		% drift: -0.0023284063594227137
# 	accelerometer processing...
# 		at index 160: packetNum not sequentially increasing. Current: 247, Previous: 245
# 		at index 160: tick increment greater than timeout. Difference: 2054ms
# 		at index 1299: packetNum not sequentially increasing. Current: 107, Previous: 105
# 		at index 1299: tick increment greater than timeout. Difference: 2113ms
# 		at index 1772: packetNum not sequentially increasing. Current: 67, Previous: 67
# 		at index 1772: packet_tick not increasing. Current: 4615547, Previous: 4615547
# 		at index 3102: packetNum not sequentially increasing. Current: 118, Previous: 116
# 		at index 3102: tick increment greater than timeout. Difference: 2046ms
# 		at index 3750: packetNum not sequentially increasing. Current: 255, Previous: 253
# 		at index 3750: tick increment greater than timeout. Difference: 1978ms
# 		at index 4083: packet_tick not increasing. Current: 6710, Previous: 6901425
# 		dropped 45 rows of data due to duplication.
# 		dropped 607 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 33 minutes and 38.37 seconds
# 		Error (server timestamp vs tick): 0.05 seconds
# 		% drift: -0.0025515670461400118
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 477: packetNum not sequentially increasing. Current: 9050, Previous: 9050
# 		at index 477: packet_tick not increasing. Current: 3023489, Previous: 3023489
# 		at index 3130: packetNum not sequentially increasing. Current: 11702, Previous: 11702
# 		at index 3130: packet_tick not increasing. Current: 3907490, Previous: 3907490
# 		at index 3850: packetNum not sequentially increasing. Current: 12421, Previous: 12421
# 		at index 3850: packet_tick not increasing. Current: 4147289, Previous: 4147289
# 		at index 5255: packetNum not sequentially increasing. Current: 13827, Previous: 13825
# 		at index 5255: tick increment greater than timeout. Difference: 601ms
# 		at index 6295: packetNum not sequentially increasing. Current: 14866, Previous: 14866
# 		at index 6295: packet_tick not increasing. Current: 4962289, Previous: 4962289
# 		at index 8483: packetNum not sequentially increasing. Current: 209, Previous: 17053
# 		at index 8483: packet_tick not increasing. Current: 5691289, Previous: 5691289
# 		at index 8484: packetNum not sequentially increasing. Current: 17054, Previous: 209
# 		at index 9201: packetNum not sequentially increasing. Current: 17770, Previous: 17770
# 		at index 9201: packet_tick not increasing. Current: 5930289, Previous: 5930289
# 		at index 10633: packetNum not sequentially increasing. Current: 19201, Previous: 19201
# 		at index 10633: packet_tick not increasing. Current: 6407290, Previous: 6407290
# 		at index 11081: packetNum not sequentially increasing. Current: 19648, Previous: 19648
# 		at index 11081: packet_tick not increasing. Current: 6556289, Previous: 6556289
# 		at index 11120: packetNum not sequentially increasing. Current: 19686, Previous: 19686
# 		at index 11120: packet_tick not increasing. Current: 6568890, Previous: 6568890
# 		at index 11170: packetNum not sequentially increasing. Current: 19735, Previous: 19735
# 		at index 11170: packet_tick not increasing. Current: 6585289, Previous: 6585289
# 		at index 12120: packet_tick not increasing. Current: 6888, Previous: 6901490
# 		dropped 4769 rows of data due to duplication.
# 		dropped 22994 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 33 minutes and 38.50 seconds
# 		Error (server timestamp vs tick): 0.32 seconds
# 		% drift: -0.015828585583353975
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_160419_p1_LAB_FLOW.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 18 minutes and 53.90 seconds
# 		Error (server timestamp vs tick): 0.08 seconds
# 		% drift: -0.0070552958814710295
# 	gyro processing...
# 		at index 886: packetNum not sequentially increasing. Current: 157, Previous: 155
# 		at index 886: tick increment greater than timeout. Difference: 1123ms
# 		at index 2675: packetNum not sequentially increasing. Current: 155, Previous: 153
# 		at index 2675: tick increment greater than timeout. Difference: 1311ms
# 		dropped 22 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 18 minutes and 52.63 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 0.0003531606554308604
# 	accelerometer processing...
# 		at index 73: packetNum not sequentially increasing. Current: 98, Previous: 96
# 		at index 73: tick increment greater than timeout. Difference: 2047ms
# 		dropped 113 rows of data due to duplication.
# 		dropped 14 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 18 minutes and 52.34 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.0032675611541732497
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 225: packetNum not sequentially increasing. Current: 293, Previous: 293
# 		at index 225: packet_tick not increasing. Current: 104488, Previous: 104488
# 		at index 1615: packetNum not sequentially increasing. Current: 1682, Previous: 1682
# 		at index 1615: packet_tick not increasing. Current: 567488, Previous: 567488
# 		at index 4897: packetNum not sequentially increasing. Current: 4963, Previous: 4963
# 		at index 4897: packet_tick not increasing. Current: 1661288, Previous: 1661288
# 		dropped 1393 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 18 minutes and 52.50 seconds
# 		Error (server timestamp vs tick): 0.27 seconds
# 		% drift: -0.024238431998615452
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P1/P1_sess1/060123_162311_p1_FLOW_CONTD.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 17 minutes and 35.90 seconds
# 		Error (server timestamp vs tick): 0.11 seconds
# 		% drift: -0.010228241310730182
# 	gyro processing...
# 		at index 262: packetNum not sequentially increasing. Current: 173, Previous: 171
# 		at index 262: tick increment greater than timeout. Difference: 1143ms
# 		at index 705: packetNum not sequentially increasing. Current: 105, Previous: 103
# 		at index 705: tick increment greater than timeout. Difference: 1183ms
# 		at index 2348: packetNum not sequentially increasing. Current: 213, Previous: 211
# 		at index 2348: tick increment greater than timeout. Difference: 1144ms
# 		dropped 1 rows of data due to duplication.
# 		dropped 1 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 17 minutes and 36.52 seconds
# 		Error (server timestamp vs tick): 0.06 seconds
# 		% drift: -0.0057263495846503545
# 	accelerometer processing...
# 		at index 1419: packetNum not sequentially increasing. Current: 110, Previous: 110
# 		at index 1419: packet_tick not increasing. Current: 3723524, Previous: 3723524
# 		at index 1756: packetNum not sequentially increasing. Current: 190, Previous: 190
# 		at index 1756: packet_tick not increasing. Current: 4060518, Previous: 4060518
# 		dropped 71 rows of data due to duplication.
# 		dropped 4 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 17 minutes and 36.45 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.0032183285705225714
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 476: packetNum not sequentially increasing. Current: 7339, Previous: 7339
# 		at index 476: packet_tick not increasing. Current: 2453292, Previous: 2453292
# 		at index 1290: packetNum not sequentially increasing. Current: 8152, Previous: 8152
# 		at index 1290: packet_tick not increasing. Current: 2724288, Previous: 2724288
# 		at index 5298: packetNum not sequentially increasing. Current: 12161, Previous: 12159
# 		at index 5298: tick increment greater than timeout. Difference: 600ms
# 		dropped 1365 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 17 minutes and 36.50 seconds
# 		Error (server timestamp vs tick): 0.33 seconds
# 		% drift: -0.030809275911026977
# 	watch processing...
# The size of the loaded data is 729.7926177978516 MB
# Successfully processed P1 sess1.
# ['/Volumes/Secondary/PhDStudy_Results/P1/P1_sess2/061723_132413_p1_HOME_TETRIS.csv', '/Volumes/Secondary/PhDStudy_Results/P1/P1_sess2/061723_134409_p1_TETRIS_CONTD.csv', '/Volumes/Secondary/PhDStudy_Results/P1/P1_sess2/061723_140740_p1_HOME_FLOW.csv', '/Volumes/Secondary/PhDStudy_Results/P1/P1_sess2/061723_142608_p1_FLOW_CONTD.csv']
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P1/P1_sess2/061723_132413_p1_HOME_TETRIS.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 19 minutes and 55.90 seconds
# 		Error (server timestamp vs tick): 0.10 seconds
# 		% drift: -0.008111046074086463
# 	gyro processing...
# 		at index 495: packetNum not sequentially increasing. Current: 154, Previous: 152
# 		at index 495: tick increment greater than timeout. Difference: 1266ms
# 		at index 764: packetNum not sequentially increasing. Current: 168, Previous: 166
# 		at index 764: tick increment greater than timeout. Difference: 1297ms
# 		dropped 175 rows of data due to duplication.
# 		dropped 8 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 19 minutes and 55.43 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.0004182607629996491
# 	accelerometer processing...
# 		dropped 45 rows of data due to duplication.
# 		dropped 4 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 19 minutes and 55.68 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: 0.0015890532629745154
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 894: packetNum not sequentially increasing. Current: 153, Previous: 2618
# 		at index 894: packet_tick not increasing. Current: 879494, Previous: 879494
# 		at index 895: packetNum not sequentially increasing. Current: 2619, Previous: 153
# 		at index 1381: packetNum not sequentially increasing. Current: 167, Previous: 3104
# 		at index 1381: packet_tick not increasing. Current: 1041495, Previous: 1041495
# 		at index 1382: packetNum not sequentially increasing. Current: 3105, Previous: 167
# 		dropped 1061 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 19 minutes and 55.50 seconds
# 		Error (server timestamp vs tick): 0.29 seconds
# 		% drift: -0.024006701801213635
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P1/P1_sess2/061723_134409_p1_TETRIS_CONTD.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 31.90 seconds
# 		Error (server timestamp vs tick): 0.13 seconds
# 		% drift: -0.008924144769459593
# 	gyro processing...
# 		at index 599: packetNum not sequentially increasing. Current: 135, Previous: 133
# 		at index 599: tick increment greater than timeout. Difference: 1158ms
# 		at index 1067: packetNum not sequentially increasing. Current: 92, Previous: 90
# 		at index 1067: tick increment greater than timeout. Difference: 1218ms
# 		at index 1488: packetNum not sequentially increasing. Current: 2, Previous: 0
# 		at index 1488: tick increment greater than timeout. Difference: 1130ms
# 		at index 1492: packetNum not sequentially increasing. Current: 7, Previous: 5
# 		at index 1492: tick increment greater than timeout. Difference: 1130ms
# 		at index 3259: packetNum not sequentially increasing. Current: 239, Previous: 237
# 		at index 3259: tick increment greater than timeout. Difference: 1270ms
# 		at index 3346: packetNum not sequentially increasing. Current: 71, Previous: 69
# 		at index 3346: tick increment greater than timeout. Difference: 1149ms
# 		at index 3350: packetNum not sequentially increasing. Current: 76, Previous: 74
# 		at index 3350: tick increment greater than timeout. Difference: 1194ms
# 		at index 3752: packetNum not sequentially increasing. Current: 223, Previous: 221
# 		at index 3752: tick increment greater than timeout. Difference: 1177ms
# 		at index 4200: packetNum not sequentially increasing. Current: 160, Previous: 158
# 		at index 4200: tick increment greater than timeout. Difference: 1117ms
# 		dropped 97 rows of data due to duplication.
# 		dropped 14 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 31.35 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.0024798986500848834
# 	accelerometer processing...
# 		at index 248: packetNum not sequentially increasing. Current: 114, Previous: 114
# 		at index 248: packet_tick not increasing. Current: 3222556, Previous: 3222556
# 		at index 590: packetNum not sequentially increasing. Current: 201, Previous: 199
# 		at index 590: tick increment greater than timeout. Difference: 2088ms
# 		at index 1649: packetNum not sequentially increasing. Current: 237, Previous: 235
# 		at index 1649: tick increment greater than timeout. Difference: 1978ms
# 		at index 2087: packetNum not sequentially increasing. Current: 162, Previous: 162
# 		at index 2087: packet_tick not increasing. Current: 5079554, Previous: 5079554
# 		at index 2700: packetNum not sequentially increasing. Current: 8, Previous: 6
# 		at index 2700: tick increment greater than timeout. Difference: 1848ms
# 		dropped 104 rows of data due to duplication.
# 		dropped 8 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 31.52 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.002727552245023457
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 749: packetNum not sequentially increasing. Current: 9648, Previous: 9646
# 		at index 749: tick increment greater than timeout. Difference: 599ms
# 		at index 1084: packetNum not sequentially increasing. Current: 9982, Previous: 9982
# 		at index 1084: packet_tick not increasing. Current: 3334299, Previous: 3334299
# 		at index 1788: packetNum not sequentially increasing. Current: 10685, Previous: 10685
# 		at index 1788: packet_tick not increasing. Current: 3568494, Previous: 3568494
# 		at index 1931: packetNum not sequentially increasing. Current: 91, Previous: 10827
# 		at index 1931: packet_tick not increasing. Current: 3615895, Previous: 3615895
# 		at index 1932: packetNum not sequentially increasing. Current: 10828, Previous: 91
# 		at index 2694: packetNum not sequentially increasing. Current: 11589, Previous: 11589
# 		at index 2694: packet_tick not increasing. Current: 3869895, Previous: 3869895
# 		at index 2706: packetNum not sequentially increasing. Current: 11600, Previous: 11600
# 		at index 2706: packet_tick not increasing. Current: 3873495, Previous: 3873495
# 		at index 4996: packetNum not sequentially increasing. Current: 13889, Previous: 13889
# 		at index 4996: packet_tick not increasing. Current: 4636494, Previous: 4636494
# 		at index 5908: packetNum not sequentially increasing. Current: 238, Previous: 14800
# 		at index 5908: packet_tick not increasing. Current: 4940294, Previous: 4940294
# 		at index 5909: packetNum not sequentially increasing. Current: 14801, Previous: 238
# 		at index 6069: packetNum not sequentially increasing. Current: 70, Previous: 14960
# 		at index 6069: packet_tick not increasing. Current: 4993495, Previous: 4993495
# 		at index 6070: packetNum not sequentially increasing. Current: 14961, Previous: 70
# 		at index 6079: packetNum not sequentially increasing. Current: 75, Previous: 14969
# 		at index 6079: packet_tick not increasing. Current: 4996495, Previous: 4996495
# 		at index 6080: packetNum not sequentially increasing. Current: 14970, Previous: 75
# 		at index 6328: packetNum not sequentially increasing. Current: 15219, Previous: 15217
# 		at index 6328: tick increment greater than timeout. Difference: 599ms
# 		at index 6812: packetNum not sequentially increasing. Current: 222, Previous: 15702
# 		at index 6812: packet_tick not increasing. Current: 5240895, Previous: 5240895
# 		at index 6813: packetNum not sequentially increasing. Current: 15703, Previous: 222
# 		at index 7630: packetNum not sequentially increasing. Current: 159, Previous: 16519
# 		at index 7630: packet_tick not increasing. Current: 5513295, Previous: 5513295
# 		at index 7631: packetNum not sequentially increasing. Current: 16520, Previous: 159
# 		at index 8196: packetNum not sequentially increasing. Current: 7, Previous: 17084
# 		at index 8196: packet_tick not increasing. Current: 5701495, Previous: 5701495
# 		at index 8197: packetNum not sequentially increasing. Current: 17085, Previous: 7
# 		dropped 4792 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 31.50 seconds
# 		Error (server timestamp vs tick): 0.30 seconds
# 		% drift: -0.02097060608239677
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P1/P1_sess2/061723_140740_p1_HOME_FLOW.csv
# got raw data.
# 	thermal processing...
# 		dropped 10 rows of data due to duplication.
# 		dropped 25 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 18 minutes and 27.90 seconds
# 		Error (server timestamp vs tick): 0.09 seconds
# 		% drift: -0.008123476848090982
# 	gyro processing...
# 		at index 703: packetNum not sequentially increasing. Current: 39, Previous: 37
# 		at index 703: tick increment greater than timeout. Difference: 1278ms
# 		at index 710: packetNum not sequentially increasing. Current: 47, Previous: 45
# 		at index 710: tick increment greater than timeout. Difference: 1027ms
# 		at index 1471: packetNum not sequentially increasing. Current: 39, Previous: 39
# 		at index 1471: packet_tick not increasing. Current: 6709556, Previous: 6709556
# 		at index 1485: packetNum not sequentially increasing. Current: 52, Previous: 52
# 		at index 1485: packet_tick not increasing. Current: 6717554, Previous: 6717554
# 		at index 1813: packetNum not sequentially increasing. Current: 125, Previous: 123
# 		at index 1813: tick increment greater than timeout. Difference: 1158ms
# 		at index 2264: packetNum not sequentially increasing. Current: 63, Previous: 63
# 		at index 2264: packet_tick not increasing. Current: 7193525, Previous: 7193525
# 		at index 2500: packetNum not sequentially increasing. Current: 42, Previous: 42
# 		at index 2500: packet_tick not increasing. Current: 7337523, Previous: 7337523
# 		at index 2933: packetNum not sequentially increasing. Current: 220, Previous: 218
# 		at index 2933: tick increment greater than timeout. Difference: 1141ms
# 		at index 3192: packetNum not sequentially increasing. Current: 222, Previous: 222
# 		at index 3192: packet_tick not increasing. Current: 7758527, Previous: 7758527
# 		dropped 182 rows of data due to duplication.
# 		dropped 16 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 18 minutes and 28.25 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.0013083672794487534
# 	accelerometer processing...
# 		at index 440: packetNum not sequentially increasing. Current: 29, Previous: 29
# 		at index 440: packet_tick not increasing. Current: 6237524, Previous: 6237524
# 		at index 1403: packetNum not sequentially increasing. Current: 223, Previous: 223
# 		at index 1403: packet_tick not increasing. Current: 7214552, Previous: 7214552
# 		at index 1906: packetNum not sequentially increasing. Current: 215, Previous: 213
# 		at index 1906: tick increment greater than timeout. Difference: 2043ms
# 		dropped 89 rows of data due to duplication.
# 		dropped 12 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 18 minutes and 27.94 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 4.512879758831706e-05
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 1340: packetNum not sequentially increasing. Current: 46, Previous: 18706
# 		at index 1340: packet_tick not increasing. Current: 6242294, Previous: 6242294
# 		at index 1341: packetNum not sequentially increasing. Current: 18707, Previous: 46
# 		at index 2742: packetNum not sequentially increasing. Current: 20109, Previous: 20107
# 		at index 2742: tick increment greater than timeout. Difference: 600ms
# 		at index 2765: packetNum not sequentially increasing. Current: 20133, Previous: 20131
# 		at index 2765: tick increment greater than timeout. Difference: 599ms
# 		at index 3362: packetNum not sequentially increasing. Current: 20729, Previous: 20729
# 		at index 3362: packet_tick not increasing. Current: 6916495, Previous: 6916495
# 		at index 4192: packetNum not sequentially increasing. Current: 21560, Previous: 21558
# 		at index 4192: tick increment greater than timeout. Difference: 600ms
# 		at index 4255: packetNum not sequentially increasing. Current: 21624, Previous: 21622
# 		at index 4255: tick increment greater than timeout. Difference: 600ms
# 		at index 4622: packetNum not sequentially increasing. Current: 21992, Previous: 21990
# 		at index 4622: tick increment greater than timeout. Difference: 600ms
# 		at index 4790: packetNum not sequentially increasing. Current: 22161, Previous: 22159
# 		at index 4790: tick increment greater than timeout. Difference: 600ms
# 		at index 5413: packetNum not sequentially increasing. Current: 22783, Previous: 22783
# 		at index 5413: packet_tick not increasing. Current: 7601295, Previous: 7601295
# 		at index 5884: packetNum not sequentially increasing. Current: 23255, Previous: 23253
# 		at index 5884: tick increment greater than timeout. Difference: 600ms
# 		dropped 1530 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 18 minutes and 28.00 seconds
# 		Error (server timestamp vs tick): 0.31 seconds
# 		% drift: -0.027842985417856875
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P1/P1_sess2/061723_142608_p1_FLOW_CONTD.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 34 minutes and 5.90 seconds
# 		Error (server timestamp vs tick): 0.19 seconds
# 		% drift: -0.009237988171464881
# 	gyro processing...
# 		at index 23: packetNum not sequentially increasing. Current: 150, Previous: 148
# 		at index 23: tick increment greater than timeout. Difference: 1198ms
# 		at index 676: packetNum not sequentially increasing. Current: 36, Previous: 34
# 		at index 676: tick increment greater than timeout. Difference: 1240ms
# 		at index 816: packetNum not sequentially increasing. Current: 177, Previous: 175
# 		at index 816: tick increment greater than timeout. Difference: 1090ms
# 		at index 1710: packetNum not sequentially increasing. Current: 48, Previous: 46
# 		at index 1710: tick increment greater than timeout. Difference: 1219ms
# 		at index 1847: packetNum not sequentially increasing. Current: 184, Previous: 184
# 		at index 1847: packet_tick not increasing. Current: 9142554, Previous: 9142554
# 		at index 2063: packetNum not sequentially increasing. Current: 145, Previous: 143
# 		at index 2063: tick increment greater than timeout. Difference: 1333ms
# 		at index 2350: packetNum not sequentially increasing. Current: 177, Previous: 175
# 		at index 2350: tick increment greater than timeout. Difference: 1208ms
# 		at index 3003: packetNum not sequentially increasing. Current: 63, Previous: 61
# 		at index 3003: tick increment greater than timeout. Difference: 1206ms
# 		at index 3593: packetNum not sequentially increasing. Current: 142, Previous: 140
# 		at index 3593: tick increment greater than timeout. Difference: 1264ms
# 		at index 3764: packetNum not sequentially increasing. Current: 58, Previous: 56
# 		at index 3764: tick increment greater than timeout. Difference: 1196ms
# 		at index 3937: packetNum not sequentially increasing. Current: 232, Previous: 230
# 		at index 3937: tick increment greater than timeout. Difference: 1218ms
# 		at index 4009: packetNum not sequentially increasing. Current: 49, Previous: 47
# 		at index 4009: tick increment greater than timeout. Difference: 1252ms
# 		at index 4143: packetNum not sequentially increasing. Current: 184, Previous: 182
# 		at index 4143: tick increment greater than timeout. Difference: 1148ms
# 		at index 4537: packetNum not sequentially increasing. Current: 67, Previous: 65
# 		at index 4537: tick increment greater than timeout. Difference: 1275ms
# 		at index 4961: packetNum not sequentially increasing. Current: 236, Previous: 234
# 		at index 4961: tick increment greater than timeout. Difference: 1204ms
# 		at index 5721: packetNum not sequentially increasing. Current: 229, Previous: 227
# 		at index 5721: tick increment greater than timeout. Difference: 1122ms
# 		at index 5804: packetNum not sequentially increasing. Current: 55, Previous: 55
# 		at index 5804: packet_tick not increasing. Current: 11566553, Previous: 11566553
# 		at index 6352: packetNum not sequentially increasing. Current: 90, Previous: 90
# 		at index 6352: packet_tick not increasing. Current: 11897506, Previous: 11897506
# 		dropped 158 rows of data due to duplication.
# 		dropped 20 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 34 minutes and 4.96 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.0004401064079492997
# 	accelerometer processing...
# 		at index 249: packetNum not sequentially increasing. Current: 240, Previous: 240
# 		at index 249: packet_tick not increasing. Current: 8262496, Previous: 8262496
# 		at index 1690: packetNum not sequentially increasing. Current: 144, Previous: 144
# 		at index 1690: packet_tick not increasing. Current: 9709504, Previous: 9709504
# 		at index 2163: packetNum not sequentially increasing. Current: 104, Previous: 104
# 		at index 2163: packet_tick not increasing. Current: 10184524, Previous: 10184524
# 		at index 2565: packetNum not sequentially increasing. Current: 249, Previous: 249
# 		at index 2565: packet_tick not increasing. Current: 10586526, Previous: 10586526
# 		at index 2629: packetNum not sequentially increasing. Current: 56, Previous: 56
# 		at index 2629: packet_tick not increasing. Current: 10649544, Previous: 10649544
# 		at index 3490: packetNum not sequentially increasing. Current: 148, Previous: 148
# 		at index 3490: packet_tick not increasing. Current: 11516530, Previous: 11516530
# 		dropped 229 rows of data due to duplication.
# 		dropped 15 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 34 minutes and 4.73 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.001833978934673426
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 45: packetNum not sequentially increasing. Current: 149, Previous: 24059
# 		at index 46: packetNum not sequentially increasing. Current: 24060, Previous: 149
# 		at index 751: packetNum not sequentially increasing. Current: 24766, Previous: 24764
# 		at index 751: tick increment greater than timeout. Difference: 800ms
# 		at index 1244: packetNum not sequentially increasing. Current: 35, Previous: 25258
# 		at index 1244: packet_tick not increasing. Current: 8426294, Previous: 8426294
# 		at index 1245: packetNum not sequentially increasing. Current: 25259, Previous: 35
# 		at index 1501: packetNum not sequentially increasing. Current: 176, Previous: 25514
# 		at index 1502: packetNum not sequentially increasing. Current: 25515, Previous: 176
# 		at index 3143: packetNum not sequentially increasing. Current: 47, Previous: 27155
# 		at index 3143: packet_tick not increasing. Current: 9058495, Previous: 9058495
# 		at index 3144: packetNum not sequentially increasing. Current: 27156, Previous: 47
# 		at index 3395: packetNum not sequentially increasing. Current: 27408, Previous: 27406
# 		at index 3395: tick increment greater than timeout. Difference: 601ms
# 		at index 3793: packetNum not sequentially increasing. Current: 144, Previous: 27805
# 		at index 3793: packet_tick not increasing. Current: 9275294, Previous: 9275294
# 		at index 3794: packetNum not sequentially increasing. Current: 27806, Previous: 144
# 		at index 4321: packetNum not sequentially increasing. Current: 28332, Previous: 28332
# 		at index 4321: packet_tick not increasing. Current: 9450895, Previous: 9450895
# 		at index 5095: packetNum not sequentially increasing. Current: 29107, Previous: 29105
# 		at index 5095: tick increment greater than timeout. Difference: 801ms
# 		at index 5521: packetNum not sequentially increasing. Current: 29532, Previous: 29532
# 		at index 5521: packet_tick not increasing. Current: 9850895, Previous: 9850895
# 		at index 6521: packetNum not sequentially increasing. Current: 30533, Previous: 30531
# 		at index 6521: tick increment greater than timeout. Difference: 600ms
# 		at index 6603: packetNum not sequentially increasing. Current: 141, Previous: 30614
# 		at index 6603: packet_tick not increasing. Current: 10211495, Previous: 10211495
# 		at index 6604: packetNum not sequentially increasing. Current: 30615, Previous: 141
# 		at index 6918: packetNum not sequentially increasing. Current: 57, Previous: 30928
# 		at index 6918: packet_tick not increasing. Current: 10316294, Previous: 10316294
# 		at index 6919: packetNum not sequentially increasing. Current: 30929, Previous: 57
# 		at index 7240: packetNum not sequentially increasing. Current: 31249, Previous: 31249
# 		at index 7240: packet_tick not increasing. Current: 10423294, Previous: 10423294
# 		at index 7377: packetNum not sequentially increasing. Current: 48, Previous: 31385
# 		at index 7377: packet_tick not increasing. Current: 10468495, Previous: 10468495
# 		at index 7378: packetNum not sequentially increasing. Current: 31386, Previous: 48
# 		at index 7626: packetNum not sequentially increasing. Current: 31633, Previous: 31633
# 		at index 7626: packet_tick not increasing. Current: 10551294, Previous: 10551294
# 		at index 7731: packetNum not sequentially increasing. Current: 31739, Previous: 31737
# 		at index 7731: tick increment greater than timeout. Difference: 600ms
# 		at index 7920: packetNum not sequentially increasing. Current: 31929, Previous: 31927
# 		at index 7920: tick increment greater than timeout. Difference: 601ms
# 		at index 8349: packetNum not sequentially increasing. Current: 66, Previous: 32357
# 		at index 8349: packet_tick not increasing. Current: 10792495, Previous: 10792495
# 		at index 8350: packetNum not sequentially increasing. Current: 32358, Previous: 66
# 		at index 9123: packetNum not sequentially increasing. Current: 235, Previous: 33130
# 		at index 9123: packet_tick not increasing. Current: 11050294, Previous: 11050294
# 		at index 9124: packetNum not sequentially increasing. Current: 33131, Previous: 235
# 		at index 10672: packetNum not sequentially increasing. Current: 34680, Previous: 34678
# 		at index 10672: tick increment greater than timeout. Difference: 600ms
# 		at index 11662: packetNum not sequentially increasing. Current: 35671, Previous: 35669
# 		at index 11662: tick increment greater than timeout. Difference: 806ms
# 		dropped 6556 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 34 minutes and 5.00 seconds
# 		Error (server timestamp vs tick): 0.29 seconds
# 		% drift: -0.014352085257743402
# 	watch processing...
# The size of the loaded data is 768.5201797485352 MB
# ERROR WITH USER 1: No objects to concatenate
# ['/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_141145_p19_LAB_DEMO.csv', '/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_141743_p19_LAB_TETRIS.csv', '/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_143033_p19_TETRIS_CONTD.csv', '/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_145444_p19_LAB_FLOW.csv', '/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_150634_p19_FLOW_CONTD.csv']
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_141145_p19_LAB_DEMO.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 55.90 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.007867378477100308
# 	gyro processing...
# 		at index 365: packetNum not sequentially increasing. Current: 216, Previous: 214
# 		at index 365: tick increment greater than timeout. Difference: 1232ms
# 		at index 540: packetNum not sequentially increasing. Current: 134, Previous: 134
# 		at index 540: packet_tick not increasing. Current: 565504, Previous: 565504
# 		at index 756: packetNum not sequentially increasing. Current: 95, Previous: 93
# 		at index 756: tick increment greater than timeout. Difference: 1148ms
# 		at index 824: packetNum not sequentially increasing. Current: 164, Previous: 162
# 		at index 824: tick increment greater than timeout. Difference: 1196ms
# 		at index 878: packetNum not sequentially increasing. Current: 219, Previous: 217
# 		at index 878: tick increment greater than timeout. Difference: 1170ms
# 		dropped 63 rows of data due to duplication.
# 		dropped 12 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 57.26 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.009376937492215043
# 	accelerometer processing...
# 		at index 235: packetNum not sequentially increasing. Current: 205, Previous: 205
# 		at index 235: packet_tick not increasing. Current: 458532, Previous: 458532
# 		at index 695: packetNum not sequentially increasing. Current: 154, Previous: 152
# 		at index 695: tick increment greater than timeout. Difference: 1875ms
# 		dropped 34 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 57.23 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.0076980246868653505
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 1002: packetNum not sequentially increasing. Current: 1675, Previous: 1673
# 		at index 1002: tick increment greater than timeout. Difference: 804ms
# 		at index 1394: packetNum not sequentially increasing. Current: 2066, Previous: 2066
# 		at index 1394: packet_tick not increasing. Current: 695493, Previous: 695493
# 		at index 1521: packetNum not sequentially increasing. Current: 2192, Previous: 2192
# 		at index 1521: packet_tick not increasing. Current: 737493, Previous: 737493
# 		at index 1620: packetNum not sequentially increasing. Current: 2290, Previous: 2290
# 		at index 1620: packet_tick not increasing. Current: 770293, Previous: 770293
# 		at index 2041: packetNum not sequentially increasing. Current: 2710, Previous: 2710
# 		at index 2041: packet_tick not increasing. Current: 910293, Previous: 910293
# 		dropped 1383 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 57.00 seconds
# 		Error (server timestamp vs tick): 0.22 seconds
# 		% drift: -0.06288533021100899
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_141743_p19_LAB_TETRIS.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 51.90 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.0020728073584661225
# 	gyro processing...
# 		at index 263: packetNum not sequentially increasing. Current: 254, Previous: 252
# 		at index 263: tick increment greater than timeout. Difference: 1151ms
# 		at index 416: packetNum not sequentially increasing. Current: 150, Previous: 150
# 		at index 416: packet_tick not increasing. Current: 1202547, Previous: 1202547
# 		at index 442: packetNum not sequentially increasing. Current: 177, Previous: 175
# 		at index 442: tick increment greater than timeout. Difference: 1261ms
# 		dropped 65 rows of data due to duplication.
# 		dropped 10 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 50.97 seconds
# 		Error (server timestamp vs tick): 0.14 seconds
# 		% drift: -0.018418368041796723
# 	accelerometer processing...
# 		at index 978: packetNum not sequentially increasing. Current: 144, Previous: 142
# 		at index 978: tick increment greater than timeout. Difference: 2068ms
# 		at index 1414: packetNum not sequentially increasing. Current: 69, Previous: 67
# 		at index 1414: tick increment greater than timeout. Difference: 1991ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 50.81 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 0.00025946849176803775
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 491: packetNum not sequentially increasing. Current: 3304, Previous: 3304
# 		at index 491: packet_tick not increasing. Current: 1108293, Previous: 1108293
# 		at index 774: packetNum not sequentially increasing. Current: 3588, Previous: 3586
# 		at index 774: tick increment greater than timeout. Difference: 599ms
# 		at index 820: packetNum not sequentially increasing. Current: 3633, Previous: 3633
# 		at index 820: packet_tick not increasing. Current: 1217894, Previous: 1217894
# 		at index 2882: packetNum not sequentially increasing. Current: 5694, Previous: 5694
# 		at index 2882: packet_tick not increasing. Current: 1904894, Previous: 1904894
# 		at index 4168: packetNum not sequentially increasing. Current: 6979, Previous: 6979
# 		at index 4168: packet_tick not increasing. Current: 2333293, Previous: 2333293
# 		dropped 1981 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 51.00 seconds
# 		Error (server timestamp vs tick): 0.17 seconds
# 		% drift: -0.02224386802058109
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_143033_p19_TETRIS_CONTD.csv
# got raw data.
# 	thermal processing...
# 		at index 53: packetNum not sequentially increasing. Current: 675, Previous: 673
# 		at index 53: tick increment greater than timeout. Difference: 7985ms
# 		at index 61: packetNum not sequentially increasing. Current: 684, Previous: 682
# 		at index 61: tick increment greater than timeout. Difference: 7994ms
# 		at index 63: packetNum not sequentially increasing. Current: 687, Previous: 685
# 		at index 63: tick increment greater than timeout. Difference: 7997ms
# 		at index 65: packetNum not sequentially increasing. Current: 690, Previous: 688
# 		at index 65: tick increment greater than timeout. Difference: 8001ms
# 		at index 240: packetNum not sequentially increasing. Current: 866, Previous: 864
# 		at index 240: tick increment greater than timeout. Difference: 8002ms
# 		at index 295: packetNum not sequentially increasing. Current: 922, Previous: 920
# 		at index 295: tick increment greater than timeout. Difference: 7991ms
# 		at index 314: packetNum not sequentially increasing. Current: 942, Previous: 940
# 		at index 314: tick increment greater than timeout. Difference: 7998ms
# 		at index 439: packetNum not sequentially increasing. Current: 1068, Previous: 1066
# 		at index 439: tick increment greater than timeout. Difference: 8013ms
# 		at index 443: packetNum not sequentially increasing. Current: 1073, Previous: 1071
# 		at index 443: tick increment greater than timeout. Difference: 7990ms
# 		at index 466: packetNum not sequentially increasing. Current: 1098, Previous: 1095
# 		at index 466: tick increment greater than timeout. Difference: 11994ms
# 		at index 492: packetNum not sequentially increasing. Current: 1125, Previous: 1123
# 		at index 492: tick increment greater than timeout. Difference: 8000ms
# 		at index 494: packetNum not sequentially increasing. Current: 1128, Previous: 1126
# 		at index 494: tick increment greater than timeout. Difference: 8010ms
# 		at index 536: packetNum not sequentially increasing. Current: 1171, Previous: 1169
# 		at index 536: tick increment greater than timeout. Difference: 7999ms
# 		at index 572: packetNum not sequentially increasing. Current: 1208, Previous: 1206
# 		at index 572: tick increment greater than timeout. Difference: 8004ms
# 		at index 574: packetNum not sequentially increasing. Current: 1211, Previous: 1209
# 		at index 574: tick increment greater than timeout. Difference: 7999ms
# 		at index 634: packetNum not sequentially increasing. Current: 1272, Previous: 1270
# 		at index 634: tick increment greater than timeout. Difference: 7980ms
# 		at index 636: packetNum not sequentially increasing. Current: 1275, Previous: 1273
# 		at index 636: tick increment greater than timeout. Difference: 8004ms
# 		at index 654: packetNum not sequentially increasing. Current: 1294, Previous: 1292
# 		at index 654: tick increment greater than timeout. Difference: 8000ms
# 		at index 663: packetNum not sequentially increasing. Current: 1304, Previous: 1302
# 		at index 663: tick increment greater than timeout. Difference: 7999ms
# 		at index 666: packetNum not sequentially increasing. Current: 1308, Previous: 1306
# 		at index 666: tick increment greater than timeout. Difference: 7991ms
# 		at index 672: packetNum not sequentially increasing. Current: 1315, Previous: 1313
# 		at index 672: tick increment greater than timeout. Difference: 7997ms
# 		at index 675: packetNum not sequentially increasing. Current: 1319, Previous: 1317
# 		at index 675: tick increment greater than timeout. Difference: 7999ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 9.90 seconds
# 		Error (server timestamp vs tick): 0.10 seconds
# 		% drift: -0.0066901165597627425
# 	gyro processing...
# 		at index 1391: packetNum not sequentially increasing. Current: 58, Previous: 56
# 		at index 1391: tick increment greater than timeout. Difference: 1222ms
# 		at index 1401: packetNum not sequentially increasing. Current: 69, Previous: 67
# 		at index 1401: tick increment greater than timeout. Difference: 1186ms
# 		at index 1534: packetNum not sequentially increasing. Current: 203, Previous: 201
# 		at index 1534: tick increment greater than timeout. Difference: 1267ms
# 		at index 2565: packetNum not sequentially increasing. Current: 211, Previous: 209
# 		at index 2565: tick increment greater than timeout. Difference: 1292ms
# 		at index 2735: packetNum not sequentially increasing. Current: 126, Previous: 124
# 		at index 2735: tick increment greater than timeout. Difference: 1224ms
# 		at index 3001: packetNum not sequentially increasing. Current: 137, Previous: 135
# 		at index 3001: tick increment greater than timeout. Difference: 1249ms
# 		at index 3126: packetNum not sequentially increasing. Current: 5, Previous: 5
# 		at index 3126: packet_tick not increasing. Current: 4393678, Previous: 4393678
# 		at index 3131: packetNum not sequentially increasing. Current: 11, Previous: 9
# 		at index 3131: tick increment greater than timeout. Difference: 1278ms
# 		at index 3243: packetNum not sequentially increasing. Current: 124, Previous: 122
# 		at index 3243: tick increment greater than timeout. Difference: 1260ms
# 		at index 3301: packetNum not sequentially increasing. Current: 183, Previous: 181
# 		at index 3301: tick increment greater than timeout. Difference: 1243ms
# 		at index 3302: packetNum not sequentially increasing. Current: 185, Previous: 183
# 		at index 3302: tick increment greater than timeout. Difference: 1212ms
# 		at index 3319: packetNum not sequentially increasing. Current: 203, Previous: 201
# 		at index 3319: tick increment greater than timeout. Difference: 1190ms
# 		at index 3552: packetNum not sequentially increasing. Current: 181, Previous: 179
# 		at index 3552: tick increment greater than timeout. Difference: 1162ms
# 		at index 3584: packetNum not sequentially increasing. Current: 214, Previous: 212
# 		at index 3584: tick increment greater than timeout. Difference: 1291ms
# 		at index 3611: packetNum not sequentially increasing. Current: 242, Previous: 240
# 		at index 3611: tick increment greater than timeout. Difference: 1232ms
# 		at index 3628: packetNum not sequentially increasing. Current: 4, Previous: 2
# 		at index 3628: tick increment greater than timeout. Difference: 1203ms
# 		at index 3686: packetNum not sequentially increasing. Current: 63, Previous: 61
# 		at index 3686: tick increment greater than timeout. Difference: 1297ms
# 		at index 4086: packetNum not sequentially increasing. Current: 208, Previous: 206
# 		at index 4086: tick increment greater than timeout. Difference: 1220ms
# 		at index 4385: packetNum not sequentially increasing. Current: 252, Previous: 250
# 		at index 4385: tick increment greater than timeout. Difference: 1211ms
# 		at index 4460: packetNum not sequentially increasing. Current: 72, Previous: 70
# 		at index 4460: tick increment greater than timeout. Difference: 1217ms
# 		at index 4507: packetNum not sequentially increasing. Current: 120, Previous: 118
# 		at index 4507: tick increment greater than timeout. Difference: 1253ms
# 		at index 4517: packetNum not sequentially increasing. Current: 131, Previous: 129
# 		at index 4517: tick increment greater than timeout. Difference: 1305ms
# 		at index 4654: packetNum not sequentially increasing. Current: 13, Previous: 11
# 		at index 4654: tick increment greater than timeout. Difference: 1198ms
# 		dropped 64 rows of data due to duplication.
# 		dropped 8 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 10.17 seconds
# 		Error (server timestamp vs tick): 0.13 seconds
# 		% drift: -0.00920579503073253
# 	accelerometer processing...
# 		at index 284: packetNum not sequentially increasing. Current: 253, Previous: 251
# 		at index 284: tick increment greater than timeout. Difference: 1860ms
# 		at index 856: packetNum not sequentially increasing. Current: 58, Previous: 56
# 		at index 856: tick increment greater than timeout. Difference: 1906ms
# 		at index 2041: packetNum not sequentially increasing. Current: 220, Previous: 218
# 		at index 2041: tick increment greater than timeout. Difference: 1781ms
# 		at index 2052: packetNum not sequentially increasing. Current: 233, Previous: 230
# 		at index 2052: tick increment greater than timeout. Difference: 3082ms
# 		at index 2628: packetNum not sequentially increasing. Current: 42, Previous: 40
# 		at index 2628: tick increment greater than timeout. Difference: 1989ms
# 		at index 2667: packetNum not sequentially increasing. Current: 82, Previous: 80
# 		at index 2667: tick increment greater than timeout. Difference: 1918ms
# 		at index 2710: packetNum not sequentially increasing. Current: 126, Previous: 124
# 		at index 2710: tick increment greater than timeout. Difference: 2007ms
# 		at index 2762: packetNum not sequentially increasing. Current: 179, Previous: 177
# 		at index 2762: tick increment greater than timeout. Difference: 1962ms
# 		at index 2770: packetNum not sequentially increasing. Current: 188, Previous: 186
# 		at index 2770: tick increment greater than timeout. Difference: 1952ms
# 		dropped 33 rows of data due to duplication.
# 		dropped 10 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 10.33 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.002447719638882061
# 	quaternion extended kalman filter application...

# %%
#users_to_process = [2,3,5,6,7,11,13,15,16,17,19,22,23,24,25]
users_to_process = [1, 12, 18, 19, 20, 21, 23] #missing one session of E4 data in [sess1, sess2]
#TODO = 4, 8, 10, 14
#DONE = 1, 9

folder = '/Volumes/Secondary/PhDStudy_Results'

for user in users_to_process:
    try:
        #grab all sections of Session 1 for that user (glasses CSVs, each separated by task/env')
        session_data = load_session_excel(folder, 'P' + str(user), 'sess1')
        try:
            session_data = update_sessions_with_E4_data(session_data, folder, user, 1)
        except:
            print('FAILED TO PROCESS e4 data for session 1')
        print('Successfully processed P' + str(user) + ' sess1.')
        
        #grab all sections of Session 2
        sess2_data = load_session_excel(folder, 'P' + str(user), 'sess2')
        try:
            sess2_data = update_sessions_with_E4_data(sess2_data, folder, user, 2)
        except:
            print('FAILED TO PROCESS e4 data for session 2')
        print('Successfully processed P' + str(user) + ' sess2.')
        
        #combine into one
        session_data.extend(sess2_data)
        print('Successfully combined P' + str(user) + ' sess1 and sess2.')
        
        #process the survey data for each session
        session_data, entrance, exit = process_surveys(folder, user, session_data)
        print('Successfully processed surveys for P' + str(user) + '.')
        
        #save to a pickle
        with open(folder + '/P' + str(user) + '_Processed.pickle', 'wb') as handle:
            pickle.dump((session_data, entrance, exit), handle, protocol=pickle.HIGHEST_PROTOCOL)
        print('Successfully saved P' + str(user) + ' data.')
        
    except Exception as e:
        print(f'ERROR WITH USER {user}: {e}')
# Out:
# ['/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_141145_p19_LAB_DEMO.csv', '/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_141743_p19_LAB_TETRIS.csv', '/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_143033_p19_TETRIS_CONTD.csv', '/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_145444_p19_LAB_FLOW.csv', '/Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_150634_p19_FLOW_CONTD.csv']
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_141145_p19_LAB_DEMO.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 55.90 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.007867378477100308
# 	gyro processing...
# 		at index 365: packetNum not sequentially increasing. Current: 216, Previous: 214
# 		at index 365: tick increment greater than timeout. Difference: 1232ms
# 		at index 540: packetNum not sequentially increasing. Current: 134, Previous: 134
# 		at index 540: packet_tick not increasing. Current: 565504, Previous: 565504
# 		at index 756: packetNum not sequentially increasing. Current: 95, Previous: 93
# 		at index 756: tick increment greater than timeout. Difference: 1148ms
# 		at index 824: packetNum not sequentially increasing. Current: 164, Previous: 162
# 		at index 824: tick increment greater than timeout. Difference: 1196ms
# 		at index 878: packetNum not sequentially increasing. Current: 219, Previous: 217
# 		at index 878: tick increment greater than timeout. Difference: 1170ms
# 		dropped 63 rows of data due to duplication.
# 		dropped 12 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 57.26 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.009376937492215043
# 	accelerometer processing...
# 		at index 235: packetNum not sequentially increasing. Current: 205, Previous: 205
# 		at index 235: packet_tick not increasing. Current: 458532, Previous: 458532
# 		at index 695: packetNum not sequentially increasing. Current: 154, Previous: 152
# 		at index 695: tick increment greater than timeout. Difference: 1875ms
# 		dropped 34 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 57.23 seconds
# 		Error (server timestamp vs tick): 0.03 seconds
# 		% drift: -0.0076980246868653505
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 1002: packetNum not sequentially increasing. Current: 1675, Previous: 1673
# 		at index 1002: tick increment greater than timeout. Difference: 804ms
# 		at index 1394: packetNum not sequentially increasing. Current: 2066, Previous: 2066
# 		at index 1394: packet_tick not increasing. Current: 695493, Previous: 695493
# 		at index 1521: packetNum not sequentially increasing. Current: 2192, Previous: 2192
# 		at index 1521: packet_tick not increasing. Current: 737493, Previous: 737493
# 		at index 1620: packetNum not sequentially increasing. Current: 2290, Previous: 2290
# 		at index 1620: packet_tick not increasing. Current: 770293, Previous: 770293
# 		at index 2041: packetNum not sequentially increasing. Current: 2710, Previous: 2710
# 		at index 2041: packet_tick not increasing. Current: 910293, Previous: 910293
# 		dropped 1383 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 5 minutes and 57.00 seconds
# 		Error (server timestamp vs tick): 0.22 seconds
# 		% drift: -0.06288533021100899
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_141743_p19_LAB_TETRIS.csv
# got raw data.
# 	thermal processing...
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 51.90 seconds
# 		Error (server timestamp vs tick): 0.02 seconds
# 		% drift: -0.0020728073584661225
# 	gyro processing...
# 		at index 263: packetNum not sequentially increasing. Current: 254, Previous: 252
# 		at index 263: tick increment greater than timeout. Difference: 1151ms
# 		at index 416: packetNum not sequentially increasing. Current: 150, Previous: 150
# 		at index 416: packet_tick not increasing. Current: 1202547, Previous: 1202547
# 		at index 442: packetNum not sequentially increasing. Current: 177, Previous: 175
# 		at index 442: tick increment greater than timeout. Difference: 1261ms
# 		dropped 65 rows of data due to duplication.
# 		dropped 10 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 50.97 seconds
# 		Error (server timestamp vs tick): 0.14 seconds
# 		% drift: -0.018418368041796723
# 	accelerometer processing...
# 		at index 978: packetNum not sequentially increasing. Current: 144, Previous: 142
# 		at index 978: tick increment greater than timeout. Difference: 2068ms
# 		at index 1414: packetNum not sequentially increasing. Current: 69, Previous: 67
# 		at index 1414: tick increment greater than timeout. Difference: 1991ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 50.81 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 0.00025946849176803775
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 491: packetNum not sequentially increasing. Current: 3304, Previous: 3304
# 		at index 491: packet_tick not increasing. Current: 1108293, Previous: 1108293
# 		at index 774: packetNum not sequentially increasing. Current: 3588, Previous: 3586
# 		at index 774: tick increment greater than timeout. Difference: 599ms
# 		at index 820: packetNum not sequentially increasing. Current: 3633, Previous: 3633
# 		at index 820: packet_tick not increasing. Current: 1217894, Previous: 1217894
# 		at index 2882: packetNum not sequentially increasing. Current: 5694, Previous: 5694
# 		at index 2882: packet_tick not increasing. Current: 1904894, Previous: 1904894
# 		at index 4168: packetNum not sequentially increasing. Current: 6979, Previous: 6979
# 		at index 4168: packet_tick not increasing. Current: 2333293, Previous: 2333293
# 		dropped 1981 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 12 minutes and 51.00 seconds
# 		Error (server timestamp vs tick): 0.17 seconds
# 		% drift: -0.02224386802058109
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_143033_p19_TETRIS_CONTD.csv
# got raw data.
# 	thermal processing...
# 		at index 53: packetNum not sequentially increasing. Current: 675, Previous: 673
# 		at index 53: tick increment greater than timeout. Difference: 7985ms
# 		at index 61: packetNum not sequentially increasing. Current: 684, Previous: 682
# 		at index 61: tick increment greater than timeout. Difference: 7994ms
# 		at index 63: packetNum not sequentially increasing. Current: 687, Previous: 685
# 		at index 63: tick increment greater than timeout. Difference: 7997ms
# 		at index 65: packetNum not sequentially increasing. Current: 690, Previous: 688
# 		at index 65: tick increment greater than timeout. Difference: 8001ms
# 		at index 240: packetNum not sequentially increasing. Current: 866, Previous: 864
# 		at index 240: tick increment greater than timeout. Difference: 8002ms
# 		at index 295: packetNum not sequentially increasing. Current: 922, Previous: 920
# 		at index 295: tick increment greater than timeout. Difference: 7991ms
# 		at index 314: packetNum not sequentially increasing. Current: 942, Previous: 940
# 		at index 314: tick increment greater than timeout. Difference: 7998ms
# 		at index 439: packetNum not sequentially increasing. Current: 1068, Previous: 1066
# 		at index 439: tick increment greater than timeout. Difference: 8013ms
# 		at index 443: packetNum not sequentially increasing. Current: 1073, Previous: 1071
# 		at index 443: tick increment greater than timeout. Difference: 7990ms
# 		at index 466: packetNum not sequentially increasing. Current: 1098, Previous: 1095
# 		at index 466: tick increment greater than timeout. Difference: 11994ms
# 		at index 492: packetNum not sequentially increasing. Current: 1125, Previous: 1123
# 		at index 492: tick increment greater than timeout. Difference: 8000ms
# 		at index 494: packetNum not sequentially increasing. Current: 1128, Previous: 1126
# 		at index 494: tick increment greater than timeout. Difference: 8010ms
# 		at index 536: packetNum not sequentially increasing. Current: 1171, Previous: 1169
# 		at index 536: tick increment greater than timeout. Difference: 7999ms
# 		at index 572: packetNum not sequentially increasing. Current: 1208, Previous: 1206
# 		at index 572: tick increment greater than timeout. Difference: 8004ms
# 		at index 574: packetNum not sequentially increasing. Current: 1211, Previous: 1209
# 		at index 574: tick increment greater than timeout. Difference: 7999ms
# 		at index 634: packetNum not sequentially increasing. Current: 1272, Previous: 1270
# 		at index 634: tick increment greater than timeout. Difference: 7980ms
# 		at index 636: packetNum not sequentially increasing. Current: 1275, Previous: 1273
# 		at index 636: tick increment greater than timeout. Difference: 8004ms
# 		at index 654: packetNum not sequentially increasing. Current: 1294, Previous: 1292
# 		at index 654: tick increment greater than timeout. Difference: 8000ms
# 		at index 663: packetNum not sequentially increasing. Current: 1304, Previous: 1302
# 		at index 663: tick increment greater than timeout. Difference: 7999ms
# 		at index 666: packetNum not sequentially increasing. Current: 1308, Previous: 1306
# 		at index 666: tick increment greater than timeout. Difference: 7991ms
# 		at index 672: packetNum not sequentially increasing. Current: 1315, Previous: 1313
# 		at index 672: tick increment greater than timeout. Difference: 7997ms
# 		at index 675: packetNum not sequentially increasing. Current: 1319, Previous: 1317
# 		at index 675: tick increment greater than timeout. Difference: 7999ms
# 		dropped 0 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 9.90 seconds
# 		Error (server timestamp vs tick): 0.10 seconds
# 		% drift: -0.0066901165597627425
# 	gyro processing...
# 		at index 1391: packetNum not sequentially increasing. Current: 58, Previous: 56
# 		at index 1391: tick increment greater than timeout. Difference: 1222ms
# 		at index 1401: packetNum not sequentially increasing. Current: 69, Previous: 67
# 		at index 1401: tick increment greater than timeout. Difference: 1186ms
# 		at index 1534: packetNum not sequentially increasing. Current: 203, Previous: 201
# 		at index 1534: tick increment greater than timeout. Difference: 1267ms
# 		at index 2565: packetNum not sequentially increasing. Current: 211, Previous: 209
# 		at index 2565: tick increment greater than timeout. Difference: 1292ms
# 		at index 2735: packetNum not sequentially increasing. Current: 126, Previous: 124
# 		at index 2735: tick increment greater than timeout. Difference: 1224ms
# 		at index 3001: packetNum not sequentially increasing. Current: 137, Previous: 135
# 		at index 3001: tick increment greater than timeout. Difference: 1249ms
# 		at index 3126: packetNum not sequentially increasing. Current: 5, Previous: 5
# 		at index 3126: packet_tick not increasing. Current: 4393678, Previous: 4393678
# 		at index 3131: packetNum not sequentially increasing. Current: 11, Previous: 9
# 		at index 3131: tick increment greater than timeout. Difference: 1278ms
# 		at index 3243: packetNum not sequentially increasing. Current: 124, Previous: 122
# 		at index 3243: tick increment greater than timeout. Difference: 1260ms
# 		at index 3301: packetNum not sequentially increasing. Current: 183, Previous: 181
# 		at index 3301: tick increment greater than timeout. Difference: 1243ms
# 		at index 3302: packetNum not sequentially increasing. Current: 185, Previous: 183
# 		at index 3302: tick increment greater than timeout. Difference: 1212ms
# 		at index 3319: packetNum not sequentially increasing. Current: 203, Previous: 201
# 		at index 3319: tick increment greater than timeout. Difference: 1190ms
# 		at index 3552: packetNum not sequentially increasing. Current: 181, Previous: 179
# 		at index 3552: tick increment greater than timeout. Difference: 1162ms
# 		at index 3584: packetNum not sequentially increasing. Current: 214, Previous: 212
# 		at index 3584: tick increment greater than timeout. Difference: 1291ms
# 		at index 3611: packetNum not sequentially increasing. Current: 242, Previous: 240
# 		at index 3611: tick increment greater than timeout. Difference: 1232ms
# 		at index 3628: packetNum not sequentially increasing. Current: 4, Previous: 2
# 		at index 3628: tick increment greater than timeout. Difference: 1203ms
# 		at index 3686: packetNum not sequentially increasing. Current: 63, Previous: 61
# 		at index 3686: tick increment greater than timeout. Difference: 1297ms
# 		at index 4086: packetNum not sequentially increasing. Current: 208, Previous: 206
# 		at index 4086: tick increment greater than timeout. Difference: 1220ms
# 		at index 4385: packetNum not sequentially increasing. Current: 252, Previous: 250
# 		at index 4385: tick increment greater than timeout. Difference: 1211ms
# 		at index 4460: packetNum not sequentially increasing. Current: 72, Previous: 70
# 		at index 4460: tick increment greater than timeout. Difference: 1217ms
# 		at index 4507: packetNum not sequentially increasing. Current: 120, Previous: 118
# 		at index 4507: tick increment greater than timeout. Difference: 1253ms
# 		at index 4517: packetNum not sequentially increasing. Current: 131, Previous: 129
# 		at index 4517: tick increment greater than timeout. Difference: 1305ms
# 		at index 4654: packetNum not sequentially increasing. Current: 13, Previous: 11
# 		at index 4654: tick increment greater than timeout. Difference: 1198ms
# 		dropped 64 rows of data due to duplication.
# 		dropped 8 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 10.17 seconds
# 		Error (server timestamp vs tick): 0.13 seconds
# 		% drift: -0.00920579503073253
# 	accelerometer processing...
# 		at index 284: packetNum not sequentially increasing. Current: 253, Previous: 251
# 		at index 284: tick increment greater than timeout. Difference: 1860ms
# 		at index 856: packetNum not sequentially increasing. Current: 58, Previous: 56
# 		at index 856: tick increment greater than timeout. Difference: 1906ms
# 		at index 2041: packetNum not sequentially increasing. Current: 220, Previous: 218
# 		at index 2041: tick increment greater than timeout. Difference: 1781ms
# 		at index 2052: packetNum not sequentially increasing. Current: 233, Previous: 230
# 		at index 2052: tick increment greater than timeout. Difference: 3082ms
# 		at index 2628: packetNum not sequentially increasing. Current: 42, Previous: 40
# 		at index 2628: tick increment greater than timeout. Difference: 1989ms
# 		at index 2667: packetNum not sequentially increasing. Current: 82, Previous: 80
# 		at index 2667: tick increment greater than timeout. Difference: 1918ms
# 		at index 2710: packetNum not sequentially increasing. Current: 126, Previous: 124
# 		at index 2710: tick increment greater than timeout. Difference: 2007ms
# 		at index 2762: packetNum not sequentially increasing. Current: 179, Previous: 177
# 		at index 2762: tick increment greater than timeout. Difference: 1962ms
# 		at index 2770: packetNum not sequentially increasing. Current: 188, Previous: 186
# 		at index 2770: tick increment greater than timeout. Difference: 1952ms
# 		dropped 33 rows of data due to duplication.
# 		dropped 10 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 10.33 seconds
# 		Error (server timestamp vs tick): 0.04 seconds
# 		% drift: -0.002447719638882061
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 59: packetNum not sequentially increasing. Current: 7500, Previous: 7498
# 		at index 59: tick increment greater than timeout. Difference: 599ms
# 		at index 2536: packetNum not sequentially increasing. Current: 9978, Previous: 9976
# 		at index 2536: tick increment greater than timeout. Difference: 600ms
# 		at index 2541: packetNum not sequentially increasing. Current: 9984, Previous: 9982
# 		at index 2541: tick increment greater than timeout. Difference: 599ms
# 		at index 2805: packetNum not sequentially increasing. Current: 10247, Previous: 10247
# 		at index 2805: packet_tick not increasing. Current: 3422493, Previous: 3422493
# 		at index 3888: packetNum not sequentially increasing. Current: 11331, Previous: 11329
# 		at index 3888: tick increment greater than timeout. Difference: 600ms
# 		at index 5486: packetNum not sequentially increasing. Current: 12928, Previous: 12928
# 		at index 5486: packet_tick not increasing. Current: 4316293, Previous: 4316293
# 		at index 5706: packetNum not sequentially increasing. Current: 13149, Previous: 13147
# 		at index 5706: tick increment greater than timeout. Difference: 598ms
# 		at index 5717: packetNum not sequentially increasing. Current: 13161, Previous: 13159
# 		at index 5717: tick increment greater than timeout. Difference: 600ms
# 		at index 5934: packetNum not sequentially increasing. Current: 13380, Previous: 13377
# 		at index 5934: tick increment greater than timeout. Difference: 999ms
# 		at index 6036: packetNum not sequentially increasing. Current: 13485, Previous: 13481
# 		at index 6036: tick increment greater than timeout. Difference: 1399ms
# 		at index 6038: packetNum not sequentially increasing. Current: 13488, Previous: 13486
# 		at index 6038: tick increment greater than timeout. Difference: 600ms
# 		at index 6052: packetNum not sequentially increasing. Current: 13503, Previous: 13501
# 		at index 6052: tick increment greater than timeout. Difference: 600ms
# 		at index 6070: packetNum not sequentially increasing. Current: 13520, Previous: 13520
# 		at index 6070: packet_tick not increasing. Current: 4513493, Previous: 4513493
# 		at index 6540: packetNum not sequentially increasing. Current: 13992, Previous: 13989
# 		at index 6540: tick increment greater than timeout. Difference: 1000ms
# 		at index 6611: packetNum not sequentially increasing. Current: 14062, Previous: 14062
# 		at index 6611: packet_tick not increasing. Current: 4694293, Previous: 4694293
# 		at index 7420: packetNum not sequentially increasing. Current: 14874, Previous: 14870
# 		at index 7420: tick increment greater than timeout. Difference: 1399ms
# 		at index 7485: packetNum not sequentially increasing. Current: 14938, Previous: 14938
# 		at index 7485: packet_tick not increasing. Current: 4986294, Previous: 4986294
# 		at index 7872: packetNum not sequentially increasing. Current: 15326, Previous: 15324
# 		at index 7872: tick increment greater than timeout. Difference: 600ms
# 		at index 8020: packetNum not sequentially increasing. Current: 15473, Previous: 15473
# 		at index 8020: packet_tick not increasing. Current: 5164493, Previous: 5164493
# 		at index 8086: packetNum not sequentially increasing. Current: 15540, Previous: 15538
# 		at index 8086: tick increment greater than timeout. Difference: 601ms
# 		at index 8175: packetNum not sequentially increasing. Current: 15630, Previous: 15628
# 		at index 8175: tick increment greater than timeout. Difference: 600ms
# 		at index 8177: packetNum not sequentially increasing. Current: 15633, Previous: 15631
# 		at index 8177: tick increment greater than timeout. Difference: 600ms
# 		at index 8267: packetNum not sequentially increasing. Current: 15722, Previous: 15722
# 		at index 8267: packet_tick not increasing. Current: 5247494, Previous: 5247494
# 		at index 8288: packetNum not sequentially increasing. Current: 15742, Previous: 15742
# 		at index 8288: packet_tick not increasing. Current: 5254293, Previous: 5254293
# 		at index 8331: packetNum not sequentially increasing. Current: 15786, Previous: 15784
# 		at index 8331: tick increment greater than timeout. Difference: 600ms
# 		at index 8602: packetNum not sequentially increasing. Current: 16059, Previous: 16056
# 		at index 8602: tick increment greater than timeout. Difference: 1000ms
# 		dropped 3135 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 24 minutes and 10.00 seconds
# 		Error (server timestamp vs tick): 0.24 seconds
# 		% drift: -0.016689660927469284
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_145444_p19_LAB_FLOW.csv
# got raw data.
# 	thermal processing...
# 		at index 4: packetNum not sequentially increasing. Current: 1352, Previous: 1349
# 		at index 4: tick increment greater than timeout. Difference: 11971ms
# 		at index 6: packetNum not sequentially increasing. Current: 1355, Previous: 1353
# 		at index 6: tick increment greater than timeout. Difference: 7999ms
# 		at index 49: packetNum not sequentially increasing. Current: 1399, Previous: 1397
# 		at index 49: tick increment greater than timeout. Difference: 8018ms
# 		at index 59: packetNum not sequentially increasing. Current: 1410, Previous: 1408
# 		at index 59: tick increment greater than timeout. Difference: 8010ms
# 		at index 74: packetNum not sequentially increasing. Current: 1426, Previous: 1424
# 		at index 74: tick increment greater than timeout. Difference: 7994ms
# 		at index 82: packetNum not sequentially increasing. Current: 1435, Previous: 1433
# 		at index 82: tick increment greater than timeout. Difference: 7990ms
# 		at index 87: packetNum not sequentially increasing. Current: 1441, Previous: 1439
# 		at index 87: tick increment greater than timeout. Difference: 8015ms
# 		at index 93: packetNum not sequentially increasing. Current: 1448, Previous: 1446
# 		at index 93: tick increment greater than timeout. Difference: 7984ms
# 		at index 150: packetNum not sequentially increasing. Current: 1506, Previous: 1504
# 		at index 150: tick increment greater than timeout. Difference: 8002ms
# 		at index 317: packetNum not sequentially increasing. Current: 1674, Previous: 1672
# 		at index 317: tick increment greater than timeout. Difference: 8003ms
# 		dropped 5 rows of data due to duplication.
# 		dropped 15 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 49.90 seconds
# 		Error (server timestamp vs tick): 0.20 seconds
# 		% drift: -0.028032117199605577
# 	gyro processing...
# 		at index 12: packetNum not sequentially increasing. Current: 101, Previous: 99
# 		at index 12: tick increment greater than timeout. Difference: 1218ms
# 		at index 16: packetNum not sequentially increasing. Current: 106, Previous: 104
# 		at index 16: tick increment greater than timeout. Difference: 1226ms
# 		at index 29: packetNum not sequentially increasing. Current: 122, Previous: 118
# 		at index 29: tick increment greater than timeout. Difference: 2341ms
# 		at index 31: packetNum not sequentially increasing. Current: 125, Previous: 123
# 		at index 31: tick increment greater than timeout. Difference: 1273ms
# 		at index 35: packetNum not sequentially increasing. Current: 130, Previous: 128
# 		at index 35: tick increment greater than timeout. Difference: 1274ms
# 		at index 37: packetNum not sequentially increasing. Current: 133, Previous: 131
# 		at index 37: tick increment greater than timeout. Difference: 1277ms
# 		at index 57: packetNum not sequentially increasing. Current: 154, Previous: 152
# 		at index 57: tick increment greater than timeout. Difference: 1161ms
# 		at index 59: packetNum not sequentially increasing. Current: 157, Previous: 155
# 		at index 59: tick increment greater than timeout. Difference: 1253ms
# 		at index 139: packetNum not sequentially increasing. Current: 238, Previous: 236
# 		at index 139: tick increment greater than timeout. Difference: 1303ms
# 		at index 271: packetNum not sequentially increasing. Current: 115, Previous: 113
# 		at index 271: tick increment greater than timeout. Difference: 1185ms
# 		at index 330: packetNum not sequentially increasing. Current: 175, Previous: 173
# 		at index 330: tick increment greater than timeout. Difference: 1198ms
# 		at index 419: packetNum not sequentially increasing. Current: 9, Previous: 7
# 		at index 419: tick increment greater than timeout. Difference: 1119ms
# 		at index 962: packetNum not sequentially increasing. Current: 41, Previous: 39
# 		at index 962: tick increment greater than timeout. Difference: 1145ms
# 		at index 1006: packetNum not sequentially increasing. Current: 86, Previous: 84
# 		at index 1006: tick increment greater than timeout. Difference: 1265ms
# 		at index 1019: packetNum not sequentially increasing. Current: 98, Previous: 98
# 		at index 1019: packet_tick not increasing. Current: 6025554, Previous: 6025554
# 		at index 1084: packetNum not sequentially increasing. Current: 164, Previous: 162
# 		at index 1084: tick increment greater than timeout. Difference: 1248ms
# 		at index 1155: packetNum not sequentially increasing. Current: 236, Previous: 234
# 		at index 1155: tick increment greater than timeout. Difference: 1221ms
# 		at index 1252: packetNum not sequentially increasing. Current: 78, Previous: 76
# 		at index 1252: tick increment greater than timeout. Difference: 1268ms
# 		at index 1282: packetNum not sequentially increasing. Current: 109, Previous: 107
# 		at index 1282: tick increment greater than timeout. Difference: 1219ms
# 		at index 1948: packetNum not sequentially increasing. Current: 8, Previous: 6
# 		at index 1948: tick increment greater than timeout. Difference: 1222ms
# 		at index 2011: packetNum not sequentially increasing. Current: 72, Previous: 70
# 		at index 2011: tick increment greater than timeout. Difference: 1269ms
# 		at index 2036: packetNum not sequentially increasing. Current: 98, Previous: 96
# 		at index 2036: tick increment greater than timeout. Difference: 1247ms
# 		dropped 29 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 50.65 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: 0.0011960805145116227
# 	accelerometer processing...
# 		at index 18: packetNum not sequentially increasing. Current: 116, Previous: 114
# 		at index 18: tick increment greater than timeout. Difference: 1910ms
# 		at index 20: packetNum not sequentially increasing. Current: 119, Previous: 117
# 		at index 20: tick increment greater than timeout. Difference: 1998ms
# 		at index 21: packetNum not sequentially increasing. Current: 121, Previous: 119
# 		at index 21: tick increment greater than timeout. Difference: 1884ms
# 		at index 22: packetNum not sequentially increasing. Current: 123, Previous: 121
# 		at index 22: tick increment greater than timeout. Difference: 1933ms
# 		at index 23: packetNum not sequentially increasing. Current: 126, Previous: 123
# 		at index 23: tick increment greater than timeout. Difference: 3023ms
# 		at index 24: packetNum not sequentially increasing. Current: 128, Previous: 126
# 		at index 24: tick increment greater than timeout. Difference: 2000ms
# 		at index 128: packetNum not sequentially increasing. Current: 233, Previous: 231
# 		at index 128: tick increment greater than timeout. Difference: 1928ms
# 		at index 273: packetNum not sequentially increasing. Current: 123, Previous: 121
# 		at index 273: tick increment greater than timeout. Difference: 1986ms
# 		at index 435: packetNum not sequentially increasing. Current: 30, Previous: 28
# 		at index 435: tick increment greater than timeout. Difference: 1926ms
# 		at index 727: packetNum not sequentially increasing. Current: 67, Previous: 65
# 		at index 727: tick increment greater than timeout. Difference: 2044ms
# 		at index 853: packetNum not sequentially increasing. Current: 194, Previous: 192
# 		at index 853: tick increment greater than timeout. Difference: 1907ms
# 		at index 1149: packetNum not sequentially increasing. Current: 235, Previous: 233
# 		at index 1149: tick increment greater than timeout. Difference: 1902ms
# 		at index 1172: packetNum not sequentially increasing. Current: 3, Previous: 1
# 		at index 1172: tick increment greater than timeout. Difference: 2025ms
# 		at index 1264: packetNum not sequentially increasing. Current: 96, Previous: 94
# 		at index 1264: tick increment greater than timeout. Difference: 1902ms
# 		dropped 43 rows of data due to duplication.
# 		dropped 14 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 50.56 seconds
# 		Error (server timestamp vs tick): 0.06 seconds
# 		% drift: -0.008725518411899355
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 26: packetNum not sequentially increasing. Current: 16167, Previous: 16165
# 		at index 26: tick increment greater than timeout. Difference: 600ms
# 		at index 57: packetNum not sequentially increasing. Current: 16199, Previous: 16197
# 		at index 57: tick increment greater than timeout. Difference: 600ms
# 		at index 58: packetNum not sequentially increasing. Current: 16203, Previous: 16199
# 		at index 58: tick increment greater than timeout. Difference: 1401ms
# 		at index 59: packetNum not sequentially increasing. Current: 16206, Previous: 16203
# 		at index 59: tick increment greater than timeout. Difference: 999ms
# 		at index 64: packetNum not sequentially increasing. Current: 16212, Previous: 16210
# 		at index 64: tick increment greater than timeout. Difference: 600ms
# 		at index 68: packetNum not sequentially increasing. Current: 16218, Previous: 16215
# 		at index 68: tick increment greater than timeout. Difference: 1001ms
# 		at index 73: packetNum not sequentially increasing. Current: 16224, Previous: 16222
# 		at index 73: tick increment greater than timeout. Difference: 600ms
# 		at index 102: packetNum not sequentially increasing. Current: 16254, Previous: 16252
# 		at index 102: tick increment greater than timeout. Difference: 597ms
# 		at index 113: packetNum not sequentially increasing. Current: 16266, Previous: 16264
# 		at index 113: tick increment greater than timeout. Difference: 601ms
# 		at index 117: packetNum not sequentially increasing. Current: 16272, Previous: 16269
# 		at index 117: tick increment greater than timeout. Difference: 1000ms
# 		at index 267: packetNum not sequentially increasing. Current: 16421, Previous: 16421
# 		at index 267: packet_tick not increasing. Current: 5480493, Previous: 5480493
# 		at index 297: packetNum not sequentially increasing. Current: 16452, Previous: 16450
# 		at index 297: tick increment greater than timeout. Difference: 599ms
# 		at index 362: packetNum not sequentially increasing. Current: 16518, Previous: 16516
# 		at index 362: tick increment greater than timeout. Difference: 601ms
# 		at index 538: packetNum not sequentially increasing. Current: 16695, Previous: 16693
# 		at index 538: tick increment greater than timeout. Difference: 601ms
# 		at index 617: packetNum not sequentially increasing. Current: 16773, Previous: 16773
# 		at index 617: packet_tick not increasing. Current: 5597894, Previous: 5597894
# 		at index 2296: packetNum not sequentially increasing. Current: 18453, Previous: 18451
# 		at index 2296: tick increment greater than timeout. Difference: 601ms
# 		at index 2333: packetNum not sequentially increasing. Current: 77, Previous: 18489
# 		at index 2333: tick increment greater than timeout. Difference: 600ms
# 		at index 2334: packetNum not sequentially increasing. Current: 18490, Previous: 77
# 		at index 2334: packet_tick not increasing. Current: 6170294, Previous: 6170494
# 		at index 2380: packetNum not sequentially increasing. Current: 18537, Previous: 18535
# 		at index 2380: tick increment greater than timeout. Difference: 601ms
# 		at index 2835: packetNum not sequentially increasing. Current: 18993, Previous: 18991
# 		at index 2835: tick increment greater than timeout. Difference: 600ms
# 		at index 2870: packetNum not sequentially increasing. Current: 19029, Previous: 19027
# 		at index 2870: tick increment greater than timeout. Difference: 601ms
# 		at index 3481: packetNum not sequentially increasing. Current: 19641, Previous: 19639
# 		at index 3481: tick increment greater than timeout. Difference: 600ms
# 		at index 3576: packetNum not sequentially increasing. Current: 19737, Previous: 19735
# 		at index 3576: tick increment greater than timeout. Difference: 600ms
# 		at index 3911: packetNum not sequentially increasing. Current: 20071, Previous: 20071
# 		at index 3911: packet_tick not increasing. Current: 6697294, Previous: 6697294
# 		at index 4140: packetNum not sequentially increasing. Current: 20301, Previous: 20299
# 		at index 4140: tick increment greater than timeout. Difference: 598ms
# 		at index 4223: packetNum not sequentially increasing. Current: 20385, Previous: 20383
# 		at index 4223: tick increment greater than timeout. Difference: 600ms
# 		dropped 1673 rows of data due to duplication.
# 		dropped 0 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 11 minutes and 51.00 seconds
# 		Error (server timestamp vs tick): 0.23 seconds
# 		% drift: -0.031645591874537186
# 	watch processing...
#
#
# Processing /Volumes/Secondary/PhDStudy_Results/P19/P19_sess1/041723_150634_p19_FLOW_CONTD.csv
# got raw data.
# 	thermal processing...
# 		at index 114: packetNum not sequentially increasing. Current: 1816, Previous: 1814
# 		at index 114: tick increment greater than timeout. Difference: 7998ms
# 		at index 213: packetNum not sequentially increasing. Current: 1916, Previous: 1914
# 		at index 213: tick increment greater than timeout. Difference: 8009ms
# 		dropped 20 rows of data due to duplication.
# 		dropped 10 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 53.90 seconds
# 		Error (server timestamp vs tick): 0.15 seconds
# 		% drift: -0.01046098054257619
# /var/folders/5b/dtlkvmxj37133_hrqx2r93qr0000gn/T/ipykernel_57767/2044786997.py:305: RuntimeWarning: invalid value encountered in log
#   Temp_K = Beta / np.log(R_t / R_inf)
# 	gyro processing...
# 		at index 86: packetNum not sequentially increasing. Current: 175, Previous: 173
# 		at index 86: tick increment greater than timeout. Difference: 1166ms
# 		at index 544: packetNum not sequentially increasing. Current: 122, Previous: 120
# 		at index 544: tick increment greater than timeout. Difference: 1239ms
# 		at index 627: packetNum not sequentially increasing. Current: 206, Previous: 204
# 		at index 627: tick increment greater than timeout. Difference: 1282ms
# 		at index 731: packetNum not sequentially increasing. Current: 55, Previous: 53
# 		at index 731: tick increment greater than timeout. Difference: 1320ms
# 		at index 732: packetNum not sequentially increasing. Current: 64, Previous: 55
# 		at index 732: tick increment greater than timeout. Difference: 5789ms
# 		at index 739: packetNum not sequentially increasing. Current: 72, Previous: 70
# 		at index 739: tick increment greater than timeout. Difference: 1291ms
# 		at index 743: packetNum not sequentially increasing. Current: 78, Previous: 75
# 		at index 743: tick increment greater than timeout. Difference: 1941ms
# 		at index 745: packetNum not sequentially increasing. Current: 81, Previous: 79
# 		at index 745: tick increment greater than timeout. Difference: 1239ms
# 		at index 749: packetNum not sequentially increasing. Current: 86, Previous: 84
# 		at index 749: tick increment greater than timeout. Difference: 1183ms
# 		at index 751: packetNum not sequentially increasing. Current: 89, Previous: 87
# 		at index 751: tick increment greater than timeout. Difference: 1260ms
# 		at index 752: packetNum not sequentially increasing. Current: 92, Previous: 89
# 		at index 752: tick increment greater than timeout. Difference: 2045ms
# 		at index 754: packetNum not sequentially increasing. Current: 95, Previous: 93
# 		at index 754: tick increment greater than timeout. Difference: 1234ms
# 		at index 755: packetNum not sequentially increasing. Current: 97, Previous: 95
# 		at index 755: tick increment greater than timeout. Difference: 1160ms
# 		at index 756: packetNum not sequentially increasing. Current: 100, Previous: 97
# 		at index 756: tick increment greater than timeout. Difference: 1794ms
# 		at index 760: packetNum not sequentially increasing. Current: 105, Previous: 103
# 		at index 760: tick increment greater than timeout. Difference: 1251ms
# 		at index 767: packetNum not sequentially increasing. Current: 113, Previous: 111
# 		at index 767: tick increment greater than timeout. Difference: 1328ms
# 		at index 1006: packetNum not sequentially increasing. Current: 97, Previous: 95
# 		at index 1006: tick increment greater than timeout. Difference: 1209ms
# 		at index 1201: packetNum not sequentially increasing. Current: 37, Previous: 35
# 		at index 1201: tick increment greater than timeout. Difference: 1218ms
# 		at index 1219: packetNum not sequentially increasing. Current: 56, Previous: 54
# 		at index 1219: tick increment greater than timeout. Difference: 1182ms
# 		at index 1281: packetNum not sequentially increasing. Current: 119, Previous: 117
# 		at index 1281: tick increment greater than timeout. Difference: 1188ms
# 		at index 1316: packetNum not sequentially increasing. Current: 155, Previous: 153
# 		at index 1316: tick increment greater than timeout. Difference: 1183ms
# 		at index 1320: packetNum not sequentially increasing. Current: 160, Previous: 158
# 		at index 1320: tick increment greater than timeout. Difference: 1184ms
# 		at index 1324: packetNum not sequentially increasing. Current: 165, Previous: 163
# 		at index 1324: tick increment greater than timeout. Difference: 1147ms
# 		at index 1331: packetNum not sequentially increasing. Current: 173, Previous: 171
# 		at index 1331: tick increment greater than timeout. Difference: 1177ms
# 		at index 1335: packetNum not sequentially increasing. Current: 178, Previous: 176
# 		at index 1335: tick increment greater than timeout. Difference: 1159ms
# 		at index 1339: packetNum not sequentially increasing. Current: 183, Previous: 181
# 		at index 1339: tick increment greater than timeout. Difference: 1294ms
# 		at index 1341: packetNum not sequentially increasing. Current: 186, Previous: 184
# 		at index 1341: tick increment greater than timeout. Difference: 1333ms
# 		at index 1342: packetNum not sequentially increasing. Current: 189, Previous: 186
# 		at index 1342: tick increment greater than timeout. Difference: 1853ms
# 		at index 1343: packetNum not sequentially increasing. Current: 191, Previous: 189
# 		at index 1343: tick increment greater than timeout. Difference: 1273ms
# 		at index 1344: packetNum not sequentially increasing. Current: 194, Previous: 191
# 		at index 1344: tick increment greater than timeout. Difference: 1854ms
# 		at index 1346: packetNum not sequentially increasing. Current: 197, Previous: 195
# 		at index 1346: tick increment greater than timeout. Difference: 1225ms
# 		at index 1350: packetNum not sequentially increasing. Current: 202, Previous: 200
# 		at index 1350: tick increment greater than timeout. Difference: 1286ms
# 		at index 1351: packetNum not sequentially increasing. Current: 205, Previous: 202
# 		at index 1351: tick increment greater than timeout. Difference: 1775ms
# 		at index 1352: packetNum not sequentially increasing. Current: 208, Previous: 205
# 		at index 1352: tick increment greater than timeout. Difference: 1950ms
# 		at index 1353: packetNum not sequentially increasing. Current: 210, Previous: 208
# 		at index 1353: tick increment greater than timeout. Difference: 1247ms
# 		at index 1355: packetNum not sequentially increasing. Current: 213, Previous: 211
# 		at index 1355: tick increment greater than timeout. Difference: 1184ms
# 		at index 1356: packetNum not sequentially increasing. Current: 215, Previous: 213
# 		at index 1356: tick increment greater than timeout. Difference: 1150ms
# 		at index 1359: packetNum not sequentially increasing. Current: 219, Previous: 217
# 		at index 1359: tick increment greater than timeout. Difference: 1234ms
# 		at index 1364: packetNum not sequentially increasing. Current: 225, Previous: 223
# 		at index 1364: tick increment greater than timeout. Difference: 1308ms
# 		at index 1377: packetNum not sequentially increasing. Current: 239, Previous: 237
# 		at index 1377: tick increment greater than timeout. Difference: 1175ms
# 		at index 1603: packetNum not sequentially increasing. Current: 210, Previous: 208
# 		at index 1603: tick increment greater than timeout. Difference: 1254ms
# 		at index 2039: packetNum not sequentially increasing. Current: 135, Previous: 133
# 		at index 2039: tick increment greater than timeout. Difference: 1275ms
# 		at index 2151: packetNum not sequentially increasing. Current: 248, Previous: 246
# 		at index 2151: tick increment greater than timeout. Difference: 1283ms
# 		at index 2248: packetNum not sequentially increasing. Current: 90, Previous: 88
# 		at index 2248: tick increment greater than timeout. Difference: 1213ms
# 		at index 2288: packetNum not sequentially increasing. Current: 131, Previous: 129
# 		at index 2288: tick increment greater than timeout. Difference: 1189ms
# 		at index 2415: packetNum not sequentially increasing. Current: 3, Previous: 1
# 		at index 2415: tick increment greater than timeout. Difference: 1218ms
# 		at index 2780: packetNum not sequentially increasing. Current: 25640, Previous: 111
# 		at index 2781: packetNum not sequentially increasing. Current: 112, Previous: 25640
# 		at index 2781: packet_tick not increasing. Current: 8553558, Previous: 8553558
# 		at index 3033: packetNum not sequentially increasing. Current: 109, Previous: 107
# 		at index 3033: tick increment greater than timeout. Difference: 1280ms
# 		at index 3110: packetNum not sequentially increasing. Current: 187, Previous: 185
# 		at index 3110: tick increment greater than timeout. Difference: 1246ms
# 		at index 3592: packetNum not sequentially increasing. Current: 158, Previous: 156
# 		at index 3592: tick increment greater than timeout. Difference: 1193ms
# 		at index 3751: packetNum not sequentially increasing. Current: 62, Previous: 60
# 		at index 3751: tick increment greater than timeout. Difference: 1238ms
# 		at index 4180: packetNum not sequentially increasing. Current: 236, Previous: 234
# 		at index 4180: tick increment greater than timeout. Difference: 1222ms
# 		at index 4331: packetNum not sequentially increasing. Current: 132, Previous: 130
# 		at index 4331: tick increment greater than timeout. Difference: 1202ms
# 		at index 4524: packetNum not sequentially increasing. Current: 70, Previous: 68
# 		at index 4524: tick increment greater than timeout. Difference: 1208ms
# 		dropped 80 rows of data due to duplication.
# 		dropped 17 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 53.33 seconds
# 		Error (server timestamp vs tick): 0.00 seconds
# 		% drift: 0.0002093032504097111
# 	accelerometer processing...
# 		at index 61: packetNum not sequentially increasing. Current: 64, Previous: 62
# 		at index 61: tick increment greater than timeout. Difference: 1954ms
# 		at index 69: packetNum not sequentially increasing. Current: 73, Previous: 71
# 		at index 69: tick increment greater than timeout. Difference: 1880ms
# 		at index 157: packetNum not sequentially increasing. Current: 162, Previous: 160
# 		at index 157: tick increment greater than timeout. Difference: 1929ms
# 		at index 164: packetNum not sequentially increasing. Current: 170, Previous: 168
# 		at index 164: tick increment greater than timeout. Difference: 1949ms
# 		at index 280: packetNum not sequentially increasing. Current: 31, Previous: 29
# 		at index 280: tick increment greater than timeout. Difference: 2004ms
# 		at index 318: packetNum not sequentially increasing. Current: 70, Previous: 68
# 		at index 318: tick increment greater than timeout. Difference: 2051ms
# 		at index 325: packetNum not sequentially increasing. Current: 78, Previous: 76
# 		at index 325: tick increment greater than timeout. Difference: 1925ms
# 		at index 328: packetNum not sequentially increasing. Current: 82, Previous: 80
# 		at index 328: tick increment greater than timeout. Difference: 1948ms
# 		at index 356: packetNum not sequentially increasing. Current: 111, Previous: 109
# 		at index 356: tick increment greater than timeout. Difference: 1941ms
# 		at index 454: packetNum not sequentially increasing. Current: 212, Previous: 208
# 		at index 454: tick increment greater than timeout. Difference: 3788ms
# 		at index 455: packetNum not sequentially increasing. Current: 214, Previous: 212
# 		at index 455: tick increment greater than timeout. Difference: 1760ms
# 		at index 467: packetNum not sequentially increasing. Current: 230, Previous: 225
# 		at index 467: tick increment greater than timeout. Difference: 4646ms
# 		at index 475: packetNum not sequentially increasing. Current: 240, Previous: 237
# 		at index 475: tick increment greater than timeout. Difference: 2889ms
# 		at index 478: packetNum not sequentially increasing. Current: 250, Previous: 242
# 		at index 478: tick increment greater than timeout. Difference: 7844ms
# 		at index 839: packetNum not sequentially increasing. Current: 100, Previous: 98
# 		at index 839: tick increment greater than timeout. Difference: 1848ms
# 		at index 840: packetNum not sequentially increasing. Current: 103, Previous: 100
# 		at index 840: tick increment greater than timeout. Difference: 2953ms
# 		at index 841: packetNum not sequentially increasing. Current: 107, Previous: 103
# 		at index 841: tick increment greater than timeout. Difference: 4097ms
# 		at index 842: packetNum not sequentially increasing. Current: 109, Previous: 107
# 		at index 842: tick increment greater than timeout. Difference: 2028ms
# 		at index 847: packetNum not sequentially increasing. Current: 115, Previous: 113
# 		at index 847: tick increment greater than timeout. Difference: 1886ms
# 		at index 848: packetNum not sequentially increasing. Current: 118, Previous: 115
# 		at index 848: tick increment greater than timeout. Difference: 2915ms
# 		at index 849: packetNum not sequentially increasing. Current: 120, Previous: 118
# 		at index 849: tick increment greater than timeout. Difference: 1945ms
# 		at index 850: packetNum not sequentially increasing. Current: 125, Previous: 120
# 		at index 850: tick increment greater than timeout. Difference: 4657ms
# 		at index 1156: packetNum not sequentially increasing. Current: 174, Previous: 174
# 		at index 1156: packet_tick not increasing. Current: 7978551, Previous: 7978551
# 		at index 1739: packetNum not sequentially increasing. Current: 246, Previous: 244
# 		at index 1739: tick increment greater than timeout. Difference: 2039ms
# 		at index 1799: packetNum not sequentially increasing. Current: 51, Previous: 49
# 		at index 1799: tick increment greater than timeout. Difference: 1943ms
# 		at index 1942: packetNum not sequentially increasing. Current: 195, Previous: 193
# 		at index 1942: tick increment greater than timeout. Difference: 1829ms
# 		at index 2208: packetNum not sequentially increasing. Current: 206, Previous: 204
# 		at index 2208: tick increment greater than timeout. Difference: 1920ms
# 		dropped 47 rows of data due to duplication.
# 		dropped 3 rows of data due to weird timestamps.
# 		-----------------------------
# 		Duration: 23 minutes and 53.42 seconds
# 		Error (server timestamp vs tick): 0.01 seconds
# 		% drift: -0.000732514870051862
# 	quaternion extended kalman filter application...
# 	blink processing...
# 		at index 98: packetNum not sequentially increasing. Current: 20505, Previous: 20503
# 		at index 98: tick increment greater than timeout. Difference: 600ms
# 		at index 121: packetNum not sequentially increasing. Current: 20529, Previous: 20527
# 		at index 121: tick increment greater than timeout. Difference: 603ms
# 		at index 132: packetNum not sequentially increasing. Current: 20541, Previous: 20539
# 		at index 132: tick increment greater than timeout. Difference: 600ms
# 		at index 155: packetNum not sequentially increasing. Current: 20565, Previous: 20563
# 		at index 155: tick increment greater than timeout. Difference: 600ms
# 		at index 157: packetNum not sequentially increasing. Current: 20568, Previous: 20566
# 		at index 157: tick increment greater than timeout. Difference: 600ms
# ...
# SAVED /Volumes/Secondary/PhDStudy_Results/Flow_Drawings/P23HomeMidSurvey.png
#                                     event
# timestamp
# 2023-05-03 17:49:36.214        START_TEST
# 2023-05-03 18:03:16.653  START_TRANSITION
# 2023-05-03 18:03:28.149           NOTICED
# 2023-05-03 18:07:53.335      START_SURVEY
# GOT UI survey results: {'HomeMidSurvey': {'startSurveyTime': ['5/3/2023', ' 6:03:33 PM'], 'durGuess': '10', 'timeAtDurGuess': ['5/3/2023', ' 6:03:47 PM'], 'durTimeConfidence': '2', 'guessTime': '5:50 PM', 'timeAtGuess': ['5/3/2023', ' 6:04:02 PM'], 'guessTimeConfidence': '2', 'flowPath': ['17.5', '39.5', '17.5', '39.5', '17.5', '39.5', '17.5', '39.5', '23', '39.5', '26', '39.5', '29', '39.5', '32', '39.5', '34.5', '39.5', '36.5', '39.5', '38.5', '39.5', '40', '39.5', '41', '39.5', '42', '39.5', '42.5', '39.5', '43.5', '39.5', '44.5', '39.5', '45', '39.5', '45.5', '39.5', '46', '39.5', '46.5', '40', '47', '40.5', '47.5', '41', '48', '41.5', '48.5', '42', '48.5', '42.5', '49', '43', '49.5', '43.5', '50', '44', '50.5', '45', '51', '45.5', '51.5', '46.5', '52', '47', '52.5', '47.5', '53', '48', '53.5', '48.5', '53.5', '49', '54', '50', '54.5', '50.5', '55', '51', '55.5', '51.5', '56', '52', '56.5', '52.5', '57', '53.5', '57.5', '54', '58', '54.5', '58.5', '56', '59', '56.5', '60', '57.5', '60.5', '58.5', '61', '59', '61.5', '60', '62', '61', '62.5', '61.5', '63', '62.5', '64', '63', '64.5', '64', '65', '65', '65', '66', '65.5', '66.5', '65.5', '67.5', '65.5', '68.5', '65.5', '69.5', '65.5', '70.5', '66', '71.5', '66', '72.5', '66', '73', '66', '73.5', '66', '74', '66.5', '75', '66.5', '75.5', '67', '76', '67', '76.5', '67.5', '76.5', '68', '76.5', '68.5', '76.5', '68.5', '76', '69', '75', '69', '74.5', '69.5', '73', '69.5', '71.5', '70', '69.5', '70', '67.5', '70.5', '65', '71', '62', '71.5', '59.5', '72', '57', '73', '54', '73.5', '52', '74', '50', '75', '48.5', '75.5', '46.5', '76.5', '45', '77.5', '43.5', '78.5', '42.5', '79', '41', '80', '40.5', '80.5', '39.5', '81', '39', '81.5', '39', '82', '39', '82', '39', '82', '39', '82.5', '39', '82.5', '39.5', '83.5', '41.5', '84', '43.5', '86', '48.5', '87.5', '52', '89', '54.5', '90', '58', '91.5', '61', '93', '64', '94', '66.5', '95.5', '68.5', '96', '70.5', '97', '72', '98', '73.5', '98.5', '74.5', '99', '75.5', '100', '76.5', '100.5', '77.5', '101', '78', '101.5', '78.5', '102', '79', '102', '79.5', '103', '79.5', '103', '80', '103', '81', '103.5', '81.5', '104', '82.5', '104', '84', '104.5', '85', '105', '85.5', '105', '86', '105.5', '86', '105.5', '86.5', '105.5', '87', '106', '87.5', '106.5', '87.5', '106.5', '88', '106.5', '86.5', '107', '84', '107.5', '81', '108', '77.5', '108.5', '74', '109.5', '69', '110.5', '63.5', '111.5', '58', '112.5', '52', '113.5', '47.5', '114.5', '44', '115.5', '41.5', '116', '40', '116.5', '40', '117', '40', '117.5', '40', '118', '40', '119', '42.5', '121', '46', '124', '50', '125.5', '54.5', '127.5', '59', '129', '62.5', '130', '66', '131', '68.5', '131.5', '71', '132.5', '73', '133', '74.5', '133.5', '76', '134', '76.5', '134.5', '77.5', '134.5', '78', '135', '78.5', '135.5', '79', '136', '80', '136.5', '80.5', '137', '81.5', '137.5', '82', '138', '82.5', '138.5', '83.5', '139', '83.5', '139.5', '83.5', '139.5', '82.5', '139.5', '81', '139.5', '79', '139.5', '76.5', '139.5', '74', '139.5', '71', '140', '67.5', '140.5', '64.5', '141', '61', '141', '58.5', '142', '55.5', '142.5', '52.5', '143', '51', '144', '49.5', '145', '49', '146', '48.5', '147', '48', '148.5', '48', '150', '48', '151.5', '48', '152.5', '47.5', '154.5', '47.5', '155.5', '47.5', '156.5', '47', '157.5', '47', '158.5', '46.5', '159.5', '46', '160', '46', '160.5', '46', '161.5', '45', '162.5', '45', '163', '44', '163.5', '43.5', '164', '42.5', '164.5', '41.5', '165', '40.5', '165.5', '39.5', '165.5', '38.5', '166', '37', '166', '35.5', '166', '34.5', '166', '33.5', '166.5', '32', '166.5', '31', '167', '30.5', '167.5', '29.5', '168', '29', '168.5', '28.5', '169', '28', '169.5', '28', '170', '28', '170.5', '28', '171', '28', '171.5', '28', '172', '28', '172.5', '28', '173', '28.5', '173.5', '29', '174', '30.5', '174.5', '31.5', '175', '33', '175.5', '34.5', '176', '36.5', '176', '39', '176.5', '41', '177', '43.5', '177', '45.5', '177.5', '47.5', '178', '49', '178', '51', '178', '52.5' ...
# ========== Processing session 2023-05-03 18:07:53 P23 sess2 HOME_FLOW
# 	>> processing HomeMidActivitySurvey
# No BIT Detected
# No Flow Desc Detected
# {'duration': '5', 'actualTimeAtDuration': ['5/3/2023', ' 6:20:30 PM']}
# No flow path data
#                                     event
# timestamp
# 2023-05-03 18:07:53.423        START_TEST
# 2023-05-03 18:20:07.425  START_TRANSITION
# 2023-05-03 18:20:26.073           NOTICED
# 2023-05-03 18:20:31.529      START_SURVEY
# GOT UI survey results: {'HomeMidActivitySurvey': {'duration': '5', 'actualTimeAtDuration': ['5/3/2023', ' 6:20:30 PM']}}
# ========== Processing session 2023-05-03 18:20:31 P23 sess2 FLOW_CONTD
# GOT unknown survey: ['2023-05-03T22:42:32.469Z', 'VIDGAME', 'SURVEY', 'empaticaEndTime', '']
# 	>> processing HomeFinalSurvey
# BIT CODING:	4.07 with std 0.56 -- DESIGNATED "AT RISK"
# 		5 BIT STRENGTHS:
# 		 ['Support', 'Self-efficacy', 'Self-worth', 'Meaning and Purpose', 'Optimism']
# 		0 BIT WEAKNESSES:
# 		 []
# FLOW DESC:	shallow: 3	deep: 1
# {'startSurveyTime': ['5/3/2023', ' 6:33:28 PM'], 'durGuess': '10', 'timeAtDurGuess': ['5/3/2023', ' 6:33:31 PM'], 'durTimeConfidence': '2', 'guessTime': '6:10 PM', 'timeAtGuess': ['5/3/2023', ' 6:33:37 PM'], 'guessTimeConfidence': '2', 'flowPath': ['14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '27', '42', '30.5', '42', '33', '42', '35.5', '42.5', '37.5', '44', '39.5', '45', '40.5', '46', '42', '47', '43.5', '47.5', '45.5', '47.5', '47', '47.5', '48.5', '47.5', '49.5', '47.5', '50', '47.5', '50.5', '47.5', '51.5', '47.5', '52', '47.5', '52.5', '47.5', '53.5', '47.5', '55.5', '48', '57.5', '48.5', '60', '49', '62.5', '49.5', '66', '50', '69', '50.5', '72', '51', '74.5', '51', '77', '51', '79', '51', '80.5', '51', '82.5', '51', '84.5', '51', '86', '51', '87.5', '51', '89.5', '51', '91', '51', '92.5', '51', '94', '50.5', '95.5', '50.5', '97', '50.5', '98', '50.5', '99.5', '50.5', '101.5', '50.5', '104', '50.5', '106.5', '50.5', '108.5', '50.5', '111', '50.5', '113.5', '50.5', '115.5', '50.5', '117.5', '50.5', '119.5', '50.5', '120.5', '50.5', '122.5', '50.5', '123.5', '50.5', '124', '50.5', '125', '50.5', '126', '50.5', '127', '50.5', '127.5', '50.5', '128.5', '50', '129', '50', '130', '50', '131', '50', '131.5', '50', '133', '50', '134', '50', '135.5', '50', '137', '50', '138.5', '50', '140', '50', '141', '50', '142.5', '50', '143', '50', '143.5', '50', '144', '50', '144.5', '50', '145', '50', '145.5', '49.5', '145.5', '46.5', '145.5', '43.5', '145.5', '40', '145.5', '36', '145.5', '32', '146', '27.5', '146.5', '24', '148', '20.5', '149', '18', '150.5', '16', '152', '15', '153', '14', '154.5', '13.5', '155.5', '13', '156.5', '12.5', '157.5', '12.5', '158', '12.5', '158.5', '12.5', '159', '12.5', '159', '13', '159', '14.5', '159.5', '16', '160', '18', '162', '20.5', '163.5', '22.5', '165', '25', '167', '27.5', '168.5', '29.5', '170', '32', '171', '34', '172', '35.5', '173', '37', '173.5', '38', '174.5', '39', '175', '39.5', '175.5', '40.5', '176', '41', '176.5', '42', '177', '42.5', '177.5', '43', '178', '43.5', '178.5', '44.5', '179', '45', '179.5', '46', '180', '46.5', '181', '47', '181.5', '47.5', '182', '48', '182.5', '48.5', '183.5', '49', '184.5', '49', '185.5', '49.5', '186.5', '49.5', '188', '49.5', '189', '49.5', '190.5', '49.5', '191.5', '50', '192.5', '50', '193.5', '50.5', '194', '51', '194.5', '51.5', '195.5', '52', '196', '52', '196.5', '52.5', '197', '53', '198', '53', '200', '53', '201', '53', '203', '53', '204.5', '53', '207', '53', '209', '53', '211', '53', '212.5', '52.5', '214', '52.5', '215', '52.5', '216.5', '52.5', '217.5', '52.5', '219.5', '52.5', '220.5', '52.5', '222', '52.5', '223.5', '52.5', '225', '52.5', '226.5', '52.5', '227.5', '52.5', '229.5', '53', '231', '53', '233', '53', '234.5', '53', '236.5', '53', '239.5', '53', '242', '53', '244.5', '52.5', '247', '51.5', '250', '50.5', '252', '50', '253', '49.5', '254', '49.5', '254.5', '49.5', '255.5', '49.5', '256', '49.5', '257', '50', '258.5', '51.5', '260', '53', '261.5', '54.5', '262.5', '56', '264', '58', '265.5', '60', '266.5', '61.5', '267.5', '62.5', '268.5', '63', '269.5', '63', '270.5', '63', '272', '63', '273.5', '63', '275', '63', '276.5', '61', '279', '58.5', '281', '57', '283', '56', '285', '54.5', '287.5', '53.5', '290', '52.5', '292.5', '51.5', '295', '50.5', '298', '50', '300', '49.5', '302', '49', '304', '49', '305.5', '49', '307', '49', '308', '49', '308.5', '49', '309', '49', '310', '49', '311.5', '49', '313.5', '49', '315.5', '49', '321', '49', '325', '48.5', '328', '47', '330.5', '46', '332.5', '45.5', '334', '44.5', '335', '44', '336.5', '43.5', '337.5', '43', '338', '42'], 'flowCanvasSize': ['327.5', '100'], 'timeExp': '4', 'focus': '4', 'effort': '1', 'deepest': '4', 'flow': 'false', 'durFlow': '1', 'durToFlow': '', 'percentFlow': '0', 'flowDesc': '', 'flowDescA': 'true', 'flowDescB': 'true', 'flowDescC': 'true', 'flo ...
# SAVED /Volumes/Secondary/PhDStudy_Results/Flow_Drawings/P23HomeFinalSurvey.png
#                                     event
# timestamp
# 2023-05-03 18:20:31.578        START_TEST
# 2023-05-03 18:32:54.956  START_TRANSITION
# 2023-05-03 18:33:23.227           NOTICED
# 2023-05-03 18:42:19.445         STOP_TEST
# 2023-05-03 18:42:19.521         STOP_TEST
# 2023-05-03 18:42:32.401      START_SURVEY
# GOT UI survey results: {'HomeFinalSurvey': {'startSurveyTime': ['5/3/2023', ' 6:33:28 PM'], 'durGuess': '10', 'timeAtDurGuess': ['5/3/2023', ' 6:33:31 PM'], 'durTimeConfidence': '2', 'guessTime': '6:10 PM', 'timeAtGuess': ['5/3/2023', ' 6:33:37 PM'], 'guessTimeConfidence': '2', 'flowPath': ['14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '14.5', '41.5', '27', '42', '30.5', '42', '33', '42', '35.5', '42.5', '37.5', '44', '39.5', '45', '40.5', '46', '42', '47', '43.5', '47.5', '45.5', '47.5', '47', '47.5', '48.5', '47.5', '49.5', '47.5', '50', '47.5', '50.5', '47.5', '51.5', '47.5', '52', '47.5', '52.5', '47.5', '53.5', '47.5', '55.5', '48', '57.5', '48.5', '60', '49', '62.5', '49.5', '66', '50', '69', '50.5', '72', '51', '74.5', '51', '77', '51', '79', '51', '80.5', '51', '82.5', '51', '84.5', '51', '86', '51', '87.5', '51', '89.5', '51', '91', '51', '92.5', '51', '94', '50.5', '95.5', '50.5', '97', '50.5', '98', '50.5', '99.5', '50.5', '101.5', '50.5', '104', '50.5', '106.5', '50.5', '108.5', '50.5', '111', '50.5', '113.5', '50.5', '115.5', '50.5', '117.5', '50.5', '119.5', '50.5', '120.5', '50.5', '122.5', '50.5', '123.5', '50.5', '124', '50.5', '125', '50.5', '126', '50.5', '127', '50.5', '127.5', '50.5', '128.5', '50', '129', '50', '130', '50', '131', '50', '131.5', '50', '133', '50', '134', '50', '135.5', '50', '137', '50', '138.5', '50', '140', '50', '141', '50', '142.5', '50', '143', '50', '143.5', '50', '144', '50', '144.5', '50', '145', '50', '145.5', '49.5', '145.5', '46.5', '145.5', '43.5', '145.5', '40', '145.5', '36', '145.5', '32', '146', '27.5', '146.5', '24', '148', '20.5', '149', '18', '150.5', '16', '152', '15', '153', '14', '154.5', '13.5', '155.5', '13', '156.5', '12.5', '157.5', '12.5', '158', '12.5', '158.5', '12.5', '159', '12.5', '159', '13', '159', '14.5', '159.5', '16', '160', '18', '162', '20.5', '163.5', '22.5', '165', '25', '167', '27.5', '168.5', '29.5', '170', '32', '171', '34', '172', '35.5', '173', '37', '173.5', '38', '174.5', '39', '175', '39.5', '175.5', '40.5', '176', '41', '176.5', '42', '177', '42.5', '177.5', '43', '178', '43.5', '178.5', '44.5', '179', '45', '179.5', '46', '180', '46.5', '181', '47', '181.5', '47.5', '182', '48', '182.5', '48.5', '183.5', '49', '184.5', '49', '185.5', '49.5', '186.5', '49.5', '188', '49.5', '189', '49.5', '190.5', '49.5', '191.5', '50', '192.5', '50', '193.5', '50.5', '194', '51', '194.5', '51.5', '195.5', '52', '196', '52', '196.5', '52.5', '197', '53', '198', '53', '200', '53', '201', '53', '203', '53', '204.5', '53', '207', '53', '209', '53', '211', '53', '212.5', '52.5', '214', '52.5', '215', '52.5', '216.5', '52.5', '217.5', '52.5', '219.5', '52.5', '220.5', '52.5', '222', '52.5', '223.5', '52.5', '225', '52.5', '226.5', '52.5', '227.5', '52.5', '229.5', '53', '231', '53', '233', '53', '234.5', '53', '236.5', '53', '239.5', '53', '242', '53', '244.5', '52.5', '247', '51.5', '250', '50.5', '252', '50', '253', '49.5', '254', '49.5', '254.5', '49.5', '255.5', '49.5', '256', '49.5', '257', '50', '258.5', '51.5', '260', '53', '261.5', '54.5', '262.5', '56', '264', '58', '265.5', '60', '266.5', '61.5', '267.5', '62.5', '268.5', '63', '269.5', '63', '270.5', '63', '272', '63', '273.5', '63', '275', '63', '276.5', '61', '279', '58.5', '281', '57', '283', '56', '285', '54.5', '287.5', '53.5', '290', '52.5', '292.5', '51.5', '295', '50.5', '298', '50', '300', '49.5', '302', '49', '304', '49', '305.5', '49', '307', '49', '308', '49', '308.5', '49', '309', '49', '310', '49', '311.5', '49', '313.5', '49', '315.5', '49', '321', '49', '325', '48.5', '328', '47', '330.5', '46', '332.5', '45.5', '334', '44.5', '335', '44', '336.5', '43.5', '337.5', '43', '338', '42'], 'flowCanvasSize': ['327.5', '100'], 'timeExp': '4', 'focus': '4', 'effort': '1', 'deepest': '4', 'flow': 'false', 'durFlow': '1', 'durToFlow': '', 'percentFlow': '0', 'flowDesc': '', 'flowDescA': 'true', 'fl ...
# Cleaning survey LabStartSurvey
# Cleaning survey LabMid1Survey
# Cleaning survey LabMidActivitySurvey
# Cleaning survey LabMid2Survey
# Cleaning survey LabMidActivitySurvey
# Cleaning survey LabFinalSurvey
# Cleaning survey HomeStartSurvey
# Cleaning survey HomeMidActivitySurvey
# Cleaning survey HomeMidSurvey
# Cleaning survey HomeMidActivitySurvey
# Cleaning survey HomeFinalSurvey
# Successfully processed surveys for P23.
# Successfully saved P23 data.

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# # FIX FLIPPED FLOW DATA
#
# A couple of participants mentioned they flipped the y-axis when drawing the flow data in their minds-- i.e. P15 on session 1.
#
# This section will (1) print possible options to fix in the first cell, and (2) if the data is passed, it will invert the y-axis, save a new image, and replace the flowData in the pickle.

# %%
# NEED TO RUN THE FOLLOWING FOR user 15, i=6 surveyname='HomeMidSurvey'

# %%
def fixFlowData(session_data, i, surveyname, folder, user):
    '''now we're going to replace the session_data[i]['surveys'][surveyname]['flowPath'] with an inverted flowpath,
    remake the call to transformFlowPathPlot to generate/save the image, and save over the session_data for this user.'''

    #grab the flow path
    flowPath = session_data[i]['surveys'][surveyname]['flowPath']
    canvassize_y = int(session_data[i]['surveys'][surveyname]['flowCanvasSize'][1])
    
    #invert the y-axis
    flowPath[1::2] = [str(canvassize_y-float(i)) for i in flowPath[1::2]]  # invert the flowPath y-axis

    #resave the data
    session_data[i]['surveys'][surveyname]['flowPath'] = flowPath
    
    #save a new flow plot
    session_data[i]['surveys'][surveyname] = transformFlowPathPlot(session_data[i]['surveys'][surveyname], folder, 'P' + str(user) + surveyname)
                                           
    return session_data

# %%
#Select the User we need to fix and the Path
folder = 'Data'
user = 15


#let's get a list of options to redo

with open(folder + '/P' + str(user) + '_Processed.pickle', 'rb') as handle:
    session_data, entrance, exit = pickle.load(handle)
    
for i, s in enumerate(session_data):
    for survey in s['surveys']:
        if 'flowPath' in s['surveys'][survey]:
            if len(s['surveys'][survey]['flowPath']):
                print(f'flowPath found in {i}: {s["session_type"]} - {survey}')
                print(f'\t>> call function with ({i}, {survey}')
# Out:
# flowPath found in 4: FLOW_CONTD - LabFinalSurvey
# 	>> call function with (4, LabFinalSurvey
# flowPath found in 6: TETRIS_CONTD - HomeMidSurvey
# 	>> call function with (6, HomeMidSurvey
# flowPath found in 8: FLOW_CONTD - HomeFinalSurvey
# 	>> call function with (8, HomeFinalSurvey

# %%
#redo and resave; make sure we're still using the correct folder/user from above!

folder = folder
user = user
i = 6
surveyname = 'HomeMidSurvey'

#open it
with open(folder + '/P' + str(user) + '_Processed.pickle', 'rb') as handle:
    session_data, entrance, exit = pickle.load(handle)
    
#fix the session_data to invert the y-axis in flowPath and redraw/resave the drawing
session_data = fixFlowData(session_data, i, surveyname, folder, user)

#resave it
with open(folder + '/P' + str(user) + '_Processed.pickle', 'wb') as handle:
        pickle.dump((session_data, entrance, exit), handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# SAVED Data/Flow_Drawings/P15HomeMidSurvey.png
